# %%
import os, shutil
if os.path.exists(os.path.join(os.getcwd(),"tfdetection")):
    shutil.rmtree(os.path.join(os.getcwd(),"tfdetection"))
if os.path.exists(os.path.join(os.getcwd(),"tfdet")):
    shutil.rmtree(os.path.join(os.getcwd(),"tfdet"))
# !git clone https://github.com/burf/tfdetection
shutil.copytree(os.path.join(os.getcwd(),"tfdetection", "tfdet"), os.path.join(os.getcwd(),"tfdet"))
# Out:
# Cloning into 'tfdetection'...
# remote: Enumerating objects: 788, done.
# remote: Counting objects: 100% (401/401), done.
# remote: Compressing objects: 100% (246/246), done.
# remote: Total 788 (delta 240), reused 276 (delta 155), pack-reused 387
# Receiving objects: 100% (788/788), 8.62 MiB | 7.08 MiB/s, done.
# Resolving deltas: 100% (449/449), done.
# '/content/tfdet'

# %%
# !wget -qq https://github.com/matterport/Mask_RCNN/releases/download/v2.1/balloon_dataset.zip
# !unzip -qq balloon_dataset.zip

import os
import json
import cv2
import skimage.draw
import tensorflow as tf
import numpy as np

def parse(path, target_size = (512, 512), method = cv2.INTER_CUBIC):
    dir_path = os.path.dirname(path)
    with open(path, "r") as file:
        anno = json.loads(file.read())
    anno = [a for a in list(anno.values()) if a["regions"]]

    images = []
    masks = []
    for a in anno:
        if type(a['regions']) is dict:
            polygons = [r['shape_attributes'] for r in a['regions'].values()]
        else:
            polygons = [r['shape_attributes'] for r in a['regions']]
        image = cv2.cvtColor(cv2.imread(os.path.join(dir_path, a["filename"]), -1), cv2.COLOR_BGR2RGB)
        h, w = np.shape(image)[:2]
        mask = np.zeros((h, w, len(polygons)), dtype = np.uint8)
        for i, p in enumerate(polygons):
            rr, cc = skimage.draw.polygon(p['all_points_y'], p['all_points_x'])
            rr = np.clip(rr, 0, h - 1)
            cc = np.clip(cc, 0, w - 1)
            mask[rr, cc, i] = 1
        
        if target_size is not None:
            image = cv2.resize(image, target_size[::-1], interpolation = method)
            mask = cv2.resize(mask, target_size[::-1], interpolation = method)
            if np.ndim(mask) == 2:
                mask = np.expand_dims(mask, axis = -1)
            mask = np.where(mask != 0, 1, 0)

        images.append(image)
        masks.append(np.transpose(mask, [2, 0, 1]))
    return images, masks

def mask2bbox(mask_true, normalize = True, decimal = 4):
    #mask_true = #(padded_num_true, h, w, 1)
    padded_num_true, h, w = np.shape(mask_true)[:3]

    bbox_true = []
    for index in range(padded_num_true):
        mask = mask_true[index]
        if 0 < np.max(mask):
            pos = np.where(0 < mask)[:2]
            bbox = [np.min(pos[1]), np.min(pos[0]), np.max(pos[1]), np.max(pos[0])] #x1, y1, x2, y2
        else:
            bbox = [0, 0, 0, 0]
        bbox_true.append(bbox)
    
    bbox_true = np.round(np.divide(bbox_true, [w, h, w, h]).astype(np.float32), decimal) if normalize else np.array(bbox_true, dtype = np.int32)
    return bbox_true

def pipe(data, func = None, batch_size = 2, shuffle = False):
    dataset = tf.data.Dataset.from_tensor_slices(data)
    if callable(func):
        dataset = dataset.map(func, num_parallel_calls = tf.data.experimental.AUTOTUNE)
    if shuffle:
        dataset = dataset.shuffle(buffer_size = batch_size * 10)
    dataset = dataset.batch(batch_size)
    #dataset = dataset.prefetch((batch_size * 2) + 1)
    dataset = dataset.prefetch(tf.data.experimental.AUTOTUNE)
    return dataset

tr_anno = "./balloon/train/via_region_data.json"
te_anno = "./balloon/val/via_region_data.json"

tr_x, tr_mask = parse(tr_anno, target_size = (512, 512))
te_x, te_mask = parse(te_anno, target_size = (512, 512))

max_cnt = 0
for mask in tr_mask + te_mask:
    if max_cnt < len(mask):
        max_cnt = len(mask)

tr_x = np.array(tr_x, dtype = np.float32) * 1/255
tr_mask = [np.pad(mask, [[0, max_cnt - len(mask)], [0, 0], [0, 0]]) for mask in tr_mask]
tr_mask = np.expand_dims(np.array(tr_mask, dtype = np.float32), axis = -1)
tr_bbox = np.array([mask2bbox(mask) for mask in tr_mask], dtype = np.float32)
tr_y = np.expand_dims(np.where(0 < np.max(tr_bbox, axis = -1), 1., 0.), axis = -1)

te_x = np.array(te_x, dtype = np.float32) * 1/255
te_mask = [np.pad(mask, [[0, max_cnt - len(mask)], [0, 0], [0, 0]]) for mask in te_mask]
te_mask = np.expand_dims(np.array(te_mask, dtype = np.float32), axis = -1)
te_bbox = np.array([mask2bbox(mask) for mask in te_mask], dtype = np.float32)
te_y = np.expand_dims(np.where(0 < np.max(te_bbox, axis = -1), 1., 0.), axis = -1)

# %%
import tfdet
import functools

x = tf.keras.layers.Input(shape = (512, 512, 3))
feature = tfdet.model.backbone.resnet50(x)

#scale = [32, 64, 128, 256, 512]
scale = [24, 48, 96, 192, 384]
ratio = [0.5, 1, 2]

bifpn = functools.partial(tfdet.model.neck.bifpn, weighted_add = False)
neck = functools.partial(tfdet.model.neck.FeatureAlign, pre_sampling = False, neck = bifpn)
rpn_assign = functools.partial(tfdet.core.assign.max_iou, positive_threshold = 0.7, negative_threshold = 0.3, min_threshold = 0.3)
cls_assign = functools.partial(tfdet.core.assign.max_iou, positive_threshold = 0.5, negative_threshold = 0.5, match_low_quality = False)
cls_assign2 = functools.partial(tfdet.core.assign.max_iou, positive_threshold = 0.6, negative_threshold = 0.6, match_low_quality = False)
cls_assign3 = functools.partial(tfdet.core.assign.max_iou, positive_threshold = 0.7, negative_threshold = 0.7, match_low_quality = False)

#sampling_positive_ratio = cls_positive_ratio, sampling_positive_threshold = cls_positive_threshold, sampling_negative_threshold = cls_negative_threshold
out = tfdet.model.detector.hybrid_task_cascade_rcnn(feature, image_shape = tf.shape(x)[1:3], n_class = 2, mask = True, interleaved = True, mask_info_flow = True, semantic_feature = False, scale = scale, ratio = ratio, soft_nms = False, neck = neck, 
                                                    proposal_count = 2000, sampling_assign = [cls_assign, cls_assign2, cls_assign3], sampling_count = 256, sampling_positive_ratio = 0.25)

#out > rpn_score, rpn_regress, cls_logits, cls_regress, proposals, anchors, mask_regress(is removed by mask{=False}), semantic_regress(is removed by semantic_feature{=False}), sampling_tag(is removed by sampling_count{=None or 0})
model = tfdet.model.train.rcnn.train_model(x, *out, rpn_assign = rpn_assign, rpn_positive_ratio = 0.5)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 1s 0us/step
# 94781440/94765736 [==============================] - 1s 0us/step
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/deprecation.py:616: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead

# %%
import albumentations
method = [albumentations.RandomBrightness(0.2, p = 0.5),
          albumentations.RandomContrast(0.2, p = 0.5),
          albumentations.ChannelShuffle(p = 0.5)]
method = albumentations.Compose(method)
    
def aug_func(image):
    return method(image = image)["image"]

key = x.name
def func(dic):
    shape = tf.shape(dic[key])
    dic[key] = tf.reshape(tf.py_function(lambda *args: aug_func(args[0].numpy()), inp = [dic[key]], Tout = tf.float32), shape)
    return dic

batch_size = 2

tr_data = pipe({x.name:tr_x, "y_true":tr_y, "bbox_true":tr_bbox, "mask_true":tr_mask}, func = func, batch_size = batch_size, shuffle = True)
te_data = pipe({x.name:te_x, "y_true":te_y, "bbox_true":te_bbox, "mask_true":te_mask}, batch_size = batch_size, shuffle = False)

# %%
opt = tf.keras.optimizers.SGD(5e-3, momentum = 0.9, nesterov = True)
model.compile(optimizer = opt)
model.fit(tr_data, validation_data = te_data, epochs = 500)
# Out:
# Epoch 1/500
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/sampling_postprocess1/map/while/gradients/model/sampling_postprocess1/map/while/GatherNd_2_grad/Squeeze:0", shape=(None,), dtype=int64), values=Tensor("gradient_tape/model/sampling_postprocess1/map/while/gradients/model/sampling_postprocess1/map/while/Pad_grad/Slice_1:0", shape=(None, 2), dtype=float32), dense_shape=Tensor("model/sampling_postprocess1/map/while/gradient_tape/model/sampling_postprocess1/map/while/gradients/model/sampling_postprocess1/map/while/GatherNd_2_grad/Shape:0", shape=(2,), dtype=int64))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/sampling_postprocess1/map/while/gradients/model/sampling_postprocess1/map/while/GatherNd_6_grad/Squeeze:0", shape=(None,), dtype=int64), values=Tensor("gradient_tape/model/sampling_postprocess1/map/while/gradients/model/sampling_postprocess1/map/while/transpose_grad/transpose:0", shape=(None, 14, 14, 2), dtype=float32), dense_shape=Tensor("model/sampling_postprocess1/map/while/gradient_tape/model/sampling_postprocess1/map/while/gradients/model/sampling_postprocess1/map/while/GatherNd_6_grad/Shape:0", shape=(4,), dtype=int64))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/sampling_postprocess1/map/while/gradients/model/sampling_postprocess1/map/while/GatherNd_3_grad/Squeeze:0", shape=(None,), dtype=int64), values=Tensor("gradient_tape/model/sampling_postprocess1/map/while/gradients/model/sampling_postprocess1/map/while/GatherNd_7_grad/ScatterNd:0", shape=(None, 2, 4), dtype=float32), dense_shape=Tensor("model/sampling_postprocess1/map/while/gradient_tape/model/sampling_postprocess1/map/while/gradients/model/sampling_postprocess1/map/while/GatherNd_3_grad/Shape:0", shape=(3,), dtype=int64))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/sampling_postprocess2/map/while/gradients/model/sampling_postprocess2/map/while/GatherNd_2_grad/Squeeze:0", shape=(None,), dtype=int64), values=Tensor("gradient_tape/model/sampling_postprocess2/map/while/gradients/model/sampling_postprocess2/map/while/Pad_grad/Slice_1:0", shape=(None, 2), dtype=float32), dense_shape=Tensor("model/sampling_postprocess2/map/while/gradient_tape/model/sampling_postprocess2/map/while/gradients/model/sampling_postprocess2/map/while/GatherNd_2_grad/Shape:0", shape=(2,), dtype=int64))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/sampling_postprocess2/map/while/gradients/model/sampling_postprocess2/map/while/GatherNd_6_grad/Squeeze:0", shape=(None,), dtype=int64), values=Tensor("gradient_tape/model/sampling_postprocess2/map/while/gradients/model/sampling_postprocess2/map/while/transpose_grad/transpose:0", shape=(None, 14, 14, 2), dtype=float32), dense_shape=Tensor("model/sampling_postprocess2/map/while/gradient_tape/model/sampling_postprocess2/map/while/gradients/model/sampling_postprocess2/map/while/GatherNd_6_grad/Shape:0", shape=(4,), dtype=int64))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/sampling_postprocess2/map/while/gradients/model/sampling_postprocess2/map/while/GatherNd_3_grad/Squeeze:0", shape=(None,), dtype=int64), values=Tensor("gradient_tape/model/sampling_postprocess2/map/while/gradients/model/sampling_postprocess2/map/while/GatherNd_7_grad/ScatterNd:0", shape=(None, 2, 4), dtype=float32), dense_shape=Tensor("model/sampling_postprocess2/map/while/gradient_tape/model/sampling_postprocess2/map/while/gradients/model/sampling_postprocess2/map/while/GatherNd_3_grad/Shape:0", shape=(3,), dtype=int64))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/sampling_postprocess3/map/while/gradients/model/sampling_postprocess3/map/while/GatherNd_2_grad/Squeeze:0", shape=(None,), dtype=int64), values=Tensor("gradient_tape/model/sampling_postprocess3/map/while/gradients/model/sampling_postprocess3/map/while/Pad_grad/Slice_1:0", shape=(None, 2), dtype=float32), dense_shape=Tensor("model/sampling_postprocess3/map/while/gradient_tape/model/sampling_postprocess3/map/while/gradients/model/sampling_postprocess3/map/while/GatherNd_2_grad/Shape:0", shape=(2,), dtype=int64))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/sampling_postprocess3/map/while/gradients/model/sampling_postprocess3/map/while/GatherNd_6_grad/Squeeze:0", shape=(None,), dtype=int64), values=Tensor("gradient_tape/model/sampling_postprocess3/map/while/gradients/model/sampling_postprocess3/map/while/transpose_grad/transpose:0", shape=(None, 14, 14, 2), dtype=float32), dense_shape=Tensor("model/sampling_postprocess3/map/while/gradient_tape/model/sampling_postprocess3/map/while/gradients/model/sampling_postprocess3/map/while/GatherNd_6_grad/Shape:0", shape=(4,), dtype=int64))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/sampling_postprocess3/map/while/gradients/model/sampling_postprocess3/map/while/GatherNd_3_grad/Squeeze:0", shape=(None,), dtype=int64), values=Tensor("gradient_tape/model/sampling_postprocess3/map/while/gradients/model/sampling_postprocess3/map/while/GatherNd_7_grad/ScatterNd:0", shape=(None, 2, 4), dtype=float32), dense_shape=Tensor("model/sampling_postprocess3/map/while/gradient_tape/model/sampling_postprocess3/map/while/gradients/model/sampling_postprocess3/map/while/GatherNd_3_grad/Shape:0", shape=(3,), dtype=int64))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/roi_align/sub:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/roi_align/GatherV2_2:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("gradient_tape/model/roi_align/Shape_2:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/roi_align/sub_1:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/roi_align/GatherV2_5:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("gradient_tape/model/roi_align/Shape_3:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/roi_align/sub_2:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/roi_align/GatherV2_8:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("gradient_tape/model/roi_align/Shape_4:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/roi_align/sub_3:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/roi_align/GatherV2_11:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("gradient_tape/model/roi_align/Shape_5:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/roi_align_2/sub:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/roi_align_2/GatherV2_2:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("gradient_tape/model/roi_align_2/Shape_2:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/roi_align_2/sub_1:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/roi_align_2/GatherV2_5:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("gradient_tape/model/roi_align_2/Shape_3:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/roi_align_2/sub_2:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/roi_align_2/GatherV2_8:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("gradient_tape/model/roi_align_2/Shape_4:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/roi_align_2/sub_3:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/roi_align_2/GatherV2_11:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("gradient_tape/model/roi_align_2/Shape_5:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/roi_align_4/sub:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/roi_align_4/GatherV2_2:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("gradient_tape/model/roi_align_4/Shape_2:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/roi_align_4/sub_1:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/roi_align_4/GatherV2_5:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("gradient_tape/model/roi_align_4/Shape_3:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/roi_align_4/sub_2:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/roi_align_4/GatherV2_8:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("gradient_tape/model/roi_align_4/Shape_4:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/roi_align_4/sub_3:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/roi_align_4/GatherV2_11:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("gradient_tape/model/roi_align_4/Shape_5:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/roi_align_1/sub:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/roi_align_1/GatherV2_2:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("gradient_tape/model/roi_align_1/Shape_2:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/roi_align_1/sub_1:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/roi_align_1/GatherV2_5:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("gradient_tape/model/roi_align_1/Shape_3:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/roi_align_1/sub_2:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/roi_align_1/GatherV2_8:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("gradient_tape/model/roi_align_1/Shape_4:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/roi_align_1/sub_3:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/roi_align_1/GatherV2_11:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("gradient_tape/model/roi_align_1/Shape_5:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/roi_align_3/sub:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/roi_align_3/GatherV2_2:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("gradient_tape/model/roi_align_3/Shape_2:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/roi_align_3/sub_1:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/roi_align_3/GatherV2_5:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("gradient_tape/model/roi_align_3/Shape_3:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/roi_align_3/sub_2:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/roi_align_3/GatherV2_8:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("gradient_tape/model/roi_align_3/Shape_4:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/roi_align_3/sub_3:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/roi_align_3/GatherV2_11:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("gradient_tape/model/roi_align_3/Shape_5:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/roi_align_5/sub:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/roi_align_5/GatherV2_2:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("gradient_tape/model/roi_align_5/Shape_2:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/roi_align_5/sub_1:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/roi_align_5/GatherV2_5:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("gradient_tape/model/roi_align_5/Shape_3:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/roi_align_5/sub_2:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/roi_align_5/GatherV2_8:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("gradient_tape/model/roi_align_5/Shape_4:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/roi_align_5/sub_3:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/roi_align_5/GatherV2_11:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("gradient_tape/model/roi_align_5/Shape_5:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# 31/31 [==============================] - 100s 1s/step - loss: 10.9200 - rpn_score_accuracy: 0.6941 - cls_logits_accuracy1: 0.3763 - cls_logits_accuracy2: 0.0000e+00 - cls_logits_accuracy3: 0.0000e+00 - rpn_score_loss: 0.6774 - rpn_regress_loss: 0.9258 - cls_logits_loss1: 2.0744 - cls_regress_loss1: 6.9853 - cls_mask_loss1: 0.2571 - cls_logits_loss2: 0.0000e+00 - cls_regress_loss2: 0.0000e+00 - cls_mask_loss2: 0.0000e+00 - cls_logits_loss3: 0.0000e+00 - cls_regress_loss3: 0.0000e+00 - cls_mask_loss3: 0.0000e+00 - val_loss: 69930015784960.0000 - val_rpn_score_accuracy: 0.6833 - val_cls_logits_accuracy1: 0.0000e+00 - val_cls_logits_accuracy2: 0.0000e+00 - val_cls_logits_accuracy3: 0.0000e+00 - val_rpn_score_loss: 4.8473 - val_rpn_regress_loss: 69930015784960.0000 - val_cls_logits_loss1: 0.0000e+00 - val_cls_regress_loss1: 0.0000e+00 - val_cls_mask_loss1: 0.0000e+00 - val_cls_logits_loss2: 0.0000e+00 - val_cls_regress_loss2: 0.0000e+00 - val_cls_mask_loss2: 0.0000e+00 - val_cls_logits_loss3: 0.0000e+00 - val_cls_regress_loss3: 0.0000e+00 - val_cls_mask_loss3: 0.0000e+00
# Epoch 2/500
# 31/31 [==============================] - 29s 915ms/step - loss: 25.9738 - rpn_score_accuracy: 0.7753 - cls_logits_accuracy1: 0.3387 - cls_logits_accuracy2: 0.0618 - cls_logits_accuracy3: 0.0000e+00 - rpn_score_loss: 0.6563 - rpn_regress_loss: 1.5404 - cls_logits_loss1: 1.8198 - cls_regress_loss1: 21.3557 - cls_mask_loss1: 0.2271 - cls_logits_loss2: 0.1311 - cls_regress_loss2: 0.2071 - cls_mask_loss2: 0.0363 - cls_logits_loss3: 0.0000e+00 - cls_regress_loss3: 0.0000e+00 - cls_mask_loss3: 0.0000e+00 - val_loss: 1172181.8750 - val_rpn_score_accuracy: 0.5166 - val_cls_logits_accuracy1: 0.0000e+00 - val_cls_logits_accuracy2: 0.0000e+00 - val_cls_logits_accuracy3: 0.0000e+00 - val_rpn_score_loss: 7.4456 - val_rpn_regress_loss: 1172174.6250 - val_cls_logits_loss1: 0.0000e+00 - val_cls_regress_loss1: 0.0000e+00 - val_cls_mask_loss1: 0.0000e+00 - val_cls_logits_loss2: 0.0000e+00 - val_cls_regress_loss2: 0.0000e+00 - val_cls_mask_loss2: 0.0000e+00 - val_cls_logits_loss3: 0.0000e+00 - val_cls_regress_loss3: 0.0000e+00 - val_cls_mask_loss3: 0.0000e+00
# Epoch 3/500
# 31/31 [==============================] - 29s 936ms/step - loss: 9.2051 - rpn_score_accuracy: 0.8334 - cls_logits_accuracy1: 0.4113 - cls_logits_accuracy2: 0.0565 - cls_logits_accuracy3: 0.0000e+00 - rpn_score_loss: 0.6582 - rpn_regress_loss: 1.6055 - cls_logits_loss1: 2.2097 - cls_regress_loss1: 4.0838 - cls_mask_loss1: 0.3188 - cls_logits_loss2: 0.1098 - cls_regress_loss2: 0.1715 - cls_mask_loss2: 0.0478 - cls_logits_loss3: 0.0000e+00 - cls_regress_loss3: 0.0000e+00 - cls_mask_loss3: 0.0000e+00 - val_loss: 3961.4045 - val_rpn_score_accuracy: 0.4498 - val_cls_logits_accuracy1: 0.0000e+00 - val_cls_logits_accuracy2: 0.0000e+00 - val_cls_logits_accuracy3: 0.0000e+00 - val_rpn_score_loss: 8.4307 - val_rpn_regress_loss: 3952.9739 - val_cls_logits_loss1: 0.0000e+00 - val_cls_regress_loss1: 0.0000e+00 - val_cls_mask_loss1: 0.0000e+00 - val_cls_logits_loss2: 0.0000e+00 - val_cls_regress_loss2: 0.0000e+00 - val_cls_mask_loss2: 0.0000e+00 - val_cls_logits_loss3: 0.0000e+00 - val_cls_regress_loss3: 0.0000e+00 - val_cls_mask_loss3: 0.0000e+00
# Epoch 4/500
# 31/31 [==============================] - 28s 895ms/step - loss: 3.2770 - rpn_score_accuracy: 0.7896 - cls_logits_accuracy1: 0.0242 - cls_logits_accuracy2: 0.0000e+00 - cls_logits_accuracy3: 0.0000e+00 - rpn_score_loss: 1.1194 - rpn_regress_loss: 1.1063 - cls_logits_loss1: 0.1300 - cls_regress_loss1: 0.9181 - cls_mask_loss1: 0.0032 - cls_logits_loss2: 0.0000e+00 - cls_regress_loss2: 0.0000e+00 - cls_mask_loss2: 0.0000e+00 - cls_logits_loss3: 0.0000e+00 - cls_regress_loss3: 0.0000e+00 - cls_mask_loss3: 0.0000e+00 - val_loss: 2933.5586 - val_rpn_score_accuracy: 0.5001 - val_cls_logits_accuracy1: 0.0000e+00 - val_cls_logits_accuracy2: 0.0000e+00 - val_cls_logits_accuracy3: 0.0000e+00 - val_rpn_score_loss: 6.7096 - val_rpn_regress_loss: 2926.8494 - val_cls_logits_loss1: 0.0000e+00 - val_cls_regress_loss1: 0.0000e+00 - val_cls_mask_loss1: 0.0000e+00 - val_cls_logits_loss2: 0.0000e+00 - val_cls_regress_loss2: 0.0000e+00 - val_cls_mask_loss2: 0.0000e+00 - val_cls_logits_loss3: 0.0000e+00 - val_cls_regress_loss3: 0.0000e+00 - val_cls_mask_loss3: 0.0000e+00
# Epoch 5/500
# 31/31 [==============================] - 28s 901ms/step - loss: 3.9153 - rpn_score_accuracy: 0.8507 - cls_logits_accuracy1: 0.1452 - cls_logits_accuracy2: 0.0242 - cls_logits_accuracy3: 0.0081 - rpn_score_loss: 0.5708 - rpn_regress_loss: 1.0872 - cls_logits_loss1: 0.7799 - cls_regress_loss1: 1.1619 - cls_mask_loss1: 0.1491 - cls_logits_loss2: 0.0650 - cls_regress_loss2: 0.0512 - cls_mask_loss2: 0.0098 - cls_logits_loss3: 0.0145 - cls_regress_loss3: 0.0203 - cls_mask_loss3: 0.0057 - val_loss: 206.1082 - val_rpn_score_accuracy: 0.6578 - val_cls_logits_accuracy1: 0.0000e+00 - val_cls_logits_accuracy2: 0.0000e+00 - val_cls_logits_accuracy3: 0.0000e+00 - val_rpn_score_loss: 3.9534 - val_rpn_regress_loss: 202.1548 - val_cls_logits_loss1: 0.0000e+00 - val_cls_regress_loss1: 0.0000e+00 - val_cls_mask_loss1: 0.0000e+00 - val_cls_logits_loss2: 0.0000e+00 - val_cls_regress_loss2: 0.0000e+00 - val_cls_mask_loss2: 0.0000e+00 - val_cls_logits_loss3: 0.0000e+00 - val_cls_regress_loss3: 0.0000e+00 - val_cls_mask_loss3: 0.0000e+00
# Epoch 6/500
# 31/31 [==============================] - 29s 933ms/step - loss: 11.9273 - rpn_score_accuracy: 0.8078 - cls_logits_accuracy1: 0.4355 - cls_logits_accuracy2: 0.0484 - cls_logits_accuracy3: 0.0242 - rpn_score_loss: 0.6018 - rpn_regress_loss: 0.9562 - cls_logits_loss1: 2.3397 - cls_regress_loss1: 7.2964 - cls_mask_loss1: 0.2389 - cls_logits_loss2: 0.1300 - cls_regress_loss2: 0.2738 - cls_mask_loss2: 0.0150 - cls_logits_loss3: 0.0325 - cls_regress_loss3: 0.0378 - cls_mask_loss3: 0.0051 - val_loss: 1.7073 - val_rpn_score_accuracy: 0.7106 - val_cls_logits_accuracy1: 0.0000e+00 - val_cls_logits_accuracy2: 0.0000e+00 - val_cls_logits_accuracy3: 0.0000e+00 - val_rpn_score_loss: 0.9032 - val_rpn_regress_loss: 0.8041 - val_cls_logits_loss1: 0.0000e+00 - val_cls_regress_loss1: 0.0000e+00 - val_cls_mask_loss1: 0.0000e+00 - val_cls_logits_loss2: 0.0000e+00 - val_cls_regress_loss2: 0.0000e+00 - val_cls_mask_loss2: 0.0000e+00 - val_cls_logits_loss3: 0.0000e+00 - val_cls_regress_loss3: 0.0000e+00 - val_cls_mask_loss3: 0.0000e+00
# Epoch 7/500
# 31/31 [==============================] - 28s 916ms/step - loss: 4.4848 - rpn_score_accuracy: 0.8451 - cls_logits_accuracy1: 0.0242 - cls_logits_accuracy2: 0.0242 - cls_logits_accuracy3: 0.0000e+00 - rpn_score_loss: 0.9416 - rpn_regress_loss: 0.9367 - cls_logits_loss1: 0.1300 - cls_regress_loss1: 1.5131 - cls_mask_loss1: 0.0013 - cls_logits_loss2: 0.0650 - cls_regress_loss2: 0.8939 - cls_mask_loss2: 0.0032 - cls_logits_loss3: 0.0000e+00 - cls_regress_loss3: 0.0000e+00 - cls_mask_loss3: 0.0000e+00 - val_loss: 20.7532 - val_rpn_score_accuracy: 0.7891 - val_cls_logits_accuracy1: 0.3214 - val_cls_logits_accuracy2: 0.1071 - val_cls_logits_accuracy3: 0.0000e+00 - val_rpn_score_loss: 0.7626 - val_rpn_regress_loss: 0.6567 - val_cls_logits_loss1: 1.7269 - val_cls_regress_loss1: 14.5410 - val_cls_mask_loss1: 0.0370 - val_cls_logits_loss2: 0.2878 - val_cls_regress_loss2: 2.7195 - val_cls_mask_loss2: 0.0216 - val_cls_logits_loss3: 0.0000e+00 - val_cls_regress_loss3: 0.0000e+00 - val_cls_mask_loss3: 0.0000e+00
# Epoch 8/500
# 31/31 [==============================] - 29s 922ms/step - loss: 17.1878 - rpn_score_accuracy: 0.8389 - cls_logits_accuracy1: 0.3387 - cls_logits_accuracy2: 0.0726 - cls_logits_accuracy3: 0.0242 - rpn_score_loss: 0.6961 - rpn_regress_loss: 1.2423 - cls_logits_loss1: 1.8198 - cls_regress_loss1: 12.4259 - cls_mask_loss1: 0.0462 - cls_logits_loss2: 0.1655 - cls_regress_loss2: 0.7076 - cls_mask_loss2: 0.0142 - cls_logits_loss3: 0.0325 - cls_regress_loss3: 0.0331 - cls_mask_loss3: 0.0047 - val_loss: 1404607.6250 - val_rpn_score_accuracy: 0.5895 - val_cls_logits_accuracy1: 0.0000e+00 - val_cls_logits_accuracy2: 0.0000e+00 - val_cls_logits_accuracy3: 0.0000e+00 - val_rpn_score_loss: 6.3221 - val_rpn_regress_loss: 1404601.3750 - val_cls_logits_loss1: 0.0000e+00 - val_cls_regress_loss1: 0.0000e+00 - val_cls_mask_loss1: 0.0000e+00 - val_cls_logits_loss2: 0.0000e+00 - val_cls_regress_loss2: 0.0000e+00 - val_cls_mask_loss2: 0.0000e+00 - val_cls_logits_loss3: 0.0000e+00 - val_cls_regress_loss3: 0.0000e+00 - val_cls_mask_loss3: 0.0000e+00
# Epoch 9/500
# 31/31 [==============================] - 29s 930ms/step - loss: 12.8794 - rpn_score_accuracy: 0.8203 - cls_logits_accuracy1: 0.4355 - cls_logits_accuracy2: 0.1048 - cls_logits_accuracy3: 0.0242 - rpn_score_loss: 0.9166 - rpn_regress_loss: 1.3640 - cls_logits_loss1: 2.3237 - cls_regress_loss1: 7.2500 - cls_mask_loss1: 0.2467 - cls_logits_loss2: 0.2954 - cls_regress_loss2: 0.3774 - cls_mask_loss2: 0.0506 - cls_logits_loss3: 0.0325 - cls_regress_loss3: 0.0177 - cls_mask_loss3: 0.0048 - val_loss: 27066.5762 - val_rpn_score_accuracy: 0.6645 - val_cls_logits_accuracy1: 0.0000e+00 - val_cls_logits_accuracy2: 0.0000e+00 - val_cls_logits_accuracy3: 0.0000e+00 - val_rpn_score_loss: 5.1627 - val_rpn_regress_loss: 27061.4160 - val_cls_logits_loss1: 0.0000e+00 - val_cls_regress_loss1: 0.0000e+00 - val_cls_mask_loss1: 0.0000e+00 - val_cls_logits_loss2: 0.0000e+00 - val_cls_regress_loss2: 0.0000e+00 - val_cls_mask_loss2: 0.0000e+00 - val_cls_logits_loss3: 0.0000e+00 - val_cls_regress_loss3: 0.0000e+00 - val_cls_mask_loss3: 0.0000e+00
# Epoch 10/500
# 31/31 [==============================] - 29s 939ms/step - loss: 11.7838 - rpn_score_accuracy: 0.7861 - cls_logits_accuracy1: 0.4798 - cls_logits_accuracy2: 0.1452 - cls_logits_accuracy3: 0.0000e+00 - rpn_score_loss: 0.9297 - rpn_regress_loss: 1.8586 - cls_logits_loss1: 2.3580 - cls_regress_loss1: 4.7574 - cls_mask_loss1: 0.4504 - cls_logits_loss2: 0.3900 - cls_regress_loss2: 1.0056 - cls_mask_loss2: 0.0342 - cls_logits_loss3: 0.0000e+00 - cls_regress_loss3: 0.0000e+00 - cls_mask_loss3: 0.0000e+00 - val_loss: 314.5316 - val_rpn_score_accuracy: 0.6440 - val_cls_logits_accuracy1: 0.0000e+00 - val_cls_logits_accuracy2: 0.0000e+00 - val_cls_logits_accuracy3: 0.0000e+00 - val_rpn_score_loss: 5.2471 - val_rpn_regress_loss: 309.2845 - val_cls_logits_loss1: 0.0000e+00 - val_cls_regress_loss1: 0.0000e+00 - val_cls_mask_loss1: 0.0000e+00 - val_cls_logits_loss2: 0.0000e+00 - val_cls_regress_loss2: 0.0000e+00 - val_cls_mask_loss2: 0.0000e+00 - val_cls_logits_loss3: 0.0000e+00 - val_cls_regress_loss3: 0.0000e+00 - val_cls_mask_loss3: 0.0000e+00
# Epoch 11/500
# 31/31 [==============================] - 30s 955ms/step - loss: 9.8563 - rpn_score_accuracy: 0.8177 - cls_logits_accuracy1: 0.5310 - cls_logits_accuracy2: 0.4113 - cls_logits_accuracy3: 0.0484 - rpn_score_loss: 0.6029 - rpn_regress_loss: 1.6712 - cls_logits_loss1: 2.3188 - cls_regress_loss1: 1.7585 - cls_mask_loss1: 0.5928 - cls_logits_loss2: 1.0876 - cls_regress_loss2: 1.2373 - cls_mask_loss2: 0.1731 - cls_logits_loss3: 0.0650 - cls_regress_loss3: 0.3457 - cls_mask_loss3: 0.0032 - val_loss: 63.0654 - val_rpn_score_accuracy: 0.6923 - val_cls_logits_accuracy1: 0.1071 - val_cls_logits_accuracy2: 0.0000e+00 - val_cls_logits_accuracy3: 0.0000e+00 - val_rpn_score_loss: 3.8359 - val_rpn_regress_loss: 57.8795 - val_cls_logits_loss1: 0.5756 - val_cls_regress_loss1: 0.7025 - val_cls_mask_loss1: 0.0718 - val_cls_logits_loss2: 0.0000e+00 - val_cls_regress_loss2: 0.0000e+00 - val_cls_mask_loss2: 0.0000e+00 - val_cls_logits_loss3: 0.0000e+00 - val_cls_regress_loss3: 0.0000e+00 - val_cls_mask_loss3: 0.0000e+00
# Epoch 12/500
# 31/31 [==============================] - 28s 907ms/step - loss: 6.4337 - rpn_score_accuracy: 0.7955 - cls_logits_accuracy1: 0.1774 - cls_logits_accuracy2: 0.1694 - cls_logits_accuracy3: 0.0000e+00 - rpn_score_loss: 1.0352 - rpn_regress_loss: 3.1507 - cls_logits_loss1: 0.5986 - cls_regress_loss1: 0.5862 - cls_mask_loss1: 0.1962 - cls_logits_loss2: 0.4435 - cls_regress_loss2: 0.3370 - cls_mask_loss2: 0.0863 - cls_logits_loss3: 0.0000e+00 - cls_regress_loss3: 0.0000e+00 - cls_mask_loss3: 0.0000e+00 - val_loss: 5.6098 - val_rpn_score_accuracy: 0.6133 - val_cls_logits_accuracy1: 0.0000e+00 - val_cls_logits_accuracy2: 0.0000e+00 - val_cls_logits_accuracy3: 0.0000e+00 - val_rpn_score_loss: 2.9314 - val_rpn_regress_loss: 2.6784 - val_cls_logits_loss1: 0.0000e+00 - val_cls_regress_loss1: 0.0000e+00 - val_cls_mask_loss1: 0.0000e+00 - val_cls_logits_loss2: 0.0000e+00 - val_cls_regress_loss2: 0.0000e+00 - val_cls_mask_loss2: 0.0000e+00 - val_cls_logits_loss3: 0.0000e+00 - val_cls_regress_loss3: 0.0000e+00 - val_cls_mask_loss3: 0.0000e+00
# Epoch 13/500
# 31/31 [==============================] - 28s 913ms/step - loss: 3.1982 - rpn_score_accuracy: 0.8190 - cls_logits_accuracy1: 0.0575 - cls_logits_accuracy2: 0.0484 - cls_logits_accuracy3: 0.0000e+00 - rpn_score_loss: 0.9932 - rpn_regress_loss: 1.0932 - cls_logits_loss1: 0.1801 - cls_regress_loss1: 0.2309 - cls_mask_loss1: 0.0755 - cls_logits_loss2: 0.1245 - cls_regress_loss2: 0.4695 - cls_mask_loss2: 0.0313 - cls_logits_loss3: 0.0000e+00 - cls_regress_loss3: 0.0000e+00 - cls_mask_loss3: 0.0000e+00 - val_loss: 8.7790 - val_rpn_score_accuracy: 0.7535 - val_cls_logits_accuracy1: 0.5357 - val_cls_logits_accuracy2: 0.0000e+00 - val_cls_logits_accuracy3: 0.0000e+00 - val_rpn_score_loss: 1.1893 - val_rpn_regress_loss: 0.7589 - val_cls_logits_loss1: 2.8782 - val_cls_regress_loss1: 3.6304 - val_cls_mask_loss1: 0.3222 - val_cls_logits_loss2: 0.0000e+00 - val_cls_regress_loss2: 0.0000e+00 - val_cls_mask_loss2: 0.0000e+00 - val_cls_logits_loss3: 0.0000e+00 - val_cls_regress_loss3: 0.0000e+00 - val_cls_mask_loss3: 0.0000e+00
# Epoch 14/500
# 31/31 [==============================] - 29s 924ms/step - loss: 3.6197 - rpn_score_accuracy: 0.8469 - cls_logits_accuracy1: 0.2097 - cls_logits_accuracy2: 0.1371 - cls_logits_accuracy3: 0.0726 - rpn_score_loss: 0.7099 - rpn_regress_loss: 1.1545 - cls_logits_loss1: 0.4572 - cls_regress_loss1: 0.2600 - cls_mask_loss1: 0.2113 - cls_logits_loss2: 0.2372 - cls_regress_loss2: 0.2894 - cls_mask_loss2: 0.0745 - cls_logits_loss3: 0.0975 - cls_regress_loss3: 0.1061 - cls_mask_loss3: 0.0222 - val_loss: 3.6404 - val_rpn_score_accuracy: 0.7772 - val_cls_logits_accuracy1: 0.2143 - val_cls_logits_accuracy2: 0.0000e+00 - val_cls_logits_accuracy3: 0.0000e+00 - val_rpn_score_loss: 0.6226 - val_rpn_regress_loss: 0.7231 - val_cls_logits_loss1: 1.1513 - val_cls_regress_loss1: 0.9484 - val_cls_mask_loss1: 0.1950 - val_cls_logits_loss2: 0.0000e+00 - val_cls_regress_loss2: 0.0000e+00 - val_cls_mask_loss2: 0.0000e+00 - val_cls_logits_loss3: 0.0000e+00 - val_cls_regress_loss3: 0.0000e+00 - val_cls_mask_loss3: 0.0000e+00
# Epoch 15/500
# 31/31 [==============================] - 29s 925ms/step - loss: 4.4187 - rpn_score_accuracy: 0.8506 - cls_logits_accuracy1: 0.1639 - cls_logits_accuracy2: 0.1621 - cls_logits_accuracy3: 0.0952 - rpn_score_loss: 0.8581 - rpn_regress_loss: 1.8670 - cls_logits_loss1: 0.3639 - cls_regress_loss1: 0.3052 - cls_mask_loss1: 0.1618 - cls_logits_loss2: 0.3184 - cls_regress_loss2: 0.0745 - cls_mask_loss2: 0.0838 - cls_logits_loss3: 0.0848 - cls_regress_loss3: 0.2844 - cls_mask_loss3: 0.0170 - val_loss: 7.7094 - val_rpn_score_accuracy: 0.7783 - val_cls_logits_accuracy1: 0.5357 - val_cls_logits_accuracy2: 0.0000e+00 - val_cls_logits_accuracy3: 0.0000e+00 - val_rpn_score_loss: 1.0843 - val_rpn_regress_loss: 1.0146 - val_cls_logits_loss1: 2.8782 - val_cls_regress_loss1: 2.2928 - val_cls_mask_loss1: 0.4395 - val_cls_logits_loss2: 0.0000e+00 - val_cls_regress_loss2: 0.0000e+00 - val_cls_mask_loss2: 0.0000e+00 - val_cls_logits_loss3: 0.0000e+00 - val_cls_regress_loss3: 0.0000e+00 - val_cls_mask_loss3: 0.0000e+00
# Epoch 16/500
# 31/31 [==============================] - 29s 925ms/step - loss: 5.0198 - rpn_score_accuracy: 0.8505 - cls_logits_accuracy1: 0.3065 - cls_logits_accuracy2: 0.1579 - cls_logits_accuracy3: 0.0887 - rpn_score_loss: 0.6505 - rpn_regress_loss: 1.1202 - cls_logits_loss1: 1.0630 - cls_regress_loss1: 1.2573 - cls_mask_loss1: 0.3180 - cls_logits_loss2: 0.2933 - cls_regress_loss2: 0.1285 - cls_mask_loss2: 0.0764 - cls_logits_loss3: 0.0187 - cls_regress_loss3: 0.0638 - cls_mask_loss3: 0.0302 - val_loss: 6.3132 - val_rpn_score_accuracy: 0.7033 - val_cls_logits_accuracy1: 0.5357 - val_cls_logits_accuracy2: 0.0000e+00 - val_cls_logits_accuracy3: 0.0000e+00 - val_rpn_score_loss: 0.6205 - val_rpn_regress_loss: 0.7122 - val_cls_logits_loss1: 2.8782 - val_cls_regress_loss1: 1.6569 - val_cls_mask_loss1: 0.4454 - val_cls_logits_loss2: 0.0000e+00 - val_cls_regress_loss2: 0.0000e+00 - val_cls_mask_loss2: 0.0000e+00 - val_cls_logits_loss3: 0.0000e+00 - val_cls_regress_loss3: 0.0000e+00 - val_cls_mask_loss3: 0.0000e+00
# Epoch 17/500
# 31/31 [==============================] - 29s 947ms/step - loss: 4.9282 - rpn_score_accuracy: 0.8160 - cls_logits_accuracy1: 0.5194 - cls_logits_accuracy2: 0.3273 - cls_logits_accuracy3: 0.1465 - rpn_score_loss: 0.5993 - rpn_regress_loss: 0.6520 - cls_logits_loss1: 0.9273 - cls_regress_loss1: 1.3796 - cls_mask_loss1: 0.4850 - cls_logits_loss2: 0.3753 - cls_regress_loss2: 0.1404 - cls_mask_loss2: 0.1561 - cls_logits_loss3: 0.0867 - cls_regress_loss3: 0.0881 - cls_mask_loss3: 0.0385 - val_loss: 7.8168 - val_rpn_score_accuracy: 0.7638 - val_cls_logits_accuracy1: 0.6429 - val_cls_logits_accuracy2: 0.0357 - val_cls_logits_accuracy3: 0.1071 - val_rpn_score_loss: 0.5133 - val_rpn_regress_loss: 0.7144 - val_cls_logits_loss1: 3.4266 - val_cls_regress_loss1: 2.1479 - val_cls_mask_loss1: 0.6823 - val_cls_logits_loss2: 0.1616 - val_cls_regress_loss2: 0.0304 - val_cls_mask_loss2: 0.0437 - val_cls_logits_loss3: 0.0332 - val_cls_regress_loss3: 0.0389 - val_cls_mask_loss3: 0.0246
# Epoch 18/500
# 31/31 [==============================] - 29s 946ms/step - loss: 5.3743 - rpn_score_accuracy: 0.8684 - cls_logits_accuracy1: 0.4933 - cls_logits_accuracy2: 0.2715 - cls_logits_accuracy3: 0.1468 - rpn_score_loss: 0.3966 - rpn_regress_loss: 1.5552 - cls_logits_loss1: 1.0509 - cls_regress_loss1: 0.9759 - cls_mask_loss1: 0.5160 - cls_logits_loss2: 0.2910 - cls_regress_loss2: 0.2398 - cls_mask_loss2: 0.1414 - cls_logits_loss3: 0.0905 - cls_regress_loss3: 0.0802 - cls_mask_loss3: 0.0369 - val_loss: 6.7770 - val_rpn_score_accuracy: 0.7701 - val_cls_logits_accuracy1: 0.7500 - val_cls_logits_accuracy2: 0.1250 - val_cls_logits_accuracy3: 0.1071 - val_rpn_score_loss: 0.6811 - val_rpn_regress_loss: 0.6526 - val_cls_logits_loss1: 3.9329 - val_cls_regress_loss1: 0.5197 - val_cls_mask_loss1: 0.6269 - val_cls_logits_loss2: 0.1250 - val_cls_regress_loss2: 0.0880 - val_cls_mask_loss2: 0.0949 - val_cls_logits_loss3: 0.0127 - val_cls_regress_loss3: 0.0187 - val_cls_mask_loss3: 0.0244
# Epoch 19/500
# 31/31 [==============================] - 30s 960ms/step - loss: 5.0351 - rpn_score_accuracy: 0.8496 - cls_logits_accuracy1: 0.5448 - cls_logits_accuracy2: 0.3580 - cls_logits_accuracy3: 0.2648 - rpn_score_loss: 0.6070 - rpn_regress_loss: 0.8086 - cls_logits_loss1: 1.1602 - cls_regress_loss1: 0.8825 - cls_mask_loss1: 0.4798 - cls_logits_loss2: 0.2545 - cls_regress_loss2: 0.2031 - cls_mask_loss2: 0.1761 - cls_logits_loss3: 0.2629 - cls_regress_loss3: 0.1207 - cls_mask_loss3: 0.0797 - val_loss: 6.8997 - val_rpn_score_accuracy: 0.7705 - val_cls_logits_accuracy1: 0.6429 - val_cls_logits_accuracy2: 0.1429 - val_cls_logits_accuracy3: 0.1071 - val_rpn_score_loss: 1.0142 - val_rpn_regress_loss: 0.9789 - val_cls_logits_loss1: 2.9903 - val_cls_regress_loss1: 0.8786 - val_cls_mask_loss1: 0.5042 - val_cls_logits_loss2: 0.1332 - val_cls_regress_loss2: 0.0694 - val_cls_mask_loss2: 0.0857 - val_cls_logits_loss3: 0.1439 - val_cls_regress_loss3: 0.0786 - val_cls_mask_loss3: 0.0228
# Epoch 20/500
# 31/31 [==============================] - 30s 966ms/step - loss: 5.9918 - rpn_score_accuracy: 0.8796 - cls_logits_accuracy1: 0.5286 - cls_logits_accuracy2: 0.4257 - cls_logits_accuracy3: 0.2816 - rpn_score_loss: 0.4458 - rpn_regress_loss: 1.1429 - cls_logits_loss1: 0.6585 - cls_regress_loss1: 2.5275 - cls_mask_loss1: 0.4567 - cls_logits_loss2: 0.1316 - cls_regress_loss2: 0.2071 - cls_mask_loss2: 0.1848 - cls_logits_loss3: 0.1144 - cls_regress_loss3: 0.0539 - cls_mask_loss3: 0.0686 - val_loss: 4.3570 - val_rpn_score_accuracy: 0.7473 - val_cls_logits_accuracy1: 0.6310 - val_cls_logits_accuracy2: 0.2232 - val_cls_logits_accuracy3: 0.0357 - val_rpn_score_loss: 0.6516 - val_rpn_regress_loss: 0.7656 - val_cls_logits_loss1: 0.6730 - val_cls_regress_loss1: 0.6110 - val_cls_mask_loss1: 0.4484 - val_cls_logits_loss2: 0.7256 - val_cls_regress_loss2: 0.2481 - val_cls_mask_loss2: 0.1741 - val_cls_logits_loss3: 0.0240 - val_cls_regress_loss3: 0.0119 - val_cls_mask_loss3: 0.0236
# Epoch 21/500
# 31/31 [==============================] - 30s 956ms/step - loss: 4.1043 - rpn_score_accuracy: 0.8671 - cls_logits_accuracy1: 0.5645 - cls_logits_accuracy2: 0.3490 - cls_logits_accuracy3: 0.2656 - rpn_score_loss: 0.3905 - rpn_regress_loss: 0.6333 - cls_logits_loss1: 0.6754 - cls_regress_loss1: 1.0871 - cls_mask_loss1: 0.5482 - cls_logits_loss2: 0.2328 - cls_regress_loss2: 0.2096 - cls_mask_loss2: 0.1590 - cls_logits_loss3: 0.0694 - cls_regress_loss3: 0.0412 - cls_mask_loss3: 0.0578 - val_loss: 2.1799 - val_rpn_score_accuracy: 0.8044 - val_cls_logits_accuracy1: 0.3839 - val_cls_logits_accuracy2: 0.1071 - val_cls_logits_accuracy3: 0.0000e+00 - val_rpn_score_loss: 0.4503 - val_rpn_regress_loss: 0.6988 - val_cls_logits_loss1: 0.1405 - val_cls_regress_loss1: 0.3421 - val_cls_mask_loss1: 0.3854 - val_cls_logits_loss2: 0.0125 - val_cls_regress_loss2: 0.1076 - val_cls_mask_loss2: 0.0427 - val_cls_logits_loss3: 0.0000e+00 - val_cls_regress_loss3: 0.0000e+00 - val_cls_mask_loss3: 0.0000e+00
# Epoch 22/500
# 31/31 [==============================] - 30s 961ms/step - loss: 5.5971 - rpn_score_accuracy: 0.8767 - cls_logits_accuracy1: 0.5792 - cls_logits_accuracy2: 0.4608 - cls_logits_accuracy3: 0.2858 - rpn_score_loss: 0.3585 - rpn_regress_loss: 0.4968 - cls_logits_loss1: 0.4756 - cls_regress_loss1: 1.8404 - cls_mask_loss1: 0.4999 - cls_logits_loss2: 0.9586 - cls_regress_loss2: 0.3986 - cls_mask_loss2: 0.2425 - cls_logits_loss3: 0.1404 - cls_regress_loss3: 0.1038 - cls_mask_loss3: 0.0821 - val_loss: 2.5319 - val_rpn_score_accuracy: 0.7381 - val_cls_logits_accuracy1: 0.4286 - val_cls_logits_accuracy2: 0.3214 - val_cls_logits_accuracy3: 0.1250 - val_rpn_score_loss: 0.5454 - val_rpn_regress_loss: 0.6839 - val_cls_logits_loss1: 0.0815 - val_cls_regress_loss1: 0.2368 - val_cls_mask_loss1: 0.3065 - val_cls_logits_loss2: 0.4079 - val_cls_regress_loss2: 0.0987 - val_cls_mask_loss2: 0.1281 - val_cls_logits_loss3: 0.0041 - val_cls_regress_loss3: 0.0147 - val_cls_mask_loss3: 0.0242
# Epoch 23/500
# 31/31 [==============================] - 30s 963ms/step - loss: 5.0311 - rpn_score_accuracy: 0.8964 - cls_logits_accuracy1: 0.5250 - cls_logits_accuracy2: 0.4231 - cls_logits_accuracy3: 0.4166 - rpn_score_loss: 0.2979 - rpn_regress_loss: 0.5929 - cls_logits_loss1: 1.0374 - cls_regress_loss1: 1.1060 - cls_mask_loss1: 0.5701 - cls_logits_loss2: 0.5229 - cls_regress_loss2: 0.2021 - cls_mask_loss2: 0.2102 - cls_logits_loss3: 0.2991 - cls_regress_loss3: 0.0987 - cls_mask_loss3: 0.0937 - val_loss: 2.1116 - val_rpn_score_accuracy: 0.7807 - val_cls_logits_accuracy1: 0.4286 - val_cls_logits_accuracy2: 0.2393 - val_cls_logits_accuracy3: 0.0000e+00 - val_rpn_score_loss: 0.4630 - val_rpn_regress_loss: 0.6639 - val_cls_logits_loss1: 0.1007 - val_cls_regress_loss1: 0.1146 - val_cls_mask_loss1: 0.2964 - val_cls_logits_loss2: 0.0738 - val_cls_regress_loss2: 0.2121 - val_cls_mask_loss2: 0.1872 - val_cls_logits_loss3: 0.0000e+00 - val_cls_regress_loss3: 0.0000e+00 - val_cls_mask_loss3: 0.0000e+00
# Epoch 24/500
# 31/31 [==============================] - 30s 961ms/step - loss: 6.1377 - rpn_score_accuracy: 0.8540 - cls_logits_accuracy1: 0.6241 - cls_logits_accuracy2: 0.4720 - cls_logits_accuracy3: 0.3019 - rpn_score_loss: 0.3971 - rpn_regress_loss: 0.5744 - cls_logits_loss1: 1.7520 - cls_regress_loss1: 2.2566 - cls_mask_loss1: 0.5056 - cls_logits_loss2: 0.0872 - cls_regress_loss2: 0.1938 - cls_mask_loss2: 0.2019 - cls_logits_loss3: 0.0667 - cls_regress_loss3: 0.0316 - cls_mask_loss3: 0.0708 - val_loss: 6.6424 - val_rpn_score_accuracy: 0.7711 - val_cls_logits_accuracy1: 0.3214 - val_cls_logits_accuracy2: 0.1071 - val_cls_logits_accuracy3: 0.0000e+00 - val_rpn_score_loss: 0.9205 - val_rpn_regress_loss: 1.5734 - val_cls_logits_loss1: 0.1174 - val_cls_regress_loss1: 0.2792 - val_cls_mask_loss1: 0.2578 - val_cls_logits_loss2: 1.7676 - val_cls_regress_loss2: 1.5798 - val_cls_mask_loss2: 0.1467 - val_cls_logits_loss3: 0.0000e+00 - val_cls_regress_loss3: 0.0000e+00 - val_cls_mask_loss3: 0.0000e+00
# Epoch 25/500
# 31/31 [==============================] - 30s 959ms/step - loss: 5.4703 - rpn_score_accuracy: 0.8723 - cls_logits_accuracy1: 0.6237 - cls_logits_accuracy2: 0.4721 - cls_logits_accuracy3: 0.2903 - rpn_score_loss: 0.4405 - rpn_regress_loss: 0.7534 - cls_logits_loss1: 0.7987 - cls_regress_loss1: 0.9749 - cls_mask_loss1: 0.4829 - cls_logits_loss2: 0.6752 - cls_regress_loss2: 0.7969 - cls_mask_loss2: 0.2718 - cls_logits_loss3: 0.1419 - cls_regress_loss3: 0.0643 - cls_mask_loss3: 0.0697 - val_loss: 12.5364 - val_rpn_score_accuracy: 0.8208 - val_cls_logits_accuracy1: 0.4286 - val_cls_logits_accuracy2: 0.4286 - val_cls_logits_accuracy3: 0.3571 - val_rpn_score_loss: 1.2342 - val_rpn_regress_loss: 9.9005 - val_cls_logits_loss1: 0.1007 - val_cls_regress_loss1: 0.1024 - val_cls_mask_loss1: 0.2932 - val_cls_logits_loss2: 0.3376 - val_cls_regress_loss2: 0.2477 - val_cls_mask_loss2: 0.2247 - val_cls_logits_loss3: 0.0137 - val_cls_regress_loss3: 0.0193 - val_cls_mask_loss3: 0.0624
# Epoch 26/500
# ...
# Epoch 485/500
# 31/31 [==============================] - 30s 973ms/step - loss: 0.7512 - rpn_score_accuracy: 0.9876 - cls_logits_accuracy1: 0.9157 - cls_logits_accuracy2: 0.9050 - cls_logits_accuracy3: 0.9065 - rpn_score_loss: 0.0375 - rpn_regress_loss: 0.0860 - cls_logits_loss1: 0.0640 - cls_regress_loss1: 0.1418 - cls_mask_loss1: 0.1517 - cls_logits_loss2: 0.0279 - cls_regress_loss2: 0.0669 - cls_mask_loss2: 0.0835 - cls_logits_loss3: 0.0157 - cls_regress_loss3: 0.0302 - cls_mask_loss3: 0.0460 - val_loss: 3.8850 - val_rpn_score_accuracy: 0.7482 - val_cls_logits_accuracy1: 0.8801 - val_cls_logits_accuracy2: 0.7670 - val_cls_logits_accuracy3: 0.7619 - val_rpn_score_loss: 1.5582 - val_rpn_regress_loss: 1.2059 - val_cls_logits_loss1: 0.1037 - val_cls_regress_loss1: 0.2765 - val_cls_mask_loss1: 0.3478 - val_cls_logits_loss2: 0.0322 - val_cls_regress_loss2: 0.1084 - val_cls_mask_loss2: 0.1156 - val_cls_logits_loss3: 0.0184 - val_cls_regress_loss3: 0.0460 - val_cls_mask_loss3: 0.0722
# Epoch 486/500
# 31/31 [==============================] - 30s 973ms/step - loss: 0.7513 - rpn_score_accuracy: 0.9807 - cls_logits_accuracy1: 0.9134 - cls_logits_accuracy2: 0.9219 - cls_logits_accuracy3: 0.9130 - rpn_score_loss: 0.0648 - rpn_regress_loss: 0.0801 - cls_logits_loss1: 0.0603 - cls_regress_loss1: 0.1444 - cls_mask_loss1: 0.1392 - cls_logits_loss2: 0.0304 - cls_regress_loss2: 0.0676 - cls_mask_loss2: 0.0749 - cls_logits_loss3: 0.0141 - cls_regress_loss3: 0.0289 - cls_mask_loss3: 0.0465 - val_loss: 3.7137 - val_rpn_score_accuracy: 0.7209 - val_cls_logits_accuracy1: 0.8869 - val_cls_logits_accuracy2: 0.8810 - val_cls_logits_accuracy3: 0.8941 - val_rpn_score_loss: 1.5207 - val_rpn_regress_loss: 1.0782 - val_cls_logits_loss1: 0.0972 - val_cls_regress_loss1: 0.2810 - val_cls_mask_loss1: 0.2807 - val_cls_logits_loss2: 0.0495 - val_cls_regress_loss2: 0.1353 - val_cls_mask_loss2: 0.1185 - val_cls_logits_loss3: 0.0210 - val_cls_regress_loss3: 0.0636 - val_cls_mask_loss3: 0.0679
# Epoch 487/500
# 31/31 [==============================] - 30s 973ms/step - loss: 0.7475 - rpn_score_accuracy: 0.9786 - cls_logits_accuracy1: 0.8997 - cls_logits_accuracy2: 0.9144 - cls_logits_accuracy3: 0.9086 - rpn_score_loss: 0.0559 - rpn_regress_loss: 0.0820 - cls_logits_loss1: 0.0628 - cls_regress_loss1: 0.1436 - cls_mask_loss1: 0.1339 - cls_logits_loss2: 0.0315 - cls_regress_loss2: 0.0675 - cls_mask_loss2: 0.0746 - cls_logits_loss3: 0.0163 - cls_regress_loss3: 0.0319 - cls_mask_loss3: 0.0474 - val_loss: 3.5456 - val_rpn_score_accuracy: 0.7478 - val_cls_logits_accuracy1: 0.8452 - val_cls_logits_accuracy2: 0.8571 - val_cls_logits_accuracy3: 0.8661 - val_rpn_score_loss: 1.4489 - val_rpn_regress_loss: 1.0092 - val_cls_logits_loss1: 0.1081 - val_cls_regress_loss1: 0.2630 - val_cls_mask_loss1: 0.2799 - val_cls_logits_loss2: 0.0487 - val_cls_regress_loss2: 0.1278 - val_cls_mask_loss2: 0.1162 - val_cls_logits_loss3: 0.0229 - val_cls_regress_loss3: 0.0580 - val_cls_mask_loss3: 0.0629
# Epoch 488/500
# 31/31 [==============================] - 30s 972ms/step - loss: 0.6751 - rpn_score_accuracy: 0.9827 - cls_logits_accuracy1: 0.9031 - cls_logits_accuracy2: 0.9073 - cls_logits_accuracy3: 0.9195 - rpn_score_loss: 0.0564 - rpn_regress_loss: 0.0641 - cls_logits_loss1: 0.0603 - cls_regress_loss1: 0.1176 - cls_mask_loss1: 0.1335 - cls_logits_loss2: 0.0282 - cls_regress_loss2: 0.0569 - cls_mask_loss2: 0.0765 - cls_logits_loss3: 0.0136 - cls_regress_loss3: 0.0251 - cls_mask_loss3: 0.0428 - val_loss: 3.4838 - val_rpn_score_accuracy: 0.7786 - val_cls_logits_accuracy1: 0.8446 - val_cls_logits_accuracy2: 0.8268 - val_cls_logits_accuracy3: 0.8476 - val_rpn_score_loss: 1.3992 - val_rpn_regress_loss: 0.9617 - val_cls_logits_loss1: 0.1101 - val_cls_regress_loss1: 0.2659 - val_cls_mask_loss1: 0.2655 - val_cls_logits_loss2: 0.0513 - val_cls_regress_loss2: 0.1289 - val_cls_mask_loss2: 0.1497 - val_cls_logits_loss3: 0.0250 - val_cls_regress_loss3: 0.0526 - val_cls_mask_loss3: 0.0739
# Epoch 489/500
# 31/31 [==============================] - 30s 972ms/step - loss: 0.7528 - rpn_score_accuracy: 0.9850 - cls_logits_accuracy1: 0.9063 - cls_logits_accuracy2: 0.8981 - cls_logits_accuracy3: 0.8929 - rpn_score_loss: 0.0374 - rpn_regress_loss: 0.0697 - cls_logits_loss1: 0.0655 - cls_regress_loss1: 0.1493 - cls_mask_loss1: 0.1486 - cls_logits_loss2: 0.0351 - cls_regress_loss2: 0.0700 - cls_mask_loss2: 0.0783 - cls_logits_loss3: 0.0203 - cls_regress_loss3: 0.0297 - cls_mask_loss3: 0.0489 - val_loss: 3.4278 - val_rpn_score_accuracy: 0.7719 - val_cls_logits_accuracy1: 0.8369 - val_cls_logits_accuracy2: 0.8113 - val_cls_logits_accuracy3: 0.8345 - val_rpn_score_loss: 1.3182 - val_rpn_regress_loss: 0.9809 - val_cls_logits_loss1: 0.1285 - val_cls_regress_loss1: 0.2560 - val_cls_mask_loss1: 0.2601 - val_cls_logits_loss2: 0.0603 - val_cls_regress_loss2: 0.1222 - val_cls_mask_loss2: 0.1431 - val_cls_logits_loss3: 0.0287 - val_cls_regress_loss3: 0.0524 - val_cls_mask_loss3: 0.0773
# Epoch 490/500
# 31/31 [==============================] - 30s 973ms/step - loss: 0.7323 - rpn_score_accuracy: 0.9827 - cls_logits_accuracy1: 0.9068 - cls_logits_accuracy2: 0.9169 - cls_logits_accuracy3: 0.8957 - rpn_score_loss: 0.0706 - rpn_regress_loss: 0.0650 - cls_logits_loss1: 0.0600 - cls_regress_loss1: 0.1299 - cls_mask_loss1: 0.1447 - cls_logits_loss2: 0.0288 - cls_regress_loss2: 0.0629 - cls_mask_loss2: 0.0777 - cls_logits_loss3: 0.0170 - cls_regress_loss3: 0.0276 - cls_mask_loss3: 0.0480 - val_loss: 3.1817 - val_rpn_score_accuracy: 0.7691 - val_cls_logits_accuracy1: 0.8732 - val_cls_logits_accuracy2: 0.8821 - val_cls_logits_accuracy3: 0.8452 - val_rpn_score_loss: 1.3405 - val_rpn_regress_loss: 0.8471 - val_cls_logits_loss1: 0.0890 - val_cls_regress_loss1: 0.2386 - val_cls_mask_loss1: 0.2516 - val_cls_logits_loss2: 0.0395 - val_cls_regress_loss2: 0.1147 - val_cls_mask_loss2: 0.1197 - val_cls_logits_loss3: 0.0202 - val_cls_regress_loss3: 0.0494 - val_cls_mask_loss3: 0.0713
# Epoch 491/500
# 31/31 [==============================] - 30s 974ms/step - loss: 0.6840 - rpn_score_accuracy: 0.9868 - cls_logits_accuracy1: 0.9235 - cls_logits_accuracy2: 0.9205 - cls_logits_accuracy3: 0.9150 - rpn_score_loss: 0.0342 - rpn_regress_loss: 0.0531 - cls_logits_loss1: 0.0542 - cls_regress_loss1: 0.1353 - cls_mask_loss1: 0.1414 - cls_logits_loss2: 0.0269 - cls_regress_loss2: 0.0662 - cls_mask_loss2: 0.0807 - cls_logits_loss3: 0.0141 - cls_regress_loss3: 0.0281 - cls_mask_loss3: 0.0498 - val_loss: 3.2861 - val_rpn_score_accuracy: 0.7773 - val_cls_logits_accuracy1: 0.8452 - val_cls_logits_accuracy2: 0.8423 - val_cls_logits_accuracy3: 0.8232 - val_rpn_score_loss: 1.3283 - val_rpn_regress_loss: 0.9479 - val_cls_logits_loss1: 0.0979 - val_cls_regress_loss1: 0.2560 - val_cls_mask_loss1: 0.2374 - val_cls_logits_loss2: 0.0454 - val_cls_regress_loss2: 0.1176 - val_cls_mask_loss2: 0.1098 - val_cls_logits_loss3: 0.0229 - val_cls_regress_loss3: 0.0491 - val_cls_mask_loss3: 0.0738
# Epoch 492/500
# 31/31 [==============================] - 30s 971ms/step - loss: 0.7136 - rpn_score_accuracy: 0.9808 - cls_logits_accuracy1: 0.9271 - cls_logits_accuracy2: 0.9235 - cls_logits_accuracy3: 0.9237 - rpn_score_loss: 0.0625 - rpn_regress_loss: 0.0618 - cls_logits_loss1: 0.0495 - cls_regress_loss1: 0.1462 - cls_mask_loss1: 0.1357 - cls_logits_loss2: 0.0274 - cls_regress_loss2: 0.0716 - cls_mask_loss2: 0.0731 - cls_logits_loss3: 0.0127 - cls_regress_loss3: 0.0289 - cls_mask_loss3: 0.0442 - val_loss: 3.2980 - val_rpn_score_accuracy: 0.7210 - val_cls_logits_accuracy1: 0.7708 - val_cls_logits_accuracy2: 0.7708 - val_cls_logits_accuracy3: 0.7827 - val_rpn_score_loss: 1.4784 - val_rpn_regress_loss: 1.0001 - val_cls_logits_loss1: 0.0618 - val_cls_regress_loss1: 0.2037 - val_cls_mask_loss1: 0.2026 - val_cls_logits_loss2: 0.0309 - val_cls_regress_loss2: 0.1022 - val_cls_mask_loss2: 0.1058 - val_cls_logits_loss3: 0.0131 - val_cls_regress_loss3: 0.0437 - val_cls_mask_loss3: 0.0557
# Epoch 493/500
# 31/31 [==============================] - 30s 973ms/step - loss: 0.6580 - rpn_score_accuracy: 0.9878 - cls_logits_accuracy1: 0.9162 - cls_logits_accuracy2: 0.9208 - cls_logits_accuracy3: 0.9018 - rpn_score_loss: 0.0329 - rpn_regress_loss: 0.0669 - cls_logits_loss1: 0.0586 - cls_regress_loss1: 0.1264 - cls_mask_loss1: 0.1313 - cls_logits_loss2: 0.0275 - cls_regress_loss2: 0.0609 - cls_mask_loss2: 0.0700 - cls_logits_loss3: 0.0143 - cls_regress_loss3: 0.0262 - cls_mask_loss3: 0.0428 - val_loss: 3.6146 - val_rpn_score_accuracy: 0.7709 - val_cls_logits_accuracy1: 0.8940 - val_cls_logits_accuracy2: 0.8940 - val_cls_logits_accuracy3: 0.9137 - val_rpn_score_loss: 1.4148 - val_rpn_regress_loss: 1.1364 - val_cls_logits_loss1: 0.1018 - val_cls_regress_loss1: 0.2408 - val_cls_mask_loss1: 0.2630 - val_cls_logits_loss2: 0.0429 - val_cls_regress_loss2: 0.1187 - val_cls_mask_loss2: 0.1430 - val_cls_logits_loss3: 0.0205 - val_cls_regress_loss3: 0.0563 - val_cls_mask_loss3: 0.0764
# Epoch 494/500
# 31/31 [==============================] - 30s 973ms/step - loss: 0.6793 - rpn_score_accuracy: 0.9820 - cls_logits_accuracy1: 0.9218 - cls_logits_accuracy2: 0.9236 - cls_logits_accuracy3: 0.9046 - rpn_score_loss: 0.0372 - rpn_regress_loss: 0.0677 - cls_logits_loss1: 0.0581 - cls_regress_loss1: 0.1217 - cls_mask_loss1: 0.1382 - cls_logits_loss2: 0.0332 - cls_regress_loss2: 0.0589 - cls_mask_loss2: 0.0737 - cls_logits_loss3: 0.0202 - cls_regress_loss3: 0.0252 - cls_mask_loss3: 0.0451 - val_loss: 3.3601 - val_rpn_score_accuracy: 0.7442 - val_cls_logits_accuracy1: 0.7833 - val_cls_logits_accuracy2: 0.7643 - val_cls_logits_accuracy3: 0.7244 - val_rpn_score_loss: 1.4115 - val_rpn_regress_loss: 1.0090 - val_cls_logits_loss1: 0.0695 - val_cls_regress_loss1: 0.2163 - val_cls_mask_loss1: 0.2394 - val_cls_logits_loss2: 0.0371 - val_cls_regress_loss2: 0.1073 - val_cls_mask_loss2: 0.1330 - val_cls_logits_loss3: 0.0232 - val_cls_regress_loss3: 0.0432 - val_cls_mask_loss3: 0.0705
# Epoch 495/500
# 31/31 [==============================] - 30s 975ms/step - loss: 0.6909 - rpn_score_accuracy: 0.9808 - cls_logits_accuracy1: 0.9106 - cls_logits_accuracy2: 0.9276 - cls_logits_accuracy3: 0.9261 - rpn_score_loss: 0.0456 - rpn_regress_loss: 0.0659 - cls_logits_loss1: 0.0600 - cls_regress_loss1: 0.1375 - cls_mask_loss1: 0.1321 - cls_logits_loss2: 0.0258 - cls_regress_loss2: 0.0659 - cls_mask_loss2: 0.0712 - cls_logits_loss3: 0.0130 - cls_regress_loss3: 0.0290 - cls_mask_loss3: 0.0449 - val_loss: 3.4354 - val_rpn_score_accuracy: 0.7454 - val_cls_logits_accuracy1: 0.7589 - val_cls_logits_accuracy2: 0.7649 - val_cls_logits_accuracy3: 0.7601 - val_rpn_score_loss: 1.3875 - val_rpn_regress_loss: 1.0398 - val_cls_logits_loss1: 0.0835 - val_cls_regress_loss1: 0.2226 - val_cls_mask_loss1: 0.2682 - val_cls_logits_loss2: 0.0405 - val_cls_regress_loss2: 0.1096 - val_cls_mask_loss2: 0.1448 - val_cls_logits_loss3: 0.0209 - val_cls_regress_loss3: 0.0468 - val_cls_mask_loss3: 0.0712
# Epoch 496/500
# 31/31 [==============================] - 30s 973ms/step - loss: 0.6790 - rpn_score_accuracy: 0.9865 - cls_logits_accuracy1: 0.9336 - cls_logits_accuracy2: 0.9231 - cls_logits_accuracy3: 0.9301 - rpn_score_loss: 0.0345 - rpn_regress_loss: 0.0734 - cls_logits_loss1: 0.0526 - cls_regress_loss1: 0.1352 - cls_mask_loss1: 0.1386 - cls_logits_loss2: 0.0256 - cls_regress_loss2: 0.0635 - cls_mask_loss2: 0.0725 - cls_logits_loss3: 0.0124 - cls_regress_loss3: 0.0246 - cls_mask_loss3: 0.0462 - val_loss: 3.6626 - val_rpn_score_accuracy: 0.7513 - val_cls_logits_accuracy1: 0.8342 - val_cls_logits_accuracy2: 0.8559 - val_cls_logits_accuracy3: 0.8655 - val_rpn_score_loss: 1.3817 - val_rpn_regress_loss: 1.0601 - val_cls_logits_loss1: 0.1946 - val_cls_regress_loss1: 0.2695 - val_cls_mask_loss1: 0.3092 - val_cls_logits_loss2: 0.0501 - val_cls_regress_loss2: 0.1172 - val_cls_mask_loss2: 0.1320 - val_cls_logits_loss3: 0.0225 - val_cls_regress_loss3: 0.0500 - val_cls_mask_loss3: 0.0757
# Epoch 497/500
# 31/31 [==============================] - 30s 977ms/step - loss: 0.7250 - rpn_score_accuracy: 0.9861 - cls_logits_accuracy1: 0.8969 - cls_logits_accuracy2: 0.8999 - cls_logits_accuracy3: 0.9067 - rpn_score_loss: 0.0376 - rpn_regress_loss: 0.0775 - cls_logits_loss1: 0.0606 - cls_regress_loss1: 0.1486 - cls_mask_loss1: 0.1311 - cls_logits_loss2: 0.0316 - cls_regress_loss2: 0.0718 - cls_mask_loss2: 0.0727 - cls_logits_loss3: 0.0149 - cls_regress_loss3: 0.0318 - cls_mask_loss3: 0.0467 - val_loss: 3.5589 - val_rpn_score_accuracy: 0.7519 - val_cls_logits_accuracy1: 0.8765 - val_cls_logits_accuracy2: 0.8795 - val_cls_logits_accuracy3: 0.8807 - val_rpn_score_loss: 1.4557 - val_rpn_regress_loss: 1.0787 - val_cls_logits_loss1: 0.0808 - val_cls_regress_loss1: 0.2618 - val_cls_mask_loss1: 0.2415 - val_cls_logits_loss2: 0.0448 - val_cls_regress_loss2: 0.1253 - val_cls_mask_loss2: 0.1225 - val_cls_logits_loss3: 0.0228 - val_cls_regress_loss3: 0.0574 - val_cls_mask_loss3: 0.0675
# Epoch 498/500
# 31/31 [==============================] - 30s 975ms/step - loss: 0.6975 - rpn_score_accuracy: 0.9867 - cls_logits_accuracy1: 0.9312 - cls_logits_accuracy2: 0.9269 - cls_logits_accuracy3: 0.9276 - rpn_score_loss: 0.0329 - rpn_regress_loss: 0.0752 - cls_logits_loss1: 0.0513 - cls_regress_loss1: 0.1410 - cls_mask_loss1: 0.1384 - cls_logits_loss2: 0.0266 - cls_regress_loss2: 0.0692 - cls_mask_loss2: 0.0755 - cls_logits_loss3: 0.0128 - cls_regress_loss3: 0.0289 - cls_mask_loss3: 0.0455 - val_loss: 3.5966 - val_rpn_score_accuracy: 0.7144 - val_cls_logits_accuracy1: 0.9089 - val_cls_logits_accuracy2: 0.8881 - val_cls_logits_accuracy3: 0.8970 - val_rpn_score_loss: 1.5454 - val_rpn_regress_loss: 1.0301 - val_cls_logits_loss1: 0.0868 - val_cls_regress_loss1: 0.2504 - val_cls_mask_loss1: 0.2537 - val_cls_logits_loss2: 0.0420 - val_cls_regress_loss2: 0.1212 - val_cls_mask_loss2: 0.1238 - val_cls_logits_loss3: 0.0236 - val_cls_regress_loss3: 0.0487 - val_cls_mask_loss3: 0.0710
# Epoch 499/500
# 31/31 [==============================] - 30s 973ms/step - loss: 0.6850 - rpn_score_accuracy: 0.9856 - cls_logits_accuracy1: 0.9238 - cls_logits_accuracy2: 0.9123 - cls_logits_accuracy3: 0.9130 - rpn_score_loss: 0.0341 - rpn_regress_loss: 0.0709 - cls_logits_loss1: 0.0575 - cls_regress_loss1: 0.1308 - cls_mask_loss1: 0.1384 - cls_logits_loss2: 0.0315 - cls_regress_loss2: 0.0610 - cls_mask_loss2: 0.0744 - cls_logits_loss3: 0.0145 - cls_regress_loss3: 0.0263 - cls_mask_loss3: 0.0457 - val_loss: 3.9092 - val_rpn_score_accuracy: 0.7237 - val_cls_logits_accuracy1: 0.8698 - val_cls_logits_accuracy2: 0.8767 - val_cls_logits_accuracy3: 0.8707 - val_rpn_score_loss: 1.6390 - val_rpn_regress_loss: 1.1998 - val_cls_logits_loss1: 0.0852 - val_cls_regress_loss1: 0.2450 - val_cls_mask_loss1: 0.2826 - val_cls_logits_loss2: 0.0449 - val_cls_regress_loss2: 0.1192 - val_cls_mask_loss2: 0.1351 - val_cls_logits_loss3: 0.0242 - val_cls_regress_loss3: 0.0540 - val_cls_mask_loss3: 0.0802
# Epoch 500/500
# 31/31 [==============================] - 30s 975ms/step - loss: 0.7364 - rpn_score_accuracy: 0.9851 - cls_logits_accuracy1: 0.8960 - cls_logits_accuracy2: 0.9125 - cls_logits_accuracy3: 0.9174 - rpn_score_loss: 0.0511 - rpn_regress_loss: 0.0708 - cls_logits_loss1: 0.0681 - cls_regress_loss1: 0.1410 - cls_mask_loss1: 0.1452 - cls_logits_loss2: 0.0299 - cls_regress_loss2: 0.0659 - cls_mask_loss2: 0.0731 - cls_logits_loss3: 0.0143 - cls_regress_loss3: 0.0283 - cls_mask_loss3: 0.0487 - val_loss: 4.0379 - val_rpn_score_accuracy: 0.7352 - val_cls_logits_accuracy1: 0.8393 - val_cls_logits_accuracy2: 0.8571 - val_cls_logits_accuracy3: 0.8542 - val_rpn_score_loss: 1.4902 - val_rpn_regress_loss: 1.2787 - val_cls_logits_loss1: 0.1372 - val_cls_regress_loss1: 0.2817 - val_cls_mask_loss1: 0.3519 - val_cls_logits_loss2: 0.0506 - val_cls_regress_loss2: 0.1272 - val_cls_mask_loss2: 0.1540 - val_cls_logits_loss3: 0.0266 - val_cls_regress_loss3: 0.0529 - val_cls_mask_loss3: 0.0869

# %%
model.save_weights("model.h5")

# %%
x = tf.keras.layers.Input(shape = (512, 512, 3))
feature = tfdet.model.backbone.resnet50(x)
#scale = [32, 64, 128, 256, 512]
scale = [24, 48, 96, 192, 384]
ratio = [0.5, 1, 2]
out = tfdet.model.detector.hybrid_task_cascade_rcnn(feature, image_shape = tf.shape(x)[1:3], n_class = 2, mask = True, interleaved = True, mask_info_flow = True, semantic_feature = False, scale = scale, ratio = ratio, soft_nms = False, neck = neck, proposal_count = 1000)
prediction = tfdet.model.postprocess.rcnn.FilterDetection(proposal_count = 100, iou_threshold = 0.3, score_threshold = 0.7, ensemble = True, soft_nms = False)(out)
model = tf.keras.Model(x, prediction)
model.load_weights("model.h5")

# %%
images = te_x[:1]
logits, proposal, mask = model.predict(images)
images = tfdet.util.draw_bbox(images, proposal, logits, mask, label = ["Background", "Balloon"])

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (10, 10))
plt.imshow(images[0])
