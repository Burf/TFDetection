# %% [markdown]
# # 0. Import Library

# %%
import os
if not os.path.exists("./tfdet"):
    # !git clone -q http://github.com/burf/tfdetection.git
    # !mv ./tfdetection/tfdet ./tfdet
    # !rm -rf ./tfdetection

# %%
#ignore warning
import warnings, os
warnings.filterwarnings(action = "ignore")
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

import tfdet
#tfdet.core.util.set_seed(777) #set seed
device = tfdet.core.util.select_device(0) #set device

if True: #apply mixed precision
    tf.keras.mixed_precision.set_global_policy("mixed_float16")

# %% [markdown]
# # 1. Init Dataset

# %%
import os
path = "./balloon"
if not os.path.exists(path):
    # !wget -qq --no-check-certificate http://github.com/matterport/Mask_RCNN/releases/download/v2.1/balloon_dataset.zip
    # !unzip -qq balloon_dataset.zip
print(tfdet.dataset.util.tree_dir(path))
# Out:
# balloon/
#     train/
#         605521662_a470fef77f_b.jpg
#         9330497995_4cf0438cb6_k.jpg
#         5178670692_63a4365c9c_b.jpg
#         ...
#     val/
#         4838031651_3e7b5ea5c7_b.jpg
#         16335852991_f55de7958d_k.jpg
#         24631331976_defa3bb61f_k.jpg
#         ...

# %%
import numpy as np

tr_path = os.path.join(path, "train/via_region_data.json")
te_path = os.path.join(path, "val/via_region_data.json")

label = tfdet.dataset.balloon.LABEL
color = None

n_class = len(label)
#image_shape = [1024, 1024]
image_shape = [512, 512]

def mask_func(mask_true):
    return np.max(mask_true, axis = 0)

def instance2semantic(x_true, y_true = None, bbox_true = None, mask_true = None, label = None):
    if y_true is not None and mask_true is not None:
        mask_true = tfdet.dataset.util.instance2semantic(y_true, mask_true, label = label)
    result = [v for v in [x_true, y_true, bbox_true, mask_true] if v is not None]
    result = result[0] if len(result) == 1 else tuple(result)
    return result

tr_dataset = tfdet.dataset.balloon.load_dataset(tr_path, mask = True,
                                                cache = None)
tr_dataset = tfdet.dataset.Dataset(tr_dataset,
                                   transform = [{"name":"load"},
                                                {"name":"resize", "image_shape":[2048, 1024], "mode":"range"},
                                                {"name":"weak_augmentation", "crop_shape":image_shape},
                                                {"name":"filter_annotation"},
                                                {"name":"label_encode", "label":label},
                                                {"name":"normalize", "mean":[123.675, 116.28, 103.53], "std":[58.395, 57.12, 57.375]},
                                                {"name":"pad", "image_shape":image_shape, "pad_val":0},
                                                {"name":"mask_downscale", "scale":4},
                                                instance2semantic, #or {"name":"load", "mask_func":mask_func},
                                               ])

te_dataset = tfdet.dataset.balloon.load_dataset(te_path, mask = True,
                                                cache = None,
                                                transform = [{"name":"load"},
                                                             {"name":"resize", "image_shape":image_shape},
                                                             {"name":"filter_annotation"},
                                                             {"name":"label_encode", "label":label},
                                                             {"name":"normalize", "mean":[123.675, 116.28, 103.53], "std":[58.395, 57.12, 57.375]},
                                                             {"name":"pad", "image_shape":image_shape, "pad_val":0},
                                                             {"name":"mask_downscale", "scale":4},
                                                             instance2semantic, #or {"name":"load", "mask_func":mask_func},
                                                            ])


tr_pipe = tfdet.dataset.PipeLoader(tr_dataset)
tr_pipe = tfdet.dataset.pipeline.args2dict(tr_pipe, keys = ["x_true", "y_true", "bbox_true", "mask_true"])
tr_pipe = tfdet.dataset.pipeline.collect(tr_pipe, keys = ["x_true", "mask_true"])

te_pipe = tfdet.dataset.PipeLoader(te_dataset)
te_pipe = tfdet.dataset.pipeline.args2dict(te_pipe, keys = ["x_true", "y_true", "bbox_true", "mask_true"])
te_pipe = tfdet.dataset.pipeline.collect(te_pipe, keys = ["x_true", "mask_true"])
# Out:
# Preprocessing Data: 100%|██████████| 61/61 [00:19<00:00,  3.08it/s]
# Preprocessing Data: 100%|██████████| 13/13 [00:01<00:00,  6.75it/s]

# %% [markdown]
# # 2. Build Detector

# %%
with device:
    x = tf.keras.layers.Input(shape = [*image_shape, 3], name = "x_true")
    feature = tfdet.model.backbone.resnet50(x, weights = "imagenet_v2")
    
    out = tfdet.model.detector.upernet(feature, n_class = n_class)
    aux_out = tfdet.model.detector.aux_fcn(feature, n_class = n_class)
    model = tfdet.model.train.segmentation.train_model(x, out, aux_out)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
#   0%|          | 0.00/97.8M [00:00<?, ?B/s]

# %% [markdown]
# # 3. Train

# %%
import shutil

epoch = 100
batch_size = 16
update_step = 64 // batch_size
save_path = "./learn/epoch@{epoch:03d}-metric@{mean_iou:.4f}-loss@{loss:.4f}.h5"

learning_rate = 1e-2
decay_rate = 1e-2 #dst learning_rate = learning_rate * decay_rate
momentum = 0.9
nesterov = True
warm_up_epoch = 5

if os.path.exists(os.path.dirname(save_path)):
    shutil.rmtree(os.path.dirname(save_path))
os.makedirs(os.path.dirname(save_path), exist_ok = True)

train_pipe = tfdet.dataset.pipeline.key_map(tr_pipe, map = {"x_true":x.name}, repeat = 8, batch_size = batch_size, shuffle = True, prefetch = True) #61 * 8 > 488
test_pipe = tfdet.dataset.pipeline.key_map(te_pipe, map = {"x_true":x.name}, batch_size = batch_size, prefetch = True)

total_step = int(train_pipe.cardinality()) #len(train_pipe)
total_test_step = int(test_pipe.cardinality()) #len(test_pipe)

ema = tfdet.callback.EMA(step = update_step, auto_apply = True, warm_up_epoch = warm_up_epoch)
metric = tfdet.callback.MeanIoU(test_pipe, label = label, name = "mean_iou")
save = tf.keras.callbacks.ModelCheckpoint(save_path, monitor = "mean_iou", mode = "max", save_best_only = True, save_weights_only = True, save_freq = "epoch", verbose = 0)
#scheduler = tfdet.callback.WarmUpCosineLearningRateScheduler(cycle = epoch, decay_rate = decay_rate, warm_up_epoch = warm_up_epoch)
scheduler = tfdet.callback.WarmUpCosineLearningRateSchedulerStep(cycle = epoch, decay_rate = decay_rate, step = update_step, total_step = total_step, warm_up_epoch = warm_up_epoch) #total step None > dynamic total step
logger = tf.keras.callbacks.CSVLogger(os.path.join(os.path.dirname(save_path), "logger.csv"), separator = ",")

# %%
with device:
    optimizer = tf.keras.optimizers.SGD(learning_rate, momentum = momentum, nesterov = nesterov)
    if tf.keras.mixed_precision.global_policy().compute_dtype == "float16":
        optimizer = tf.keras.mixed_precision.LossScaleOptimizer(optimizer)
    model.compile(optimizer = optimizer)

    model.fit(train_pipe,
              #validation_data = test_pipe,
              epochs = epoch, steps_per_epoch = total_step, validation_steps = total_test_step,
              callbacks = [ema, metric, save, scheduler, logger],
              verbose = 2)
# Out:
# Epoch 1/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9784  |0.9575|0.9783|0.9783|
# |balloon   |0.644   |0.4763|0.6453|0.6453|
# +----------+--------+------+------+------+
# |summary   |0.8112  |0.7169|0.8118|0.8118|
# +----------+--------+------+------+------+
# 32/32 - 1378s - loss: 0.8188 - loss_mask: 0.5998 - loss_aux_mask: 0.2190 - ema_n_update: 32.0000 - mean_accuracy: 0.8112 - mean_iou: 0.7169 - mean_dice: 0.8118 - mean_f1: 0.8118 - learning_rate: 0.0020 - 1378s/epoch - 43s/step
# Epoch 2/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9691  |0.9585|0.9788|0.9788|
# |balloon   |0.8199  |0.5451|0.7056|0.7056|
# +----------+--------+------+------+------+
# |summary   |0.8945  |0.7518|0.8422|0.8422|
# +----------+--------+------+------+------+
# 32/32 - 104s - loss: 0.4514 - loss_mask: 0.2657 - loss_aux_mask: 0.1858 - ema_n_update: 48.0000 - mean_accuracy: 0.8945 - mean_iou: 0.7518 - mean_dice: 0.8422 - mean_f1: 0.8422 - learning_rate: 0.0040 - 104s/epoch - 3s/step
# Epoch 3/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9631  |0.9516|0.9752|0.9752|
# |balloon   |0.8039  |0.5018|0.6682|0.6682|
# +----------+--------+------+------+------+
# |summary   |0.8835  |0.7267|0.8217|0.8217|
# +----------+--------+------+------+------+
# 32/32 - 102s - loss: 0.3699 - loss_mask: 0.2150 - loss_aux_mask: 0.1549 - ema_n_update: 64.0000 - mean_accuracy: 0.8835 - mean_iou: 0.7267 - mean_dice: 0.8217 - mean_f1: 0.8217 - learning_rate: 0.0060 - 102s/epoch - 3s/step
# Epoch 4/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9892  |0.9827|0.9913|0.9913|
# |balloon   |0.8926  |0.7591|0.8631|0.8631|
# +----------+--------+------+------+------+
# |summary   |0.9409  |0.8709|0.9272|0.9272|
# +----------+--------+------+------+------+
# 32/32 - 101s - loss: 0.2948 - loss_mask: 0.1748 - loss_aux_mask: 0.1201 - ema_n_update: 74.0000 - mean_accuracy: 0.9409 - mean_iou: 0.8709 - mean_dice: 0.9272 - mean_f1: 0.9272 - learning_rate: 0.0080 - 101s/epoch - 3s/step
# Epoch 5/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9938  |0.9842|0.992 |0.992 |
# |balloon   |0.8402  |0.7633|0.8658|0.8658|
# +----------+--------+------+------+------+
# |summary   |0.917   |0.8737|0.9289|0.9289|
# +----------+--------+------+------+------+
# 32/32 - 99s - loss: 0.2439 - loss_mask: 0.1409 - loss_aux_mask: 0.1030 - ema_n_update: 82.0000 - mean_accuracy: 0.9170 - mean_iou: 0.8737 - mean_dice: 0.9289 - mean_f1: 0.9289 - learning_rate: 0.0100 - 99s/epoch - 3s/step
# Epoch 6/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9958  |0.9855|0.9927|0.9927|
# |balloon   |0.8306  |0.7769|0.8744|0.8744|
# +----------+--------+------+------+------+
# |summary   |0.9132  |0.8812|0.9336|0.9336|
# +----------+--------+------+------+------+
# 32/32 - 98s - loss: 0.2754 - loss_mask: 0.1792 - loss_aux_mask: 0.0962 - ema_n_update: 90.0000 - mean_accuracy: 0.9132 - mean_iou: 0.8812 - mean_dice: 0.9336 - mean_f1: 0.9336 - learning_rate: 0.0100 - 98s/epoch - 3s/step
# Epoch 7/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9846  |0.9822|0.991 |0.991 |
# |balloon   |0.9595  |0.767 |0.8681|0.8681|
# +----------+--------+------+------+------+
# |summary   |0.9721  |0.8746|0.9296|0.9296|
# +----------+--------+------+------+------+
# 32/32 - 98s - loss: 0.2462 - loss_mask: 0.1470 - loss_aux_mask: 0.0991 - ema_n_update: 98.0000 - mean_accuracy: 0.9721 - mean_iou: 0.8746 - mean_dice: 0.9296 - mean_f1: 0.9296 - learning_rate: 0.0100 - 98s/epoch - 3s/step
# Epoch 8/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9994  |0.9788|0.9893|0.9893|
# |balloon   |0.6562  |0.65  |0.7878|0.7878|
# +----------+--------+------+------+------+
# |summary   |0.8278  |0.8144|0.8886|0.8886|
# +----------+--------+------+------+------+
# 32/32 - 97s - loss: 0.1886 - loss_mask: 0.1052 - loss_aux_mask: 0.0834 - ema_n_update: 106.0000 - mean_accuracy: 0.8278 - mean_iou: 0.8144 - mean_dice: 0.8886 - mean_f1: 0.8886 - learning_rate: 0.0100 - 97s/epoch - 3s/step
# Epoch 9/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9997  |0.9823|0.9911|0.9911|
# |balloon   |0.7126  |0.7086|0.8295|0.8295|
# +----------+--------+------+------+------+
# |summary   |0.8561  |0.8455|0.9103|0.9103|
# +----------+--------+------+------+------+
# 32/32 - 94s - loss: 0.1674 - loss_mask: 0.0886 - loss_aux_mask: 0.0788 - ema_n_update: 114.0000 - mean_accuracy: 0.8561 - mean_iou: 0.8455 - mean_dice: 0.9103 - mean_f1: 0.9103 - learning_rate: 0.0100 - 94s/epoch - 3s/step
# Epoch 10/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9997  |0.9843|0.9921|0.9921|
# |balloon   |0.7442  |0.7406|0.8509|0.8509|
# +----------+--------+------+------+------+
# |summary   |0.8719  |0.8624|0.9215|0.9215|
# +----------+--------+------+------+------+
# 32/32 - 103s - loss: 0.1813 - loss_mask: 0.1065 - loss_aux_mask: 0.0748 - ema_n_update: 122.0000 - mean_accuracy: 0.8719 - mean_iou: 0.8624 - mean_dice: 0.9215 - mean_f1: 0.9215 - learning_rate: 0.0099 - 103s/epoch - 3s/step
# Epoch 11/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9959  |0.9893|0.9946|0.9946|
# |balloon   |0.8909  |0.8352|0.9102|0.9102|
# +----------+--------+------+------+------+
# |summary   |0.9434  |0.9123|0.9524|0.9524|
# +----------+--------+------+------+------+
# 32/32 - 102s - loss: 0.1551 - loss_mask: 0.0864 - loss_aux_mask: 0.0686 - ema_n_update: 130.0000 - mean_accuracy: 0.9434 - mean_iou: 0.9123 - mean_dice: 0.9524 - mean_f1: 0.9524 - learning_rate: 0.0099 - 102s/epoch - 3s/step
# Epoch 12/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9959  |0.9914|0.9957|0.9957|
# |balloon   |0.9269  |0.8684|0.9295|0.9295|
# +----------+--------+------+------+------+
# |summary   |0.9614  |0.9299|0.9626|0.9626|
# +----------+--------+------+------+------+
# 32/32 - 97s - loss: 0.1313 - loss_mask: 0.0641 - loss_aux_mask: 0.0673 - ema_n_update: 138.0000 - mean_accuracy: 0.9614 - mean_iou: 0.9299 - mean_dice: 0.9626 - mean_f1: 0.9626 - learning_rate: 0.0099 - 97s/epoch - 3s/step
# Epoch 13/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9983  |0.9797|0.9898|0.9898|
# |balloon   |0.6913  |0.6722|0.804 |0.804 |
# +----------+--------+------+------+------+
# |summary   |0.8448  |0.826 |0.8969|0.8969|
# +----------+--------+------+------+------+
# 32/32 - 101s - loss: 0.2045 - loss_mask: 0.1181 - loss_aux_mask: 0.0865 - ema_n_update: 146.0000 - mean_accuracy: 0.8448 - mean_iou: 0.8260 - mean_dice: 0.8969 - mean_f1: 0.8969 - learning_rate: 0.0098 - 101s/epoch - 3s/step
# Epoch 14/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9994  |0.9849|0.9924|0.9924|
# |balloon   |0.7599  |0.7528|0.859 |0.859 |
# +----------+--------+------+------+------+
# |summary   |0.8797  |0.8689|0.9257|0.9257|
# +----------+--------+------+------+------+
# 32/32 - 95s - loss: 0.1572 - loss_mask: 0.0898 - loss_aux_mask: 0.0674 - ema_n_update: 154.0000 - mean_accuracy: 0.8797 - mean_iou: 0.8689 - mean_dice: 0.9257 - mean_f1: 0.9257 - learning_rate: 0.0098 - 95s/epoch - 3s/step
# Epoch 15/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9997  |0.9856|0.9927|0.9927|
# |balloon   |0.7666  |0.7626|0.8653|0.8653|
# +----------+--------+------+------+------+
# |summary   |0.8831  |0.8741|0.929 |0.929 |
# +----------+--------+------+------+------+
# 32/32 - 96s - loss: 0.1346 - loss_mask: 0.0731 - loss_aux_mask: 0.0615 - ema_n_update: 162.0000 - mean_accuracy: 0.8831 - mean_iou: 0.8741 - mean_dice: 0.9290 - mean_f1: 0.9290 - learning_rate: 0.0098 - 96s/epoch - 3s/step
# Epoch 16/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9985  |0.9883|0.9941|0.9941|
# |balloon   |0.8313  |0.8116|0.896 |0.896 |
# +----------+--------+------+------+------+
# |summary   |0.9149  |0.9   |0.9451|0.9451|
# +----------+--------+------+------+------+
# 32/32 - 90s - loss: 0.1163 - loss_mask: 0.0568 - loss_aux_mask: 0.0596 - ema_n_update: 170.0000 - mean_accuracy: 0.9149 - mean_iou: 0.9000 - mean_dice: 0.9451 - mean_f1: 0.9451 - learning_rate: 0.0097 - 90s/epoch - 3s/step
# Epoch 17/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9911  |0.9861|0.993 |0.993 |
# |balloon   |0.9181  |0.8013|0.8897|0.8897|
# +----------+--------+------+------+------+
# |summary   |0.9546  |0.8937|0.9414|0.9414|
# +----------+--------+------+------+------+
# 32/32 - 90s - loss: 0.1175 - loss_mask: 0.0611 - loss_aux_mask: 0.0564 - ema_n_update: 178.0000 - mean_accuracy: 0.9546 - mean_iou: 0.8937 - mean_dice: 0.9414 - mean_f1: 0.9414 - learning_rate: 0.0097 - 90s/epoch - 3s/step
# Epoch 18/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9967  |0.9832|0.9916|0.9916|
# |balloon   |0.7774  |0.7373|0.8488|0.8488|
# +----------+--------+------+------+------+
# |summary   |0.887   |0.8603|0.9202|0.9202|
# +----------+--------+------+------+------+
# 32/32 - 92s - loss: 0.1097 - loss_mask: 0.0545 - loss_aux_mask: 0.0551 - ema_n_update: 186.0000 - mean_accuracy: 0.8870 - mean_iou: 0.8603 - mean_dice: 0.9202 - mean_f1: 0.9202 - learning_rate: 0.0096 - 92s/epoch - 3s/step
# Epoch 19/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9967  |0.9847|0.9923|0.9923|
# |balloon   |0.802   |0.7609|0.8642|0.8642|
# +----------+--------+------+------+------+
# |summary   |0.8993  |0.8728|0.9283|0.9283|
# +----------+--------+------+------+------+
# 32/32 - 90s - loss: 0.1142 - loss_mask: 0.0567 - loss_aux_mask: 0.0576 - ema_n_update: 194.0000 - mean_accuracy: 0.8993 - mean_iou: 0.8728 - mean_dice: 0.9283 - mean_f1: 0.9283 - learning_rate: 0.0095 - 90s/epoch - 3s/step
# Epoch 20/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9968  |0.9905|0.9952|0.9952|
# |balloon   |0.8965  |0.8517|0.9199|0.9199|
# +----------+--------+------+------+------+
# |summary   |0.9466  |0.9211|0.9576|0.9576|
# +----------+--------+------+------+------+
# 32/32 - 91s - loss: 0.1071 - loss_mask: 0.0486 - loss_aux_mask: 0.0585 - ema_n_update: 202.0000 - mean_accuracy: 0.9466 - mean_iou: 0.9211 - mean_dice: 0.9576 - mean_f1: 0.9576 - learning_rate: 0.0095 - 91s/epoch - 3s/step
# Epoch 21/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9959  |0.9927|0.9964|0.9964|
# |balloon   |0.9486  |0.8888|0.9411|0.9411|
# +----------+--------+------+------+------+
# |summary   |0.9723  |0.9408|0.9687|0.9687|
# +----------+--------+------+------+------+
# 32/32 - 92s - loss: 0.1107 - loss_mask: 0.0524 - loss_aux_mask: 0.0583 - ema_n_update: 210.0000 - mean_accuracy: 0.9723 - mean_iou: 0.9408 - mean_dice: 0.9687 - mean_f1: 0.9687 - learning_rate: 0.0094 - 92s/epoch - 3s/step
# Epoch 22/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9961  |0.9914|0.9957|0.9957|
# |balloon   |0.9222  |0.8673|0.9289|0.9289|
# +----------+--------+------+------+------+
# |summary   |0.9592  |0.9294|0.9623|0.9623|
# +----------+--------+------+------+------+
# 32/32 - 91s - loss: 0.0898 - loss_mask: 0.0402 - loss_aux_mask: 0.0496 - ema_n_update: 218.0000 - mean_accuracy: 0.9592 - mean_iou: 0.9294 - mean_dice: 0.9623 - mean_f1: 0.9623 - learning_rate: 0.0093 - 91s/epoch - 3s/step
# Epoch 23/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9975  |0.9929|0.9964|0.9964|
# |balloon   |0.9243  |0.8879|0.9406|0.9406|
# +----------+--------+------+------+------+
# |summary   |0.9609  |0.9404|0.9685|0.9685|
# +----------+--------+------+------+------+
# 32/32 - 94s - loss: 0.1065 - loss_mask: 0.0498 - loss_aux_mask: 0.0566 - ema_n_update: 226.0000 - mean_accuracy: 0.9609 - mean_iou: 0.9404 - mean_dice: 0.9685 - mean_f1: 0.9685 - learning_rate: 0.0092 - 94s/epoch - 3s/step
# Epoch 24/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9982  |0.9919|0.9959|0.9959|
# |balloon   |0.8964  |0.8711|0.9311|0.9311|
# +----------+--------+------+------+------+
# |summary   |0.9473  |0.9315|0.9635|0.9635|
# +----------+--------+------+------+------+
# 32/32 - 92s - loss: 0.0818 - loss_mask: 0.0352 - loss_aux_mask: 0.0466 - ema_n_update: 234.0000 - mean_accuracy: 0.9473 - mean_iou: 0.9315 - mean_dice: 0.9635 - mean_f1: 0.9635 - learning_rate: 0.0091 - 92s/epoch - 3s/step
# Epoch 25/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9993  |0.9913|0.9956|0.9956|
# |balloon   |0.8686  |0.8583|0.9237|0.9237|
# +----------+--------+------+------+------+
# |summary   |0.9339  |0.9248|0.9597|0.9597|
# +----------+--------+------+------+------+
# 32/32 - 95s - loss: 0.0946 - loss_mask: 0.0442 - loss_aux_mask: 0.0503 - ema_n_update: 242.0000 - mean_accuracy: 0.9339 - mean_iou: 0.9248 - mean_dice: 0.9597 - mean_f1: 0.9597 - learning_rate: 0.0091 - 95s/epoch - 3s/step
# Epoch 26/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9979  |0.9927|0.9963|0.9963|
# |balloon   |0.9134  |0.8836|0.9382|0.9382|
# +----------+--------+------+------+------+
# |summary   |0.9557  |0.9381|0.9673|0.9673|
# +----------+--------+------+------+------+
# 32/32 - 92s - loss: 0.1090 - loss_mask: 0.0524 - loss_aux_mask: 0.0566 - ema_n_update: 250.0000 - mean_accuracy: 0.9557 - mean_iou: 0.9381 - mean_dice: 0.9673 - mean_f1: 0.9673 - learning_rate: 0.0090 - 92s/epoch - 3s/step
# Epoch 27/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9986  |0.9891|0.9945|0.9945|
# |balloon   |0.843   |0.8248|0.904 |0.904 |
# +----------+--------+------+------+------+
# |summary   |0.9208  |0.907 |0.9493|0.9493|
# +----------+--------+------+------+------+
# 32/32 - 90s - loss: 0.0919 - loss_mask: 0.0395 - loss_aux_mask: 0.0524 - ema_n_update: 258.0000 - mean_accuracy: 0.9208 - mean_iou: 0.9070 - mean_dice: 0.9493 - mean_f1: 0.9493 - learning_rate: 0.0089 - 90s/epoch - 3s/step
# Epoch 28/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9983  |0.9883|0.9941|0.9941|
# |balloon   |0.8348  |0.812 |0.8962|0.8962|
# +----------+--------+------+------+------+
# |summary   |0.9165  |0.9001|0.9452|0.9452|
# +----------+--------+------+------+------+
# 32/32 - 92s - loss: 0.0869 - loss_mask: 0.0369 - loss_aux_mask: 0.0500 - ema_n_update: 266.0000 - mean_accuracy: 0.9165 - mean_iou: 0.9001 - mean_dice: 0.9452 - mean_f1: 0.9452 - learning_rate: 0.0088 - 92s/epoch - 3s/step
# Epoch 29/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9977  |0.9878|0.9939|0.9939|
# |balloon   |0.8374  |0.8071|0.8932|0.8932|
# +----------+--------+------+------+------+
# |summary   |0.9175  |0.8975|0.9436|0.9436|
# +----------+--------+------+------+------+
# 32/32 - 89s - loss: 0.0673 - loss_mask: 0.0289 - loss_aux_mask: 0.0384 - ema_n_update: 274.0000 - mean_accuracy: 0.9175 - mean_iou: 0.8975 - mean_dice: 0.9436 - mean_f1: 0.9436 - learning_rate: 0.0087 - 89s/epoch - 3s/step
# Epoch 30/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9969  |0.9872|0.9935|0.9935|
# |balloon   |0.8394  |0.799 |0.8882|0.8882|
# +----------+--------+------+------+------+
# |summary   |0.9182  |0.8931|0.9409|0.9409|
# +----------+--------+------+------+------+
# 32/32 - 89s - loss: 0.0734 - loss_mask: 0.0288 - loss_aux_mask: 0.0446 - ema_n_update: 282.0000 - mean_accuracy: 0.9182 - mean_iou: 0.8931 - mean_dice: 0.9409 - mean_f1: 0.9409 - learning_rate: 0.0086 - 89s/epoch - 3s/step
# Epoch 31/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9974  |0.9888|0.9944|0.9944|
# |balloon   |0.8589  |0.8234|0.9031|0.9031|
# +----------+--------+------+------+------+
# |summary   |0.9281  |0.9061|0.9488|0.9488|
# +----------+--------+------+------+------+
# 32/32 - 92s - loss: 0.0583 - loss_mask: 0.0229 - loss_aux_mask: 0.0354 - ema_n_update: 290.0000 - mean_accuracy: 0.9281 - mean_iou: 0.9061 - mean_dice: 0.9488 - mean_f1: 0.9488 - learning_rate: 0.0084 - 92s/epoch - 3s/step
# Epoch 32/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9985  |0.9882|0.994 |0.994 |
# |balloon   |0.8289  |0.8095|0.8947|0.8947|
# +----------+--------+------+------+------+
# |summary   |0.9137  |0.8988|0.9444|0.9444|
# +----------+--------+------+------+------+
# 32/32 - 90s - loss: 0.0634 - loss_mask: 0.0256 - loss_aux_mask: 0.0378 - ema_n_update: 298.0000 - mean_accuracy: 0.9137 - mean_iou: 0.8988 - mean_dice: 0.9444 - mean_f1: 0.9444 - learning_rate: 0.0083 - 90s/epoch - 3s/step
# Epoch 33/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.997   |0.9887|0.9943|0.9943|
# |balloon   |0.8624  |0.8225|0.9026|0.9026|
# +----------+--------+------+------+------+
# |summary   |0.9297  |0.9056|0.9485|0.9485|
# +----------+--------+------+------+------+
# 32/32 - 92s - loss: 0.0787 - loss_mask: 0.0387 - loss_aux_mask: 0.0399 - ema_n_update: 306.0000 - mean_accuracy: 0.9297 - mean_iou: 0.9056 - mean_dice: 0.9485 - mean_f1: 0.9485 - learning_rate: 0.0082 - 92s/epoch - 3s/step
# Epoch 34/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9987  |0.9869|0.9934|0.9934|
# |balloon   |0.8037  |0.7874|0.8811|0.8811|
# +----------+--------+------+------+------+
# |summary   |0.9012  |0.8871|0.9372|0.9372|
# +----------+--------+------+------+------+
# 32/32 - 90s - loss: 0.0690 - loss_mask: 0.0271 - loss_aux_mask: 0.0419 - ema_n_update: 314.0000 - mean_accuracy: 0.9012 - mean_iou: 0.8871 - mean_dice: 0.9372 - mean_f1: 0.9372 - learning_rate: 0.0081 - 90s/epoch - 3s/step
# Epoch 35/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9976  |0.9886|0.9943|0.9943|
# |balloon   |0.8516  |0.8201|0.9011|0.9011|
# +----------+--------+------+------+------+
# |summary   |0.9246  |0.9044|0.9477|0.9477|
# +----------+--------+------+------+------+
# 32/32 - 90s - loss: 0.0713 - loss_mask: 0.0273 - loss_aux_mask: 0.0440 - ema_n_update: 322.0000 - mean_accuracy: 0.9246 - mean_iou: 0.9044 - mean_dice: 0.9477 - mean_f1: 0.9477 - learning_rate: 0.0080 - 90s/epoch - 3s/step
# Epoch 36/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9992  |0.9878|0.9938|0.9938|
# |balloon   |0.8114  |0.8008|0.8894|0.8894|
# +----------+--------+------+------+------+
# |summary   |0.9053  |0.8943|0.9416|0.9416|
# +----------+--------+------+------+------+
# 32/32 - 90s - loss: 0.0618 - loss_mask: 0.0236 - loss_aux_mask: 0.0382 - ema_n_update: 330.0000 - mean_accuracy: 0.9053 - mean_iou: 0.8943 - mean_dice: 0.9416 - mean_f1: 0.9416 - learning_rate: 0.0078 - 90s/epoch - 3s/step
# Epoch 37/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9973  |0.9886|0.9942|0.9942|
# |balloon   |0.8559  |0.8197|0.9009|0.9009|
# +----------+--------+------+------+------+
# |summary   |0.9266  |0.9041|0.9476|0.9476|
# +----------+--------+------+------+------+
# 32/32 - 90s - loss: 0.0591 - loss_mask: 0.0224 - loss_aux_mask: 0.0367 - ema_n_update: 338.0000 - mean_accuracy: 0.9266 - mean_iou: 0.9041 - mean_dice: 0.9476 - mean_f1: 0.9476 - learning_rate: 0.0077 - 90s/epoch - 3s/step
# Epoch 38/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9994  |0.987 |0.9935|0.9935|
# |balloon   |0.7946  |0.7874|0.881 |0.881 |
# +----------+--------+------+------+------+
# |summary   |0.897   |0.8872|0.9373|0.9373|
# +----------+--------+------+------+------+
# 32/32 - 91s - loss: 0.0725 - loss_mask: 0.0300 - loss_aux_mask: 0.0424 - ema_n_update: 346.0000 - mean_accuracy: 0.8970 - mean_iou: 0.8872 - mean_dice: 0.9373 - mean_f1: 0.9373 - learning_rate: 0.0076 - 91s/epoch - 3s/step
# Epoch 39/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9985  |0.9868|0.9934|0.9934|
# |balloon   |0.808   |0.7881|0.8815|0.8815|
# +----------+--------+------+------+------+
# |summary   |0.9032  |0.8875|0.9374|0.9374|
# +----------+--------+------+------+------+
# 32/32 - 94s - loss: 0.0850 - loss_mask: 0.0353 - loss_aux_mask: 0.0497 - ema_n_update: 354.0000 - mean_accuracy: 0.9032 - mean_iou: 0.8875 - mean_dice: 0.9374 - mean_f1: 0.9374 - learning_rate: 0.0074 - 94s/epoch - 3s/step
# Epoch 40/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9988  |0.9863|0.9931|0.9931|
# |balloon   |0.7939  |0.7786|0.8755|0.8755|
# +----------+--------+------+------+------+
# |summary   |0.8963  |0.8825|0.9343|0.9343|
# +----------+--------+------+------+------+
# 32/32 - 91s - loss: 0.0704 - loss_mask: 0.0298 - loss_aux_mask: 0.0406 - ema_n_update: 362.0000 - mean_accuracy: 0.8963 - mean_iou: 0.8825 - mean_dice: 0.9343 - mean_f1: 0.9343 - learning_rate: 0.0073 - 91s/epoch - 3s/step
# Epoch 41/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.997   |0.9884|0.9941|0.9941|
# |balloon   |0.8568  |0.8174|0.8995|0.8995|
# +----------+--------+------+------+------+
# |summary   |0.9269  |0.9029|0.9468|0.9468|
# +----------+--------+------+------+------+
# 32/32 - 91s - loss: 0.0746 - loss_mask: 0.0333 - loss_aux_mask: 0.0413 - ema_n_update: 370.0000 - mean_accuracy: 0.9269 - mean_iou: 0.9029 - mean_dice: 0.9468 - mean_f1: 0.9468 - learning_rate: 0.0072 - 91s/epoch - 3s/step
# Epoch 42/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9996  |0.9871|0.9935|0.9935|
# |balloon   |0.7926  |0.7875|0.8811|0.8811|
# +----------+--------+------+------+------+
# |summary   |0.8961  |0.8873|0.9373|0.9373|
# +----------+--------+------+------+------+
# 32/32 - 93s - loss: 0.0740 - loss_mask: 0.0332 - loss_aux_mask: 0.0407 - ema_n_update: 378.0000 - mean_accuracy: 0.8961 - mean_iou: 0.8873 - mean_dice: 0.9373 - mean_f1: 0.9373 - learning_rate: 0.0070 - 93s/epoch - 3s/step
# Epoch 43/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9985  |0.9873|0.9936|0.9936|
# |balloon   |0.8141  |0.7952|0.8859|0.8859|
# +----------+--------+------+------+------+
# |summary   |0.9063  |0.8912|0.9398|0.9398|
# +----------+--------+------+------+------+
# 32/32 - 91s - loss: 0.0683 - loss_mask: 0.0310 - loss_aux_mask: 0.0373 - ema_n_update: 386.0000 - mean_accuracy: 0.9063 - mean_iou: 0.8912 - mean_dice: 0.9398 - mean_f1: 0.9398 - learning_rate: 0.0069 - 91s/epoch - 3s/step
# Epoch 44/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9977  |0.9895|0.9947|0.9947|
# |balloon   |0.8657  |0.834 |0.9095|0.9095|
# +----------+--------+------+------+------+
# |summary   |0.9317  |0.9118|0.9521|0.9521|
# +----------+--------+------+------+------+
# 32/32 - 91s - loss: 0.0465 - loss_mask: 0.0198 - loss_aux_mask: 0.0267 - ema_n_update: 394.0000 - mean_accuracy: 0.9317 - mean_iou: 0.9118 - mean_dice: 0.9521 - mean_f1: 0.9521 - learning_rate: 0.0067 - 91s/epoch - 3s/step
# Epoch 45/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9994  |0.9877|0.9938|0.9938|
# |balloon   |0.8076  |0.7992|0.8884|0.8884|
# +----------+--------+------+------+------+
# |summary   |0.9035  |0.8934|0.9411|0.9411|
# +----------+--------+------+------+------+
# 32/32 - 90s - loss: 0.0584 - loss_mask: 0.0236 - loss_aux_mask: 0.0348 - ema_n_update: 402.0000 - mean_accuracy: 0.9035 - mean_iou: 0.8934 - mean_dice: 0.9411 - mean_f1: 0.9411 - learning_rate: 0.0066 - 90s/epoch - 3s/step
# Epoch 46/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9971  |0.9895|0.9947|0.9947|
# |balloon   |0.876   |0.836 |0.9107|0.9107|
# +----------+--------+------+------+------+
# |summary   |0.9365  |0.9128|0.9527|0.9527|
# +----------+--------+------+------+------+
# 32/32 - 90s - loss: 0.0652 - loss_mask: 0.0325 - loss_aux_mask: 0.0327 - ema_n_update: 410.0000 - mean_accuracy: 0.9365 - mean_iou: 0.9128 - mean_dice: 0.9527 - mean_f1: 0.9527 - learning_rate: 0.0064 - 90s/epoch - 3s/step
# Epoch 47/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9957  |0.9882|0.9941|0.9941|
# |balloon   |0.8755  |0.8184|0.9002|0.9002|
# +----------+--------+------+------+------+
# |summary   |0.9356  |0.9033|0.9471|0.9471|
# +----------+--------+------+------+------+
# 32/32 - 92s - loss: 0.0590 - loss_mask: 0.0254 - loss_aux_mask: 0.0336 - ema_n_update: 418.0000 - mean_accuracy: 0.9356 - mean_iou: 0.9033 - mean_dice: 0.9471 - mean_f1: 0.9471 - learning_rate: 0.0063 - 92s/epoch - 3s/step
# Epoch 48/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9986  |0.989 |0.9945|0.9945|
# |balloon   |0.8421  |0.8233|0.9031|0.9031|
# +----------+--------+------+------+------+
# |summary   |0.9203  |0.9062|0.9488|0.9488|
# +----------+--------+------+------+------+
# 32/32 - 91s - loss: 0.0542 - loss_mask: 0.0223 - loss_aux_mask: 0.0319 - ema_n_update: 426.0000 - mean_accuracy: 0.9203 - mean_iou: 0.9062 - mean_dice: 0.9488 - mean_f1: 0.9488 - learning_rate: 0.0061 - 91s/epoch - 3s/step
# Epoch 49/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9993  |0.9882|0.9941|0.9941|
# |balloon   |0.8175  |0.8081|0.8939|0.8939|
# +----------+--------+------+------+------+
# |summary   |0.9084  |0.8982|0.944 |0.944 |
# +----------+--------+------+------+------+
# 32/32 - 91s - loss: 0.0567 - loss_mask: 0.0217 - loss_aux_mask: 0.0350 - ema_n_update: 434.0000 - mean_accuracy: 0.9084 - mean_iou: 0.8982 - mean_dice: 0.9440 - mean_f1: 0.9440 - learning_rate: 0.0060 - 91s/epoch - 3s/step
# Epoch 50/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9983  |0.9894|0.9947|0.9947|
# |balloon   |0.8537  |0.8307|0.9075|0.9075|
# +----------+--------+------+------+------+
# |summary   |0.926   |0.9101|0.9511|0.9511|
# +----------+--------+------+------+------+
# 32/32 - 89s - loss: 0.0477 - loss_mask: 0.0182 - loss_aux_mask: 0.0295 - ema_n_update: 442.0000 - mean_accuracy: 0.9260 - mean_iou: 0.9101 - mean_dice: 0.9511 - mean_f1: 0.9511 - learning_rate: 0.0058 - 89s/epoch - 3s/step

# %% [markdown]
# # 4. Evaluate

# %%
model_path = tfdet.dataset.util.list_dir(os.path.dirname(save_path), "h5")
model_path = sorted(model_path, key = lambda x: x.split("metric@")[1].split("-")[0], reverse = True)[0]

with device:
    x = tf.keras.layers.Input(shape = [*image_shape, 3], name = "x_true")
    feature = tfdet.model.backbone.resnet50(x)

    out = tfdet.model.detector.upernet(feature, n_class = n_class)
    model = tf.keras.Model(x, out)
    model.load_weights(model_path, by_name = True)
    
metric = tfdet.core.metric.MeanIoU(label = label)
for te_dict in test_pipe:
    x_true, mask_true = te_dict["x_true"], te_dict["mask_true"]
    mask_pred = model.predict(x_true, verbose = 0)
    metric.add(mask_true, mask_pred)
print(metric.summary_text)
# Out:
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9959  |0.9927|0.9964|0.9964|
# |balloon   |0.9486  |0.8888|0.9411|0.9411|
# +----------+--------+------+------+------+
# |summary   |0.9723  |0.9408|0.9687|0.9687|
# +----------+--------+------+------+------+

# %% [markdown]
# # 5. Visualize

# %%
import matplotlib.pyplot as plt

out = te_dataset[0] #or next(iter(tr_dataset))
x_true, y_true, bbox_true = out[:3]
mask_true = out[3] if 3 < len(out) else None

mask_pred = model.predict(np.expand_dims(x_true, axis = 0), verbose = 0)

x_true = tfdet.dataset.transform.unnormalize(x_true, mean = [123.675, 116.28, 103.53], std = [58.395, 57.12, 57.375])

fig_size = (5, 5)
plt.figure(figsize = fig_size)
plt.imshow(x_true)
plt.figure(figsize = fig_size)
plt.imshow(mask_true[..., 0])
plt.figure(figsize = fig_size)
plt.imshow(np.argmax(mask_pred[0], axis = -1))
