# %% [markdown]
# # 0. Import Library

# %%
import os
if not os.path.exists("./tfdet"):
    # !git clone -q http://github.com/burf/tfdetection.git
    # !mv ./tfdetection/tfdet ./tfdet
    # !rm -rf ./tfdetection

# %%
#ignore warning
import warnings, os
warnings.filterwarnings(action = "ignore")
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

import tfdet
#tfdet.core.util.set_seed(777) #set seed
device = tfdet.core.util.select_device(0) #set device

# %% [markdown]
# # 1. Init Dataset

# %%
import os
path = "./balloon"
if not os.path.exists(path):
    # !wget -qq --no-check-certificate http://github.com/matterport/Mask_RCNN/releases/download/v2.1/balloon_dataset.zip
    # !unzip -qq balloon_dataset.zip
print(tfdet.dataset.util.tree_dir(path))
# Out:
# balloon/
#     train/
#         605521662_a470fef77f_b.jpg
#         9330497995_4cf0438cb6_k.jpg
#         5178670692_63a4365c9c_b.jpg
#         ...
#     val/
#         4838031651_3e7b5ea5c7_b.jpg
#         16335852991_f55de7958d_k.jpg
#         24631331976_defa3bb61f_k.jpg
#         ...

# %%
import numpy as np

image_shape = [256, 256]

label = tfdet.dataset.balloon.LABEL #["background", "balloon"]
n_class = len(label)

tr_path = os.path.join(path, "train/via_region_data.json")
te_path = os.path.join(path, "val/via_region_data.json")

def mask_func(mask_true):
    return np.max(mask_true, axis = 0)

for filename in os.listdir("./"):
    name, ext = os.path.splitext(filename)
    if name in ["train_cache", "sample_cache"]:# and (ext == ".index" or ".data" in ext):
        os.remove(filename)

tr_pipe = tfdet.dataset.balloon.load_pipe(tr_path, mask = True)
tr_pipe = tfdet.dataset.pipeline.load(tr_pipe, mask_func = mask_func)
tr_pipe = tfdet.dataset.pipeline.args2dict(tr_pipe)
if True: #If the number of training data is small, it is better to apply weak augmentation without spatial transform, or offline augmentation.
    tr_pipe = tfdet.dataset.pipeline.weak_augmentation(tr_pipe.cache("./train_cache"), crop_shape = None) #If crop_shape is shape or ratio, apply random_crop.
    tr_pipe = tfdet.dataset.pipeline.resize(tr_pipe, image_shape = image_shape, keep_ratio = True)
elif True:
    #tr_pipe = tfdet.dataset.pipeline.albumentations(tr_pipe)
    #tr_pipe = tfdet.dataset.pipeline.mmdet_augmentation(tr_pipe.cache("./train_cache"), image_shape = [int(min(image_shape) * 0.1), int(max(image_shape) * 2)], crop_shape = image_shape, resize_mode = "range", keep_ratio = True, shape_divisor = 32)
    tr_pipe = tfdet.dataset.pipeline.mmdet_augmentation(tr_pipe.cache("./train_cache"), image_shape = image_shape, crop_shape = None, keep_ratio = True, shape_divisor = 32)
else:
    tr_pipe = tfdet.dataset.pipeline.resize(tr_pipe, image_shape = image_shape, keep_ratio = True)
    tr_pipe = tfdet.dataset.pipeline.yolo_augmentation(tr_pipe.cache("./train_cache"), sample_x_true = tr_pipe.cache("./sample_cache"), p_mix_up = 0.15, p_copy_paste = 0.)
tr_pipe = tfdet.dataset.pipeline.pad(tr_pipe, image_shape = image_shape, mode = "both")
tr_pipe = tfdet.dataset.pipeline.filter_annotation(tr_pipe, min_scale = 2, min_instance_area = 1)
tr_pipe = tfdet.dataset.pipeline.collect(tr_pipe, keys = ["x_true", "mask_true"])
tr_pipe = tfdet.dataset.pipeline.label_encode(tr_pipe, label = tfdet.dataset.balloon.LABEL, one_hot = True, label_smoothing = 0)
tr_pipe = tfdet.dataset.pipeline.normalize(tr_pipe, mean = [123.675, 116.28, 103.53], std = [58.395, 57.12, 57.375])
tr_pipe = tfdet.dataset.pipeline.cast(tr_pipe)

te_pipe = tfdet.dataset.balloon.load_pipe(te_path, mask = True)
te_pipe = tfdet.dataset.pipeline.load(te_pipe, mask_func = mask_func)
te_pipe = tfdet.dataset.pipeline.args2dict(te_pipe)
te_pipe = tfdet.dataset.pipeline.resize(te_pipe, image_shape = image_shape, keep_ratio = True)
te_pipe = tfdet.dataset.pipeline.pad(te_pipe, image_shape = image_shape, mode = "both")
te_pipe = tfdet.dataset.pipeline.filter_annotation(te_pipe, min_scale = 2, min_instance_area = 1)
te_pipe = tfdet.dataset.pipeline.collect(te_pipe, keys = ["x_true", "mask_true"])
te_pipe = tfdet.dataset.pipeline.label_encode(te_pipe, label = tfdet.dataset.balloon.LABEL, one_hot = True, label_smoothing = 0)
te_pipe = tfdet.dataset.pipeline.normalize(te_pipe, mean = [123.675, 116.28, 103.53], std = [58.395, 57.12, 57.375])
te_pipe = tfdet.dataset.pipeline.cast(te_pipe)

# %% [markdown]
# # 2. Build Detector

# %%
with device:
    x = tf.keras.layers.Input(shape = [*image_shape, 3], name = "x_true")
    feature = tfdet.model.backbone.resnet50(x, weights = "imagenet")
    
    out = tfdet.model.detector.upernet(feature, n_class = n_class)
    out = tf.keras.layers.UpSampling2D((4, 4))(out)
    model = tf.keras.Model(x, out)
    model.add_loss(lambda: tf.reduce_sum(tfdet.core.loss.regularize(model, weight_decay = 1e-4), name = "regularize_loss"))

# %% [markdown]
# # 3.Train

# %% [markdown]
# 3-0. Init HyperParameter

# %%
import os, shutil

#epoch = 300
epoch = 50
train_batch_size = 4
batch_size = 16
save_path = "./learn/epoch@{epoch:03d}-metric@{mean_iou:.4f}-loss@{loss:.4f}-val_loss@{val_loss:.4f}.h5"

learning_rate = 1e-2
dst_learning_rate = 1e-4
momentum = 0.9
nesterov = True
warm_up_epoch = 5

if os.path.exists(os.path.dirname(save_path)):
    shutil.rmtree(os.path.dirname(save_path))
os.makedirs(os.path.dirname(save_path), exist_ok = True)

train_pipe = tfdet.dataset.pipeline.dict2args(tr_pipe, batch_size = train_batch_size, shuffle = True, prefetch = True)
test_pipe = tfdet.dataset.pipeline.dict2args(te_pipe, batch_size = batch_size, prefetch = True)

metric = tfdet.callback.MeanIoU(test_pipe, label = label, name = "mean_iou")
save = tf.keras.callbacks.ModelCheckpoint(save_path, monitor = "mean_iou", mode = "max", save_best_only = True, save_weights_only = True, save_freq = "epoch", verbose = 0)
scheduler = tfdet.callback.WarmUpCosineLearningRateScheduler(cycle = epoch, decay_rate = dst_learning_rate / learning_rate, total_step = None, warm_up_epoch = warm_up_epoch) #total step None > dynamic total step
logger = tf.keras.callbacks.CSVLogger(os.path.join(os.path.dirname(save_path), "logger.csv"), separator = ",")

# %% [markdown]
# 3-1. Default

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate, momentum = momentum, nesterov = nesterov)
model.compile(loss = tf.keras.losses.categorical_crossentropy, optimizer = optimizer)

with device:
    model.fit(train_pipe.repeat(8), validation_data = test_pipe, epochs = epoch, callbacks = [metric, save, scheduler, logger], verbose = 2)
    
for filename in os.listdir("./"):
    name, ext = os.path.splitext(filename)
    if name in ["train_cache", "sample_cache"]:# and (ext == ".index" or ".data" in ext):
        os.remove(filename)
# Out:
# Epoch 1/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.2358  |0.2333|0.3783|0.3783|
# |balloon   |0.8184  |0.0595|0.1122|0.1122|
# +----------+--------+------+------+------+
# |summary   |0.5271  |0.1464|0.2453|0.2453|
# +----------+--------+------+------+------+
# 32/32 - 186s - loss: 0.6655 - val_loss: 0.9194 - mean_accuracy: 0.5271 - mean_iou: 0.1464 - mean_dice: 0.2453 - mean_f1: 0.2453 - learning_rate: 6.6000e-05 - 186s/epoch - 6s/step
# Epoch 2/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.8674  |0.8561|0.9225|0.9225|
# |balloon   |0.7786  |0.2422|0.39  |0.39  |
# +----------+--------+------+------+------+
# |summary   |0.823   |0.5491|0.6562|0.6562|
# +----------+--------+------+------+------+
# 32/32 - 144s - loss: 0.2398 - val_loss: 0.4194 - mean_accuracy: 0.8230 - mean_iou: 0.5491 - mean_dice: 0.6562 - mean_f1: 0.6562 - learning_rate: 0.0039 - 144s/epoch - 4s/step
# Epoch 3/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9673  |0.9477|0.9731|0.9731|
# |balloon   |0.6535  |0.4227|0.5942|0.5942|
# +----------+--------+------+------+------+
# |summary   |0.8104  |0.6852|0.7837|0.7837|
# +----------+--------+------+------+------+
# 32/32 - 144s - loss: 0.0690 - val_loss: 0.2185 - mean_accuracy: 0.8104 - mean_iou: 0.6852 - mean_dice: 0.7837 - mean_f1: 0.7837 - learning_rate: 0.0059 - 144s/epoch - 5s/step
# Epoch 4/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9965  |0.9648|0.9821|0.9821|
# |balloon   |0.4502  |0.4255|0.597 |0.597 |
# +----------+--------+------+------+------+
# |summary   |0.7234  |0.6952|0.7895|0.7895|
# +----------+--------+------+------+------+
# 32/32 - 145s - loss: 0.0499 - val_loss: 0.1167 - mean_accuracy: 0.7234 - mean_iou: 0.6952 - mean_dice: 0.7895 - mean_f1: 0.7895 - learning_rate: 0.0079 - 145s/epoch - 5s/step
# Epoch 5/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9973  |0.9662|0.9828|0.9828|
# |balloon   |0.4625  |0.4428|0.6138|0.6138|
# +----------+--------+------+------+------+
# |summary   |0.7299  |0.7045|0.7983|0.7983|
# +----------+--------+------+------+------+
# 32/32 - 145s - loss: 0.0413 - val_loss: 0.0985 - mean_accuracy: 0.7299 - mean_iou: 0.7045 - mean_dice: 0.7983 - mean_f1: 0.7983 - learning_rate: 0.0099 - 145s/epoch - 5s/step
# Epoch 6/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9978  |0.9684|0.984 |0.984 |
# |balloon   |0.4938  |0.4762|0.6451|0.6451|
# +----------+--------+------+------+------+
# |summary   |0.7458  |0.7223|0.8146|0.8146|
# +----------+--------+------+------+------+
# 32/32 - 146s - loss: 0.0338 - val_loss: 0.0857 - mean_accuracy: 0.7458 - mean_iou: 0.7223 - mean_dice: 0.8146 - mean_f1: 0.8146 - learning_rate: 0.0100 - 146s/epoch - 5s/step
# Epoch 7/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9974  |0.9724|0.986 |0.986 |
# |balloon   |0.5704  |0.547 |0.7072|0.7072|
# +----------+--------+------+------+------+
# |summary   |0.7839  |0.7597|0.8466|0.8466|
# +----------+--------+------+------+------+
# 32/32 - 146s - loss: 0.0313 - val_loss: 0.0728 - mean_accuracy: 0.7839 - mean_iou: 0.7597 - mean_dice: 0.8466 - mean_f1: 0.8466 - learning_rate: 0.0100 - 146s/epoch - 5s/step
# Epoch 8/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9986  |0.9668|0.9831|0.9831|
# |balloon   |0.4506  |0.4406|0.6117|0.6117|
# +----------+--------+------+------+------+
# |summary   |0.7246  |0.7037|0.7974|0.7974|
# +----------+--------+------+------+------+
# 32/32 - 144s - loss: 0.0278 - val_loss: 0.0868 - mean_accuracy: 0.7246 - mean_iou: 0.7037 - mean_dice: 0.7974 - mean_f1: 0.7974 - learning_rate: 0.0100 - 144s/epoch - 5s/step
# Epoch 9/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9984  |0.9737|0.9867|0.9867|
# |balloon   |0.5763  |0.5609|0.7187|0.7187|
# +----------+--------+------+------+------+
# |summary   |0.7873  |0.7673|0.8527|0.8527|
# +----------+--------+------+------+------+
# 32/32 - 144s - loss: 0.0259 - val_loss: 0.0728 - mean_accuracy: 0.7873 - mean_iou: 0.7673 - mean_dice: 0.8527 - mean_f1: 0.8527 - learning_rate: 0.0099 - 144s/epoch - 5s/step
# Epoch 10/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9982  |0.978 |0.9889|0.9889|
# |balloon   |0.6556  |0.6365|0.7779|0.7779|
# +----------+--------+------+------+------+
# |summary   |0.8269  |0.8073|0.8834|0.8834|
# +----------+--------+------+------+------+
# 32/32 - 144s - loss: 0.0253 - val_loss: 0.0623 - mean_accuracy: 0.8269 - mean_iou: 0.8073 - mean_dice: 0.8834 - mean_f1: 0.8834 - learning_rate: 0.0098 - 144s/epoch - 5s/step
# Epoch 11/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9986  |0.9786|0.9892|0.9892|
# |balloon   |0.6573  |0.6428|0.7826|0.7826|
# +----------+--------+------+------+------+
# |summary   |0.828   |0.8107|0.8859|0.8859|
# +----------+--------+------+------+------+
# 32/32 - 145s - loss: 0.0244 - val_loss: 0.0605 - mean_accuracy: 0.8280 - mean_iou: 0.8107 - mean_dice: 0.8859 - mean_f1: 0.8859 - learning_rate: 0.0098 - 145s/epoch - 5s/step
# Epoch 12/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9982  |0.9821|0.991 |0.991 |
# |balloon   |0.7275  |0.7059|0.8276|0.8276|
# +----------+--------+------+------+------+
# |summary   |0.8628  |0.844 |0.9093|0.9093|
# +----------+--------+------+------+------+
# 32/32 - 143s - loss: 0.0229 - val_loss: 0.0521 - mean_accuracy: 0.8628 - mean_iou: 0.8440 - mean_dice: 0.9093 - mean_f1: 0.9093 - learning_rate: 0.0097 - 143s/epoch - 4s/step
# Epoch 13/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.998   |0.9845|0.9922|0.9922|
# |balloon   |0.7724  |0.7469|0.8551|0.8551|
# +----------+--------+------+------+------+
# |summary   |0.8852  |0.8657|0.9237|0.9237|
# +----------+--------+------+------+------+
# 32/32 - 145s - loss: 0.0221 - val_loss: 0.0463 - mean_accuracy: 0.8852 - mean_iou: 0.8657 - mean_dice: 0.9237 - mean_f1: 0.9237 - learning_rate: 0.0095 - 145s/epoch - 5s/step
# Epoch 14/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9977  |0.9858|0.9929|0.9929|
# |balloon   |0.7983  |0.769 |0.8694|0.8694|
# +----------+--------+------+------+------+
# |summary   |0.898   |0.8774|0.9311|0.9311|
# +----------+--------+------+------+------+
# 32/32 - 145s - loss: 0.0211 - val_loss: 0.0424 - mean_accuracy: 0.8980 - mean_iou: 0.8774 - mean_dice: 0.9311 - mean_f1: 0.9311 - learning_rate: 0.0094 - 145s/epoch - 5s/step
# Epoch 15/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9977  |0.9863|0.9931|0.9931|
# |balloon   |0.8072  |0.7777|0.8749|0.8749|
# +----------+--------+------+------+------+
# |summary   |0.9025  |0.882 |0.934 |0.934 |
# +----------+--------+------+------+------+
# 32/32 - 145s - loss: 0.0210 - val_loss: 0.0407 - mean_accuracy: 0.9025 - mean_iou: 0.8820 - mean_dice: 0.9340 - mean_f1: 0.9340 - learning_rate: 0.0092 - 145s/epoch - 5s/step
# Epoch 16/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9974  |0.9876|0.9937|0.9937|
# |balloon   |0.8337  |0.799 |0.8883|0.8883|
# +----------+--------+------+------+------+
# |summary   |0.9155  |0.8933|0.941 |0.941 |
# +----------+--------+------+------+------+
# 32/32 - 147s - loss: 0.0208 - val_loss: 0.0364 - mean_accuracy: 0.9155 - mean_iou: 0.8933 - mean_dice: 0.9410 - mean_f1: 0.9410 - learning_rate: 0.0091 - 147s/epoch - 5s/step
# Epoch 17/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9977  |0.9881|0.994 |0.994 |
# |balloon   |0.8377  |0.8062|0.8927|0.8927|
# +----------+--------+------+------+------+
# |summary   |0.9177  |0.8972|0.9434|0.9434|
# +----------+--------+------+------+------+
# 32/32 - 143s - loss: 0.0209 - val_loss: 0.0348 - mean_accuracy: 0.9177 - mean_iou: 0.8972 - mean_dice: 0.9434 - mean_f1: 0.9434 - learning_rate: 0.0089 - 143s/epoch - 4s/step
# Epoch 18/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9973  |0.9887|0.9943|0.9943|
# |balloon   |0.8551  |0.818 |0.8999|0.8999|
# +----------+--------+------+------+------+
# |summary   |0.9262  |0.9033|0.9471|0.9471|
# +----------+--------+------+------+------+
# 32/32 - 143s - loss: 0.0203 - val_loss: 0.0328 - mean_accuracy: 0.9262 - mean_iou: 0.9033 - mean_dice: 0.9471 - mean_f1: 0.9471 - learning_rate: 0.0087 - 143s/epoch - 4s/step
# Epoch 19/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9977  |0.9892|0.9946|0.9946|
# |balloon   |0.8566  |0.8249|0.904 |0.904 |
# +----------+--------+------+------+------+
# |summary   |0.9271  |0.907 |0.9493|0.9493|
# +----------+--------+------+------+------+
# 32/32 - 144s - loss: 0.0199 - val_loss: 0.0322 - mean_accuracy: 0.9271 - mean_iou: 0.9070 - mean_dice: 0.9493 - mean_f1: 0.9493 - learning_rate: 0.0084 - 144s/epoch - 5s/step
# Epoch 20/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9973  |0.9899|0.9949|0.9949|
# |balloon   |0.874   |0.8369|0.9112|0.9112|
# +----------+--------+------+------+------+
# |summary   |0.9357  |0.9134|0.9531|0.9531|
# +----------+--------+------+------+------+
# 32/32 - 145s - loss: 0.0191 - val_loss: 0.0298 - mean_accuracy: 0.9357 - mean_iou: 0.9134 - mean_dice: 0.9531 - mean_f1: 0.9531 - learning_rate: 0.0082 - 145s/epoch - 5s/step
# Epoch 21/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9974  |0.9904|0.9952|0.9952|
# |balloon   |0.8823  |0.845 |0.916 |0.916 |
# +----------+--------+------+------+------+
# |summary   |0.9398  |0.9177|0.9556|0.9556|
# +----------+--------+------+------+------+
# 32/32 - 145s - loss: 0.0190 - val_loss: 0.0281 - mean_accuracy: 0.9398 - mean_iou: 0.9177 - mean_dice: 0.9556 - mean_f1: 0.9556 - learning_rate: 0.0080 - 145s/epoch - 5s/step
# Epoch 22/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9973  |0.9906|0.9953|0.9953|
# |balloon   |0.8878  |0.8494|0.9186|0.9186|
# +----------+--------+------+------+------+
# |summary   |0.9425  |0.92  |0.9569|0.9569|
# +----------+--------+------+------+------+
# 32/32 - 145s - loss: 0.0189 - val_loss: 0.0278 - mean_accuracy: 0.9425 - mean_iou: 0.9200 - mean_dice: 0.9569 - mean_f1: 0.9569 - learning_rate: 0.0077 - 145s/epoch - 5s/step
# Epoch 23/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9976  |0.9904|0.9952|0.9952|
# |balloon   |0.879   |0.8447|0.9158|0.9158|
# +----------+--------+------+------+------+
# |summary   |0.9383  |0.9175|0.9555|0.9555|
# +----------+--------+------+------+------+
# 32/32 - 150s - loss: 0.0191 - val_loss: 0.0287 - mean_accuracy: 0.9383 - mean_iou: 0.9175 - mean_dice: 0.9555 - mean_f1: 0.9555 - learning_rate: 0.0074 - 150s/epoch - 5s/step
# Epoch 24/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9972  |0.9908|0.9954|0.9954|
# |balloon   |0.8919  |0.8518|0.92  |0.92  |
# +----------+--------+------+------+------+
# |summary   |0.9445  |0.9213|0.9577|0.9577|
# +----------+--------+------+------+------+
# 32/32 - 143s - loss: 0.0187 - val_loss: 0.0263 - mean_accuracy: 0.9445 - mean_iou: 0.9213 - mean_dice: 0.9577 - mean_f1: 0.9577 - learning_rate: 0.0072 - 143s/epoch - 4s/step
# Epoch 25/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9966  |0.9909|0.9954|0.9954|
# |balloon   |0.905   |0.856 |0.9224|0.9224|
# +----------+--------+------+------+------+
# |summary   |0.9508  |0.9235|0.9589|0.9589|
# +----------+--------+------+------+------+
# 32/32 - 144s - loss: 0.0187 - val_loss: 0.0258 - mean_accuracy: 0.9508 - mean_iou: 0.9235 - mean_dice: 0.9589 - mean_f1: 0.9589 - learning_rate: 0.0069 - 144s/epoch - 4s/step
# Epoch 26/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9965  |0.9911|0.9955|0.9955|
# |balloon   |0.9088  |0.8591|0.9242|0.9242|
# +----------+--------+------+------+------+
# |summary   |0.9526  |0.9251|0.9599|0.9599|
# +----------+--------+------+------+------+
# 32/32 - 144s - loss: 0.0177 - val_loss: 0.0251 - mean_accuracy: 0.9526 - mean_iou: 0.9251 - mean_dice: 0.9599 - mean_f1: 0.9599 - learning_rate: 0.0066 - 144s/epoch - 5s/step
# Epoch 27/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9965  |0.9911|0.9955|0.9955|
# |balloon   |0.9097  |0.8592|0.9242|0.9242|
# +----------+--------+------+------+------+
# |summary   |0.9531  |0.9251|0.9599|0.9599|
# +----------+--------+------+------+------+
# 32/32 - 146s - loss: 0.0184 - val_loss: 0.0247 - mean_accuracy: 0.9531 - mean_iou: 0.9251 - mean_dice: 0.9599 - mean_f1: 0.9599 - learning_rate: 0.0063 - 146s/epoch - 5s/step
# Epoch 28/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9965  |0.9911|0.9955|0.9955|
# |balloon   |0.9095  |0.8591|0.9242|0.9242|
# +----------+--------+------+------+------+
# |summary   |0.953   |0.9251|0.9599|0.9599|
# +----------+--------+------+------+------+
# 32/32 - 150s - loss: 0.0179 - val_loss: 0.0246 - mean_accuracy: 0.9530 - mean_iou: 0.9251 - mean_dice: 0.9599 - mean_f1: 0.9599 - learning_rate: 0.0060 - 150s/epoch - 5s/step
# Epoch 29/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.996   |0.9911|0.9955|0.9955|
# |balloon   |0.917   |0.86  |0.9247|0.9247|
# +----------+--------+------+------+------+
# |summary   |0.9565  |0.9256|0.9601|0.9601|
# +----------+--------+------+------+------+
# 32/32 - 151s - loss: 0.0176 - val_loss: 0.0244 - mean_accuracy: 0.9565 - mean_iou: 0.9256 - mean_dice: 0.9601 - mean_f1: 0.9601 - learning_rate: 0.0057 - 151s/epoch - 5s/step
# Epoch 30/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9962  |0.9911|0.9955|0.9955|
# |balloon   |0.9149  |0.8597|0.9246|0.9246|
# +----------+--------+------+------+------+
# |summary   |0.9555  |0.9254|0.96  |0.96  |
# +----------+--------+------+------+------+
# 32/32 - 143s - loss: 0.0174 - val_loss: 0.0245 - mean_accuracy: 0.9555 - mean_iou: 0.9254 - mean_dice: 0.9600 - mean_f1: 0.9600 - learning_rate: 0.0054 - 143s/epoch - 4s/step
# Epoch 31/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.996   |0.9911|0.9955|0.9955|
# |balloon   |0.9166  |0.8592|0.9243|0.9243|
# +----------+--------+------+------+------+
# |summary   |0.9563  |0.9251|0.9599|0.9599|
# +----------+--------+------+------+------+
# 32/32 - 146s - loss: 0.0171 - val_loss: 0.0246 - mean_accuracy: 0.9563 - mean_iou: 0.9251 - mean_dice: 0.9599 - mean_f1: 0.9599 - learning_rate: 0.0050 - 146s/epoch - 5s/step
# Epoch 32/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9964  |0.9911|0.9955|0.9955|
# |balloon   |0.9102  |0.8588|0.924 |0.924 |
# +----------+--------+------+------+------+
# |summary   |0.9533  |0.9249|0.9598|0.9598|
# +----------+--------+------+------+------+
# 32/32 - 143s - loss: 0.0178 - val_loss: 0.0248 - mean_accuracy: 0.9533 - mean_iou: 0.9249 - mean_dice: 0.9598 - mean_f1: 0.9598 - learning_rate: 0.0047 - 143s/epoch - 4s/step
# Epoch 33/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9964  |0.991 |0.9955|0.9955|
# |balloon   |0.9103  |0.8581|0.9236|0.9236|
# +----------+--------+------+------+------+
# |summary   |0.9533  |0.9246|0.9596|0.9596|
# +----------+--------+------+------+------+
# 32/32 - 144s - loss: 0.0172 - val_loss: 0.0250 - mean_accuracy: 0.9533 - mean_iou: 0.9246 - mean_dice: 0.9596 - mean_f1: 0.9596 - learning_rate: 0.0044 - 144s/epoch - 5s/step
# Epoch 34/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9961  |0.991 |0.9955|0.9955|
# |balloon   |0.9144  |0.8579|0.9235|0.9235|
# +----------+--------+------+------+------+
# |summary   |0.9552  |0.9245|0.9595|0.9595|
# +----------+--------+------+------+------+
# 32/32 - 146s - loss: 0.0173 - val_loss: 0.0249 - mean_accuracy: 0.9552 - mean_iou: 0.9245 - mean_dice: 0.9595 - mean_f1: 0.9595 - learning_rate: 0.0041 - 146s/epoch - 5s/step
# Epoch 35/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.996   |0.9909|0.9954|0.9954|
# |balloon   |0.914   |0.857 |0.923 |0.923 |
# +----------+--------+------+------+------+
# |summary   |0.955   |0.924 |0.9592|0.9592|
# +----------+--------+------+------+------+
# 32/32 - 144s - loss: 0.0172 - val_loss: 0.0250 - mean_accuracy: 0.9550 - mean_iou: 0.9240 - mean_dice: 0.9592 - mean_f1: 0.9592 - learning_rate: 0.0038 - 144s/epoch - 4s/step
# Epoch 36/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9962  |0.991 |0.9955|0.9955|
# |balloon   |0.9118  |0.8577|0.9234|0.9234|
# +----------+--------+------+------+------+
# |summary   |0.954   |0.9243|0.9594|0.9594|
# +----------+--------+------+------+------+
# 32/32 - 143s - loss: 0.0171 - val_loss: 0.0250 - mean_accuracy: 0.9540 - mean_iou: 0.9243 - mean_dice: 0.9594 - mean_f1: 0.9594 - learning_rate: 0.0035 - 143s/epoch - 4s/step
# Epoch 37/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9965  |0.991 |0.9955|0.9955|
# |balloon   |0.9069  |0.8567|0.9228|0.9228|
# +----------+--------+------+------+------+
# |summary   |0.9517  |0.9239|0.9592|0.9592|
# +----------+--------+------+------+------+
# 32/32 - 144s - loss: 0.0170 - val_loss: 0.0250 - mean_accuracy: 0.9517 - mean_iou: 0.9239 - mean_dice: 0.9592 - mean_f1: 0.9592 - learning_rate: 0.0032 - 144s/epoch - 5s/step
# Epoch 38/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9958  |0.991 |0.9955|0.9955|
# |balloon   |0.92    |0.8594|0.9244|0.9244|
# +----------+--------+------+------+------+
# |summary   |0.9579  |0.9252|0.9599|0.9599|
# +----------+--------+------+------+------+
# 32/32 - 144s - loss: 0.0168 - val_loss: 0.0246 - mean_accuracy: 0.9579 - mean_iou: 0.9252 - mean_dice: 0.9599 - mean_f1: 0.9599 - learning_rate: 0.0029 - 144s/epoch - 4s/step
# Epoch 39/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9962  |0.9911|0.9955|0.9955|
# |balloon   |0.9134  |0.8592|0.9243|0.9243|
# +----------+--------+------+------+------+
# |summary   |0.9548  |0.9251|0.9599|0.9599|
# +----------+--------+------+------+------+
# 32/32 - 145s - loss: 0.0174 - val_loss: 0.0246 - mean_accuracy: 0.9548 - mean_iou: 0.9251 - mean_dice: 0.9599 - mean_f1: 0.9599 - learning_rate: 0.0027 - 145s/epoch - 5s/step
# Epoch 40/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9961  |0.991 |0.9955|0.9955|
# |balloon   |0.914   |0.8587|0.924 |0.924 |
# +----------+--------+------+------+------+
# |summary   |0.9551  |0.9249|0.9597|0.9597|
# +----------+--------+------+------+------+
# 32/32 - 143s - loss: 0.0172 - val_loss: 0.0247 - mean_accuracy: 0.9551 - mean_iou: 0.9249 - mean_dice: 0.9597 - mean_f1: 0.9597 - learning_rate: 0.0024 - 143s/epoch - 4s/step
# Epoch 41/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9961  |0.9911|0.9955|0.9955|
# |balloon   |0.9152  |0.8594|0.9244|0.9244|
# +----------+--------+------+------+------+
# |summary   |0.9557  |0.9252|0.9599|0.9599|
# +----------+--------+------+------+------+
# 32/32 - 143s - loss: 0.0173 - val_loss: 0.0247 - mean_accuracy: 0.9557 - mean_iou: 0.9252 - mean_dice: 0.9599 - mean_f1: 0.9599 - learning_rate: 0.0021 - 143s/epoch - 4s/step
# Epoch 42/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9963  |0.9911|0.9955|0.9955|
# |balloon   |0.9118  |0.8586|0.9239|0.9239|
# +----------+--------+------+------+------+
# |summary   |0.9541  |0.9248|0.9597|0.9597|
# +----------+--------+------+------+------+
# 32/32 - 144s - loss: 0.0171 - val_loss: 0.0250 - mean_accuracy: 0.9541 - mean_iou: 0.9248 - mean_dice: 0.9597 - mean_f1: 0.9597 - learning_rate: 0.0019 - 144s/epoch - 4s/step
# Epoch 43/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9961  |0.9911|0.9955|0.9955|
# |balloon   |0.916   |0.8602|0.9248|0.9248|
# +----------+--------+------+------+------+
# |summary   |0.956   |0.9256|0.9602|0.9602|
# +----------+--------+------+------+------+
# 32/32 - 146s - loss: 0.0168 - val_loss: 0.0246 - mean_accuracy: 0.9560 - mean_iou: 0.9256 - mean_dice: 0.9602 - mean_f1: 0.9602 - learning_rate: 0.0017 - 146s/epoch - 5s/step
# Epoch 44/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9959  |0.9911|0.9955|0.9955|
# |balloon   |0.9185  |0.86  |0.9247|0.9247|
# +----------+--------+------+------+------+
# |summary   |0.9572  |0.9255|0.9601|0.9601|
# +----------+--------+------+------+------+
# 32/32 - 143s - loss: 0.0167 - val_loss: 0.0245 - mean_accuracy: 0.9572 - mean_iou: 0.9255 - mean_dice: 0.9601 - mean_f1: 0.9601 - learning_rate: 0.0014 - 143s/epoch - 4s/step
# Epoch 45/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9959  |0.9911|0.9955|0.9955|
# |balloon   |0.9196  |0.8606|0.9251|0.9251|
# +----------+--------+------+------+------+
# |summary   |0.9577  |0.9259|0.9603|0.9603|
# +----------+--------+------+------+------+
# 32/32 - 144s - loss: 0.0169 - val_loss: 0.0245 - mean_accuracy: 0.9577 - mean_iou: 0.9259 - mean_dice: 0.9603 - mean_f1: 0.9603 - learning_rate: 0.0012 - 144s/epoch - 4s/step
# Epoch 46/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9961  |0.9911|0.9955|0.9955|
# |balloon   |0.9159  |0.8597|0.9246|0.9246|
# +----------+--------+------+------+------+
# |summary   |0.956   |0.9254|0.9601|0.9601|
# +----------+--------+------+------+------+
# 32/32 - 144s - loss: 0.0169 - val_loss: 0.0245 - mean_accuracy: 0.9560 - mean_iou: 0.9254 - mean_dice: 0.9601 - mean_f1: 0.9601 - learning_rate: 0.0010 - 144s/epoch - 4s/step
# Epoch 47/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9961  |0.9912|0.9956|0.9956|
# |balloon   |0.9174  |0.8607|0.9252|0.9252|
# +----------+--------+------+------+------+
# |summary   |0.9567  |0.926 |0.9604|0.9604|
# +----------+--------+------+------+------+
# 32/32 - 144s - loss: 0.0167 - val_loss: 0.0245 - mean_accuracy: 0.9567 - mean_iou: 0.9260 - mean_dice: 0.9604 - mean_f1: 0.9604 - learning_rate: 8.7058e-04 - 144s/epoch - 4s/step
# Epoch 48/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.996   |0.9912|0.9956|0.9956|
# |balloon   |0.9189  |0.8615|0.9256|0.9256|
# +----------+--------+------+------+------+
# |summary   |0.9575  |0.9264|0.9606|0.9606|
# +----------+--------+------+------+------+
# 32/32 - 143s - loss: 0.0170 - val_loss: 0.0245 - mean_accuracy: 0.9575 - mean_iou: 0.9264 - mean_dice: 0.9606 - mean_f1: 0.9606 - learning_rate: 7.1228e-04 - 143s/epoch - 4s/step
# Epoch 49/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9961  |0.9912|0.9956|0.9956|
# |balloon   |0.9174  |0.8608|0.9252|0.9252|
# +----------+--------+------+------+------+
# |summary   |0.9567  |0.926 |0.9604|0.9604|
# +----------+--------+------+------+------+
# 32/32 - 144s - loss: 0.0167 - val_loss: 0.0246 - mean_accuracy: 0.9567 - mean_iou: 0.9260 - mean_dice: 0.9604 - mean_f1: 0.9604 - learning_rate: 5.7111e-04 - 144s/epoch - 4s/step
# Epoch 50/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9962  |0.9912|0.9956|0.9956|
# |balloon   |0.9159  |0.8606|0.925 |0.925 |
# +----------+--------+------+------+------+
# |summary   |0.956   |0.9259|0.9603|0.9603|
# +----------+--------+------+------+------+
# 32/32 - 142s - loss: 0.0166 - val_loss: 0.0245 - mean_accuracy: 0.9560 - mean_iou: 0.9259 - mean_dice: 0.9603 - mean_f1: 0.9603 - learning_rate: 4.4761e-04 - 142s/epoch - 4s/step

# %% [markdown]
# 3-2. Stochastic Weight Averaging(SWA)

# %%
import traceback

optimizer = tf.keras.optimizers.SGD(learning_rate, momentum = momentum, nesterov = nesterov)
try:
    # !pip install tensorflow_addons
    import tensorflow_addons as tfa
    #optimizer = tfa.optimizers.SGDW(learning_rate = learning_rate, weight_decay = 1e-4, momentum = momentum, nesterov = nesterov)
    optimizer = tfa.optimizers.SWA(optimizer, start_averaging = epoch // 3, average_period = epoch // 10)
except:
    print(traceback.format_exc())
model.compile(loss = tf.keras.losses.categorical_crossentropy, optimizer = optimizer)

with device:
    model.fit(train_pipe.repeat(8), validation_data = test_pipe, epochs = epoch, callbacks = [metric, save, scheduler, logger], verbose = 2)
    
for filename in os.listdir("./"):
    name, ext = os.path.splitext(filename)
    if name in ["train_cache", "sample_cache"]:# and (ext == ".index" or ".data" in ext):
        os.remove(filename)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow_addons
#   Using cached tensorflow_addons-0.18.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tensorflow_addons) (21.3)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow_addons) (2.7.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tensorflow_addons) (3.0.9)
# Installing collected packages: tensorflow-addons
# Successfully installed tensorflow-addons-0.18.0
# Epoch 1/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.2951  |0.2941|0.4546|0.4546|
# |balloon   |0.9437  |0.0739|0.1376|0.1376|
# +----------+--------+------+------+------+
# |summary   |0.6194  |0.184 |0.2961|0.2961|
# +----------+--------+------+------+------+
# 32/32 - 191s - loss: 0.7924 - val_loss: 0.8305 - mean_accuracy: 0.6194 - mean_iou: 0.1840 - mean_dice: 0.2961 - mean_f1: 0.2961 - learning_rate: 6.6000e-05 - 191s/epoch - 6s/step
# Epoch 2/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9647  |0.9486|0.9736|0.9736|
# |balloon   |0.7153  |0.4502|0.6209|0.6209|
# +----------+--------+------+------+------+
# |summary   |0.84    |0.6994|0.7972|0.7972|
# +----------+--------+------+------+------+
# 32/32 - 139s - loss: 0.2961 - val_loss: 0.3595 - mean_accuracy: 0.8400 - mean_iou: 0.6994 - mean_dice: 0.7972 - mean_f1: 0.7972 - learning_rate: 0.0039 - 139s/epoch - 4s/step
# Epoch 3/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9598  |0.947 |0.9728|0.9728|
# |balloon   |0.7728  |0.4626|0.6325|0.6325|
# +----------+--------+------+------+------+
# |summary   |0.8663  |0.7048|0.8026|0.8026|
# +----------+--------+------+------+------+
# 32/32 - 142s - loss: 0.0720 - val_loss: 0.2369 - mean_accuracy: 0.8663 - mean_iou: 0.7048 - mean_dice: 0.8026 - mean_f1: 0.8026 - learning_rate: 0.0059 - 142s/epoch - 4s/step
# Epoch 4/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.992   |0.973 |0.9863|0.9863|
# |balloon   |0.6726  |0.5936|0.745 |0.745 |
# +----------+--------+------+------+------+
# |summary   |0.8323  |0.7833|0.8657|0.8657|
# +----------+--------+------+------+------+
# 32/32 - 142s - loss: 0.0510 - val_loss: 0.1075 - mean_accuracy: 0.8323 - mean_iou: 0.7833 - mean_dice: 0.8657 - mean_f1: 0.8657 - learning_rate: 0.0079 - 142s/epoch - 4s/step
# Epoch 5/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.997   |0.9751|0.9874|0.9874|
# |balloon   |0.6249  |0.5951|0.7461|0.7461|
# +----------+--------+------+------+------+
# |summary   |0.8109  |0.7851|0.8668|0.8668|
# +----------+--------+------+------+------+
# 32/32 - 142s - loss: 0.0424 - val_loss: 0.0841 - mean_accuracy: 0.8109 - mean_iou: 0.7851 - mean_dice: 0.8668 - mean_f1: 0.8668 - learning_rate: 0.0099 - 142s/epoch - 4s/step
# Epoch 6/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9975  |0.9752|0.9874|0.9874|
# |balloon   |0.6174  |0.5929|0.7444|0.7444|
# +----------+--------+------+------+------+
# |summary   |0.8075  |0.7841|0.8659|0.8659|
# +----------+--------+------+------+------+
# 32/32 - 142s - loss: 0.0349 - val_loss: 0.0714 - mean_accuracy: 0.8075 - mean_iou: 0.7841 - mean_dice: 0.8659 - mean_f1: 0.8659 - learning_rate: 0.0100 - 142s/epoch - 4s/step
# Epoch 7/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9983  |0.9736|0.9866|0.9866|
# |balloon   |0.5757  |0.5602|0.7181|0.7181|
# +----------+--------+------+------+------+
# |summary   |0.787   |0.7669|0.8524|0.8524|
# +----------+--------+------+------+------+
# 32/32 - 141s - loss: 0.0310 - val_loss: 0.0737 - mean_accuracy: 0.7870 - mean_iou: 0.7669 - mean_dice: 0.8524 - mean_f1: 0.8524 - learning_rate: 0.0100 - 141s/epoch - 4s/step
# Epoch 8/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9985  |0.9746|0.9871|0.9871|
# |balloon   |0.5897  |0.5752|0.7303|0.7303|
# +----------+--------+------+------+------+
# |summary   |0.7941  |0.7749|0.8587|0.8587|
# +----------+--------+------+------+------+
# 32/32 - 140s - loss: 0.0279 - val_loss: 0.0699 - mean_accuracy: 0.7941 - mean_iou: 0.7749 - mean_dice: 0.8587 - mean_f1: 0.8587 - learning_rate: 0.0100 - 140s/epoch - 4s/step
# Epoch 9/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9988  |0.9764|0.9881|0.9881|
# |balloon   |0.6168  |0.6046|0.7536|0.7536|
# +----------+--------+------+------+------+
# |summary   |0.8078  |0.7905|0.8708|0.8708|
# +----------+--------+------+------+------+
# 32/32 - 141s - loss: 0.0279 - val_loss: 0.0644 - mean_accuracy: 0.8078 - mean_iou: 0.7905 - mean_dice: 0.8708 - mean_f1: 0.8708 - learning_rate: 0.0099 - 141s/epoch - 4s/step
# Epoch 10/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9988  |0.9804|0.9901|0.9901|
# |balloon   |0.6862  |0.6731|0.8046|0.8046|
# +----------+--------+------+------+------+
# |summary   |0.8425  |0.8268|0.8974|0.8974|
# +----------+--------+------+------+------+
# 32/32 - 140s - loss: 0.0253 - val_loss: 0.0539 - mean_accuracy: 0.8425 - mean_iou: 0.8268 - mean_dice: 0.8974 - mean_f1: 0.8974 - learning_rate: 0.0098 - 140s/epoch - 4s/step
# Epoch 11/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9983  |0.9822|0.991 |0.991 |
# |balloon   |0.7252  |0.7056|0.8274|0.8274|
# +----------+--------+------+------+------+
# |summary   |0.8618  |0.8439|0.9092|0.9092|
# +----------+--------+------+------+------+
# 32/32 - 139s - loss: 0.0233 - val_loss: 0.0476 - mean_accuracy: 0.8618 - mean_iou: 0.8439 - mean_dice: 0.9092 - mean_f1: 0.9092 - learning_rate: 0.0098 - 139s/epoch - 4s/step
# Epoch 12/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.998   |0.9841|0.992 |0.992 |
# |balloon   |0.7651  |0.74  |0.8506|0.8506|
# +----------+--------+------+------+------+
# |summary   |0.8815  |0.8621|0.9213|0.9213|
# +----------+--------+------+------+------+
# 32/32 - 139s - loss: 0.0223 - val_loss: 0.0420 - mean_accuracy: 0.8815 - mean_iou: 0.8621 - mean_dice: 0.9213 - mean_f1: 0.9213 - learning_rate: 0.0097 - 139s/epoch - 4s/step
# Epoch 13/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9983  |0.9839|0.9919|0.9919|
# |balloon   |0.7553  |0.7345|0.8469|0.8469|
# +----------+--------+------+------+------+
# |summary   |0.8768  |0.8592|0.9194|0.9194|
# +----------+--------+------+------+------+
# 32/32 - 139s - loss: 0.0216 - val_loss: 0.0428 - mean_accuracy: 0.8768 - mean_iou: 0.8592 - mean_dice: 0.9194 - mean_f1: 0.9194 - learning_rate: 0.0095 - 139s/epoch - 4s/step
# Epoch 14/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9984  |0.9842|0.992 |0.992 |
# |balloon   |0.758   |0.7386|0.8496|0.8496|
# +----------+--------+------+------+------+
# |summary   |0.8782  |0.8614|0.9208|0.9208|
# +----------+--------+------+------+------+
# 32/32 - 138s - loss: 0.0210 - val_loss: 0.0422 - mean_accuracy: 0.8782 - mean_iou: 0.8614 - mean_dice: 0.9208 - mean_f1: 0.9208 - learning_rate: 0.0094 - 138s/epoch - 4s/step
# Epoch 15/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9984  |0.9847|0.9923|0.9923|
# |balloon   |0.7673  |0.7476|0.8556|0.8556|
# +----------+--------+------+------+------+
# |summary   |0.8829  |0.8662|0.9239|0.9239|
# +----------+--------+------+------+------+
# 32/32 - 140s - loss: 0.0222 - val_loss: 0.0399 - mean_accuracy: 0.8829 - mean_iou: 0.8662 - mean_dice: 0.9239 - mean_f1: 0.9239 - learning_rate: 0.0092 - 140s/epoch - 4s/step
# Epoch 16/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9976  |0.9871|0.9935|0.9935|
# |balloon   |0.8228  |0.7907|0.8831|0.8831|
# +----------+--------+------+------+------+
# |summary   |0.9102  |0.8889|0.9383|0.9383|
# +----------+--------+------+------+------+
# 32/32 - 139s - loss: 0.0199 - val_loss: 0.0331 - mean_accuracy: 0.9102 - mean_iou: 0.8889 - mean_dice: 0.9383 - mean_f1: 0.9383 - learning_rate: 0.0091 - 139s/epoch - 4s/step
# Epoch 17/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.998   |0.9877|0.9938|0.9938|
# |balloon   |0.8246  |0.7984|0.8879|0.8879|
# +----------+--------+------+------+------+
# |summary   |0.9113  |0.893 |0.9408|0.9408|
# +----------+--------+------+------+------+
# 32/32 - 143s - loss: 0.0216 - val_loss: 0.0327 - mean_accuracy: 0.9113 - mean_iou: 0.8930 - mean_dice: 0.9408 - mean_f1: 0.9408 - learning_rate: 0.0089 - 143s/epoch - 4s/step
# Epoch 18/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9976  |0.989 |0.9945|0.9945|
# |balloon   |0.8549  |0.8216|0.9021|0.9021|
# +----------+--------+------+------+------+
# |summary   |0.9262  |0.9053|0.9483|0.9483|
# +----------+--------+------+------+------+
# 32/32 - 148s - loss: 0.0212 - val_loss: 0.0286 - mean_accuracy: 0.9262 - mean_iou: 0.9053 - mean_dice: 0.9483 - mean_f1: 0.9483 - learning_rate: 0.0087 - 148s/epoch - 5s/step
# Epoch 19/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9971  |0.9893|0.9946|0.9946|
# |balloon   |0.8677  |0.8277|0.9057|0.9057|
# +----------+--------+------+------+------+
# |summary   |0.9324  |0.9085|0.9502|0.9502|
# +----------+--------+------+------+------+
# 32/32 - 149s - loss: 0.0204 - val_loss: 0.0280 - mean_accuracy: 0.9324 - mean_iou: 0.9085 - mean_dice: 0.9502 - mean_f1: 0.9502 - learning_rate: 0.0084 - 149s/epoch - 5s/step
# Epoch 20/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9969  |0.9905|0.9952|0.9952|
# |balloon   |0.8922  |0.8485|0.9181|0.9181|
# +----------+--------+------+------+------+
# |summary   |0.9445  |0.9195|0.9566|0.9566|
# +----------+--------+------+------+------+
# 32/32 - 145s - loss: 0.0193 - val_loss: 0.0251 - mean_accuracy: 0.9445 - mean_iou: 0.9195 - mean_dice: 0.9566 - mean_f1: 0.9566 - learning_rate: 0.0082 - 145s/epoch - 5s/step
# Epoch 21/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9973  |0.9909|0.9955|0.9955|
# |balloon   |0.8936  |0.8545|0.9215|0.9215|
# +----------+--------+------+------+------+
# |summary   |0.9454  |0.9227|0.9585|0.9585|
# +----------+--------+------+------+------+
# 32/32 - 145s - loss: 0.0189 - val_loss: 0.0243 - mean_accuracy: 0.9454 - mean_iou: 0.9227 - mean_dice: 0.9585 - mean_f1: 0.9585 - learning_rate: 0.0080 - 145s/epoch - 5s/step
# Epoch 22/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9974  |0.991 |0.9955|0.9955|
# |balloon   |0.891   |0.8546|0.9216|0.9216|
# +----------+--------+------+------+------+
# |summary   |0.9442  |0.9228|0.9585|0.9585|
# +----------+--------+------+------+------+
# 32/32 - 143s - loss: 0.0195 - val_loss: 0.0243 - mean_accuracy: 0.9442 - mean_iou: 0.9228 - mean_dice: 0.9585 - mean_f1: 0.9585 - learning_rate: 0.0077 - 143s/epoch - 4s/step
# Epoch 23/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.997   |0.9913|0.9956|0.9956|
# |balloon   |0.9031  |0.8605|0.925 |0.925 |
# +----------+--------+------+------+------+
# |summary   |0.9501  |0.9259|0.9603|0.9603|
# +----------+--------+------+------+------+
# 32/32 - 144s - loss: 0.0188 - val_loss: 0.0235 - mean_accuracy: 0.9501 - mean_iou: 0.9259 - mean_dice: 0.9603 - mean_f1: 0.9603 - learning_rate: 0.0074 - 144s/epoch - 4s/step
# Epoch 24/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.997   |0.9916|0.9958|0.9958|
# |balloon   |0.9092  |0.8654|0.9278|0.9278|
# +----------+--------+------+------+------+
# |summary   |0.9531  |0.9285|0.9618|0.9618|
# +----------+--------+------+------+------+
# 32/32 - 144s - loss: 0.0185 - val_loss: 0.0229 - mean_accuracy: 0.9531 - mean_iou: 0.9285 - mean_dice: 0.9618 - mean_f1: 0.9618 - learning_rate: 0.0072 - 144s/epoch - 5s/step
# Epoch 25/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9961  |0.9914|0.9957|0.9957|
# |balloon   |0.9208  |0.8652|0.9277|0.9277|
# +----------+--------+------+------+------+
# |summary   |0.9585  |0.9283|0.9617|0.9617|
# +----------+--------+------+------+------+
# 32/32 - 144s - loss: 0.0184 - val_loss: 0.0223 - mean_accuracy: 0.9585 - mean_iou: 0.9283 - mean_dice: 0.9617 - mean_f1: 0.9617 - learning_rate: 0.0069 - 144s/epoch - 5s/step
# Epoch 26/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.997   |0.9917|0.9958|0.9958|
# |balloon   |0.9109  |0.867 |0.9287|0.9287|
# +----------+--------+------+------+------+
# |summary   |0.9539  |0.9293|0.9623|0.9623|
# +----------+--------+------+------+------+
# 32/32 - 144s - loss: 0.0180 - val_loss: 0.0222 - mean_accuracy: 0.9539 - mean_iou: 0.9293 - mean_dice: 0.9623 - mean_f1: 0.9623 - learning_rate: 0.0066 - 144s/epoch - 4s/step
# Epoch 27/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.997   |0.9914|0.9957|0.9957|
# |balloon   |0.9053  |0.8624|0.9261|0.9261|
# +----------+--------+------+------+------+
# |summary   |0.9511  |0.9269|0.9609|0.9609|
# +----------+--------+------+------+------+
# 32/32 - 144s - loss: 0.0180 - val_loss: 0.0226 - mean_accuracy: 0.9511 - mean_iou: 0.9269 - mean_dice: 0.9609 - mean_f1: 0.9609 - learning_rate: 0.0063 - 144s/epoch - 4s/step
# Epoch 28/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9964  |0.9915|0.9957|0.9957|
# |balloon   |0.9175  |0.8658|0.928 |0.928 |
# +----------+--------+------+------+------+
# |summary   |0.9569  |0.9286|0.9619|0.9619|
# +----------+--------+------+------+------+
# 32/32 - 141s - loss: 0.0176 - val_loss: 0.0222 - mean_accuracy: 0.9569 - mean_iou: 0.9286 - mean_dice: 0.9619 - mean_f1: 0.9619 - learning_rate: 0.0060 - 141s/epoch - 4s/step
# Epoch 29/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.997   |0.9915|0.9957|0.9957|
# |balloon   |0.907   |0.8636|0.9268|0.9268|
# +----------+--------+------+------+------+
# |summary   |0.952   |0.9275|0.9612|0.9612|
# +----------+--------+------+------+------+
# 32/32 - 139s - loss: 0.0181 - val_loss: 0.0223 - mean_accuracy: 0.9520 - mean_iou: 0.9275 - mean_dice: 0.9612 - mean_f1: 0.9612 - learning_rate: 0.0057 - 139s/epoch - 4s/step
# Epoch 30/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9969  |0.9914|0.9957|0.9957|
# |balloon   |0.9065  |0.8622|0.926 |0.926 |
# +----------+--------+------+------+------+
# |summary   |0.9517  |0.9268|0.9608|0.9608|
# +----------+--------+------+------+------+
# 32/32 - 138s - loss: 0.0180 - val_loss: 0.0226 - mean_accuracy: 0.9517 - mean_iou: 0.9268 - mean_dice: 0.9608 - mean_f1: 0.9608 - learning_rate: 0.0054 - 138s/epoch - 4s/step
# Epoch 31/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9966  |0.9912|0.9956|0.9956|
# |balloon   |0.9089  |0.8604|0.925 |0.925 |
# +----------+--------+------+------+------+
# |summary   |0.9528  |0.9258|0.9603|0.9603|
# +----------+--------+------+------+------+
# 32/32 - 139s - loss: 0.0175 - val_loss: 0.0226 - mean_accuracy: 0.9528 - mean_iou: 0.9258 - mean_dice: 0.9603 - mean_f1: 0.9603 - learning_rate: 0.0050 - 139s/epoch - 4s/step
# Epoch 32/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9968  |0.9913|0.9956|0.9956|
# |balloon   |0.9074  |0.8613|0.9255|0.9255|
# +----------+--------+------+------+------+
# |summary   |0.9521  |0.9263|0.9606|0.9606|
# +----------+--------+------+------+------+
# 32/32 - 140s - loss: 0.0176 - val_loss: 0.0227 - mean_accuracy: 0.9521 - mean_iou: 0.9263 - mean_dice: 0.9606 - mean_f1: 0.9606 - learning_rate: 0.0047 - 140s/epoch - 4s/step
# Epoch 33/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9962  |0.9913|0.9956|0.9956|
# |balloon   |0.9173  |0.8628|0.9264|0.9264|
# +----------+--------+------+------+------+
# |summary   |0.9568  |0.9271|0.961 |0.961 |
# +----------+--------+------+------+------+
# 32/32 - 140s - loss: 0.0177 - val_loss: 0.0224 - mean_accuracy: 0.9568 - mean_iou: 0.9271 - mean_dice: 0.9610 - mean_f1: 0.9610 - learning_rate: 0.0044 - 140s/epoch - 4s/step
# Epoch 34/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9964  |0.9914|0.9957|0.9957|
# |balloon   |0.9168  |0.8643|0.9272|0.9272|
# +----------+--------+------+------+------+
# |summary   |0.9566  |0.9279|0.9615|0.9615|
# +----------+--------+------+------+------+
# 32/32 - 139s - loss: 0.0168 - val_loss: 0.0223 - mean_accuracy: 0.9566 - mean_iou: 0.9279 - mean_dice: 0.9615 - mean_f1: 0.9615 - learning_rate: 0.0041 - 139s/epoch - 4s/step
# Epoch 35/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9966  |0.9915|0.9957|0.9957|
# |balloon   |0.9127  |0.8641|0.9271|0.9271|
# +----------+--------+------+------+------+
# |summary   |0.9547  |0.9278|0.9614|0.9614|
# +----------+--------+------+------+------+
# 32/32 - 141s - loss: 0.0175 - val_loss: 0.0222 - mean_accuracy: 0.9547 - mean_iou: 0.9278 - mean_dice: 0.9614 - mean_f1: 0.9614 - learning_rate: 0.0038 - 141s/epoch - 4s/step
# Epoch 36/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9963  |0.9915|0.9957|0.9957|
# |balloon   |0.919   |0.8652|0.9277|0.9277|
# +----------+--------+------+------+------+
# |summary   |0.9576  |0.9283|0.9617|0.9617|
# +----------+--------+------+------+------+
# 32/32 - 139s - loss: 0.0171 - val_loss: 0.0222 - mean_accuracy: 0.9576 - mean_iou: 0.9283 - mean_dice: 0.9617 - mean_f1: 0.9617 - learning_rate: 0.0035 - 139s/epoch - 4s/step
# Epoch 37/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9962  |0.9914|0.9957|0.9957|
# |balloon   |0.9185  |0.8635|0.9268|0.9268|
# +----------+--------+------+------+------+
# |summary   |0.9573  |0.9274|0.9612|0.9612|
# +----------+--------+------+------+------+
# 32/32 - 140s - loss: 0.0176 - val_loss: 0.0223 - mean_accuracy: 0.9573 - mean_iou: 0.9274 - mean_dice: 0.9612 - mean_f1: 0.9612 - learning_rate: 0.0032 - 140s/epoch - 4s/step
# Epoch 38/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9964  |0.9915|0.9957|0.9957|
# |balloon   |0.9168  |0.8655|0.9279|0.9279|
# +----------+--------+------+------+------+
# |summary   |0.9566  |0.9285|0.9618|0.9618|
# +----------+--------+------+------+------+
# 32/32 - 139s - loss: 0.0174 - val_loss: 0.0222 - mean_accuracy: 0.9566 - mean_iou: 0.9285 - mean_dice: 0.9618 - mean_f1: 0.9618 - learning_rate: 0.0029 - 139s/epoch - 4s/step
# Epoch 39/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9966  |0.9913|0.9956|0.9956|
# |balloon   |0.9109  |0.8614|0.9256|0.9256|
# +----------+--------+------+------+------+
# |summary   |0.9537  |0.9264|0.9606|0.9606|
# +----------+--------+------+------+------+
# 32/32 - 140s - loss: 0.0171 - val_loss: 0.0228 - mean_accuracy: 0.9537 - mean_iou: 0.9264 - mean_dice: 0.9606 - mean_f1: 0.9606 - learning_rate: 0.0027 - 140s/epoch - 4s/step
# Epoch 40/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9963  |0.9912|0.9956|0.9956|
# |balloon   |0.9142  |0.8614|0.9255|0.9255|
# +----------+--------+------+------+------+
# |summary   |0.9553  |0.9263|0.9606|0.9606|
# +----------+--------+------+------+------+
# 32/32 - 139s - loss: 0.0171 - val_loss: 0.0226 - mean_accuracy: 0.9553 - mean_iou: 0.9263 - mean_dice: 0.9606 - mean_f1: 0.9606 - learning_rate: 0.0024 - 139s/epoch - 4s/step
# Epoch 41/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9962  |0.9913|0.9956|0.9956|
# |balloon   |0.918   |0.8629|0.9264|0.9264|
# +----------+--------+------+------+------+
# |summary   |0.9571  |0.9271|0.961 |0.961 |
# +----------+--------+------+------+------+
# 32/32 - 140s - loss: 0.0170 - val_loss: 0.0225 - mean_accuracy: 0.9571 - mean_iou: 0.9271 - mean_dice: 0.9610 - mean_f1: 0.9610 - learning_rate: 0.0021 - 140s/epoch - 4s/step
# Epoch 42/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9963  |0.9913|0.9956|0.9956|
# |balloon   |0.9152  |0.8617|0.9257|0.9257|
# +----------+--------+------+------+------+
# |summary   |0.9557  |0.9265|0.9607|0.9607|
# +----------+--------+------+------+------+
# 32/32 - 140s - loss: 0.0166 - val_loss: 0.0225 - mean_accuracy: 0.9557 - mean_iou: 0.9265 - mean_dice: 0.9607 - mean_f1: 0.9607 - learning_rate: 0.0019 - 140s/epoch - 4s/step
# Epoch 43/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9961  |0.9914|0.9957|0.9957|
# |balloon   |0.9205  |0.8642|0.9272|0.9272|
# +----------+--------+------+------+------+
# |summary   |0.9583  |0.9278|0.9614|0.9614|
# +----------+--------+------+------+------+
# 32/32 - 140s - loss: 0.0168 - val_loss: 0.0224 - mean_accuracy: 0.9583 - mean_iou: 0.9278 - mean_dice: 0.9614 - mean_f1: 0.9614 - learning_rate: 0.0017 - 140s/epoch - 4s/step
# Epoch 44/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9962  |0.9914|0.9957|0.9957|
# |balloon   |0.9198  |0.8645|0.9273|0.9273|
# +----------+--------+------+------+------+
# |summary   |0.958   |0.928 |0.9615|0.9615|
# +----------+--------+------+------+------+
# 32/32 - 143s - loss: 0.0166 - val_loss: 0.0223 - mean_accuracy: 0.9580 - mean_iou: 0.9280 - mean_dice: 0.9615 - mean_f1: 0.9615 - learning_rate: 0.0014 - 143s/epoch - 4s/step
# Epoch 45/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.996   |0.9914|0.9957|0.9957|
# |balloon   |0.9223  |0.8643|0.9272|0.9272|
# +----------+--------+------+------+------+
# |summary   |0.9592  |0.9278|0.9614|0.9614|
# +----------+--------+------+------+------+
# 32/32 - 141s - loss: 0.0170 - val_loss: 0.0223 - mean_accuracy: 0.9592 - mean_iou: 0.9278 - mean_dice: 0.9614 - mean_f1: 0.9614 - learning_rate: 0.0012 - 141s/epoch - 4s/step
# Epoch 46/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9961  |0.9914|0.9957|0.9957|
# |balloon   |0.9205  |0.8643|0.9272|0.9272|
# +----------+--------+------+------+------+
# |summary   |0.9583  |0.9278|0.9614|0.9614|
# +----------+--------+------+------+------+
# 32/32 - 140s - loss: 0.0168 - val_loss: 0.0224 - mean_accuracy: 0.9583 - mean_iou: 0.9278 - mean_dice: 0.9614 - mean_f1: 0.9614 - learning_rate: 0.0010 - 140s/epoch - 4s/step
# Epoch 47/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9962  |0.9914|0.9957|0.9957|
# |balloon   |0.9197  |0.8643|0.9272|0.9272|
# +----------+--------+------+------+------+
# |summary   |0.9579  |0.9279|0.9615|0.9615|
# +----------+--------+------+------+------+
# 32/32 - 138s - loss: 0.0171 - val_loss: 0.0224 - mean_accuracy: 0.9579 - mean_iou: 0.9279 - mean_dice: 0.9615 - mean_f1: 0.9615 - learning_rate: 8.7058e-04 - 138s/epoch - 4s/step
# Epoch 48/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9961  |0.9914|0.9957|0.9957|
# |balloon   |0.9197  |0.8638|0.9269|0.9269|
# +----------+--------+------+------+------+
# |summary   |0.9579  |0.9276|0.9613|0.9613|
# +----------+--------+------+------+------+
# 32/32 - 139s - loss: 0.0167 - val_loss: 0.0224 - mean_accuracy: 0.9579 - mean_iou: 0.9276 - mean_dice: 0.9613 - mean_f1: 0.9613 - learning_rate: 7.1228e-04 - 139s/epoch - 4s/step
# Epoch 49/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9962  |0.9913|0.9957|0.9957|
# |balloon   |0.9183  |0.8634|0.9267|0.9267|
# +----------+--------+------+------+------+
# |summary   |0.9572  |0.9274|0.9612|0.9612|
# +----------+--------+------+------+------+
# 32/32 - 141s - loss: 0.0166 - val_loss: 0.0224 - mean_accuracy: 0.9572 - mean_iou: 0.9274 - mean_dice: 0.9612 - mean_f1: 0.9612 - learning_rate: 5.7111e-04 - 141s/epoch - 4s/step
# Epoch 50/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9962  |0.9914|0.9957|0.9957|
# |balloon   |0.9186  |0.8639|0.927 |0.927 |
# +----------+--------+------+------+------+
# |summary   |0.9574  |0.9276|0.9613|0.9613|
# +----------+--------+------+------+------+
# 32/32 - 139s - loss: 0.0167 - val_loss: 0.0225 - mean_accuracy: 0.9574 - mean_iou: 0.9276 - mean_dice: 0.9613 - mean_f1: 0.9613 - learning_rate: 4.4761e-04 - 139s/epoch - 4s/step

# %% [markdown]
# 3-2. Exponential Moving Average(EMA)

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate, momentum = momentum, nesterov = nesterov)
model.compile(loss = tf.keras.losses.categorical_crossentropy, optimizer = optimizer)

ema = tfdet.callback.EMA(step = 64 // batch_size, auto_apply = True, warm_up_epoch = warm_up_epoch)

with device:
    model.fit(train_pipe.repeat(8), validation_data = test_pipe, epochs = epoch, callbacks = [ema, metric, save, scheduler, logger], verbose = 2)
    
for filename in os.listdir("./"):
    name, ext = os.path.splitext(filename)
    if name in ["train_cache", "sample_cache"]:# and (ext == ".index" or ".data" in ext):
        os.remove(filename)
# Out:
# Epoch 1/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.0382  |0.0381|0.0734|0.0734|
# |balloon   |0.9402  |0.0551|0.1044|0.1044|
# +----------+--------+------+------+------+
# |summary   |0.4892  |0.0466|0.0889|0.0889|
# +----------+--------+------+------+------+
# 32/32 - 204s - loss: 0.6349 - val_loss: 1.3676 - mean_accuracy: 0.4892 - mean_iou: 0.0466 - mean_dice: 0.0889 - mean_f1: 0.0889 - learning_rate: 6.6000e-05 - 204s/epoch - 6s/step
# Epoch 2/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.7779  |0.7649|0.8668|0.8668|
# |balloon   |0.7149  |0.1518|0.2636|0.2636|
# +----------+--------+------+------+------+
# |summary   |0.7464  |0.4583|0.5652|0.5652|
# +----------+--------+------+------+------+
# 32/32 - 149s - loss: 0.2214 - val_loss: 0.5421 - mean_accuracy: 0.7464 - mean_iou: 0.4583 - mean_dice: 0.5652 - mean_f1: 0.5652 - learning_rate: 0.0039 - 149s/epoch - 5s/step
# Epoch 3/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.8936  |0.8815|0.937 |0.937 |
# |balloon   |0.7714  |0.2778|0.4348|0.4348|
# +----------+--------+------+------+------+
# |summary   |0.8325  |0.5796|0.6859|0.6859|
# +----------+--------+------+------+------+
# 32/32 - 148s - loss: 0.0665 - val_loss: 0.3426 - mean_accuracy: 0.8325 - mean_iou: 0.5796 - mean_dice: 0.6859 - mean_f1: 0.6859 - learning_rate: 0.0059 - 148s/epoch - 5s/step
# Epoch 4/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9732  |0.9564|0.9777|0.9777|
# |balloon   |0.7071  |0.4884|0.6562|0.6562|
# +----------+--------+------+------+------+
# |summary   |0.8402  |0.7224|0.817 |0.817 |
# +----------+--------+------+------+------+
# 32/32 - 147s - loss: 0.0454 - val_loss: 0.1394 - mean_accuracy: 0.8402 - mean_iou: 0.7224 - mean_dice: 0.8170 - mean_f1: 0.8170 - learning_rate: 0.0079 - 147s/epoch - 5s/step
# Epoch 5/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.995   |0.9739|0.9868|0.9868|
# |balloon   |0.6384  |0.5891|0.7414|0.7414|
# +----------+--------+------+------+------+
# |summary   |0.8167  |0.7815|0.8641|0.8641|
# +----------+--------+------+------+------+
# 32/32 - 148s - loss: 0.0379 - val_loss: 0.0828 - mean_accuracy: 0.8167 - mean_iou: 0.7815 - mean_dice: 0.8641 - mean_f1: 0.8641 - learning_rate: 0.0099 - 148s/epoch - 5s/step
# Epoch 6/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9967  |0.9731|0.9864|0.9864|
# |balloon   |0.5943  |0.5633|0.7207|0.7207|
# +----------+--------+------+------+------+
# |summary   |0.7955  |0.7682|0.8535|0.8535|
# +----------+--------+------+------+------+
# 32/32 - 148s - loss: 0.0355 - val_loss: 0.0781 - mean_accuracy: 0.7955 - mean_iou: 0.7682 - mean_dice: 0.8535 - mean_f1: 0.8535 - learning_rate: 0.0100 - 148s/epoch - 5s/step
# Epoch 7/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.998   |0.9727|0.9862|0.9862|
# |balloon   |0.5666  |0.5479|0.7079|0.7079|
# +----------+--------+------+------+------+
# |summary   |0.7823  |0.7603|0.847 |0.847 |
# +----------+--------+------+------+------+
# 32/32 - 149s - loss: 0.0304 - val_loss: 0.0744 - mean_accuracy: 0.7823 - mean_iou: 0.7603 - mean_dice: 0.8470 - mean_f1: 0.8470 - learning_rate: 0.0100 - 149s/epoch - 5s/step
# Epoch 8/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.997   |0.9786|0.9892|0.9892|
# |balloon   |0.6867  |0.654 |0.7908|0.7908|
# +----------+--------+------+------+------+
# |summary   |0.8419  |0.8163|0.89  |0.89  |
# +----------+--------+------+------+------+
# 32/32 - 150s - loss: 0.0279 - val_loss: 0.0620 - mean_accuracy: 0.8419 - mean_iou: 0.8163 - mean_dice: 0.8900 - mean_f1: 0.8900 - learning_rate: 0.0100 - 150s/epoch - 5s/step
# Epoch 9/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9985  |0.9766|0.9882|0.9882|
# |balloon   |0.6249  |0.6098|0.7576|0.7576|
# +----------+--------+------+------+------+
# |summary   |0.8117  |0.7932|0.8729|0.8729|
# +----------+--------+------+------+------+
# 32/32 - 148s - loss: 0.0255 - val_loss: 0.0674 - mean_accuracy: 0.8117 - mean_iou: 0.7932 - mean_dice: 0.8729 - mean_f1: 0.8729 - learning_rate: 0.0099 - 148s/epoch - 5s/step
# Epoch 10/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9985  |0.9796|0.9897|0.9897|
# |balloon   |0.678   |0.6613|0.7961|0.7961|
# +----------+--------+------+------+------+
# |summary   |0.8382  |0.8205|0.8929|0.8929|
# +----------+--------+------+------+------+
# 32/32 - 149s - loss: 0.0246 - val_loss: 0.0606 - mean_accuracy: 0.8382 - mean_iou: 0.8205 - mean_dice: 0.8929 - mean_f1: 0.8929 - learning_rate: 0.0098 - 149s/epoch - 5s/step
# Epoch 11/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9984  |0.982 |0.9909|0.9909|
# |balloon   |0.7216  |0.7027|0.8254|0.8254|
# +----------+--------+------+------+------+
# |summary   |0.86    |0.8424|0.9082|0.9082|
# +----------+--------+------+------+------+
# 32/32 - 146s - loss: 0.0243 - val_loss: 0.0521 - mean_accuracy: 0.8600 - mean_iou: 0.8424 - mean_dice: 0.9082 - mean_f1: 0.9082 - learning_rate: 0.0098 - 146s/epoch - 5s/step
# Epoch 12/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9967  |0.9835|0.9917|0.9917|
# |balloon   |0.7762  |0.7355|0.8476|0.8476|
# +----------+--------+------+------+------+
# |summary   |0.8865  |0.8595|0.9196|0.9196|
# +----------+--------+------+------+------+
# 32/32 - 146s - loss: 0.0227 - val_loss: 0.0438 - mean_accuracy: 0.8865 - mean_iou: 0.8595 - mean_dice: 0.9196 - mean_f1: 0.9196 - learning_rate: 0.0097 - 146s/epoch - 5s/step
# Epoch 13/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9972  |0.9847|0.9923|0.9923|
# |balloon   |0.789   |0.7534|0.8594|0.8594|
# +----------+--------+------+------+------+
# |summary   |0.8931  |0.8691|0.9258|0.9258|
# +----------+--------+------+------+------+
# 32/32 - 146s - loss: 0.0227 - val_loss: 0.0426 - mean_accuracy: 0.8931 - mean_iou: 0.8691 - mean_dice: 0.9258 - mean_f1: 0.9258 - learning_rate: 0.0095 - 146s/epoch - 5s/step
# Epoch 14/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9979  |0.9845|0.9922|0.9922|
# |balloon   |0.7713  |0.7457|0.8543|0.8543|
# +----------+--------+------+------+------+
# |summary   |0.8846  |0.8651|0.9233|0.9233|
# +----------+--------+------+------+------+
# 32/32 - 148s - loss: 0.0211 - val_loss: 0.0403 - mean_accuracy: 0.8846 - mean_iou: 0.8651 - mean_dice: 0.9233 - mean_f1: 0.9233 - learning_rate: 0.0094 - 148s/epoch - 5s/step
# Epoch 15/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9973  |0.9856|0.9928|0.9928|
# |balloon   |0.8018  |0.7675|0.8684|0.8684|
# +----------+--------+------+------+------+
# |summary   |0.8996  |0.8766|0.9306|0.9306|
# +----------+--------+------+------+------+
# 32/32 - 148s - loss: 0.0221 - val_loss: 0.0375 - mean_accuracy: 0.8996 - mean_iou: 0.8766 - mean_dice: 0.9306 - mean_f1: 0.9306 - learning_rate: 0.0092 - 148s/epoch - 5s/step
# Epoch 16/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.996   |0.9871|0.9935|0.9935|
# |balloon   |0.8492  |0.7965|0.8868|0.8868|
# +----------+--------+------+------+------+
# |summary   |0.9226  |0.8918|0.9401|0.9401|
# +----------+--------+------+------+------+
# 32/32 - 148s - loss: 0.0207 - val_loss: 0.0347 - mean_accuracy: 0.9226 - mean_iou: 0.8918 - mean_dice: 0.9401 - mean_f1: 0.9401 - learning_rate: 0.0091 - 148s/epoch - 5s/step
# Epoch 17/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9953  |0.9881|0.994 |0.994 |
# |balloon   |0.8783  |0.8137|0.8973|0.8973|
# +----------+--------+------+------+------+
# |summary   |0.9368  |0.9009|0.9456|0.9456|
# +----------+--------+------+------+------+
# 32/32 - 149s - loss: 0.0196 - val_loss: 0.0315 - mean_accuracy: 0.9368 - mean_iou: 0.9009 - mean_dice: 0.9456 - mean_f1: 0.9456 - learning_rate: 0.0089 - 149s/epoch - 5s/step
# Epoch 18/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9959  |0.9887|0.9943|0.9943|
# |balloon   |0.8777  |0.8219|0.9022|0.9022|
# +----------+--------+------+------+------+
# |summary   |0.9368  |0.9053|0.9483|0.9483|
# +----------+--------+------+------+------+
# 32/32 - 147s - loss: 0.0191 - val_loss: 0.0295 - mean_accuracy: 0.9368 - mean_iou: 0.9053 - mean_dice: 0.9483 - mean_f1: 0.9483 - learning_rate: 0.0087 - 147s/epoch - 5s/step
# Epoch 19/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9963  |0.9891|0.9945|0.9945|
# |balloon   |0.8792  |0.8279|0.9058|0.9058|
# +----------+--------+------+------+------+
# |summary   |0.9378  |0.9085|0.9502|0.9502|
# +----------+--------+------+------+------+
# 32/32 - 147s - loss: 0.0191 - val_loss: 0.0284 - mean_accuracy: 0.9378 - mean_iou: 0.9085 - mean_dice: 0.9502 - mean_f1: 0.9502 - learning_rate: 0.0084 - 147s/epoch - 5s/step
# Epoch 20/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9963  |0.9893|0.9946|0.9946|
# |balloon   |0.8823  |0.8308|0.9076|0.9076|
# +----------+--------+------+------+------+
# |summary   |0.9393  |0.91  |0.9511|0.9511|
# +----------+--------+------+------+------+
# 32/32 - 147s - loss: 0.0186 - val_loss: 0.0276 - mean_accuracy: 0.9393 - mean_iou: 0.9100 - mean_dice: 0.9511 - mean_f1: 0.9511 - learning_rate: 0.0082 - 147s/epoch - 5s/step
# Epoch 21/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9974  |0.9893|0.9946|0.9946|
# |balloon   |0.8641  |0.828 |0.9059|0.9059|
# +----------+--------+------+------+------+
# |summary   |0.9307  |0.9087|0.9503|0.9503|
# +----------+--------+------+------+------+
# 32/32 - 146s - loss: 0.0195 - val_loss: 0.0287 - mean_accuracy: 0.9307 - mean_iou: 0.9087 - mean_dice: 0.9503 - mean_f1: 0.9503 - learning_rate: 0.0080 - 146s/epoch - 5s/step
# Epoch 22/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9976  |0.9898|0.9949|0.9949|
# |balloon   |0.8687  |0.8348|0.91  |0.91  |
# +----------+--------+------+------+------+
# |summary   |0.9331  |0.9123|0.9524|0.9524|
# +----------+--------+------+------+------+
# 32/32 - 147s - loss: 0.0194 - val_loss: 0.0267 - mean_accuracy: 0.9331 - mean_iou: 0.9123 - mean_dice: 0.9524 - mean_f1: 0.9524 - learning_rate: 0.0077 - 147s/epoch - 5s/step
# Epoch 23/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9967  |0.9905|0.9952|0.9952|
# |balloon   |0.8946  |0.8483|0.9179|0.9179|
# +----------+--------+------+------+------+
# |summary   |0.9457  |0.9194|0.9566|0.9566|
# +----------+--------+------+------+------+
# 32/32 - 148s - loss: 0.0180 - val_loss: 0.0245 - mean_accuracy: 0.9457 - mean_iou: 0.9194 - mean_dice: 0.9566 - mean_f1: 0.9566 - learning_rate: 0.0074 - 148s/epoch - 5s/step
# Epoch 24/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9973  |0.9906|0.9953|0.9953|
# |balloon   |0.886   |0.8479|0.9177|0.9177|
# +----------+--------+------+------+------+
# |summary   |0.9417  |0.9192|0.9565|0.9565|
# +----------+--------+------+------+------+
# 32/32 - 145s - loss: 0.0185 - val_loss: 0.0257 - mean_accuracy: 0.9417 - mean_iou: 0.9192 - mean_dice: 0.9565 - mean_f1: 0.9565 - learning_rate: 0.0072 - 145s/epoch - 5s/step
# Epoch 25/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9971  |0.9911|0.9955|0.9955|
# |balloon   |0.8994  |0.8575|0.9233|0.9233|
# +----------+--------+------+------+------+
# |summary   |0.9482  |0.9243|0.9594|0.9594|
# +----------+--------+------+------+------+
# 32/32 - 147s - loss: 0.0181 - val_loss: 0.0239 - mean_accuracy: 0.9482 - mean_iou: 0.9243 - mean_dice: 0.9594 - mean_f1: 0.9594 - learning_rate: 0.0069 - 147s/epoch - 5s/step
# Epoch 26/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9971  |0.991 |0.9955|0.9955|
# |balloon   |0.8966  |0.8555|0.9221|0.9221|
# +----------+--------+------+------+------+
# |summary   |0.9469  |0.9233|0.9588|0.9588|
# +----------+--------+------+------+------+
# 32/32 - 146s - loss: 0.0181 - val_loss: 0.0242 - mean_accuracy: 0.9469 - mean_iou: 0.9233 - mean_dice: 0.9588 - mean_f1: 0.9588 - learning_rate: 0.0066 - 146s/epoch - 5s/step
# Epoch 27/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9971  |0.9911|0.9955|0.9955|
# |balloon   |0.8981  |0.8569|0.9229|0.9229|
# +----------+--------+------+------+------+
# |summary   |0.9476  |0.924 |0.9592|0.9592|
# +----------+--------+------+------+------+
# 32/32 - 145s - loss: 0.0181 - val_loss: 0.0245 - mean_accuracy: 0.9476 - mean_iou: 0.9240 - mean_dice: 0.9592 - mean_f1: 0.9592 - learning_rate: 0.0063 - 145s/epoch - 5s/step
# Epoch 28/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9974  |0.9908|0.9954|0.9954|
# |balloon   |0.8894  |0.8522|0.9202|0.9202|
# +----------+--------+------+------+------+
# |summary   |0.9434  |0.9215|0.9578|0.9578|
# +----------+--------+------+------+------+
# 32/32 - 146s - loss: 0.0180 - val_loss: 0.0247 - mean_accuracy: 0.9434 - mean_iou: 0.9215 - mean_dice: 0.9578 - mean_f1: 0.9578 - learning_rate: 0.0060 - 146s/epoch - 5s/step
# Epoch 29/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9974  |0.991 |0.9955|0.9955|
# |balloon   |0.8931  |0.8554|0.922 |0.922 |
# +----------+--------+------+------+------+
# |summary   |0.9452  |0.9232|0.9588|0.9588|
# +----------+--------+------+------+------+
# 32/32 - 149s - loss: 0.0178 - val_loss: 0.0239 - mean_accuracy: 0.9452 - mean_iou: 0.9232 - mean_dice: 0.9588 - mean_f1: 0.9588 - learning_rate: 0.0057 - 149s/epoch - 5s/step
# Epoch 30/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9971  |0.9914|0.9957|0.9957|
# |balloon   |0.9034  |0.8622|0.926 |0.926 |
# +----------+--------+------+------+------+
# |summary   |0.9503  |0.9268|0.9608|0.9608|
# +----------+--------+------+------+------+
# 32/32 - 149s - loss: 0.0175 - val_loss: 0.0233 - mean_accuracy: 0.9503 - mean_iou: 0.9268 - mean_dice: 0.9608 - mean_f1: 0.9608 - learning_rate: 0.0054 - 149s/epoch - 5s/step
# Epoch 31/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9969  |0.9913|0.9956|0.9956|
# |balloon   |0.9051  |0.8608|0.9252|0.9252|
# +----------+--------+------+------+------+
# |summary   |0.951   |0.926 |0.9604|0.9604|
# +----------+--------+------+------+------+
# 32/32 - 148s - loss: 0.0177 - val_loss: 0.0233 - mean_accuracy: 0.9510 - mean_iou: 0.9260 - mean_dice: 0.9604 - mean_f1: 0.9604 - learning_rate: 0.0050 - 148s/epoch - 5s/step
# Epoch 32/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9967  |0.9913|0.9956|0.9956|
# |balloon   |0.9089  |0.861 |0.9253|0.9253|
# +----------+--------+------+------+------+
# |summary   |0.9528  |0.9261|0.9605|0.9605|
# +----------+--------+------+------+------+
# 32/32 - 149s - loss: 0.0173 - val_loss: 0.0237 - mean_accuracy: 0.9528 - mean_iou: 0.9261 - mean_dice: 0.9605 - mean_f1: 0.9605 - learning_rate: 0.0047 - 149s/epoch - 5s/step
# Epoch 33/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9967  |0.9914|0.9957|0.9957|
# |balloon   |0.9114  |0.8637|0.9269|0.9269|
# +----------+--------+------+------+------+
# |summary   |0.954   |0.9276|0.9613|0.9613|
# +----------+--------+------+------+------+
# 32/32 - 148s - loss: 0.0169 - val_loss: 0.0236 - mean_accuracy: 0.9540 - mean_iou: 0.9276 - mean_dice: 0.9613 - mean_f1: 0.9613 - learning_rate: 0.0044 - 148s/epoch - 5s/step
# Epoch 34/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9968  |0.9914|0.9957|0.9957|
# |balloon   |0.9096  |0.8634|0.9267|0.9267|
# +----------+--------+------+------+------+
# |summary   |0.9532  |0.9274|0.9612|0.9612|
# +----------+--------+------+------+------+
# 32/32 - 147s - loss: 0.0174 - val_loss: 0.0234 - mean_accuracy: 0.9532 - mean_iou: 0.9274 - mean_dice: 0.9612 - mean_f1: 0.9612 - learning_rate: 0.0041 - 147s/epoch - 5s/step
# Epoch 35/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9969  |0.9915|0.9958|0.9958|
# |balloon   |0.9101  |0.8651|0.9276|0.9276|
# +----------+--------+------+------+------+
# |summary   |0.9535  |0.9283|0.9617|0.9617|
# +----------+--------+------+------+------+
# 32/32 - 150s - loss: 0.0172 - val_loss: 0.0235 - mean_accuracy: 0.9535 - mean_iou: 0.9283 - mean_dice: 0.9617 - mean_f1: 0.9617 - learning_rate: 0.0038 - 150s/epoch - 5s/step
# Epoch 36/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9967  |0.9916|0.9958|0.9958|
# |balloon   |0.913   |0.8655|0.9279|0.9279|
# +----------+--------+------+------+------+
# |summary   |0.9549  |0.9285|0.9618|0.9618|
# +----------+--------+------+------+------+
# 32/32 - 148s - loss: 0.0171 - val_loss: 0.0233 - mean_accuracy: 0.9549 - mean_iou: 0.9285 - mean_dice: 0.9618 - mean_f1: 0.9618 - learning_rate: 0.0035 - 148s/epoch - 5s/step
# Epoch 37/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9966  |0.9916|0.9958|0.9958|
# |balloon   |0.9156  |0.8668|0.9287|0.9287|
# +----------+--------+------+------+------+
# |summary   |0.9561  |0.9292|0.9622|0.9622|
# +----------+--------+------+------+------+
# 32/32 - 150s - loss: 0.0170 - val_loss: 0.0232 - mean_accuracy: 0.9561 - mean_iou: 0.9292 - mean_dice: 0.9622 - mean_f1: 0.9622 - learning_rate: 0.0032 - 150s/epoch - 5s/step
# Epoch 38/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9966  |0.9915|0.9957|0.9957|
# |balloon   |0.9143  |0.8645|0.9273|0.9273|
# +----------+--------+------+------+------+
# |summary   |0.9554  |0.928 |0.9615|0.9615|
# +----------+--------+------+------+------+
# 32/32 - 148s - loss: 0.0169 - val_loss: 0.0232 - mean_accuracy: 0.9554 - mean_iou: 0.9280 - mean_dice: 0.9615 - mean_f1: 0.9615 - learning_rate: 0.0029 - 148s/epoch - 5s/step
# Epoch 39/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9963  |0.9914|0.9957|0.9957|
# |balloon   |0.9174  |0.8646|0.9274|0.9274|
# +----------+--------+------+------+------+
# |summary   |0.9569  |0.928 |0.9616|0.9616|
# +----------+--------+------+------+------+
# 32/32 - 149s - loss: 0.0169 - val_loss: 0.0231 - mean_accuracy: 0.9569 - mean_iou: 0.9280 - mean_dice: 0.9616 - mean_f1: 0.9616 - learning_rate: 0.0027 - 149s/epoch - 5s/step
# Epoch 40/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.997   |0.9915|0.9957|0.9957|
# |balloon   |0.9067  |0.8634|0.9267|0.9267|
# +----------+--------+------+------+------+
# |summary   |0.9518  |0.9274|0.9612|0.9612|
# +----------+--------+------+------+------+
# 32/32 - 147s - loss: 0.0174 - val_loss: 0.0239 - mean_accuracy: 0.9518 - mean_iou: 0.9274 - mean_dice: 0.9612 - mean_f1: 0.9612 - learning_rate: 0.0024 - 147s/epoch - 5s/step
# Epoch 41/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9963  |0.9916|0.9958|0.9958|
# |balloon   |0.9201  |0.8668|0.9287|0.9287|
# +----------+--------+------+------+------+
# |summary   |0.9582  |0.9292|0.9622|0.9622|
# +----------+--------+------+------+------+
# 32/32 - 147s - loss: 0.0172 - val_loss: 0.0232 - mean_accuracy: 0.9582 - mean_iou: 0.9292 - mean_dice: 0.9622 - mean_f1: 0.9622 - learning_rate: 0.0021 - 147s/epoch - 5s/step
# Epoch 42/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9963  |0.9915|0.9957|0.9957|
# |balloon   |0.9187  |0.8656|0.9279|0.9279|
# +----------+--------+------+------+------+
# |summary   |0.9575  |0.9285|0.9618|0.9618|
# +----------+--------+------+------+------+
# 32/32 - 149s - loss: 0.0171 - val_loss: 0.0233 - mean_accuracy: 0.9575 - mean_iou: 0.9285 - mean_dice: 0.9618 - mean_f1: 0.9618 - learning_rate: 0.0019 - 149s/epoch - 5s/step
# Epoch 43/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9968  |0.9914|0.9957|0.9957|
# |balloon   |0.9095  |0.8634|0.9267|0.9267|
# +----------+--------+------+------+------+
# |summary   |0.9532  |0.9274|0.9612|0.9612|
# +----------+--------+------+------+------+
# 32/32 - 148s - loss: 0.0168 - val_loss: 0.0237 - mean_accuracy: 0.9532 - mean_iou: 0.9274 - mean_dice: 0.9612 - mean_f1: 0.9612 - learning_rate: 0.0017 - 148s/epoch - 5s/step
# Epoch 44/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9963  |0.9915|0.9957|0.9957|
# |balloon   |0.919   |0.8657|0.928 |0.928 |
# +----------+--------+------+------+------+
# |summary   |0.9577  |0.9286|0.9619|0.9619|
# +----------+--------+------+------+------+
# 32/32 - 149s - loss: 0.0168 - val_loss: 0.0233 - mean_accuracy: 0.9577 - mean_iou: 0.9286 - mean_dice: 0.9619 - mean_f1: 0.9619 - learning_rate: 0.0014 - 149s/epoch - 5s/step
# Epoch 45/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9964  |0.9915|0.9957|0.9957|
# |balloon   |0.9177  |0.8651|0.9277|0.9277|
# +----------+--------+------+------+------+
# |summary   |0.957   |0.9283|0.9617|0.9617|
# +----------+--------+------+------+------+
# 32/32 - 148s - loss: 0.0171 - val_loss: 0.0235 - mean_accuracy: 0.9570 - mean_iou: 0.9283 - mean_dice: 0.9617 - mean_f1: 0.9617 - learning_rate: 0.0012 - 148s/epoch - 5s/step
# Epoch 46/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9963  |0.9915|0.9957|0.9957|
# |balloon   |0.9181  |0.8652|0.9277|0.9277|
# +----------+--------+------+------+------+
# |summary   |0.9572  |0.9284|0.9617|0.9617|
# +----------+--------+------+------+------+
# 32/32 - 148s - loss: 0.0168 - val_loss: 0.0236 - mean_accuracy: 0.9572 - mean_iou: 0.9284 - mean_dice: 0.9617 - mean_f1: 0.9617 - learning_rate: 0.0010 - 148s/epoch - 5s/step
# Epoch 47/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9967  |0.9915|0.9957|0.9957|
# |balloon   |0.9133  |0.865 |0.9276|0.9276|
# +----------+--------+------+------+------+
# |summary   |0.955   |0.9282|0.9617|0.9617|
# +----------+--------+------+------+------+
# 32/32 - 149s - loss: 0.0167 - val_loss: 0.0237 - mean_accuracy: 0.9550 - mean_iou: 0.9282 - mean_dice: 0.9617 - mean_f1: 0.9617 - learning_rate: 8.7058e-04 - 149s/epoch - 5s/step
# Epoch 48/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9965  |0.9915|0.9957|0.9957|
# |balloon   |0.9162  |0.8654|0.9279|0.9279|
# +----------+--------+------+------+------+
# |summary   |0.9563  |0.9285|0.9618|0.9618|
# +----------+--------+------+------+------+
# 32/32 - 147s - loss: 0.0166 - val_loss: 0.0235 - mean_accuracy: 0.9563 - mean_iou: 0.9285 - mean_dice: 0.9618 - mean_f1: 0.9618 - learning_rate: 7.1228e-04 - 147s/epoch - 5s/step
# Epoch 49/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9964  |0.9915|0.9958|0.9958|
# |balloon   |0.9177  |0.8661|0.9283|0.9283|
# +----------+--------+------+------+------+
# |summary   |0.9571  |0.9288|0.962 |0.962 |
# +----------+--------+------+------+------+
# 32/32 - 146s - loss: 0.0167 - val_loss: 0.0235 - mean_accuracy: 0.9571 - mean_iou: 0.9288 - mean_dice: 0.9620 - mean_f1: 0.9620 - learning_rate: 5.7111e-04 - 146s/epoch - 5s/step
# Epoch 50/50
#
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9965  |0.9916|0.9958|0.9958|
# |balloon   |0.9174  |0.8662|0.9283|0.9283|
# +----------+--------+------+------+------+
# |summary   |0.9569  |0.9289|0.962 |0.962 |
# +----------+--------+------+------+------+
# 32/32 - 145s - loss: 0.0165 - val_loss: 0.0234 - mean_accuracy: 0.9569 - mean_iou: 0.9289 - mean_dice: 0.9620 - mean_f1: 0.9620 - learning_rate: 4.4761e-04 - 145s/epoch - 5s/step

# %% [markdown]
# # 4. Evaluate

# %%
model_path = tfdet.dataset.util.list_dir(os.path.dirname(save_path), "h5")
model_path = sorted(model_path, key = lambda x: x.split("metric@")[1].split("-")[0], reverse = True)[0]
model.load_weights(model_path)

metric = tfdet.core.metric.MeanIoU(label = label)
for x_true, y_true in test_pipe:
    y_pred = model.predict(x_true, verbose = 0)
    metric.add(y_true, y_pred)
print(metric.summary_text)
# Out:
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9966  |0.9916|0.9958|0.9958|
# |balloon   |0.9156  |0.8668|0.9287|0.9287|
# +----------+--------+------+------+------+
# |summary   |0.9561  |0.9292|0.9622|0.9622|
# +----------+--------+------+------+------+

# %% [markdown]
# # 5. Load

# %%
with device:
    x = tf.keras.layers.Input(shape = [*image_shape, 3], name = "x_true")
    feature = tfdet.model.backbone.resnet50(x, weights = None)

    out = tfdet.model.detector.upernet(feature, n_class = n_class)
    out = tf.keras.layers.UpSampling2D((4, 4))(out)
    model = tf.keras.Model(x, out)
    model.load_weights(model_path)
    
metric = tfdet.core.metric.MeanIoU(label = label)
for x_true, y_true in test_pipe:
    y_pred = model.predict(x_true, verbose = 0)
    metric.add(y_true, y_pred)
print(metric.summary_text)
# Out:
# +----------+--------+------+------+------+
# |label     |accuracy|iou   |dice  |f1    |
# +----------+--------+------+------+------+
# |background|0.9966  |0.9916|0.9958|0.9958|
# |balloon   |0.9156  |0.8668|0.9287|0.9287|
# +----------+--------+------+------+------+
# |summary   |0.9561  |0.9292|0.9622|0.9622|
# +----------+--------+------+------+------+
