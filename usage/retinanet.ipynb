# %%
import os, shutil
if os.path.exists(os.path.join(os.getcwd(),"tfdetection")):
    shutil.rmtree(os.path.join(os.getcwd(),"tfdetection"))
if os.path.exists(os.path.join(os.getcwd(),"tfdet")):
    shutil.rmtree(os.path.join(os.getcwd(),"tfdet"))
# !git clone https://github.com/burf/tfdetection
shutil.copytree(os.path.join(os.getcwd(),"tfdetection", "tfdet"), os.path.join(os.getcwd(),"tfdet"))
# Out:
# Cloning into 'tfdetection'...
# remote: Enumerating objects: 788, done.
# remote: Counting objects: 100% (401/401), done.
# remote: Compressing objects: 100% (246/246), done.
# remote: Total 788 (delta 240), reused 276 (delta 155), pack-reused 387
# Receiving objects: 100% (788/788), 8.62 MiB | 27.01 MiB/s, done.
# Resolving deltas: 100% (449/449), done.
# '/content/tfdet'

# %%
# !wget -qq https://github.com/matterport/Mask_RCNN/releases/download/v2.1/balloon_dataset.zip
# !unzip -qq balloon_dataset.zip

import os
import json
import cv2
import skimage.draw
import tensorflow as tf
import numpy as np

def parse(path, target_size = (512, 512), method = cv2.INTER_CUBIC):
    dir_path = os.path.dirname(path)
    with open(path, "r") as file:
        anno = json.loads(file.read())
    anno = [a for a in list(anno.values()) if a["regions"]]

    images = []
    masks = []
    for a in anno:
        if type(a['regions']) is dict:
            polygons = [r['shape_attributes'] for r in a['regions'].values()]
        else:
            polygons = [r['shape_attributes'] for r in a['regions']]
        image = cv2.cvtColor(cv2.imread(os.path.join(dir_path, a["filename"]), -1), cv2.COLOR_BGR2RGB)
        h, w = np.shape(image)[:2]
        mask = np.zeros((h, w, len(polygons)), dtype = np.uint8)
        for i, p in enumerate(polygons):
            rr, cc = skimage.draw.polygon(p['all_points_y'], p['all_points_x'])
            rr = np.clip(rr, 0, h - 1)
            cc = np.clip(cc, 0, w - 1)
            mask[rr, cc, i] = 1
        
        if target_size is not None:
            image = cv2.resize(image, target_size[::-1], interpolation = method)
            mask = cv2.resize(mask, target_size[::-1], interpolation = method)
            if np.ndim(mask) == 2:
                mask = np.expand_dims(mask, axis = -1)
            mask = np.where(mask != 0, 1, 0)

        images.append(image)
        masks.append(np.transpose(mask, [2, 0, 1]))
    return images, masks

def mask2bbox(mask_true, normalize = True, decimal = 4):
    #mask_true = #(padded_num_true, h, w, 1)
    padded_num_true, h, w = np.shape(mask_true)[:3]

    bbox_true = []
    for index in range(padded_num_true):
        mask = mask_true[index]
        if 0 < np.max(mask):
            pos = np.where(0 < mask)[:2]
            bbox = [np.min(pos[1]), np.min(pos[0]), np.max(pos[1]), np.max(pos[0])] #x1, y1, x2, y2
        else:
            bbox = [0, 0, 0, 0]
        bbox_true.append(bbox)
    
    bbox_true = np.round(np.divide(bbox_true, [w, h, w, h]).astype(np.float32), decimal) if normalize else np.array(bbox_true, dtype = np.int32)
    return bbox_true

def pipe(data, func = None, batch_size = 2, shuffle = False):
    dataset = tf.data.Dataset.from_tensor_slices(data)
    if callable(func):
        dataset = dataset.map(func, num_parallel_calls = tf.data.experimental.AUTOTUNE)
    if shuffle:
        dataset = dataset.shuffle(buffer_size = batch_size * 10)
    dataset = dataset.batch(batch_size)
    #dataset = dataset.prefetch((batch_size * 2) + 1)
    dataset = dataset.prefetch(tf.data.experimental.AUTOTUNE)
    return dataset

tr_anno = "./balloon/train/via_region_data.json"
te_anno = "./balloon/val/via_region_data.json"

tr_x, tr_mask = parse(tr_anno, target_size = (512, 512))
te_x, te_mask = parse(te_anno, target_size = (512, 512))

max_cnt = 0
for mask in tr_mask + te_mask:
    if max_cnt < len(mask):
        max_cnt = len(mask)

tr_x = np.array(tr_x, dtype = np.float32) * 1/255
tr_mask = [np.pad(mask, [[0, max_cnt - len(mask)], [0, 0], [0, 0]]) for mask in tr_mask]
tr_mask = np.expand_dims(np.array(tr_mask, dtype = np.float32), axis = -1)
tr_bbox = np.array([mask2bbox(mask) for mask in tr_mask], dtype = np.float32)
tr_y = np.expand_dims(np.where(0 < np.max(tr_bbox, axis = -1), 1., 0.), axis = -1)

te_x = np.array(te_x, dtype = np.float32) * 1/255
te_mask = [np.pad(mask, [[0, max_cnt - len(mask)], [0, 0], [0, 0]]) for mask in te_mask]
te_mask = np.expand_dims(np.array(te_mask, dtype = np.float32), axis = -1)
te_bbox = np.array([mask2bbox(mask) for mask in te_mask], dtype = np.float32)
te_y = np.expand_dims(np.where(0 < np.max(te_bbox, axis = -1), 1., 0.), axis = -1)

# %%
import tfdet
import functools

x = tf.keras.layers.Input(shape = (512, 512, 3))
feature = tfdet.model.backbone.resnet50(x)

#scale = [32, 64, 128, 256, 512]
scale = [24, 48, 96, 192, 384]
ratio = [0.5, 1, 2]

bifpn = functools.partial(tfdet.model.neck.bifpn, weighted_add = False)
neck = functools.partial(tfdet.model.neck.FeatureAlign, pre_sampling = True, neck = bifpn)

out = tfdet.model.detector.retinanet(feature, n_class = 2, image_shape = tf.shape(x)[1:3], scale = scale, ratio = ratio, neck = neck)
model = tfdet.model.train.retina.train_model(x, *out, assign = tfdet.core.assign.max_iou, sampling_count = 256, positive_ratio = 0.5)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 1s 0us/step
# 94781440/94765736 [==============================] - 1s 0us/step
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/deprecation.py:616: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead

# %%
import albumentations
method = [albumentations.RandomBrightness(0.2, p = 0.5),
          albumentations.RandomContrast(0.2, p = 0.5),
          albumentations.ChannelShuffle(p = 0.5)]
method = albumentations.Compose(method)
    
def aug_func(image):
    return method(image = image)["image"]

key = x.name
def func(dic):
    shape = tf.shape(dic[key])
    dic[key] = tf.reshape(tf.py_function(lambda *args: aug_func(args[0].numpy()), inp = [dic[key]], Tout = tf.float32), shape)
    return dic

batch_size = 2

tr_data = pipe({x.name:tr_x, "y_true":tr_y, "bbox_true":tr_bbox}, func = func, batch_size = batch_size, shuffle = True)
te_data = pipe({x.name:te_x, "y_true":te_y, "bbox_true":te_bbox}, batch_size = batch_size, shuffle = False)

# %%
opt = tf.keras.optimizers.SGD(5e-3, momentum = 0.9, nesterov = True)
model.compile(optimizer = opt)
model.fit(tr_data, validation_data = te_data, epochs = 50)
# Out:
# Epoch 1/50
# 31/31 [==============================] - 44s 424ms/step - loss: 1.4365 - score_accuracy: 0.6079 - score_loss: 0.1570 - regress_loss: 1.2795 - val_loss: 1.2141 - val_score_accuracy: 0.5539 - val_score_loss: 0.1153 - val_regress_loss: 1.0987
# Epoch 2/50
# 31/31 [==============================] - 8s 266ms/step - loss: 1.2253 - score_accuracy: 0.6938 - score_loss: 0.1141 - regress_loss: 1.1112 - val_loss: 1.2212 - val_score_accuracy: 0.6670 - val_score_loss: 0.0991 - val_regress_loss: 1.1221
# Epoch 3/50
# 31/31 [==============================] - 8s 260ms/step - loss: 1.0917 - score_accuracy: 0.7646 - score_loss: 0.0934 - regress_loss: 0.9984 - val_loss: 1.1930 - val_score_accuracy: 0.6593 - val_score_loss: 0.1039 - val_regress_loss: 1.0891
# Epoch 4/50
# 31/31 [==============================] - 8s 260ms/step - loss: 0.9221 - score_accuracy: 0.8484 - score_loss: 0.0651 - regress_loss: 0.8570 - val_loss: 1.2232 - val_score_accuracy: 0.6873 - val_score_loss: 0.1307 - val_regress_loss: 1.0925
# Epoch 5/50
# 31/31 [==============================] - 8s 261ms/step - loss: 0.8065 - score_accuracy: 0.8780 - score_loss: 0.0553 - regress_loss: 0.7512 - val_loss: 1.3136 - val_score_accuracy: 0.6841 - val_score_loss: 0.1715 - val_regress_loss: 1.1421
# Epoch 6/50
# 31/31 [==============================] - 8s 260ms/step - loss: 0.7344 - score_accuracy: 0.8940 - score_loss: 0.0489 - regress_loss: 0.6855 - val_loss: 1.4803 - val_score_accuracy: 0.5009 - val_score_loss: 0.2273 - val_regress_loss: 1.2530
# Epoch 7/50
# 31/31 [==============================] - 8s 260ms/step - loss: 0.6856 - score_accuracy: 0.9059 - score_loss: 0.0457 - regress_loss: 0.6400 - val_loss: 1.6825 - val_score_accuracy: 0.5000 - val_score_loss: 0.3659 - val_regress_loss: 1.3166
# Epoch 8/50
# 31/31 [==============================] - 8s 261ms/step - loss: 0.6139 - score_accuracy: 0.9317 - score_loss: 0.0333 - regress_loss: 0.5805 - val_loss: 1.7252 - val_score_accuracy: 0.5000 - val_score_loss: 0.3780 - val_regress_loss: 1.3472
# Epoch 9/50
# 31/31 [==============================] - 8s 261ms/step - loss: 0.5791 - score_accuracy: 0.9298 - score_loss: 0.0345 - regress_loss: 0.5446 - val_loss: 1.6946 - val_score_accuracy: 0.5000 - val_score_loss: 0.4293 - val_regress_loss: 1.2653
# Epoch 10/50
# 31/31 [==============================] - 8s 260ms/step - loss: 0.5153 - score_accuracy: 0.9442 - score_loss: 0.0282 - regress_loss: 0.4871 - val_loss: 1.7531 - val_score_accuracy: 0.5000 - val_score_loss: 0.4120 - val_regress_loss: 1.3411
# Epoch 11/50
# 31/31 [==============================] - 8s 260ms/step - loss: 0.5198 - score_accuracy: 0.9478 - score_loss: 0.0262 - regress_loss: 0.4936 - val_loss: 1.7280 - val_score_accuracy: 0.5000 - val_score_loss: 0.4613 - val_regress_loss: 1.2667
# Epoch 12/50
# 31/31 [==============================] - 8s 261ms/step - loss: 0.4624 - score_accuracy: 0.9539 - score_loss: 0.0239 - regress_loss: 0.4385 - val_loss: 1.7544 - val_score_accuracy: 0.5000 - val_score_loss: 0.4745 - val_regress_loss: 1.2799
# Epoch 13/50
# 31/31 [==============================] - 8s 261ms/step - loss: 0.4237 - score_accuracy: 0.9645 - score_loss: 0.0198 - regress_loss: 0.4039 - val_loss: 1.7556 - val_score_accuracy: 0.5000 - val_score_loss: 0.4828 - val_regress_loss: 1.2728
# Epoch 14/50
# 31/31 [==============================] - 8s 260ms/step - loss: 0.4209 - score_accuracy: 0.9614 - score_loss: 0.0209 - regress_loss: 0.3999 - val_loss: 1.5721 - val_score_accuracy: 0.5473 - val_score_loss: 0.3535 - val_regress_loss: 1.2187
# Epoch 15/50
# 31/31 [==============================] - 8s 260ms/step - loss: 0.3977 - score_accuracy: 0.9676 - score_loss: 0.0175 - regress_loss: 0.3802 - val_loss: 1.5390 - val_score_accuracy: 0.6037 - val_score_loss: 0.3267 - val_regress_loss: 1.2123
# Epoch 16/50
# 31/31 [==============================] - 8s 262ms/step - loss: 0.3773 - score_accuracy: 0.9665 - score_loss: 0.0173 - regress_loss: 0.3600 - val_loss: 1.4706 - val_score_accuracy: 0.6075 - val_score_loss: 0.3100 - val_regress_loss: 1.1606
# Epoch 17/50
# 31/31 [==============================] - 8s 260ms/step - loss: 0.3573 - score_accuracy: 0.9652 - score_loss: 0.0169 - regress_loss: 0.3403 - val_loss: 1.4208 - val_score_accuracy: 0.6308 - val_score_loss: 0.2918 - val_regress_loss: 1.1290
# Epoch 18/50
# 31/31 [==============================] - 8s 260ms/step - loss: 0.3511 - score_accuracy: 0.9667 - score_loss: 0.0177 - regress_loss: 0.3334 - val_loss: 1.3704 - val_score_accuracy: 0.5710 - val_score_loss: 0.3061 - val_regress_loss: 1.0643
# Epoch 19/50
# 31/31 [==============================] - 8s 260ms/step - loss: 0.3457 - score_accuracy: 0.9671 - score_loss: 0.0172 - regress_loss: 0.3284 - val_loss: 1.2023 - val_score_accuracy: 0.6056 - val_score_loss: 0.2719 - val_regress_loss: 0.9304
# Epoch 20/50
# 31/31 [==============================] - 8s 260ms/step - loss: 0.3208 - score_accuracy: 0.9769 - score_loss: 0.0140 - regress_loss: 0.3068 - val_loss: 1.0881 - val_score_accuracy: 0.6351 - val_score_loss: 0.2119 - val_regress_loss: 0.8762
# Epoch 21/50
# 31/31 [==============================] - 8s 260ms/step - loss: 0.3075 - score_accuracy: 0.9772 - score_loss: 0.0131 - regress_loss: 0.2944 - val_loss: 0.9166 - val_score_accuracy: 0.7202 - val_score_loss: 0.1455 - val_regress_loss: 0.7711
# Epoch 22/50
# 31/31 [==============================] - 8s 260ms/step - loss: 0.2984 - score_accuracy: 0.9797 - score_loss: 0.0121 - regress_loss: 0.2863 - val_loss: 0.8517 - val_score_accuracy: 0.7620 - val_score_loss: 0.1248 - val_regress_loss: 0.7268
# Epoch 23/50
# 31/31 [==============================] - 8s 259ms/step - loss: 0.2765 - score_accuracy: 0.9786 - score_loss: 0.0121 - regress_loss: 0.2644 - val_loss: 0.7656 - val_score_accuracy: 0.7967 - val_score_loss: 0.0946 - val_regress_loss: 0.6710
# Epoch 24/50
# 31/31 [==============================] - 8s 260ms/step - loss: 0.2841 - score_accuracy: 0.9776 - score_loss: 0.0111 - regress_loss: 0.2730 - val_loss: 0.7785 - val_score_accuracy: 0.8127 - val_score_loss: 0.0943 - val_regress_loss: 0.6842
# Epoch 25/50
# 31/31 [==============================] - 8s 259ms/step - loss: 0.2672 - score_accuracy: 0.9825 - score_loss: 0.0105 - regress_loss: 0.2566 - val_loss: 0.7181 - val_score_accuracy: 0.8424 - val_score_loss: 0.0790 - val_regress_loss: 0.6391
# Epoch 26/50
# 31/31 [==============================] - 8s 262ms/step - loss: 0.2695 - score_accuracy: 0.9791 - score_loss: 0.0112 - regress_loss: 0.2582 - val_loss: 0.6779 - val_score_accuracy: 0.8690 - val_score_loss: 0.0639 - val_regress_loss: 0.6140
# Epoch 27/50
# 31/31 [==============================] - 8s 260ms/step - loss: 0.2562 - score_accuracy: 0.9842 - score_loss: 0.0093 - regress_loss: 0.2469 - val_loss: 0.6597 - val_score_accuracy: 0.8734 - val_score_loss: 0.0593 - val_regress_loss: 0.6004
# Epoch 28/50
# 31/31 [==============================] - 8s 260ms/step - loss: 0.2495 - score_accuracy: 0.9814 - score_loss: 0.0101 - regress_loss: 0.2394 - val_loss: 0.6418 - val_score_accuracy: 0.8937 - val_score_loss: 0.0534 - val_regress_loss: 0.5884
# Epoch 29/50
# 31/31 [==============================] - 8s 261ms/step - loss: 0.2687 - score_accuracy: 0.9850 - score_loss: 0.0091 - regress_loss: 0.2596 - val_loss: 0.6366 - val_score_accuracy: 0.9093 - val_score_loss: 0.0486 - val_regress_loss: 0.5880
# Epoch 30/50
# 31/31 [==============================] - 8s 260ms/step - loss: 0.2804 - score_accuracy: 0.9804 - score_loss: 0.0115 - regress_loss: 0.2689 - val_loss: 0.6460 - val_score_accuracy: 0.8935 - val_score_loss: 0.0573 - val_regress_loss: 0.5887
# Epoch 31/50
# 31/31 [==============================] - 8s 261ms/step - loss: 0.2424 - score_accuracy: 0.9830 - score_loss: 0.0099 - regress_loss: 0.2324 - val_loss: 0.6559 - val_score_accuracy: 0.8977 - val_score_loss: 0.0600 - val_regress_loss: 0.5959
# Epoch 32/50
# 31/31 [==============================] - 8s 259ms/step - loss: 0.2429 - score_accuracy: 0.9853 - score_loss: 0.0089 - regress_loss: 0.2339 - val_loss: 0.6173 - val_score_accuracy: 0.9030 - val_score_loss: 0.0536 - val_regress_loss: 0.5637
# Epoch 33/50
# 31/31 [==============================] - 8s 260ms/step - loss: 0.2293 - score_accuracy: 0.9838 - score_loss: 0.0089 - regress_loss: 0.2204 - val_loss: 0.5793 - val_score_accuracy: 0.9199 - val_score_loss: 0.0496 - val_regress_loss: 0.5297
# Epoch 34/50
# 31/31 [==============================] - 8s 259ms/step - loss: 0.2111 - score_accuracy: 0.9875 - score_loss: 0.0077 - regress_loss: 0.2033 - val_loss: 0.5844 - val_score_accuracy: 0.9124 - val_score_loss: 0.0522 - val_regress_loss: 0.5322
# Epoch 35/50
# 31/31 [==============================] - 8s 261ms/step - loss: 0.2087 - score_accuracy: 0.9863 - score_loss: 0.0083 - regress_loss: 0.2004 - val_loss: 0.6037 - val_score_accuracy: 0.9010 - val_score_loss: 0.0611 - val_regress_loss: 0.5426
# Epoch 36/50
# 31/31 [==============================] - 8s 260ms/step - loss: 0.2043 - score_accuracy: 0.9862 - score_loss: 0.0078 - regress_loss: 0.1964 - val_loss: 0.6110 - val_score_accuracy: 0.9041 - val_score_loss: 0.0617 - val_regress_loss: 0.5493
# Epoch 37/50
# 31/31 [==============================] - 8s 260ms/step - loss: 0.1950 - score_accuracy: 0.9886 - score_loss: 0.0066 - regress_loss: 0.1884 - val_loss: 0.5914 - val_score_accuracy: 0.9035 - val_score_loss: 0.0584 - val_regress_loss: 0.5330
# Epoch 38/50
# 31/31 [==============================] - 8s 260ms/step - loss: 0.2013 - score_accuracy: 0.9872 - score_loss: 0.0071 - regress_loss: 0.1942 - val_loss: 0.5665 - val_score_accuracy: 0.9073 - val_score_loss: 0.0499 - val_regress_loss: 0.5166
# Epoch 39/50
# 31/31 [==============================] - 8s 260ms/step - loss: 0.1935 - score_accuracy: 0.9882 - score_loss: 0.0073 - regress_loss: 0.1862 - val_loss: 0.5830 - val_score_accuracy: 0.9093 - val_score_loss: 0.0550 - val_regress_loss: 0.5280
# Epoch 40/50
# 31/31 [==============================] - 8s 261ms/step - loss: 0.1806 - score_accuracy: 0.9907 - score_loss: 0.0058 - regress_loss: 0.1748 - val_loss: 0.6012 - val_score_accuracy: 0.9066 - val_score_loss: 0.0537 - val_regress_loss: 0.5475
# Epoch 41/50
# 31/31 [==============================] - 8s 260ms/step - loss: 0.1899 - score_accuracy: 0.9862 - score_loss: 0.0075 - regress_loss: 0.1824 - val_loss: 0.5650 - val_score_accuracy: 0.9061 - val_score_loss: 0.0466 - val_regress_loss: 0.5183
# Epoch 42/50
# 31/31 [==============================] - 8s 262ms/step - loss: 0.1692 - score_accuracy: 0.9910 - score_loss: 0.0062 - regress_loss: 0.1630 - val_loss: 0.5800 - val_score_accuracy: 0.9029 - val_score_loss: 0.0553 - val_regress_loss: 0.5246
# Epoch 43/50
# 31/31 [==============================] - 8s 261ms/step - loss: 0.1879 - score_accuracy: 0.9892 - score_loss: 0.0063 - regress_loss: 0.1816 - val_loss: 0.5666 - val_score_accuracy: 0.9021 - val_score_loss: 0.0555 - val_regress_loss: 0.5110
# Epoch 44/50
# 31/31 [==============================] - 8s 260ms/step - loss: 0.1653 - score_accuracy: 0.9916 - score_loss: 0.0052 - regress_loss: 0.1601 - val_loss: 0.5796 - val_score_accuracy: 0.8893 - val_score_loss: 0.0656 - val_regress_loss: 0.5140
# Epoch 45/50
# 31/31 [==============================] - 8s 260ms/step - loss: 0.1695 - score_accuracy: 0.9862 - score_loss: 0.0081 - regress_loss: 0.1614 - val_loss: 0.5899 - val_score_accuracy: 0.8776 - val_score_loss: 0.0752 - val_regress_loss: 0.5147
# Epoch 46/50
# 31/31 [==============================] - 8s 261ms/step - loss: 0.1555 - score_accuracy: 0.9900 - score_loss: 0.0057 - regress_loss: 0.1498 - val_loss: 0.6066 - val_score_accuracy: 0.8773 - val_score_loss: 0.0730 - val_regress_loss: 0.5335
# Epoch 47/50
# 31/31 [==============================] - 8s 262ms/step - loss: 0.1594 - score_accuracy: 0.9912 - score_loss: 0.0052 - regress_loss: 0.1542 - val_loss: 0.5632 - val_score_accuracy: 0.8915 - val_score_loss: 0.0628 - val_regress_loss: 0.5004
# Epoch 48/50
# 31/31 [==============================] - 8s 261ms/step - loss: 0.1632 - score_accuracy: 0.9906 - score_loss: 0.0059 - regress_loss: 0.1573 - val_loss: 0.5910 - val_score_accuracy: 0.8795 - val_score_loss: 0.0695 - val_regress_loss: 0.5215
# Epoch 49/50
# 31/31 [==============================] - 8s 261ms/step - loss: 0.1583 - score_accuracy: 0.9895 - score_loss: 0.0059 - regress_loss: 0.1524 - val_loss: 0.5640 - val_score_accuracy: 0.8824 - val_score_loss: 0.0709 - val_regress_loss: 0.4932
# Epoch 50/50
# 31/31 [==============================] - 8s 260ms/step - loss: 0.1450 - score_accuracy: 0.9913 - score_loss: 0.0054 - regress_loss: 0.1396 - val_loss: 0.5749 - val_score_accuracy: 0.8892 - val_score_loss: 0.0675 - val_regress_loss: 0.5074

# %%
model.save_weights("model.h5")

# %%
x = tf.keras.layers.Input(shape = (512, 512, 3))
feature = tfdet.model.backbone.resnet50(x)
#scale = [32, 64, 128, 256, 512]
scale = [24, 48, 96, 192, 384]
ratio = [0.5, 1, 2]
bifpn = functools.partial(tfdet.model.neck.bifpn, weighted_add = False)
neck = functools.partial(tfdet.model.neck.FeatureAlign, pre_sampling = True, neck = bifpn)
out = tfdet.model.detector.retinanet(feature, n_class = 2, image_shape = tf.shape(x)[1:3], scale = scale, ratio = ratio, neck = neck)
prediction = tfdet.model.postprocess.retina.FilterDetection(proposal_count = 100, iou_threshold = 0.3, score_threshold = 0.9, soft_nms = False)(out)
model = tf.keras.Model(x, prediction)
model.load_weights("model.h5")

# %%
images = te_x[:1]
logits, proposal = model.predict(images)
images = tfdet.util.draw_bbox(images, proposal, logits, label = ["Background", "Balloon"])

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (10, 10))
plt.imshow(images[0])
