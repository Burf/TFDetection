# %%
import os, shutil
if os.path.exists(os.path.join(os.getcwd(),"tfdetection")):
    shutil.rmtree(os.path.join(os.getcwd(),"tfdetection"))
if os.path.exists(os.path.join(os.getcwd(),"tfdet")):
    shutil.rmtree(os.path.join(os.getcwd(),"tfdet"))
# !git clone https://github.com/burf/tfdetection
shutil.copytree(os.path.join(os.getcwd(),"tfdetection", "tfdet"), os.path.join(os.getcwd(),"tfdet"))
# Out:
# Cloning into 'tfdetection'...
# remote: Enumerating objects: 788, done.
# remote: Counting objects: 100% (401/401), done.
# remote: Compressing objects: 100% (246/246), done.
# remote: Total 788 (delta 240), reused 276 (delta 155), pack-reused 387
# Receiving objects: 100% (788/788), 8.62 MiB | 22.42 MiB/s, done.
# Resolving deltas: 100% (449/449), done.
# '/content/tfdet'

# %%
# !wget -qq https://github.com/matterport/Mask_RCNN/releases/download/v2.1/balloon_dataset.zip
# !unzip -qq balloon_dataset.zip

import os
import json
import cv2
import skimage.draw
import tensorflow as tf
import numpy as np

def parse(path, target_size = (512, 512), method = cv2.INTER_CUBIC):
    dir_path = os.path.dirname(path)
    with open(path, "r") as file:
        anno = json.loads(file.read())
    anno = [a for a in list(anno.values()) if a["regions"]]

    images = []
    masks = []
    for a in anno:
        if type(a['regions']) is dict:
            polygons = [r['shape_attributes'] for r in a['regions'].values()]
        else:
            polygons = [r['shape_attributes'] for r in a['regions']]
        image = cv2.cvtColor(cv2.imread(os.path.join(dir_path, a["filename"]), -1), cv2.COLOR_BGR2RGB)
        h, w = np.shape(image)[:2]
        mask = np.zeros((h, w, len(polygons)), dtype = np.uint8)
        for i, p in enumerate(polygons):
            rr, cc = skimage.draw.polygon(p['all_points_y'], p['all_points_x'])
            rr = np.clip(rr, 0, h - 1)
            cc = np.clip(cc, 0, w - 1)
            mask[rr, cc, i] = 1
        
        if target_size is not None:
            image = cv2.resize(image, target_size[::-1], interpolation = method)
            mask = cv2.resize(mask, target_size[::-1], interpolation = method)
            if np.ndim(mask) == 2:
                mask = np.expand_dims(mask, axis = -1)
            mask = np.where(mask != 0, 1, 0)

        images.append(image)
        masks.append(np.transpose(mask, [2, 0, 1]))
    return images, masks

def mask2bbox(mask_true, normalize = True, decimal = 4):
    #mask_true = #(padded_num_true, h, w, 1)
    padded_num_true, h, w = np.shape(mask_true)[:3]

    bbox_true = []
    for index in range(padded_num_true):
        mask = mask_true[index]
        if 0 < np.max(mask):
            pos = np.where(0 < mask)[:2]
            bbox = [np.min(pos[1]), np.min(pos[0]), np.max(pos[1]), np.max(pos[0])] #x1, y1, x2, y2
        else:
            bbox = [0, 0, 0, 0]
        bbox_true.append(bbox)
    
    bbox_true = np.round(np.divide(bbox_true, [w, h, w, h]).astype(np.float32), decimal) if normalize else np.array(bbox_true, dtype = np.int32)
    return bbox_true

def pipe(data, func = None, batch_size = 2, shuffle = False):
    dataset = tf.data.Dataset.from_tensor_slices(data)
    if callable(func):
        dataset = dataset.map(func, num_parallel_calls = tf.data.experimental.AUTOTUNE)
    if shuffle:
        dataset = dataset.shuffle(buffer_size = batch_size * 10)
    dataset = dataset.batch(batch_size)
    #dataset = dataset.prefetch((batch_size * 2) + 1)
    dataset = dataset.prefetch(tf.data.experimental.AUTOTUNE)
    return dataset

tr_anno = "./balloon/train/via_region_data.json"
te_anno = "./balloon/val/via_region_data.json"

tr_x, tr_mask = parse(tr_anno, target_size = (512, 512))
te_x, te_mask = parse(te_anno, target_size = (512, 512))

max_cnt = 0
for mask in tr_mask + te_mask:
    if max_cnt < len(mask):
        max_cnt = len(mask)

tr_x = np.array(tr_x, dtype = np.float32) * 1/255
tr_mask = [np.pad(mask, [[0, max_cnt - len(mask)], [0, 0], [0, 0]]) for mask in tr_mask]
tr_mask = np.expand_dims(np.array(tr_mask, dtype = np.float32), axis = -1)
tr_bbox = np.array([mask2bbox(mask) for mask in tr_mask], dtype = np.float32)
tr_y = np.expand_dims(np.where(0 < np.max(tr_bbox, axis = -1), 1., 0.), axis = -1)

te_x = np.array(te_x, dtype = np.float32) * 1/255
te_mask = [np.pad(mask, [[0, max_cnt - len(mask)], [0, 0], [0, 0]]) for mask in te_mask]
te_mask = np.expand_dims(np.array(te_mask, dtype = np.float32), axis = -1)
te_bbox = np.array([mask2bbox(mask) for mask in te_mask], dtype = np.float32)
te_y = np.expand_dims(np.where(0 < np.max(te_bbox, axis = -1), 1., 0.), axis = -1)

# %%
import tfdet
import functools

#x = tf.keras.layers.Input(shape = (1024, 1024, 3))
x = tf.keras.layers.Input(shape = (512, 512, 3))

#scale = [32, 64, 128, 256, 512]
scale = [24, 48, 96, 192, 384]
ratio = [0.5, 1, 2]

out = tfdet.model.detector.effdet_d4(x, n_class = 2, scale = scale, ratio = ratio, octave = 3)
model = tfdet.model.train.effdet.train_model(x, *out, assign = tfdet.core.assign.max_iou, sampling_count = 256, positive_ratio = 0.5)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb4_notop.h5
# 71688192/71686520 [==============================] - 0s 0us/step
# 71696384/71686520 [==============================] - 0s 0us/step
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/deprecation.py:616: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead

# %%
import albumentations
method = [albumentations.RandomBrightness(0.2, p = 0.5),
          albumentations.RandomContrast(0.2, p = 0.5),
          albumentations.ChannelShuffle(p = 0.5)]
method = albumentations.Compose(method)
    
def aug_func(image):
    return method(image = image)["image"]

key = x.name
def func(dic):
    shape = tf.shape(dic[key])
    dic[key] = tf.reshape(tf.py_function(lambda *args: aug_func(args[0].numpy()), inp = [dic[key]], Tout = tf.float32), shape)
    return dic

batch_size = 2

tr_data = pipe({x.name:tr_x, "y_true":tr_y, "bbox_true":tr_bbox}, func = func, batch_size = batch_size, shuffle = True)
te_data = pipe({x.name:te_x, "y_true":te_y, "bbox_true":te_bbox}, batch_size = batch_size, shuffle = False)

# %%
opt = tf.keras.optimizers.SGD(5e-3, momentum = 0.9, nesterov = True)
model.compile(optimizer = opt)
model.fit(tr_data, validation_data = te_data, epochs = 100)
# Out:
# Epoch 1/100
# 31/31 [==============================] - 74s 656ms/step - loss: 1.1761 - score_accuracy: 0.5366 - score_loss: 0.1218 - regress_loss: 1.0528 - val_loss: 1.2274 - val_score_accuracy: 0.5589 - val_score_loss: 0.1219 - val_regress_loss: 1.1040
# Epoch 2/100
# 31/31 [==============================] - 11s 364ms/step - loss: 1.1572 - score_accuracy: 0.5859 - score_loss: 0.1191 - regress_loss: 1.0365 - val_loss: 1.2235 - val_score_accuracy: 0.5843 - val_score_loss: 0.1210 - val_regress_loss: 1.1009
# Epoch 3/100
# 31/31 [==============================] - 11s 364ms/step - loss: 1.1434 - score_accuracy: 0.6486 - score_loss: 0.1165 - regress_loss: 1.0254 - val_loss: 1.2202 - val_score_accuracy: 0.5682 - val_score_loss: 0.1203 - val_regress_loss: 1.0984
# Epoch 4/100
# 31/31 [==============================] - 11s 364ms/step - loss: 1.1334 - score_accuracy: 0.6383 - score_loss: 0.1140 - regress_loss: 1.0178 - val_loss: 1.2174 - val_score_accuracy: 0.5778 - val_score_loss: 0.1195 - val_regress_loss: 1.0963
# Epoch 5/100
# 31/31 [==============================] - 11s 366ms/step - loss: 1.1274 - score_accuracy: 0.6836 - score_loss: 0.1119 - regress_loss: 1.0140 - val_loss: 1.2149 - val_score_accuracy: 0.5705 - val_score_loss: 0.1189 - val_regress_loss: 1.0944
# Epoch 6/100
# 31/31 [==============================] - 11s 365ms/step - loss: 1.1117 - score_accuracy: 0.7116 - score_loss: 0.1093 - regress_loss: 1.0009 - val_loss: 1.2124 - val_score_accuracy: 0.5787 - val_score_loss: 0.1184 - val_regress_loss: 1.0924
# Epoch 7/100
# 31/31 [==============================] - 11s 364ms/step - loss: 1.0922 - score_accuracy: 0.7203 - score_loss: 0.1064 - regress_loss: 0.9843 - val_loss: 1.2104 - val_score_accuracy: 0.5895 - val_score_loss: 0.1178 - val_regress_loss: 1.0911
# Epoch 8/100
# 31/31 [==============================] - 11s 363ms/step - loss: 1.0852 - score_accuracy: 0.7231 - score_loss: 0.1023 - regress_loss: 0.9814 - val_loss: 1.2088 - val_score_accuracy: 0.5664 - val_score_loss: 0.1173 - val_regress_loss: 1.0899
# Epoch 9/100
# 31/31 [==============================] - 11s 364ms/step - loss: 1.0607 - score_accuracy: 0.7427 - score_loss: 0.0983 - regress_loss: 0.9608 - val_loss: 1.2076 - val_score_accuracy: 0.5717 - val_score_loss: 0.1170 - val_regress_loss: 1.0891
# Epoch 10/100
# 31/31 [==============================] - 11s 365ms/step - loss: 1.0546 - score_accuracy: 0.7422 - score_loss: 0.0990 - regress_loss: 0.9541 - val_loss: 1.2064 - val_score_accuracy: 0.5793 - val_score_loss: 0.1165 - val_regress_loss: 1.0883
# Epoch 11/100
# 31/31 [==============================] - 11s 365ms/step - loss: 1.0284 - score_accuracy: 0.7815 - score_loss: 0.0959 - regress_loss: 0.9310 - val_loss: 1.2052 - val_score_accuracy: 0.5689 - val_score_loss: 0.1161 - val_regress_loss: 1.0876
# Epoch 12/100
# 31/31 [==============================] - 11s 364ms/step - loss: 1.0364 - score_accuracy: 0.7804 - score_loss: 0.0937 - regress_loss: 0.9412 - val_loss: 1.2044 - val_score_accuracy: 0.5641 - val_score_loss: 0.1158 - val_regress_loss: 1.0871
# Epoch 13/100
# 31/31 [==============================] - 11s 365ms/step - loss: 1.0010 - score_accuracy: 0.7928 - score_loss: 0.0915 - regress_loss: 0.9080 - val_loss: 1.2040 - val_score_accuracy: 0.5655 - val_score_loss: 0.1156 - val_regress_loss: 1.0869
# Epoch 14/100
# 31/31 [==============================] - 11s 364ms/step - loss: 0.9776 - score_accuracy: 0.7997 - score_loss: 0.0886 - regress_loss: 0.8875 - val_loss: 1.2037 - val_score_accuracy: 0.5679 - val_score_loss: 0.1153 - val_regress_loss: 1.0869
# Epoch 15/100
# 31/31 [==============================] - 11s 365ms/step - loss: 0.9775 - score_accuracy: 0.8089 - score_loss: 0.0890 - regress_loss: 0.8869 - val_loss: 1.2036 - val_score_accuracy: 0.5787 - val_score_loss: 0.1153 - val_regress_loss: 1.0867
# Epoch 16/100
# 31/31 [==============================] - 11s 365ms/step - loss: 0.9516 - score_accuracy: 0.8275 - score_loss: 0.0861 - regress_loss: 0.8640 - val_loss: 1.2036 - val_score_accuracy: 0.5197 - val_score_loss: 0.1151 - val_regress_loss: 1.0869
# Epoch 17/100
# 31/31 [==============================] - 11s 364ms/step - loss: 0.9416 - score_accuracy: 0.8214 - score_loss: 0.0853 - regress_loss: 0.8548 - val_loss: 1.2038 - val_score_accuracy: 0.5000 - val_score_loss: 0.1152 - val_regress_loss: 1.0870
# Epoch 18/100
# 31/31 [==============================] - 11s 366ms/step - loss: 0.9484 - score_accuracy: 0.8024 - score_loss: 0.0861 - regress_loss: 0.8608 - val_loss: 1.2041 - val_score_accuracy: 0.5000 - val_score_loss: 0.1152 - val_regress_loss: 1.0873
# Epoch 19/100
# 31/31 [==============================] - 11s 363ms/step - loss: 0.9297 - score_accuracy: 0.8507 - score_loss: 0.0819 - regress_loss: 0.8463 - val_loss: 1.2038 - val_score_accuracy: 0.5000 - val_score_loss: 0.1152 - val_regress_loss: 1.0870
# Epoch 20/100
# 31/31 [==============================] - 11s 365ms/step - loss: 0.9474 - score_accuracy: 0.8407 - score_loss: 0.0830 - regress_loss: 0.8629 - val_loss: 1.2044 - val_score_accuracy: 0.5000 - val_score_loss: 0.1156 - val_regress_loss: 1.0873
# Epoch 21/100
# 31/31 [==============================] - 11s 365ms/step - loss: 0.9219 - score_accuracy: 0.8457 - score_loss: 0.0803 - regress_loss: 0.8401 - val_loss: 1.2042 - val_score_accuracy: 0.5000 - val_score_loss: 0.1155 - val_regress_loss: 1.0871
# Epoch 22/100
# 31/31 [==============================] - 11s 364ms/step - loss: 0.8796 - score_accuracy: 0.8402 - score_loss: 0.0779 - regress_loss: 0.8001 - val_loss: 1.1927 - val_score_accuracy: 0.5201 - val_score_loss: 0.1146 - val_regress_loss: 1.0765
# Epoch 23/100
# 31/31 [==============================] - 11s 362ms/step - loss: 0.8693 - score_accuracy: 0.8395 - score_loss: 0.0787 - regress_loss: 0.7890 - val_loss: 1.0630 - val_score_accuracy: 0.7177 - val_score_loss: 0.0965 - val_regress_loss: 0.9650
# Epoch 24/100
# 31/31 [==============================] - 11s 364ms/step - loss: 0.8333 - score_accuracy: 0.8448 - score_loss: 0.0762 - regress_loss: 0.7555 - val_loss: 1.1721 - val_score_accuracy: 0.5754 - val_score_loss: 0.1105 - val_regress_loss: 1.0601
# Epoch 25/100
# 31/31 [==============================] - 11s 364ms/step - loss: 0.8445 - score_accuracy: 0.8475 - score_loss: 0.0735 - regress_loss: 0.7695 - val_loss: 1.1449 - val_score_accuracy: 0.6087 - val_score_loss: 0.1079 - val_regress_loss: 1.0355
# Epoch 26/100
# 31/31 [==============================] - 12s 367ms/step - loss: 0.8332 - score_accuracy: 0.8369 - score_loss: 0.0751 - regress_loss: 0.7566 - val_loss: 1.1835 - val_score_accuracy: 0.5800 - val_score_loss: 0.1126 - val_regress_loss: 1.0694
# Epoch 27/100
# 31/31 [==============================] - 11s 364ms/step - loss: 0.7812 - score_accuracy: 0.8456 - score_loss: 0.0727 - regress_loss: 0.7070 - val_loss: 1.1066 - val_score_accuracy: 0.7098 - val_score_loss: 0.0973 - val_regress_loss: 1.0078
# Epoch 28/100
# 31/31 [==============================] - 11s 363ms/step - loss: 0.7609 - score_accuracy: 0.8557 - score_loss: 0.0718 - regress_loss: 0.6875 - val_loss: 2.6781 - val_score_accuracy: 0.5000 - val_score_loss: 0.6072 - val_regress_loss: 2.0693
# Epoch 29/100
# 31/31 [==============================] - 11s 365ms/step - loss: 0.7410 - score_accuracy: 0.8623 - score_loss: 0.0698 - regress_loss: 0.6697 - val_loss: 2.6553 - val_score_accuracy: 0.5065 - val_score_loss: 0.4663 - val_regress_loss: 2.1875
# Epoch 30/100
# 31/31 [==============================] - 11s 365ms/step - loss: 0.7131 - score_accuracy: 0.8526 - score_loss: 0.0695 - regress_loss: 0.6421 - val_loss: 1.9193 - val_score_accuracy: 0.5779 - val_score_loss: 0.2410 - val_regress_loss: 1.6768
# Epoch 31/100
# 31/31 [==============================] - 11s 364ms/step - loss: 0.7087 - score_accuracy: 0.8673 - score_loss: 0.0677 - regress_loss: 0.6395 - val_loss: 2.0265 - val_score_accuracy: 0.5937 - val_score_loss: 0.2594 - val_regress_loss: 1.7655
# Epoch 32/100
# 31/31 [==============================] - 11s 367ms/step - loss: 0.6827 - score_accuracy: 0.8624 - score_loss: 0.0685 - regress_loss: 0.6126 - val_loss: 3.1717 - val_score_accuracy: 0.5338 - val_score_loss: 0.4743 - val_regress_loss: 2.6958
# Epoch 33/100
# 31/31 [==============================] - 11s 364ms/step - loss: 0.6690 - score_accuracy: 0.8591 - score_loss: 0.0668 - regress_loss: 0.6006 - val_loss: 5.6913 - val_score_accuracy: 0.5027 - val_score_loss: 0.9833 - val_regress_loss: 4.7064
# Epoch 34/100
# 31/31 [==============================] - 11s 363ms/step - loss: 0.6498 - score_accuracy: 0.8684 - score_loss: 0.0650 - regress_loss: 0.5833 - val_loss: 5.8226 - val_score_accuracy: 0.5060 - val_score_loss: 1.1187 - val_regress_loss: 4.7023
# Epoch 35/100
# 31/31 [==============================] - 11s 365ms/step - loss: 0.6435 - score_accuracy: 0.8718 - score_loss: 0.0652 - regress_loss: 0.5768 - val_loss: 0.9182 - val_score_accuracy: 0.8528 - val_score_loss: 0.0751 - val_regress_loss: 0.8416
# Epoch 36/100
# 31/31 [==============================] - 11s 362ms/step - loss: 0.6214 - score_accuracy: 0.8855 - score_loss: 0.0636 - regress_loss: 0.5564 - val_loss: 1.0972 - val_score_accuracy: 0.7106 - val_score_loss: 0.0931 - val_regress_loss: 1.0026
# Epoch 37/100
# 31/31 [==============================] - 11s 365ms/step - loss: 0.6036 - score_accuracy: 0.8824 - score_loss: 0.0639 - regress_loss: 0.5382 - val_loss: 0.9560 - val_score_accuracy: 0.8141 - val_score_loss: 0.0759 - val_regress_loss: 0.8786
# Epoch 38/100
# 31/31 [==============================] - 11s 363ms/step - loss: 0.6438 - score_accuracy: 0.8759 - score_loss: 0.0637 - regress_loss: 0.5785 - val_loss: 0.9764 - val_score_accuracy: 0.7721 - val_score_loss: 0.0853 - val_regress_loss: 0.8895
# Epoch 39/100
# 31/31 [==============================] - 11s 365ms/step - loss: 0.6197 - score_accuracy: 0.8754 - score_loss: 0.0631 - regress_loss: 0.5551 - val_loss: 1.3118 - val_score_accuracy: 0.7465 - val_score_loss: 0.1112 - val_regress_loss: 1.1991
# Epoch 40/100
# 31/31 [==============================] - 11s 365ms/step - loss: 0.5517 - score_accuracy: 0.8982 - score_loss: 0.0603 - regress_loss: 0.4899 - val_loss: 0.9685 - val_score_accuracy: 0.8330 - val_score_loss: 0.0742 - val_regress_loss: 0.8927
# Epoch 41/100
# 31/31 [==============================] - 12s 367ms/step - loss: 0.6017 - score_accuracy: 0.8824 - score_loss: 0.0619 - regress_loss: 0.5383 - val_loss: 1.1193 - val_score_accuracy: 0.5991 - val_score_loss: 0.1095 - val_regress_loss: 1.0082
# Epoch 42/100
# 31/31 [==============================] - 11s 364ms/step - loss: 0.5605 - score_accuracy: 0.8854 - score_loss: 0.0617 - regress_loss: 0.4972 - val_loss: 0.8562 - val_score_accuracy: 0.8142 - val_score_loss: 0.0750 - val_regress_loss: 0.7797
# Epoch 43/100
# 31/31 [==============================] - 11s 365ms/step - loss: 0.5544 - score_accuracy: 0.9003 - score_loss: 0.0590 - regress_loss: 0.4938 - val_loss: 0.8599 - val_score_accuracy: 0.7888 - val_score_loss: 0.0746 - val_regress_loss: 0.7837
# Epoch 44/100
# 31/31 [==============================] - 11s 363ms/step - loss: 0.5347 - score_accuracy: 0.9073 - score_loss: 0.0574 - regress_loss: 0.4758 - val_loss: 1.0102 - val_score_accuracy: 0.7267 - val_score_loss: 0.0852 - val_regress_loss: 0.9235
# Epoch 45/100
# 31/31 [==============================] - 11s 363ms/step - loss: 0.5050 - score_accuracy: 0.9051 - score_loss: 0.0567 - regress_loss: 0.4468 - val_loss: 0.9500 - val_score_accuracy: 0.7381 - val_score_loss: 0.0851 - val_regress_loss: 0.8634
# Epoch 46/100
# 31/31 [==============================] - 11s 363ms/step - loss: 0.4933 - score_accuracy: 0.9001 - score_loss: 0.0571 - regress_loss: 0.4347 - val_loss: 0.8403 - val_score_accuracy: 0.7962 - val_score_loss: 0.0758 - val_regress_loss: 0.7630
# Epoch 47/100
# 31/31 [==============================] - 11s 365ms/step - loss: 0.4998 - score_accuracy: 0.8987 - score_loss: 0.0563 - regress_loss: 0.4419 - val_loss: 0.7974 - val_score_accuracy: 0.8273 - val_score_loss: 0.0709 - val_regress_loss: 0.7249
# Epoch 48/100
# 31/31 [==============================] - 11s 362ms/step - loss: 0.4697 - score_accuracy: 0.9137 - score_loss: 0.0546 - regress_loss: 0.4135 - val_loss: 0.8719 - val_score_accuracy: 0.8092 - val_score_loss: 0.0790 - val_regress_loss: 0.7914
# Epoch 49/100
# 31/31 [==============================] - 11s 362ms/step - loss: 0.4665 - score_accuracy: 0.9193 - score_loss: 0.0537 - regress_loss: 0.4112 - val_loss: 0.7882 - val_score_accuracy: 0.8555 - val_score_loss: 0.0661 - val_regress_loss: 0.7206
# Epoch 50/100
# 31/31 [==============================] - 11s 365ms/step - loss: 0.4597 - score_accuracy: 0.9137 - score_loss: 0.0531 - regress_loss: 0.4051 - val_loss: 0.8084 - val_score_accuracy: 0.8746 - val_score_loss: 0.0648 - val_regress_loss: 0.7421
# Epoch 51/100
# 31/31 [==============================] - 11s 364ms/step - loss: 0.4583 - score_accuracy: 0.9156 - score_loss: 0.0528 - regress_loss: 0.4040 - val_loss: 1.1497 - val_score_accuracy: 0.4911 - val_score_loss: 0.1215 - val_regress_loss: 1.0267
# Epoch 52/100
# 31/31 [==============================] - 11s 363ms/step - loss: 0.4275 - score_accuracy: 0.9161 - score_loss: 0.0523 - regress_loss: 0.3736 - val_loss: 1.0429 - val_score_accuracy: 0.5218 - val_score_loss: 0.1138 - val_regress_loss: 0.9276
# Epoch 53/100
# 31/31 [==============================] - 11s 362ms/step - loss: 0.4279 - score_accuracy: 0.9270 - score_loss: 0.0524 - regress_loss: 0.3740 - val_loss: 0.8631 - val_score_accuracy: 0.7429 - val_score_loss: 0.0871 - val_regress_loss: 0.7744
# Epoch 54/100
# 31/31 [==============================] - 11s 363ms/step - loss: 0.4202 - score_accuracy: 0.9274 - score_loss: 0.0503 - regress_loss: 0.3683 - val_loss: 0.8093 - val_score_accuracy: 0.8706 - val_score_loss: 0.0669 - val_regress_loss: 0.7409
# Epoch 55/100
# 31/31 [==============================] - 11s 365ms/step - loss: 0.4130 - score_accuracy: 0.9232 - score_loss: 0.0508 - regress_loss: 0.3607 - val_loss: 0.9698 - val_score_accuracy: 0.5708 - val_score_loss: 0.1294 - val_regress_loss: 0.8389
# Epoch 56/100
# 31/31 [==============================] - 11s 365ms/step - loss: 0.3901 - score_accuracy: 0.9377 - score_loss: 0.0498 - regress_loss: 0.3388 - val_loss: 0.8927 - val_score_accuracy: 0.7466 - val_score_loss: 0.0803 - val_regress_loss: 0.8109
# Epoch 57/100
# 31/31 [==============================] - 11s 363ms/step - loss: 0.3652 - score_accuracy: 0.9473 - score_loss: 0.0478 - regress_loss: 0.3159 - val_loss: 0.7624 - val_score_accuracy: 0.8159 - val_score_loss: 0.0702 - val_regress_loss: 0.6907
# Epoch 58/100
# 31/31 [==============================] - 11s 362ms/step - loss: 0.3929 - score_accuracy: 0.9426 - score_loss: 0.0475 - regress_loss: 0.3438 - val_loss: 0.7003 - val_score_accuracy: 0.8528 - val_score_loss: 0.0649 - val_regress_loss: 0.6339
# Epoch 59/100
# 31/31 [==============================] - 11s 365ms/step - loss: 0.3849 - score_accuracy: 0.9413 - score_loss: 0.0479 - regress_loss: 0.3355 - val_loss: 0.7319 - val_score_accuracy: 0.8369 - val_score_loss: 0.0623 - val_regress_loss: 0.6681
# Epoch 60/100
# 31/31 [==============================] - 11s 363ms/step - loss: 0.3888 - score_accuracy: 0.9403 - score_loss: 0.0475 - regress_loss: 0.3398 - val_loss: 0.7188 - val_score_accuracy: 0.8608 - val_score_loss: 0.0645 - val_regress_loss: 0.6527
# Epoch 61/100
# 31/31 [==============================] - 11s 364ms/step - loss: 0.3703 - score_accuracy: 0.9473 - score_loss: 0.0465 - regress_loss: 0.3222 - val_loss: 0.7315 - val_score_accuracy: 0.8551 - val_score_loss: 0.0648 - val_regress_loss: 0.6652
# Epoch 62/100
# 31/31 [==============================] - 11s 363ms/step - loss: 0.3383 - score_accuracy: 0.9492 - score_loss: 0.0456 - regress_loss: 0.2912 - val_loss: 0.6893 - val_score_accuracy: 0.8811 - val_score_loss: 0.0586 - val_regress_loss: 0.6291
# Epoch 63/100
# 31/31 [==============================] - 11s 364ms/step - loss: 0.3383 - score_accuracy: 0.9422 - score_loss: 0.0458 - regress_loss: 0.2909 - val_loss: 0.6758 - val_score_accuracy: 0.8952 - val_score_loss: 0.0545 - val_regress_loss: 0.6197
# Epoch 64/100
# 31/31 [==============================] - 11s 362ms/step - loss: 0.3320 - score_accuracy: 0.9538 - score_loss: 0.0434 - regress_loss: 0.2870 - val_loss: 0.6912 - val_score_accuracy: 0.9253 - val_score_loss: 0.0510 - val_regress_loss: 0.6387
# Epoch 65/100
# 31/31 [==============================] - 11s 365ms/step - loss: 0.3335 - score_accuracy: 0.9545 - score_loss: 0.0457 - regress_loss: 0.2863 - val_loss: 0.7033 - val_score_accuracy: 0.8587 - val_score_loss: 0.0609 - val_regress_loss: 0.6409
# Epoch 66/100
# 31/31 [==============================] - 11s 363ms/step - loss: 0.3259 - score_accuracy: 0.9556 - score_loss: 0.0422 - regress_loss: 0.2822 - val_loss: 0.6974 - val_score_accuracy: 0.8906 - val_score_loss: 0.0590 - val_regress_loss: 0.6369
# Epoch 67/100
# 31/31 [==============================] - 11s 363ms/step - loss: 0.3374 - score_accuracy: 0.9473 - score_loss: 0.0440 - regress_loss: 0.2919 - val_loss: 0.7088 - val_score_accuracy: 0.8776 - val_score_loss: 0.0613 - val_regress_loss: 0.6459
# Epoch 68/100
# 31/31 [==============================] - 11s 364ms/step - loss: 0.3453 - score_accuracy: 0.9551 - score_loss: 0.0426 - regress_loss: 0.3011 - val_loss: 0.6568 - val_score_accuracy: 0.8923 - val_score_loss: 0.0544 - val_regress_loss: 0.6009
# Epoch 69/100
# 31/31 [==============================] - 11s 364ms/step - loss: 0.3183 - score_accuracy: 0.9424 - score_loss: 0.0431 - regress_loss: 0.2737 - val_loss: 0.7356 - val_score_accuracy: 0.8414 - val_score_loss: 0.0636 - val_regress_loss: 0.6704
# Epoch 70/100
# 31/31 [==============================] - 11s 364ms/step - loss: 0.2972 - score_accuracy: 0.9543 - score_loss: 0.0425 - regress_loss: 0.2531 - val_loss: 0.7014 - val_score_accuracy: 0.8622 - val_score_loss: 0.0611 - val_regress_loss: 0.6388
# Epoch 71/100
# 31/31 [==============================] - 11s 364ms/step - loss: 0.3132 - score_accuracy: 0.9582 - score_loss: 0.0413 - regress_loss: 0.2704 - val_loss: 0.7384 - val_score_accuracy: 0.8453 - val_score_loss: 0.0643 - val_regress_loss: 0.6726
# Epoch 72/100
# 31/31 [==============================] - 11s 365ms/step - loss: 0.2980 - score_accuracy: 0.9555 - score_loss: 0.0412 - regress_loss: 0.2553 - val_loss: 0.8117 - val_score_accuracy: 0.8021 - val_score_loss: 0.0699 - val_regress_loss: 0.7402
# Epoch 73/100
# 31/31 [==============================] - 11s 366ms/step - loss: 0.2769 - score_accuracy: 0.9628 - score_loss: 0.0394 - regress_loss: 0.2360 - val_loss: 0.7200 - val_score_accuracy: 0.8795 - val_score_loss: 0.0569 - val_regress_loss: 0.6616
# Epoch 74/100
# 31/31 [==============================] - 11s 364ms/step - loss: 0.2998 - score_accuracy: 0.9553 - score_loss: 0.0411 - regress_loss: 0.2572 - val_loss: 0.6475 - val_score_accuracy: 0.9057 - val_score_loss: 0.0544 - val_regress_loss: 0.5916
# Epoch 75/100
# 31/31 [==============================] - 11s 363ms/step - loss: 0.2825 - score_accuracy: 0.9611 - score_loss: 0.0402 - regress_loss: 0.2408 - val_loss: 0.6500 - val_score_accuracy: 0.9090 - val_score_loss: 0.0522 - val_regress_loss: 0.5962
# Epoch 76/100
# 31/31 [==============================] - 11s 363ms/step - loss: 0.2556 - score_accuracy: 0.9588 - score_loss: 0.0396 - regress_loss: 0.2145 - val_loss: 0.6350 - val_score_accuracy: 0.9233 - val_score_loss: 0.0515 - val_regress_loss: 0.5820
# Epoch 77/100
# 31/31 [==============================] - 11s 364ms/step - loss: 0.2628 - score_accuracy: 0.9624 - score_loss: 0.0378 - regress_loss: 0.2235 - val_loss: 0.6760 - val_score_accuracy: 0.8921 - val_score_loss: 0.0560 - val_regress_loss: 0.6185
# Epoch 78/100
# 31/31 [==============================] - 11s 365ms/step - loss: 0.2686 - score_accuracy: 0.9665 - score_loss: 0.0375 - regress_loss: 0.2296 - val_loss: 0.6361 - val_score_accuracy: 0.8973 - val_score_loss: 0.0570 - val_regress_loss: 0.5776
# Epoch 79/100
# 31/31 [==============================] - 11s 365ms/step - loss: 0.2646 - score_accuracy: 0.9608 - score_loss: 0.0376 - regress_loss: 0.2254 - val_loss: 0.8069 - val_score_accuracy: 0.7902 - val_score_loss: 0.0743 - val_regress_loss: 0.7310
# Epoch 80/100
# 31/31 [==============================] - 11s 364ms/step - loss: 0.2638 - score_accuracy: 0.9670 - score_loss: 0.0365 - regress_loss: 0.2258 - val_loss: 0.7098 - val_score_accuracy: 0.8832 - val_score_loss: 0.0593 - val_regress_loss: 0.6491
# Epoch 81/100
# 31/31 [==============================] - 11s 365ms/step - loss: 0.2625 - score_accuracy: 0.9650 - score_loss: 0.0362 - regress_loss: 0.2247 - val_loss: 0.7058 - val_score_accuracy: 0.8937 - val_score_loss: 0.0565 - val_regress_loss: 0.6478
# Epoch 82/100
# 31/31 [==============================] - 11s 365ms/step - loss: 0.2564 - score_accuracy: 0.9599 - score_loss: 0.0370 - regress_loss: 0.2178 - val_loss: 0.9418 - val_score_accuracy: 0.7029 - val_score_loss: 0.0892 - val_regress_loss: 0.8511
# Epoch 83/100
# 31/31 [==============================] - 11s 363ms/step - loss: 0.2465 - score_accuracy: 0.9661 - score_loss: 0.0353 - regress_loss: 0.2097 - val_loss: 0.6379 - val_score_accuracy: 0.8757 - val_score_loss: 0.0561 - val_regress_loss: 0.5803
# Epoch 84/100
# 31/31 [==============================] - 11s 363ms/step - loss: 0.2342 - score_accuracy: 0.9702 - score_loss: 0.0352 - regress_loss: 0.1975 - val_loss: 0.8743 - val_score_accuracy: 0.7354 - val_score_loss: 0.0851 - val_regress_loss: 0.7876
# Epoch 85/100
# 31/31 [==============================] - 11s 365ms/step - loss: 0.2475 - score_accuracy: 0.9629 - score_loss: 0.0364 - regress_loss: 0.2096 - val_loss: 1.0007 - val_score_accuracy: 0.6612 - val_score_loss: 0.0956 - val_regress_loss: 0.9036
# Epoch 86/100
# 31/31 [==============================] - 11s 361ms/step - loss: 0.2279 - score_accuracy: 0.9701 - score_loss: 0.0338 - regress_loss: 0.1926 - val_loss: 0.8165 - val_score_accuracy: 0.7739 - val_score_loss: 0.0781 - val_regress_loss: 0.7368
# Epoch 87/100
# 31/31 [==============================] - 11s 364ms/step - loss: 0.2244 - score_accuracy: 0.9643 - score_loss: 0.0344 - regress_loss: 0.1885 - val_loss: 0.6751 - val_score_accuracy: 0.8769 - val_score_loss: 0.0574 - val_regress_loss: 0.6162
# Epoch 88/100
# 31/31 [==============================] - 11s 363ms/step - loss: 0.2249 - score_accuracy: 0.9696 - score_loss: 0.0342 - regress_loss: 0.1892 - val_loss: 0.7263 - val_score_accuracy: 0.8273 - val_score_loss: 0.0679 - val_regress_loss: 0.6569
# Epoch 89/100
# 31/31 [==============================] - 11s 364ms/step - loss: 0.2503 - score_accuracy: 0.9654 - score_loss: 0.0347 - regress_loss: 0.2141 - val_loss: 0.6376 - val_score_accuracy: 0.8973 - val_score_loss: 0.0504 - val_regress_loss: 0.5856
# Epoch 90/100
# 31/31 [==============================] - 11s 364ms/step - loss: 0.2278 - score_accuracy: 0.9714 - score_loss: 0.0321 - regress_loss: 0.1941 - val_loss: 0.6352 - val_score_accuracy: 0.9017 - val_score_loss: 0.0507 - val_regress_loss: 0.5829
# Epoch 91/100
# 31/31 [==============================] - 11s 363ms/step - loss: 0.2155 - score_accuracy: 0.9676 - score_loss: 0.0334 - regress_loss: 0.1806 - val_loss: 0.6248 - val_score_accuracy: 0.8890 - val_score_loss: 0.0526 - val_regress_loss: 0.5707
# Epoch 92/100
# 31/31 [==============================] - 11s 364ms/step - loss: 0.2308 - score_accuracy: 0.9670 - score_loss: 0.0334 - regress_loss: 0.1959 - val_loss: 0.6143 - val_score_accuracy: 0.9003 - val_score_loss: 0.0499 - val_regress_loss: 0.5629
# Epoch 93/100
# 31/31 [==============================] - 11s 363ms/step - loss: 0.2293 - score_accuracy: 0.9741 - score_loss: 0.0319 - regress_loss: 0.1959 - val_loss: 0.6200 - val_score_accuracy: 0.8719 - val_score_loss: 0.0525 - val_regress_loss: 0.5660
# Epoch 94/100
# 31/31 [==============================] - 11s 363ms/step - loss: 0.2110 - score_accuracy: 0.9696 - score_loss: 0.0327 - regress_loss: 0.1768 - val_loss: 0.7384 - val_score_accuracy: 0.8760 - val_score_loss: 0.0581 - val_regress_loss: 0.6788
# Epoch 95/100
# 31/31 [==============================] - 11s 365ms/step - loss: 0.2197 - score_accuracy: 0.9705 - score_loss: 0.0317 - regress_loss: 0.1865 - val_loss: 0.6241 - val_score_accuracy: 0.9022 - val_score_loss: 0.0501 - val_regress_loss: 0.5725
# Epoch 96/100
# 31/31 [==============================] - 11s 363ms/step - loss: 0.2123 - score_accuracy: 0.9702 - score_loss: 0.0310 - regress_loss: 0.1797 - val_loss: 0.7066 - val_score_accuracy: 0.8734 - val_score_loss: 0.0567 - val_regress_loss: 0.6483
# Epoch 97/100
# 31/31 [==============================] - 11s 363ms/step - loss: 0.1944 - score_accuracy: 0.9750 - score_loss: 0.0299 - regress_loss: 0.1630 - val_loss: 0.6924 - val_score_accuracy: 0.8807 - val_score_loss: 0.0585 - val_regress_loss: 0.6324
# Epoch 98/100
# 31/31 [==============================] - 11s 362ms/step - loss: 0.1890 - score_accuracy: 0.9753 - score_loss: 0.0303 - regress_loss: 0.1572 - val_loss: 0.7021 - val_score_accuracy: 0.8796 - val_score_loss: 0.0561 - val_regress_loss: 0.6446
# Epoch 99/100
# 31/31 [==============================] - 11s 363ms/step - loss: 0.1889 - score_accuracy: 0.9706 - score_loss: 0.0306 - regress_loss: 0.1568 - val_loss: 0.6812 - val_score_accuracy: 0.8772 - val_score_loss: 0.0578 - val_regress_loss: 0.6219
# Epoch 100/100
# 31/31 [==============================] - 11s 364ms/step - loss: 0.1989 - score_accuracy: 0.9742 - score_loss: 0.0315 - regress_loss: 0.1658 - val_loss: 0.6995 - val_score_accuracy: 0.8377 - val_score_loss: 0.0650 - val_regress_loss: 0.6329

# %%
model.save_weights("model.h5")

# %%
#x = tf.keras.layers.Input(shape = (1024, 1024, 3))
x = tf.keras.layers.Input(shape = (512, 512, 3))
#scale = [32, 64, 128, 256, 512]
scale = [24, 48, 96, 192, 384]
ratio = [0.5, 1, 2]
out = tfdet.model.detector.effdet_d4(x, n_class = 2, scale = scale, ratio = ratio)
prediction = tfdet.model.postprocess.effdet.FilterDetection(proposal_count = 100, iou_threshold = 0.3, score_threshold = 0.8, soft_nms = False)(out)
model = tf.keras.Model(x, prediction)
model.load_weights("model.h5")

# %%
images = te_x[:1]
logits, proposal = model.predict(images)
images = tfdet.util.draw_bbox(images, proposal, logits, label = ["Background", "Balloon"])

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (10, 10))
plt.imshow(images[0])
