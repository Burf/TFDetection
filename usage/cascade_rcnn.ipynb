# %%
import os, shutil
if os.path.exists(os.path.join(os.getcwd(),"tfdetection")):
    shutil.rmtree(os.path.join(os.getcwd(),"tfdetection"))
if os.path.exists(os.path.join(os.getcwd(),"tfdet")):
    shutil.rmtree(os.path.join(os.getcwd(),"tfdet"))
# !git clone https://github.com/burf/tfdetection
shutil.copytree(os.path.join(os.getcwd(),"tfdetection", "tfdet"), os.path.join(os.getcwd(),"tfdet"))
# Out:
# Cloning into 'tfdetection'...
# remote: Enumerating objects: 788, done.
# remote: Counting objects: 100% (401/401), done.
# remote: Compressing objects: 100% (246/246), done.
# remote: Total 788 (delta 240), reused 276 (delta 155), pack-reused 387
# Receiving objects: 100% (788/788), 8.62 MiB | 29.84 MiB/s, done.
# Resolving deltas: 100% (449/449), done.
# '/content/tfdet'

# %%
# !wget -qq https://github.com/matterport/Mask_RCNN/releases/download/v2.1/balloon_dataset.zip
# !unzip -qq balloon_dataset.zip

import os
import json
import cv2
import skimage.draw
import tensorflow as tf
import numpy as np

def parse(path, target_size = (512, 512), method = cv2.INTER_CUBIC):
    dir_path = os.path.dirname(path)
    with open(path, "r") as file:
        anno = json.loads(file.read())
    anno = [a for a in list(anno.values()) if a["regions"]]

    images = []
    masks = []
    for a in anno:
        if type(a['regions']) is dict:
            polygons = [r['shape_attributes'] for r in a['regions'].values()]
        else:
            polygons = [r['shape_attributes'] for r in a['regions']]
        image = cv2.cvtColor(cv2.imread(os.path.join(dir_path, a["filename"]), -1), cv2.COLOR_BGR2RGB)
        h, w = np.shape(image)[:2]
        mask = np.zeros((h, w, len(polygons)), dtype = np.uint8)
        for i, p in enumerate(polygons):
            rr, cc = skimage.draw.polygon(p['all_points_y'], p['all_points_x'])
            rr = np.clip(rr, 0, h - 1)
            cc = np.clip(cc, 0, w - 1)
            mask[rr, cc, i] = 1
        
        if target_size is not None:
            image = cv2.resize(image, target_size[::-1], interpolation = method)
            mask = cv2.resize(mask, target_size[::-1], interpolation = method)
            if np.ndim(mask) == 2:
                mask = np.expand_dims(mask, axis = -1)
            mask = np.where(mask != 0, 1, 0)

        images.append(image)
        masks.append(np.transpose(mask, [2, 0, 1]))
    return images, masks

def mask2bbox(mask_true, normalize = True, decimal = 4):
    #mask_true = #(padded_num_true, h, w, 1)
    padded_num_true, h, w = np.shape(mask_true)[:3]

    bbox_true = []
    for index in range(padded_num_true):
        mask = mask_true[index]
        if 0 < np.max(mask):
            pos = np.where(0 < mask)[:2]
            bbox = [np.min(pos[1]), np.min(pos[0]), np.max(pos[1]), np.max(pos[0])] #x1, y1, x2, y2
        else:
            bbox = [0, 0, 0, 0]
        bbox_true.append(bbox)
    
    bbox_true = np.round(np.divide(bbox_true, [w, h, w, h]).astype(np.float32), decimal) if normalize else np.array(bbox_true, dtype = np.int32)
    return bbox_true

def pipe(data, func = None, batch_size = 2, shuffle = False):
    dataset = tf.data.Dataset.from_tensor_slices(data)
    if callable(func):
        dataset = dataset.map(func, num_parallel_calls = tf.data.experimental.AUTOTUNE)
    if shuffle:
        dataset = dataset.shuffle(buffer_size = batch_size * 10)
    dataset = dataset.batch(batch_size)
    #dataset = dataset.prefetch((batch_size * 2) + 1)
    dataset = dataset.prefetch(tf.data.experimental.AUTOTUNE)
    return dataset

tr_anno = "./balloon/train/via_region_data.json"
te_anno = "./balloon/val/via_region_data.json"

tr_x, tr_mask = parse(tr_anno, target_size = (512, 512))
te_x, te_mask = parse(te_anno, target_size = (512, 512))

max_cnt = 0
for mask in tr_mask + te_mask:
    if max_cnt < len(mask):
        max_cnt = len(mask)

tr_x = np.array(tr_x, dtype = np.float32) * 1/255
tr_mask = [np.pad(mask, [[0, max_cnt - len(mask)], [0, 0], [0, 0]]) for mask in tr_mask]
tr_mask = np.expand_dims(np.array(tr_mask, dtype = np.float32), axis = -1)
tr_bbox = np.array([mask2bbox(mask) for mask in tr_mask], dtype = np.float32)
tr_y = np.expand_dims(np.where(0 < np.max(tr_bbox, axis = -1), 1., 0.), axis = -1)

te_x = np.array(te_x, dtype = np.float32) * 1/255
te_mask = [np.pad(mask, [[0, max_cnt - len(mask)], [0, 0], [0, 0]]) for mask in te_mask]
te_mask = np.expand_dims(np.array(te_mask, dtype = np.float32), axis = -1)
te_bbox = np.array([mask2bbox(mask) for mask in te_mask], dtype = np.float32)
te_y = np.expand_dims(np.where(0 < np.max(te_bbox, axis = -1), 1., 0.), axis = -1)

# %%
import tfdet
import functools

x = tf.keras.layers.Input(shape = (512, 512, 3))
feature = tfdet.model.backbone.resnet50(x)

#scale = [32, 64, 128, 256, 512]
scale = [24, 48, 96, 192, 384]
ratio = [0.5, 1, 2]

bifpn = functools.partial(tfdet.model.neck.bifpn, weighted_add = False)
neck = functools.partial(tfdet.model.neck.FeatureAlign, pre_sampling = False, neck = bifpn)
rpn_assign = functools.partial(tfdet.core.assign.max_iou, positive_threshold = 0.7, negative_threshold = 0.3, min_threshold = 0.3)
cls_assign = functools.partial(tfdet.core.assign.max_iou, positive_threshold = 0.5, negative_threshold = 0.5, match_low_quality = False)
cls_assign2 = functools.partial(tfdet.core.assign.max_iou, positive_threshold = 0.6, negative_threshold = 0.6, match_low_quality = False)
cls_assign3 = functools.partial(tfdet.core.assign.max_iou, positive_threshold = 0.7, negative_threshold = 0.7, match_low_quality = False)

#sampling_positive_ratio = cls_positive_ratio, sampling_positive_threshold = cls_positive_threshold, sampling_negative_threshold = cls_negative_threshold
out = tfdet.model.detector.cascade_rcnn(feature, image_shape = tf.shape(x)[1:3], n_class = 2, mask = False, scale = scale, ratio = ratio, soft_nms = False, neck = neck, 
                                        proposal_count = 2000, sampling_assign = [cls_assign, cls_assign2, cls_assign3], sampling_count = 256, sampling_positive_ratio = 0.25)

#out > rpn_score, rpn_regress, cls_logits, cls_regress, proposals, anchors, mask_regress(is removed by mask{=False}), semantic_regress(is removed by semantic_feature{=False}), sampling_tag(is removed by sampling_count{=None or 0})
model = tfdet.model.train.rcnn.train_model(x, *out, rpn_assign = rpn_assign, rpn_positive_ratio = 0.5)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 1s 0us/step
# 94781440/94765736 [==============================] - 1s 0us/step
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/deprecation.py:616: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead

# %%
import albumentations
method = [albumentations.RandomBrightness(0.2, p = 0.5),
          albumentations.RandomContrast(0.2, p = 0.5),
          albumentations.ChannelShuffle(p = 0.5)]
method = albumentations.Compose(method)
    
def aug_func(image):
    return method(image = image)["image"]

key = x.name
def func(dic):
    shape = tf.shape(dic[key])
    dic[key] = tf.reshape(tf.py_function(lambda *args: aug_func(args[0].numpy()), inp = [dic[key]], Tout = tf.float32), shape)
    return dic

batch_size = 2

tr_data = pipe({x.name:tr_x, "y_true":tr_y, "bbox_true":tr_bbox}, func = func, batch_size = batch_size, shuffle = True)
te_data = pipe({x.name:te_x, "y_true":te_y, "bbox_true":te_bbox}, batch_size = batch_size, shuffle = False)

# %%
opt = tf.keras.optimizers.SGD(5e-3, momentum = 0.9, nesterov = True)
model.compile(optimizer = opt)
model.fit(tr_data, validation_data = te_data, epochs = 500)
# Out:
# Epoch 1/500
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/cls_target1/map/while/gradients/model/cls_target1/map/while/GatherNd_2_grad/Squeeze:0", shape=(None,), dtype=int64), values=Tensor("gradient_tape/model/cls_target1/map/while/gradients/model/cls_target1/map/while/Pad_grad/Slice_1:0", shape=(None, 2), dtype=float32), dense_shape=Tensor("model/cls_target1/map/while/gradient_tape/model/cls_target1/map/while/gradients/model/cls_target1/map/while/GatherNd_2_grad/Shape:0", shape=(2,), dtype=int64))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/cls_target1/map/while/gradients/model/cls_target1/map/while/GatherNd_3_grad/Squeeze:0", shape=(None,), dtype=int64), values=Tensor("gradient_tape/model/cls_target1/map/while/gradients/model/cls_target1/map/while/GatherNd_5_grad/ScatterNd:0", shape=(None, 2, 4), dtype=float32), dense_shape=Tensor("model/cls_target1/map/while/gradient_tape/model/cls_target1/map/while/gradients/model/cls_target1/map/while/GatherNd_3_grad/Shape:0", shape=(3,), dtype=int64))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/cls_target2/map/while/gradients/model/cls_target2/map/while/GatherNd_2_grad/Squeeze:0", shape=(None,), dtype=int64), values=Tensor("gradient_tape/model/cls_target2/map/while/gradients/model/cls_target2/map/while/Pad_grad/Slice_1:0", shape=(None, 2), dtype=float32), dense_shape=Tensor("model/cls_target2/map/while/gradient_tape/model/cls_target2/map/while/gradients/model/cls_target2/map/while/GatherNd_2_grad/Shape:0", shape=(2,), dtype=int64))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/cls_target2/map/while/gradients/model/cls_target2/map/while/GatherNd_3_grad/Squeeze:0", shape=(None,), dtype=int64), values=Tensor("gradient_tape/model/cls_target2/map/while/gradients/model/cls_target2/map/while/GatherNd_5_grad/ScatterNd:0", shape=(None, 2, 4), dtype=float32), dense_shape=Tensor("model/cls_target2/map/while/gradient_tape/model/cls_target2/map/while/gradients/model/cls_target2/map/while/GatherNd_3_grad/Shape:0", shape=(3,), dtype=int64))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/cls_target3/map/while/gradients/model/cls_target3/map/while/GatherNd_2_grad/Squeeze:0", shape=(None,), dtype=int64), values=Tensor("gradient_tape/model/cls_target3/map/while/gradients/model/cls_target3/map/while/Pad_grad/Slice_1:0", shape=(None, 2), dtype=float32), dense_shape=Tensor("model/cls_target3/map/while/gradient_tape/model/cls_target3/map/while/gradients/model/cls_target3/map/while/GatherNd_2_grad/Shape:0", shape=(2,), dtype=int64))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/cls_target3/map/while/gradients/model/cls_target3/map/while/GatherNd_3_grad/Squeeze:0", shape=(None,), dtype=int64), values=Tensor("gradient_tape/model/cls_target3/map/while/gradients/model/cls_target3/map/while/GatherNd_5_grad/ScatterNd:0", shape=(None, 2, 4), dtype=float32), dense_shape=Tensor("model/cls_target3/map/while/gradient_tape/model/cls_target3/map/while/gradients/model/cls_target3/map/while/GatherNd_3_grad/Shape:0", shape=(3,), dtype=int64))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/roi_align/sub:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/roi_align/GatherV2_2:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("gradient_tape/model/roi_align/Shape_2:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/roi_align/sub_1:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/roi_align/GatherV2_5:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("gradient_tape/model/roi_align/Shape_3:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/roi_align/sub_2:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/roi_align/GatherV2_8:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("gradient_tape/model/roi_align/Shape_4:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/roi_align/sub_3:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/roi_align/GatherV2_11:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("gradient_tape/model/roi_align/Shape_5:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/roi_align_1/sub:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/roi_align_1/GatherV2_2:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("gradient_tape/model/roi_align_1/Shape_2:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/roi_align_1/sub_1:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/roi_align_1/GatherV2_5:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("gradient_tape/model/roi_align_1/Shape_3:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/roi_align_1/sub_2:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/roi_align_1/GatherV2_8:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("gradient_tape/model/roi_align_1/Shape_4:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/roi_align_1/sub_3:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/roi_align_1/GatherV2_11:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("gradient_tape/model/roi_align_1/Shape_5:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/roi_align_2/sub:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/roi_align_2/GatherV2_2:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("gradient_tape/model/roi_align_2/Shape_2:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/roi_align_2/sub_1:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/roi_align_2/GatherV2_5:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("gradient_tape/model/roi_align_2/Shape_3:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/roi_align_2/sub_2:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/roi_align_2/GatherV2_8:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("gradient_tape/model/roi_align_2/Shape_4:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/roi_align_2/sub_3:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/roi_align_2/GatherV2_11:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("gradient_tape/model/roi_align_2/Shape_5:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# 31/31 [==============================] - 67s 817ms/step - loss: 15.1736 - rpn_score_accuracy: 0.6367 - cls_logits_accuracy1: 0.5457 - cls_logits_accuracy2: 0.1048 - cls_logits_accuracy3: 0.0000e+00 - rpn_score_loss: 0.9104 - rpn_regress_loss: 1.4820 - cls_logits_loss1: 2.9203 - cls_regress_loss1: 8.8331 - cls_logits_loss2: 0.4299 - cls_regress_loss2: 0.5977 - cls_logits_loss3: 0.0000e+00 - cls_regress_loss3: 0.0000e+00 - val_loss: 7339618304.0000 - val_rpn_score_accuracy: 0.7144 - val_cls_logits_accuracy1: 0.0000e+00 - val_cls_logits_accuracy2: 0.0000e+00 - val_cls_logits_accuracy3: 0.0000e+00 - val_rpn_score_loss: 4.3768 - val_rpn_regress_loss: 7339618304.0000 - val_cls_logits_loss1: 0.0000e+00 - val_cls_regress_loss1: 0.0000e+00 - val_cls_logits_loss2: 0.0000e+00 - val_cls_regress_loss2: 0.0000e+00 - val_cls_logits_loss3: 0.0000e+00 - val_cls_regress_loss3: 0.0000e+00
# Epoch 2/500
# 31/31 [==============================] - 14s 444ms/step - loss: 10.9675 - rpn_score_accuracy: 0.8059 - cls_logits_accuracy1: 0.1210 - cls_logits_accuracy2: 0.0000e+00 - cls_logits_accuracy3: 0.0000e+00 - rpn_score_loss: 0.6972 - rpn_regress_loss: 3.0208 - cls_logits_loss1: 0.6499 - cls_regress_loss1: 6.5995 - cls_logits_loss2: 0.0000e+00 - cls_regress_loss2: 0.0000e+00 - cls_logits_loss3: 0.0000e+00 - cls_regress_loss3: 0.0000e+00 - val_loss: 67365842944.0000 - val_rpn_score_accuracy: 0.6988 - val_cls_logits_accuracy1: 0.0000e+00 - val_cls_logits_accuracy2: 0.0000e+00 - val_cls_logits_accuracy3: 0.0000e+00 - val_rpn_score_loss: 4.6213 - val_rpn_regress_loss: 67365842944.0000 - val_cls_logits_loss1: 0.0000e+00 - val_cls_regress_loss1: 0.0000e+00 - val_cls_logits_loss2: 0.0000e+00 - val_cls_regress_loss2: 0.0000e+00 - val_cls_logits_loss3: 0.0000e+00 - val_cls_regress_loss3: 0.0000e+00
# Epoch 3/500
# 31/31 [==============================] - 14s 450ms/step - loss: 10.0264 - rpn_score_accuracy: 0.8388 - cls_logits_accuracy1: 0.2661 - cls_logits_accuracy2: 0.0484 - cls_logits_accuracy3: 0.0000e+00 - rpn_score_loss: 0.6147 - rpn_regress_loss: 2.1296 - cls_logits_loss1: 1.4298 - cls_regress_loss1: 5.6458 - cls_logits_loss2: 0.1300 - cls_regress_loss2: 0.0764 - cls_logits_loss3: 0.0000e+00 - cls_regress_loss3: 0.0000e+00 - val_loss: 1324992.3750 - val_rpn_score_accuracy: 0.6621 - val_cls_logits_accuracy1: 0.0000e+00 - val_cls_logits_accuracy2: 0.0000e+00 - val_cls_logits_accuracy3: 0.0000e+00 - val_rpn_score_loss: 5.1768 - val_rpn_regress_loss: 1324987.3750 - val_cls_logits_loss1: 0.0000e+00 - val_cls_regress_loss1: 0.0000e+00 - val_cls_logits_loss2: 0.0000e+00 - val_cls_regress_loss2: 0.0000e+00 - val_cls_logits_loss3: 0.0000e+00 - val_cls_regress_loss3: 0.0000e+00
# Epoch 4/500
# 31/31 [==============================] - 14s 460ms/step - loss: 16.0412 - rpn_score_accuracy: 0.8443 - cls_logits_accuracy1: 0.4113 - cls_logits_accuracy2: 0.1210 - cls_logits_accuracy3: 0.0081 - rpn_score_loss: 0.5283 - rpn_regress_loss: 1.7545 - cls_logits_loss1: 2.2097 - cls_regress_loss1: 10.6550 - cls_logits_loss2: 0.3250 - cls_regress_loss2: 0.4972 - cls_logits_loss3: 0.0371 - cls_regress_loss3: 0.0344 - val_loss: 217.0863 - val_rpn_score_accuracy: 0.7304 - val_cls_logits_accuracy1: 0.0000e+00 - val_cls_logits_accuracy2: 0.0000e+00 - val_cls_logits_accuracy3: 0.0000e+00 - val_rpn_score_loss: 3.0771 - val_rpn_regress_loss: 214.0092 - val_cls_logits_loss1: 0.0000e+00 - val_cls_regress_loss1: 0.0000e+00 - val_cls_logits_loss2: 0.0000e+00 - val_cls_regress_loss2: 0.0000e+00 - val_cls_logits_loss3: 0.0000e+00 - val_cls_regress_loss3: 0.0000e+00
# Epoch 5/500
# 31/31 [==============================] - 14s 456ms/step - loss: 6.8031 - rpn_score_accuracy: 0.8198 - cls_logits_accuracy1: 0.3145 - cls_logits_accuracy2: 0.0242 - cls_logits_accuracy3: 0.0000e+00 - rpn_score_loss: 0.5352 - rpn_regress_loss: 1.0741 - cls_logits_loss1: 1.6898 - cls_regress_loss1: 3.3931 - cls_logits_loss2: 0.0650 - cls_regress_loss2: 0.0459 - cls_logits_loss3: 0.0000e+00 - cls_regress_loss3: 0.0000e+00 - val_loss: 161.5004 - val_rpn_score_accuracy: 0.7059 - val_cls_logits_accuracy1: 0.0000e+00 - val_cls_logits_accuracy2: 0.0000e+00 - val_cls_logits_accuracy3: 0.0000e+00 - val_rpn_score_loss: 2.9328 - val_rpn_regress_loss: 158.5675 - val_cls_logits_loss1: 0.0000e+00 - val_cls_regress_loss1: 0.0000e+00 - val_cls_logits_loss2: 0.0000e+00 - val_cls_regress_loss2: 0.0000e+00 - val_cls_logits_loss3: 0.0000e+00 - val_cls_regress_loss3: 0.0000e+00
# Epoch 6/500
# 31/31 [==============================] - 14s 461ms/step - loss: 6.7336 - rpn_score_accuracy: 0.8395 - cls_logits_accuracy1: 0.4839 - cls_logits_accuracy2: 0.1935 - cls_logits_accuracy3: 0.0000e+00 - rpn_score_loss: 0.4455 - rpn_regress_loss: 0.8038 - cls_logits_loss1: 2.5997 - cls_regress_loss1: 1.7979 - cls_logits_loss2: 0.5199 - cls_regress_loss2: 0.5668 - cls_logits_loss3: 0.0000e+00 - cls_regress_loss3: 0.0000e+00 - val_loss: 87.3085 - val_rpn_score_accuracy: 0.7541 - val_cls_logits_accuracy1: 0.1071 - val_cls_logits_accuracy2: 0.0000e+00 - val_cls_logits_accuracy3: 0.0000e+00 - val_rpn_score_loss: 2.2443 - val_rpn_regress_loss: 80.4616 - val_cls_logits_loss1: 0.5756 - val_cls_regress_loss1: 4.0269 - val_cls_logits_loss2: 0.0000e+00 - val_cls_regress_loss2: 0.0000e+00 - val_cls_logits_loss3: 0.0000e+00 - val_cls_regress_loss3: 0.0000e+00
# Epoch 7/500
# 31/31 [==============================] - 15s 465ms/step - loss: 9.0808 - rpn_score_accuracy: 0.8949 - cls_logits_accuracy1: 0.6774 - cls_logits_accuracy2: 0.3145 - cls_logits_accuracy3: 0.0242 - rpn_score_loss: 0.3688 - rpn_regress_loss: 0.7140 - cls_logits_loss1: 3.6394 - cls_regress_loss1: 3.0930 - cls_logits_loss2: 0.8387 - cls_regress_loss2: 0.3510 - cls_logits_loss3: 0.0259 - cls_regress_loss3: 0.0499 - val_loss: 21.3917 - val_rpn_score_accuracy: 0.7304 - val_cls_logits_accuracy1: 0.3214 - val_cls_logits_accuracy2: 0.0000e+00 - val_cls_logits_accuracy3: 0.0000e+00 - val_rpn_score_loss: 1.7178 - val_rpn_regress_loss: 17.4343 - val_cls_logits_loss1: 1.7269 - val_cls_regress_loss1: 0.5127 - val_cls_logits_loss2: 0.0000e+00 - val_cls_regress_loss2: 0.0000e+00 - val_cls_logits_loss3: 0.0000e+00 - val_cls_regress_loss3: 0.0000e+00
# Epoch 8/500
# 31/31 [==============================] - 15s 475ms/step - loss: 8.8686 - rpn_score_accuracy: 0.8699 - cls_logits_accuracy1: 0.7258 - cls_logits_accuracy2: 0.2661 - cls_logits_accuracy3: 0.0565 - rpn_score_loss: 0.3313 - rpn_regress_loss: 0.6122 - cls_logits_loss1: 3.8995 - cls_regress_loss1: 3.1934 - cls_logits_loss2: 0.7149 - cls_regress_loss2: 0.0675 - cls_logits_loss3: 0.0126 - cls_regress_loss3: 0.0371 - val_loss: 7.8674 - val_rpn_score_accuracy: 0.7700 - val_cls_logits_accuracy1: 0.5357 - val_cls_logits_accuracy2: 0.2143 - val_cls_logits_accuracy3: 0.0000e+00 - val_rpn_score_loss: 0.6421 - val_rpn_regress_loss: 0.6619 - val_cls_logits_loss1: 2.8782 - val_cls_regress_loss1: 3.0087 - val_cls_logits_loss2: 0.5756 - val_cls_regress_loss2: 0.1007 - val_cls_logits_loss3: 0.0000e+00 - val_cls_regress_loss3: 0.0000e+00
# Epoch 9/500
# 31/31 [==============================] - 15s 468ms/step - loss: 7.6220 - rpn_score_accuracy: 0.8593 - cls_logits_accuracy1: 0.6048 - cls_logits_accuracy2: 0.3387 - cls_logits_accuracy3: 0.0753 - rpn_score_loss: 0.3950 - rpn_regress_loss: 0.5295 - cls_logits_loss1: 3.2249 - cls_regress_loss1: 2.0565 - cls_logits_loss2: 0.9099 - cls_regress_loss2: 0.3547 - cls_logits_loss3: 0.0725 - cls_regress_loss3: 0.0789 - val_loss: 4.6012 - val_rpn_score_accuracy: 0.7168 - val_cls_logits_accuracy1: 0.3214 - val_cls_logits_accuracy2: 0.1071 - val_cls_logits_accuracy3: 0.0000e+00 - val_rpn_score_loss: 0.7522 - val_rpn_regress_loss: 0.6383 - val_cls_logits_loss1: 1.7269 - val_cls_regress_loss1: 1.0703 - val_cls_logits_loss2: 0.2878 - val_cls_regress_loss2: 0.1256 - val_cls_logits_loss3: 0.0000e+00 - val_cls_regress_loss3: 0.0000e+00
# Epoch 10/500
# 31/31 [==============================] - 15s 466ms/step - loss: 6.9661 - rpn_score_accuracy: 0.8890 - cls_logits_accuracy1: 0.6290 - cls_logits_accuracy2: 0.3871 - cls_logits_accuracy3: 0.0565 - rpn_score_loss: 0.3167 - rpn_regress_loss: 0.5518 - cls_logits_loss1: 3.3796 - cls_regress_loss1: 1.0690 - cls_logits_loss2: 1.0399 - cls_regress_loss2: 0.5338 - cls_logits_loss3: 0.0551 - cls_regress_loss3: 0.0201 - val_loss: 3.1719 - val_rpn_score_accuracy: 0.7630 - val_cls_logits_accuracy1: 0.2143 - val_cls_logits_accuracy2: 0.1071 - val_cls_logits_accuracy3: 0.0000e+00 - val_rpn_score_loss: 0.7633 - val_rpn_regress_loss: 0.6474 - val_cls_logits_loss1: 1.1513 - val_cls_regress_loss1: 0.2593 - val_cls_logits_loss2: 0.2878 - val_cls_regress_loss2: 0.0628 - val_cls_logits_loss3: 0.0000e+00 - val_cls_regress_loss3: 0.0000e+00
# Epoch 11/500
# 31/31 [==============================] - 15s 480ms/step - loss: 6.9947 - rpn_score_accuracy: 0.8892 - cls_logits_accuracy1: 0.6774 - cls_logits_accuracy2: 0.4355 - cls_logits_accuracy3: 0.0726 - rpn_score_loss: 0.3170 - rpn_regress_loss: 0.5146 - cls_logits_loss1: 3.6076 - cls_regress_loss1: 0.9900 - cls_logits_loss2: 1.1699 - cls_regress_loss2: 0.3482 - cls_logits_loss3: 0.0257 - cls_regress_loss3: 0.0216 - val_loss: 5.6553 - val_rpn_score_accuracy: 0.7687 - val_cls_logits_accuracy1: 0.5357 - val_cls_logits_accuracy2: 0.3214 - val_cls_logits_accuracy3: 0.0000e+00 - val_rpn_score_loss: 0.6724 - val_rpn_regress_loss: 0.6471 - val_cls_logits_loss1: 2.8782 - val_cls_regress_loss1: 0.2971 - val_cls_logits_loss2: 0.8635 - val_cls_regress_loss2: 0.2969 - val_cls_logits_loss3: 0.0000e+00 - val_cls_regress_loss3: 0.0000e+00
# Epoch 12/500
# 31/31 [==============================] - 15s 478ms/step - loss: 7.3449 - rpn_score_accuracy: 0.8760 - cls_logits_accuracy1: 0.6532 - cls_logits_accuracy2: 0.4355 - cls_logits_accuracy3: 0.0242 - rpn_score_loss: 0.3088 - rpn_regress_loss: 0.4955 - cls_logits_loss1: 3.5096 - cls_regress_loss1: 1.5450 - cls_logits_loss2: 1.1699 - cls_regress_loss2: 0.2715 - cls_logits_loss3: 0.0303 - cls_regress_loss3: 0.0143 - val_loss: 7.2447 - val_rpn_score_accuracy: 0.7539 - val_cls_logits_accuracy1: 0.5357 - val_cls_logits_accuracy2: 0.3214 - val_cls_logits_accuracy3: 0.0000e+00 - val_rpn_score_loss: 0.6237 - val_rpn_regress_loss: 0.6676 - val_cls_logits_loss1: 2.8782 - val_cls_regress_loss1: 2.1182 - val_cls_logits_loss2: 0.8635 - val_cls_regress_loss2: 0.0936 - val_cls_logits_loss3: 0.0000e+00 - val_cls_regress_loss3: 0.0000e+00
# Epoch 13/500
# 31/31 [==============================] - 15s 473ms/step - loss: 7.4875 - rpn_score_accuracy: 0.8984 - cls_logits_accuracy1: 0.7016 - cls_logits_accuracy2: 0.3871 - cls_logits_accuracy3: 0.1048 - rpn_score_loss: 0.2818 - rpn_regress_loss: 0.4676 - cls_logits_loss1: 3.7696 - cls_regress_loss1: 1.7520 - cls_logits_loss2: 1.0399 - cls_regress_loss2: 0.1383 - cls_logits_loss3: 0.0294 - cls_regress_loss3: 0.0089 - val_loss: 6.5572 - val_rpn_score_accuracy: 0.7746 - val_cls_logits_accuracy1: 0.5357 - val_cls_logits_accuracy2: 0.3214 - val_cls_logits_accuracy3: 0.0000e+00 - val_rpn_score_loss: 0.6158 - val_rpn_regress_loss: 0.6785 - val_cls_logits_loss1: 2.8782 - val_cls_regress_loss1: 1.4295 - val_cls_logits_loss2: 0.8635 - val_cls_regress_loss2: 0.0917 - val_cls_logits_loss3: 0.0000e+00 - val_cls_regress_loss3: 0.0000e+00
# Epoch 14/500
# 31/31 [==============================] - 15s 471ms/step - loss: 8.0864 - rpn_score_accuracy: 0.8971 - cls_logits_accuracy1: 0.6774 - cls_logits_accuracy2: 0.4355 - cls_logits_accuracy3: 0.0323 - rpn_score_loss: 0.2972 - rpn_regress_loss: 0.5777 - cls_logits_loss1: 3.6396 - cls_regress_loss1: 2.2864 - cls_logits_loss2: 1.1699 - cls_regress_loss2: 0.0811 - cls_logits_loss3: 0.0280 - cls_regress_loss3: 0.0065 - val_loss: 4.9328 - val_rpn_score_accuracy: 0.8074 - val_cls_logits_accuracy1: 0.4286 - val_cls_logits_accuracy2: 0.3214 - val_cls_logits_accuracy3: 0.0000e+00 - val_rpn_score_loss: 0.6448 - val_rpn_regress_loss: 0.7207 - val_cls_logits_loss1: 2.3026 - val_cls_regress_loss1: 0.3630 - val_cls_logits_loss2: 0.8635 - val_cls_regress_loss2: 0.0382 - val_cls_logits_loss3: 0.0000e+00 - val_cls_regress_loss3: 0.0000e+00
# Epoch 15/500
# 31/31 [==============================] - 15s 475ms/step - loss: 6.3558 - rpn_score_accuracy: 0.9101 - cls_logits_accuracy1: 0.6774 - cls_logits_accuracy2: 0.3629 - cls_logits_accuracy3: 0.0605 - rpn_score_loss: 0.2678 - rpn_regress_loss: 0.4802 - cls_logits_loss1: 3.6130 - cls_regress_loss1: 0.8820 - cls_logits_loss2: 0.9640 - cls_regress_loss2: 0.1258 - cls_logits_loss3: 0.0175 - cls_regress_loss3: 0.0056 - val_loss: 6.2154 - val_rpn_score_accuracy: 0.7923 - val_cls_logits_accuracy1: 0.5357 - val_cls_logits_accuracy2: 0.2143 - val_cls_logits_accuracy3: 0.1071 - val_rpn_score_loss: 0.5771 - val_rpn_regress_loss: 0.6445 - val_cls_logits_loss1: 2.8782 - val_cls_regress_loss1: 1.4693 - val_cls_logits_loss2: 0.5756 - val_cls_regress_loss2: 0.0532 - val_cls_logits_loss3: 0.0055 - val_cls_regress_loss3: 0.0119
# Epoch 16/500
# 31/31 [==============================] - 15s 472ms/step - loss: 7.4780 - rpn_score_accuracy: 0.8903 - cls_logits_accuracy1: 0.7016 - cls_logits_accuracy2: 0.3871 - cls_logits_accuracy3: 0.0565 - rpn_score_loss: 0.3023 - rpn_regress_loss: 0.5232 - cls_logits_loss1: 3.7696 - cls_regress_loss1: 1.6211 - cls_logits_loss2: 1.0399 - cls_regress_loss2: 0.2092 - cls_logits_loss3: 0.0048 - cls_regress_loss3: 0.0079 - val_loss: 7.2958 - val_rpn_score_accuracy: 0.7754 - val_cls_logits_accuracy1: 0.5357 - val_cls_logits_accuracy2: 0.3214 - val_cls_logits_accuracy3: 0.1071 - val_rpn_score_loss: 0.6107 - val_rpn_regress_loss: 0.6602 - val_cls_logits_loss1: 2.8782 - val_cls_regress_loss1: 2.0459 - val_cls_logits_loss2: 0.8635 - val_cls_regress_loss2: 0.2125 - val_cls_logits_loss3: 0.0070 - val_cls_regress_loss3: 0.0179
# Epoch 17/500
# 31/31 [==============================] - 15s 478ms/step - loss: 8.8767 - rpn_score_accuracy: 0.9100 - cls_logits_accuracy1: 0.7500 - cls_logits_accuracy2: 0.6048 - cls_logits_accuracy3: 0.1048 - rpn_score_loss: 0.2493 - rpn_regress_loss: 0.4549 - cls_logits_loss1: 4.0295 - cls_regress_loss1: 2.2296 - cls_logits_loss2: 1.6248 - cls_regress_loss2: 0.2622 - cls_logits_loss3: 0.0105 - cls_regress_loss3: 0.0160 - val_loss: 6.0862 - val_rpn_score_accuracy: 0.7864 - val_cls_logits_accuracy1: 0.4286 - val_cls_logits_accuracy2: 0.2143 - val_cls_logits_accuracy3: 0.0357 - val_rpn_score_loss: 0.6309 - val_rpn_regress_loss: 0.6557 - val_cls_logits_loss1: 2.3026 - val_cls_regress_loss1: 1.8461 - val_cls_logits_loss2: 0.5756 - val_cls_regress_loss2: 0.0588 - val_cls_logits_loss3: 0.0124 - val_cls_regress_loss3: 0.0041
# Epoch 18/500
# 31/31 [==============================] - 15s 476ms/step - loss: 10.4266 - rpn_score_accuracy: 0.8921 - cls_logits_accuracy1: 0.7258 - cls_logits_accuracy2: 0.5806 - cls_logits_accuracy3: 0.0484 - rpn_score_loss: 0.2955 - rpn_regress_loss: 0.4728 - cls_logits_loss1: 3.8940 - cls_regress_loss1: 3.2781 - cls_logits_loss2: 1.5335 - cls_regress_loss2: 0.9424 - cls_logits_loss3: 0.0043 - cls_regress_loss3: 0.0061 - val_loss: 6.3808 - val_rpn_score_accuracy: 0.7653 - val_cls_logits_accuracy1: 0.5357 - val_cls_logits_accuracy2: 0.3214 - val_cls_logits_accuracy3: 0.0000e+00 - val_rpn_score_loss: 0.5854 - val_rpn_regress_loss: 0.6107 - val_cls_logits_loss1: 2.8782 - val_cls_regress_loss1: 1.4109 - val_cls_logits_loss2: 0.8635 - val_cls_regress_loss2: 0.0320 - val_cls_logits_loss3: 0.0000e+00 - val_cls_regress_loss3: 0.0000e+00
# Epoch 19/500
# 31/31 [==============================] - 15s 475ms/step - loss: 6.8499 - rpn_score_accuracy: 0.9210 - cls_logits_accuracy1: 0.7016 - cls_logits_accuracy2: 0.4113 - cls_logits_accuracy3: 0.0323 - rpn_score_loss: 0.2410 - rpn_regress_loss: 0.4587 - cls_logits_loss1: 3.7696 - cls_regress_loss1: 1.0828 - cls_logits_loss2: 1.1049 - cls_regress_loss2: 0.1790 - cls_logits_loss3: 0.0115 - cls_regress_loss3: 0.0025 - val_loss: 6.4811 - val_rpn_score_accuracy: 0.7988 - val_cls_logits_accuracy1: 0.5357 - val_cls_logits_accuracy2: 0.4286 - val_cls_logits_accuracy3: 0.0000e+00 - val_rpn_score_loss: 0.6092 - val_rpn_regress_loss: 0.6381 - val_cls_logits_loss1: 2.8782 - val_cls_regress_loss1: 1.1475 - val_cls_logits_loss2: 1.1513 - val_cls_regress_loss2: 0.0566 - val_cls_logits_loss3: 0.0000e+00 - val_cls_regress_loss3: 0.0000e+00
# Epoch 20/500
# 31/31 [==============================] - 15s 475ms/step - loss: 7.7044 - rpn_score_accuracy: 0.9075 - cls_logits_accuracy1: 0.7016 - cls_logits_accuracy2: 0.4812 - cls_logits_accuracy3: 0.0968 - rpn_score_loss: 0.2717 - rpn_regress_loss: 0.4397 - cls_logits_loss1: 3.7696 - cls_regress_loss1: 1.4327 - cls_logits_loss2: 1.3037 - cls_regress_loss2: 0.4629 - cls_logits_loss3: 0.0102 - cls_regress_loss3: 0.0138 - val_loss: 5.4840 - val_rpn_score_accuracy: 0.7854 - val_cls_logits_accuracy1: 0.5357 - val_cls_logits_accuracy2: 0.3214 - val_cls_logits_accuracy3: 0.0357 - val_rpn_score_loss: 0.6248 - val_rpn_regress_loss: 0.6457 - val_cls_logits_loss1: 2.8782 - val_cls_regress_loss1: 0.3206 - val_cls_logits_loss2: 0.8635 - val_cls_regress_loss2: 0.0792 - val_cls_logits_loss3: 0.0459 - val_cls_regress_loss3: 0.0262
# Epoch 21/500
# 31/31 [==============================] - 15s 475ms/step - loss: 7.8094 - rpn_score_accuracy: 0.8839 - cls_logits_accuracy1: 0.7016 - cls_logits_accuracy2: 0.4355 - cls_logits_accuracy3: 0.0887 - rpn_score_loss: 0.2904 - rpn_regress_loss: 0.4076 - cls_logits_loss1: 3.7696 - cls_regress_loss1: 1.9632 - cls_logits_loss2: 1.1699 - cls_regress_loss2: 0.1771 - cls_logits_loss3: 0.0203 - cls_regress_loss3: 0.0114 - val_loss: 8.8883 - val_rpn_score_accuracy: 0.8006 - val_cls_logits_accuracy1: 0.5357 - val_cls_logits_accuracy2: 0.3214 - val_cls_logits_accuracy3: 0.0000e+00 - val_rpn_score_loss: 0.5276 - val_rpn_regress_loss: 0.6371 - val_cls_logits_loss1: 2.8782 - val_cls_regress_loss1: 2.9943 - val_cls_logits_loss2: 0.8635 - val_cls_regress_loss2: 0.9876 - val_cls_logits_loss3: 0.0000e+00 - val_cls_regress_loss3: 0.0000e+00
# Epoch 22/500
# 31/31 [==============================] - 15s 474ms/step - loss: 10.9806 - rpn_score_accuracy: 0.9191 - cls_logits_accuracy1: 0.7016 - cls_logits_accuracy2: 0.4597 - cls_logits_accuracy3: 0.1815 - rpn_score_loss: 0.2465 - rpn_regress_loss: 0.4613 - cls_logits_loss1: 3.7696 - cls_regress_loss1: 4.3686 - cls_logits_loss2: 1.2349 - cls_regress_loss2: 0.8129 - cls_logits_loss3: 0.0673 - cls_regress_loss3: 0.0196 - val_loss: 6.0417 - val_rpn_score_accuracy: 0.8028 - val_cls_logits_accuracy1: 0.5357 - val_cls_logits_accuracy2: 0.4286 - val_cls_logits_accuracy3: 0.0000e+00 - val_rpn_score_loss: 0.5586 - val_rpn_regress_loss: 0.6244 - val_cls_logits_loss1: 2.8782 - val_cls_regress_loss1: 0.6116 - val_cls_logits_loss2: 1.1513 - val_cls_regress_loss2: 0.2175 - val_cls_logits_loss3: 0.0000e+00 - val_cls_regress_loss3: 0.0000e+00
# Epoch 23/500
# 31/31 [==============================] - 15s 475ms/step - loss: 6.1804 - rpn_score_accuracy: 0.9159 - cls_logits_accuracy1: 0.6774 - cls_logits_accuracy2: 0.4355 - cls_logits_accuracy3: 0.1613 - rpn_score_loss: 0.2712 - rpn_regress_loss: 0.4938 - cls_logits_loss1: 3.6396 - cls_regress_loss1: 0.4018 - cls_logits_loss2: 1.1699 - cls_regress_loss2: 0.1325 - cls_logits_loss3: 0.0462 - cls_regress_loss3: 0.0254 - val_loss: 6.1841 - val_rpn_score_accuracy: 0.7647 - val_cls_logits_accuracy1: 0.5357 - val_cls_logits_accuracy2: 0.5357 - val_cls_logits_accuracy3: 0.1071 - val_rpn_score_loss: 0.6117 - val_rpn_regress_loss: 0.6298 - val_cls_logits_loss1: 2.8782 - val_cls_regress_loss1: 0.3498 - val_cls_logits_loss2: 1.4391 - val_cls_regress_loss2: 0.2115 - val_cls_logits_loss3: 0.0598 - val_cls_regress_loss3: 0.0042
# Epoch 24/500
# 31/31 [==============================] - 15s 480ms/step - loss: 6.8233 - rpn_score_accuracy: 0.9047 - cls_logits_accuracy1: 0.7258 - cls_logits_accuracy2: 0.5323 - cls_logits_accuracy3: 0.2218 - rpn_score_loss: 0.2691 - rpn_regress_loss: 0.4838 - cls_logits_loss1: 3.8457 - cls_regress_loss1: 0.3940 - cls_logits_loss2: 1.4298 - cls_regress_loss2: 0.3395 - cls_logits_loss3: 0.0406 - cls_regress_loss3: 0.0210 - val_loss: 7.9152 - val_rpn_score_accuracy: 0.8337 - val_cls_logits_accuracy1: 0.7500 - val_cls_logits_accuracy2: 0.3214 - val_cls_logits_accuracy3: 0.0357 - val_rpn_score_loss: 0.4832 - val_rpn_regress_loss: 0.6367 - val_cls_logits_loss1: 4.0295 - val_cls_regress_loss1: 0.7003 - val_cls_logits_loss2: 0.8635 - val_cls_regress_loss2: 1.1757 - val_cls_logits_loss3: 0.0205 - val_cls_regress_loss3: 0.0058
# Epoch 25/500
# 31/31 [==============================] - 15s 476ms/step - loss: 7.3139 - rpn_score_accuracy: 0.9262 - cls_logits_accuracy1: 0.7016 - cls_logits_accuracy2: 0.4597 - cls_logits_accuracy3: 0.1371 - rpn_score_loss: 0.2492 - rpn_regress_loss: 0.4486 - cls_logits_loss1: 3.7696 - cls_regress_loss1: 1.0523 - cls_logits_loss2: 1.2349 - cls_regress_loss2: 0.4331 - cls_logits_loss3: 0.1089 - cls_regress_loss3: 0.0173 - val_loss: 5.9201 - val_rpn_score_accuracy: 0.7797 - val_cls_logits_accuracy1: 0.5357 - val_cls_logits_accuracy2: 0.3214 - val_cls_logits_accuracy3: 0.2143 - val_rpn_score_loss: 0.6169 - val_rpn_regress_loss: 0.6559 - val_cls_logits_loss1: 2.8782 - val_cls_regress_loss1: 0.3718 - val_cls_logits_loss2: 0.8635 - val_cls_regress_loss2: 0.4231 - val_cls_logits_loss3: 0.0907 - val_cls_regress_loss3: 0.0200
# Epoch 26/500
# 31/31 [==============================] - 15s 478ms/step - loss: 8.8580 - rpn_score_accuracy: 0.9062 - cls_logits_accuracy1: 0.7258 - cls_logits_accuracy2: 0.5565 - cls_logits_accuracy3: 0.1075 - rpn_score_loss: 0.2636 - rpn_regress_loss: 0.4163 - cls_logits_loss1: 3.8726 - cls_regress_loss1: 1.7225 - cls_logits_loss2: 1.4602 - cls_regress_loss2: 1.0869 - cls_logits_loss3: 0.0237 - cls_regress_loss3: 0.0123 - val_loss: 4.6973 - val_rpn_score_accuracy: 0.7663 - val_cls_logits_accuracy1: 0.3214 - val_cls_logits_accuracy2: 0.2143 - val_cls_logits_accuracy3: 0.0000e+00 - val_rpn_score_loss: 0.7852 - val_rpn_regress_loss: 1.3672 - val_cls_logits_loss1: 1.7269 - val_cls_regress_loss1: 0.1744 - val_cls_logits_loss2: 0.5756 - val_cls_regress_loss2: 0.0679 - val_cls_logits_loss3: 0.0000e+00 - val_cls_regress_loss3: 0.0000e+00
# Epoch 27/500
# 31/31 [==============================] - 15s 471ms/step - loss: 9.0903 - rpn_score_accuracy: 0.9064 - cls_logits_accuracy1: 0.7500 - cls_logits_accuracy2: 0.6435 - cls_logits_accuracy3: 0.2661 - rpn_score_loss: 0.2794 - rpn_regress_loss: 0.3902 - cls_logits_loss1: 3.8733 - cls_regress_loss1: 1.9356 - cls_logits_loss2: 1.6739 - cls_regress_loss2: 0.6584 - cls_logits_loss3: 0.1196 - cls_regress_loss3: 0.1597 - val_loss: 5.5691 - val_rpn_score_accuracy: 0.7843 - val_cls_logits_accuracy1: 0.4286 - val_cls_logits_accuracy2: 0.3214 - val_cls_logits_accuracy3: 0.3214 - val_rpn_score_loss: 0.6726 - val_rpn_regress_loss: 0.6699 - val_cls_logits_loss1: 2.3026 - val_cls_regress_loss1: 0.3147 - val_cls_logits_loss2: 0.8635 - val_cls_regress_loss2: 0.5235 - val_cls_logits_loss3: 0.0477 - val_cls_regress_loss3: 0.1747
# Epoch 28/500
# 31/31 [==============================] - 15s 473ms/step - loss: 7.7193 - rpn_score_accuracy: 0.8963 - cls_logits_accuracy1: 0.7258 - cls_logits_accuracy2: 0.6441 - cls_logits_accuracy3: 0.1710 - rpn_score_loss: 0.2560 - rpn_regress_loss: 0.5101 - cls_logits_loss1: 3.6716 - cls_regress_loss1: 0.6500 - cls_logits_loss2: 1.5471 - cls_regress_loss2: 0.9962 - cls_logits_loss3: 0.0433 - cls_regress_loss3: 0.0450 - val_loss: 5.2471 - val_rpn_score_accuracy: 0.7855 - val_cls_logits_accuracy1: 0.5357 - val_cls_logits_accuracy2: 0.4286 - val_cls_logits_accuracy3: 0.0000e+00 - val_rpn_score_loss: 0.6043 - val_rpn_regress_loss: 0.6019 - val_cls_logits_loss1: 2.8782 - val_cls_regress_loss1: 0.2694 - val_cls_logits_loss2: 0.8553 - val_cls_regress_loss2: 0.0380 - val_cls_logits_loss3: 0.0000e+00 - val_cls_regress_loss3: 0.0000e+00
# Epoch 29/500
# 31/31 [==============================] - 15s 476ms/step - loss: 4.8357 - rpn_score_accuracy: 0.9122 - cls_logits_accuracy1: 0.6519 - cls_logits_accuracy2: 0.4698 - cls_logits_accuracy3: 0.2661 - rpn_score_loss: 0.2963 - rpn_regress_loss: 0.4886 - cls_logits_loss1: 2.3692 - cls_regress_loss1: 0.6778 - cls_logits_loss2: 0.5342 - cls_regress_loss2: 0.3947 - cls_logits_loss3: 0.0163 - cls_regress_loss3: 0.0588 - val_loss: 4.4355 - val_rpn_score_accuracy: 0.8362 - val_cls_logits_accuracy1: 0.1786 - val_cls_logits_accuracy2: 0.1429 - val_cls_logits_accuracy3: 0.0000e+00 - val_rpn_score_loss: 0.4985 - val_rpn_regress_loss: 0.6477 - val_cls_logits_loss1: 1.1545 - val_cls_regress_loss1: 0.2767 - val_cls_logits_loss2: 1.1795 - val_cls_regress_loss2: 0.6786 - val_cls_logits_loss3: 0.0000e+00 - val_cls_regress_loss3: 0.0000e+00
# Epoch 30/500
# 31/31 [==============================] - 15s 482ms/step - loss: 4.4563 - rpn_score_accuracy: 0.9149 - cls_logits_accuracy1: 0.6622 - cls_logits_accuracy2: 0.5301 - cls_logits_accuracy3: 0.2137 - rpn_score_loss: 0.2567 - rpn_regress_loss: 0.4349 - cls_logits_loss1: 1.8592 - cls_regress_loss1: 0.7397 - cls_logits_loss2: 0.7684 - cls_regress_loss2: 0.2531 - cls_logits_loss3: 0.0744 - cls_regress_loss3: 0.0699 - val_loss: 3.3874 - val_rpn_score_accuracy: 0.7992 - val_cls_logits_accuracy1: 0.2143 - val_cls_logits_accuracy2: 0.2143 - val_cls_logits_accuracy3: 0.0357 - val_rpn_score_loss: 0.5824 - val_rpn_regress_loss: 0.6401 - val_cls_logits_loss1: 0.4316 - val_cls_regress_loss1: 0.5256 - val_cls_logits_loss2: 0.5756 - val_cls_regress_loss2: 0.1702 - val_cls_logits_loss3: 0.2728 - val_cls_regress_loss3: 0.1891
# Epoch 31/500
# 31/31 [==============================] - 15s 481ms/step - loss: 4.7392 - rpn_score_accuracy: 0.9231 - cls_logits_accuracy1: 0.6573 - cls_logits_accuracy2: 0.6512 - cls_logits_accuracy3: 0.1781 - rpn_score_loss: 0.2037 - rpn_regress_loss: 0.3610 - cls_logits_loss1: 0.7679 - cls_regress_loss1: 0.8339 - cls_logits_loss2: 1.7490 - cls_regress_loss2: 0.4771 - cls_logits_loss3: 0.1727 - cls_regress_loss3: 0.1740 - val_loss: 5.7535 - val_rpn_score_accuracy: 0.7749 - val_cls_logits_accuracy1: 0.2143 - val_cls_logits_accuracy2: 0.0000e+00 - val_cls_logits_accuracy3: 0.0000e+00 - val_rpn_score_loss: 0.6455 - val_rpn_regress_loss: 0.6597 - val_cls_logits_loss1: 2.8882 - val_cls_regress_loss1: 1.5601 - val_cls_logits_loss2: 0.0000e+00 - val_cls_regress_loss2: 0.0000e+00 - val_cls_logits_loss3: 0.0000e+00 - val_cls_regress_loss3: 0.0000e+00
# Epoch 32/500
# 31/31 [==============================] - 15s 482ms/step - loss: 4.9203 - rpn_score_accuracy: 0.9258 - cls_logits_accuracy1: 0.5642 - cls_logits_accuracy2: 0.4839 - cls_logits_accuracy3: 0.1815 - rpn_score_loss: 0.2201 - rpn_regress_loss: 0.3572 - cls_logits_loss1: 0.7878 - cls_regress_loss1: 1.4629 - cls_logits_loss2: 1.2998 - cls_regress_loss2: 0.5862 - cls_logits_loss3: 0.0173 - cls_regress_loss3: 0.1889 - val_loss: 5.3711 - val_rpn_score_accuracy: 0.7900 - val_cls_logits_accuracy1: 0.1786 - val_cls_logits_accuracy2: 0.5357 - val_cls_logits_accuracy3: 0.1071 - val_rpn_score_loss: 0.5335 - val_rpn_regress_loss: 0.6509 - val_cls_logits_loss1: 1.2224 - val_cls_regress_loss1: 0.1339 - val_cls_logits_loss2: 1.4391 - val_cls_regress_loss2: 1.3746 - val_cls_logits_loss3: 0.0051 - val_cls_regress_loss3: 0.0115
# Epoch 33/500
# 31/31 [==============================] - 15s 479ms/step - loss: 4.4460 - rpn_score_accuracy: 0.9076 - cls_logits_accuracy1: 0.6259 - cls_logits_accuracy2: 0.5766 - cls_logits_accuracy3: 0.2944 - rpn_score_loss: 0.2893 - rpn_regress_loss: 0.4654 - cls_logits_loss1: 0.6284 - cls_regress_loss1: 0.8201 - cls_logits_loss2: 1.4607 - cls_regress_loss2: 0.6974 - cls_logits_loss3: 0.0363 - cls_regress_loss3: 0.0484 - val_loss: 2.2939 - val_rpn_score_accuracy: 0.7505 - val_cls_logits_accuracy1: 0.0893 - val_cls_logits_accuracy2: 0.0000e+00 - val_cls_logits_accuracy3: 0.0000e+00 - val_rpn_score_loss: 0.7230 - val_rpn_regress_loss: 1.0484 - val_cls_logits_loss1: 0.3410 - val_cls_regress_loss1: 0.1815 - val_cls_logits_loss2: 0.0000e+00 - val_cls_regress_loss2: 0.0000e+00 - val_cls_logits_loss3: 0.0000e+00 - val_cls_regress_loss3: 0.0000e+00
# Epoch 34/500
# 31/31 [==============================] - 15s 477ms/step - loss: 4.7107 - rpn_score_accuracy: 0.9041 - cls_logits_accuracy1: 0.6654 - cls_logits_accuracy2: 0.6532 - cls_logits_accuracy3: 0.1774 - rpn_score_loss: 0.2922 - rpn_regress_loss: 0.4290 - cls_logits_loss1: 1.3263 - cls_regress_loss1: 0.4781 - cls_logits_loss2: 1.8024 - cls_regress_loss2: 0.3524 - cls_logits_loss3: 0.0112 - cls_regress_loss3: 0.0192 - val_loss: 2.2440 - val_rpn_score_accuracy: 0.7434 - val_cls_logits_accuracy1: 0.3214 - val_cls_logits_accuracy2: 0.1071 - val_cls_logits_accuracy3: 0.0000e+00 - val_rpn_score_loss: 0.6384 - val_rpn_regress_loss: 0.8773 - val_cls_logits_loss1: 0.2241 - val_cls_regress_loss1: 0.0936 - val_cls_logits_loss2: 0.2878 - val_cls_regress_loss2: 0.1228 - val_cls_logits_loss3: 0.0000e+00 - val_cls_regress_loss3: 0.0000e+00
# Epoch 35/500
# 31/31 [==============================] - 15s 478ms/step - loss: 4.9586 - rpn_score_accuracy: 0.8914 - cls_logits_accuracy1: 0.6104 - cls_logits_accuracy2: 0.5806 - cls_logits_accuracy3: 0.1774 - rpn_score_loss: 0.2900 - rpn_regress_loss: 0.4680 - cls_logits_loss1: 1.2734 - cls_regress_loss1: 0.6700 - cls_logits_loss2: 1.5598 - cls_regress_loss2: 0.5702 - cls_logits_loss3: 0.0825 - cls_regress_loss3: 0.0446 - val_loss: 4.4909 - val_rpn_score_accuracy: 0.7991 - val_cls_logits_accuracy1: 0.2381 - val_cls_logits_accuracy2: 0.5357 - val_cls_logits_accuracy3: 0.3214 - val_rpn_score_loss: 0.6297 - val_rpn_regress_loss: 0.6442 - val_cls_logits_loss1: 1.2318 - val_cls_regress_loss1: 0.2146 - val_cls_logits_loss2: 1.4391 - val_cls_regress_loss2: 0.2536 - val_cls_logits_loss3: 0.0446 - val_cls_regress_loss3: 0.0331
# Epoch 36/500
# 31/31 [==============================] - 15s 471ms/step - loss: 4.9931 - rpn_score_accuracy: 0.8976 - cls_logits_accuracy1: 0.6036 - cls_logits_accuracy2: 0.5554 - cls_logits_accuracy3: 0.1828 - rpn_score_loss: 0.2588 - rpn_regress_loss: 0.4453 - cls_logits_loss1: 1.8691 - cls_regress_loss1: 0.7283 - cls_logits_loss2: 1.4956 - cls_regress_loss2: 0.1474 - cls_logits_loss3: 0.0312 - cls_regress_loss3: 0.0174 - val_loss: 2.0626 - val_rpn_score_accuracy: 0.7424 - val_cls_logits_accuracy1: 0.1429 - val_cls_logits_accuracy2: 0.0000e+00 - val_cls_logits_accuracy3: 0.0000e+00 - val_rpn_score_loss: 0.7181 - val_rpn_regress_loss: 0.6843 - val_cls_logits_loss1: 0.2103 - val_cls_regress_loss1: 0.4498 - val_cls_logits_loss2: 0.0000e+00 - val_cls_regress_loss2: 0.0000e+00 - val_cls_logits_loss3: 0.0000e+00 - val_cls_regress_loss3: 0.0000e+00
# Epoch 37/500
# 31/31 [==============================] - 15s 473ms/step - loss: 3.3315 - rpn_score_accuracy: 0.8690 - cls_logits_accuracy1: 0.6529 - cls_logits_accuracy2: 0.6532 - cls_logits_accuracy3: 0.2460 - rpn_score_loss: 0.3131 - rpn_regress_loss: 0.3893 - cls_logits_loss1: 0.2369 - cls_regress_loss1: 0.4491 - cls_logits_loss2: 1.7054 - cls_regress_loss2: 0.1418 - cls_logits_loss3: 0.0491 - cls_regress_loss3: 0.0466 - val_loss: 2.7059 - val_rpn_score_accuracy: 0.7927 - val_cls_logits_accuracy1: 0.1429 - val_cls_logits_accuracy2: 0.4286 - val_cls_logits_accuracy3: 0.1071 - val_rpn_score_loss: 0.5463 - val_rpn_regress_loss: 0.6870 - val_cls_logits_loss1: 0.1061 - val_cls_regress_loss1: 0.1050 - val_cls_logits_loss2: 1.1513 - val_cls_regress_loss2: 0.0730 - val_cls_logits_loss3: 0.0236 - val_cls_regress_loss3: 0.0136
# Epoch 38/500
# 31/31 [==============================] - 15s 472ms/step - loss: 3.7272 - rpn_score_accuracy: 0.9073 - cls_logits_accuracy1: 0.5587 - cls_logits_accuracy2: 0.4839 - cls_logits_accuracy3: 0.2661 - rpn_score_loss: 0.2459 - rpn_regress_loss: 0.3840 - cls_logits_loss1: 0.6250 - cls_regress_loss1: 1.0134 - cls_logits_loss2: 1.2370 - cls_regress_loss2: 0.1170 - cls_logits_loss3: 0.0458 - cls_regress_loss3: 0.0591 - val_loss: 2.0996 - val_rpn_score_accuracy: 0.7819 - val_cls_logits_accuracy1: 0.2738 - val_cls_logits_accuracy2: 0.0000e+00 - val_cls_logits_accuracy3: 0.0000e+00 - val_rpn_score_loss: 0.5586 - val_rpn_regress_loss: 0.6839 - val_cls_logits_loss1: 0.1854 - val_cls_regress_loss1: 0.6717 - val_cls_logits_loss2: 0.0000e+00 - val_cls_regress_loss2: 0.0000e+00 - val_cls_logits_loss3: 0.0000e+00 - val_cls_regress_loss3: 0.0000e+00
# Epoch 39/500
# 31/31 [==============================] - 15s 478ms/step - loss: 5.3347 - rpn_score_accuracy: 0.9033 - cls_logits_accuracy1: 0.6493 - cls_logits_accuracy2: 0.6290 - cls_logits_accuracy3: 0.2742 - rpn_score_loss: 0.2602 - rpn_regress_loss: 0.3491 - cls_logits_loss1: 1.5488 - cls_regress_loss1: 0.9928 - cls_logits_loss2: 1.6898 - cls_regress_loss2: 0.2165 - cls_logits_loss3: 0.0722 - cls_regress_loss3: 0.2052 - val_loss: 3.3929 - val_rpn_score_accuracy: 0.7968 - val_cls_logits_accuracy1: 0.6429 - val_cls_logits_accuracy2: 0.5357 - val_cls_logits_accuracy3: 0.1071 - val_rpn_score_loss: 0.5551 - val_rpn_regress_loss: 0.6274 - val_cls_logits_loss1: 0.1629 - val_cls_regress_loss1: 0.2175 - val_cls_logits_loss2: 1.4391 - val_cls_regress_loss2: 0.3526 - val_cls_logits_loss3: 0.0089 - val_cls_regress_loss3: 0.0294
# Epoch 40/500
# 31/31 [==============================] - 15s 477ms/step - loss: 4.1506 - rpn_score_accuracy: 0.9023 - cls_logits_accuracy1: 0.6540 - cls_logits_accuracy2: 0.6532 - cls_logits_accuracy3: 0.2228 - rpn_score_loss: 0.2446 - rpn_regress_loss: 0.5629 - cls_logits_loss1: 0.5505 - cls_regress_loss1: 0.8038 - cls_logits_loss2: 1.7006 - cls_regress_loss2: 0.1880 - cls_logits_loss3: 0.0256 - cls_regress_loss3: 0.0747 - val_loss: 2.8777 - val_rpn_score_accuracy: 0.7851 - val_cls_logits_accuracy1: 0.2143 - val_cls_logits_accuracy2: 0.1071 - val_cls_logits_accuracy3: 0.1071 - val_rpn_score_loss: 0.6666 - val_rpn_regress_loss: 0.6484 - val_cls_logits_loss1: 0.5507 - val_cls_regress_loss1: 0.6676 - val_cls_logits_loss2: 0.2878 - val_cls_regress_loss2: 0.0164 - val_cls_logits_loss3: 0.0271 - val_cls_regress_loss3: 0.0130
# Epoch 41/500
# 31/31 [==============================] - 15s 475ms/step - loss: 4.2193 - rpn_score_accuracy: 0.9000 - cls_logits_accuracy1: 0.6496 - cls_logits_accuracy2: 0.6263 - cls_logits_accuracy3: 0.2823 - rpn_score_loss: 0.2556 - rpn_regress_loss: 0.7048 - cls_logits_loss1: 0.3902 - cls_regress_loss1: 0.8065 - cls_logits_loss2: 1.5597 - cls_regress_loss2: 0.3950 - cls_logits_loss3: 0.0392 - cls_regress_loss3: 0.0683 - val_loss: 2.8469 - val_rpn_score_accuracy: 0.7265 - val_cls_logits_accuracy1: 0.1857 - val_cls_logits_accuracy2: 0.3214 - val_cls_logits_accuracy3: 0.2143 - val_rpn_score_loss: 0.8057 - val_rpn_regress_loss: 0.6216 - val_cls_logits_loss1: 0.2265 - val_cls_regress_loss1: 0.2600 - val_cls_logits_loss2: 0.8635 - val_cls_regress_loss2: 0.0415 - val_cls_logits_loss3: 0.0113 - val_cls_regress_loss3: 0.0168
# Epoch 42/500
# 31/31 [==============================] - 15s 482ms/step - loss: 4.3632 - rpn_score_accuracy: 0.8909 - cls_logits_accuracy1: 0.6558 - cls_logits_accuracy2: 0.6935 - cls_logits_accuracy3: 0.3613 - rpn_score_loss: 0.3492 - rpn_regress_loss: 0.3626 - cls_logits_loss1: 0.4605 - cls_regress_loss1: 0.7871 - cls_logits_loss2: 1.6513 - cls_regress_loss2: 0.4832 - cls_logits_loss3: 0.1009 - cls_regress_loss3: 0.1684 - val_loss: 2.8278 - val_rpn_score_accuracy: 0.7155 - val_cls_logits_accuracy1: 0.2214 - val_cls_logits_accuracy2: 0.3214 - val_cls_logits_accuracy3: 0.0000e+00 - val_rpn_score_loss: 0.7399 - val_rpn_regress_loss: 0.6034 - val_cls_logits_loss1: 0.1670 - val_cls_regress_loss1: 0.3868 - val_cls_logits_loss2: 0.8635 - val_cls_regress_loss2: 0.0672 - val_cls_logits_loss3: 0.0000e+00 - val_cls_regress_loss3: 0.0000e+00
# Epoch 43/500
# 31/31 [==============================] - 15s 486ms/step - loss: 4.0393 - rpn_score_accuracy: 0.9076 - cls_logits_accuracy1: 0.6598 - cls_logits_accuracy2: 0.6290 - cls_logits_accuracy3: 0.3145 - rpn_score_loss: 0.2375 - rpn_regress_loss: 0.3678 - cls_logits_loss1: 0.3627 - cls_regress_loss1: 0.9244 - cls_logits_loss2: 1.6895 - cls_regress_loss2: 0.2761 - cls_logits_loss3: 0.0239 - cls_regress_loss3: 0.1574 - val_loss: 2.6706 - val_rpn_score_accuracy: 0.7778 - val_cls_logits_accuracy1: 0.5357 - val_cls_logits_accuracy2: 0.3214 - val_cls_logits_accuracy3: 0.3214 - val_rpn_score_loss: 0.6259 - val_rpn_regress_loss: 0.6271 - val_cls_logits_loss1: 0.1002 - val_cls_regress_loss1: 0.3424 - val_cls_logits_loss2: 0.8635 - val_cls_regress_loss2: 0.0398 - val_cls_logits_loss3: 0.0195 - val_cls_regress_loss3: 0.0522
# Epoch 44/500
# ...
# Epoch 482/500
# 31/31 [==============================] - 16s 498ms/step - loss: 0.2879 - rpn_score_accuracy: 0.9984 - cls_logits_accuracy1: 0.9338 - cls_logits_accuracy2: 0.9300 - cls_logits_accuracy3: 0.8994 - rpn_score_loss: 0.0075 - rpn_regress_loss: 0.0211 - cls_logits_loss1: 0.0481 - cls_regress_loss1: 0.1001 - cls_logits_loss2: 0.0289 - cls_regress_loss2: 0.0497 - cls_logits_loss3: 0.0128 - cls_regress_loss3: 0.0198 - val_loss: 3.0181 - val_rpn_score_accuracy: 0.7622 - val_cls_logits_accuracy1: 0.8638 - val_cls_logits_accuracy2: 0.8423 - val_cls_logits_accuracy3: 0.8576 - val_rpn_score_loss: 1.7319 - val_rpn_regress_loss: 0.6663 - val_cls_logits_loss1: 0.1446 - val_cls_regress_loss1: 0.2290 - val_cls_logits_loss2: 0.0535 - val_cls_regress_loss2: 0.1140 - val_cls_logits_loss3: 0.0250 - val_cls_regress_loss3: 0.0536
# Epoch 483/500
# 31/31 [==============================] - 15s 495ms/step - loss: 0.3012 - rpn_score_accuracy: 0.9977 - cls_logits_accuracy1: 0.9012 - cls_logits_accuracy2: 0.9252 - cls_logits_accuracy3: 0.9276 - rpn_score_loss: 0.0090 - rpn_regress_loss: 0.0208 - cls_logits_loss1: 0.0565 - cls_regress_loss1: 0.1037 - cls_logits_loss2: 0.0234 - cls_regress_loss2: 0.0520 - cls_logits_loss3: 0.0124 - cls_regress_loss3: 0.0234 - val_loss: 2.9524 - val_rpn_score_accuracy: 0.7735 - val_cls_logits_accuracy1: 0.8683 - val_cls_logits_accuracy2: 0.8714 - val_cls_logits_accuracy3: 0.8732 - val_rpn_score_loss: 1.7226 - val_rpn_regress_loss: 0.6633 - val_cls_logits_loss1: 0.0902 - val_cls_regress_loss1: 0.2434 - val_cls_logits_loss2: 0.0382 - val_cls_regress_loss2: 0.1167 - val_cls_logits_loss3: 0.0233 - val_cls_regress_loss3: 0.0547
# Epoch 484/500
# 31/31 [==============================] - 15s 496ms/step - loss: 0.2969 - rpn_score_accuracy: 0.9979 - cls_logits_accuracy1: 0.9320 - cls_logits_accuracy2: 0.9396 - cls_logits_accuracy3: 0.9294 - rpn_score_loss: 0.0121 - rpn_regress_loss: 0.0240 - cls_logits_loss1: 0.0442 - cls_regress_loss1: 0.1083 - cls_logits_loss2: 0.0220 - cls_regress_loss2: 0.0490 - cls_logits_loss3: 0.0119 - cls_regress_loss3: 0.0254 - val_loss: 2.9711 - val_rpn_score_accuracy: 0.7448 - val_cls_logits_accuracy1: 0.8442 - val_cls_logits_accuracy2: 0.8661 - val_cls_logits_accuracy3: 0.8909 - val_rpn_score_loss: 1.7471 - val_rpn_regress_loss: 0.6430 - val_cls_logits_loss1: 0.0928 - val_cls_regress_loss1: 0.2547 - val_cls_logits_loss2: 0.0458 - val_cls_regress_loss2: 0.1148 - val_cls_logits_loss3: 0.0185 - val_cls_regress_loss3: 0.0543
# Epoch 485/500
# 31/31 [==============================] - 15s 492ms/step - loss: 0.2944 - rpn_score_accuracy: 0.9878 - cls_logits_accuracy1: 0.9326 - cls_logits_accuracy2: 0.9337 - cls_logits_accuracy3: 0.9245 - rpn_score_loss: 0.0223 - rpn_regress_loss: 0.0226 - cls_logits_loss1: 0.0439 - cls_regress_loss1: 0.1007 - cls_logits_loss2: 0.0219 - cls_regress_loss2: 0.0490 - cls_logits_loss3: 0.0123 - cls_regress_loss3: 0.0217 - val_loss: 2.8926 - val_rpn_score_accuracy: 0.7393 - val_cls_logits_accuracy1: 0.8785 - val_cls_logits_accuracy2: 0.8518 - val_cls_logits_accuracy3: 0.8625 - val_rpn_score_loss: 1.6971 - val_rpn_regress_loss: 0.6445 - val_cls_logits_loss1: 0.0763 - val_cls_regress_loss1: 0.2490 - val_cls_logits_loss2: 0.0468 - val_cls_regress_loss2: 0.1084 - val_cls_logits_loss3: 0.0228 - val_cls_regress_loss3: 0.0476
# Epoch 486/500
# 31/31 [==============================] - 15s 498ms/step - loss: 0.2830 - rpn_score_accuracy: 0.9929 - cls_logits_accuracy1: 0.9310 - cls_logits_accuracy2: 0.9222 - cls_logits_accuracy3: 0.9196 - rpn_score_loss: 0.0170 - rpn_regress_loss: 0.0225 - cls_logits_loss1: 0.0446 - cls_regress_loss1: 0.0976 - cls_logits_loss2: 0.0232 - cls_regress_loss2: 0.0447 - cls_logits_loss3: 0.0128 - cls_regress_loss3: 0.0206 - val_loss: 2.9561 - val_rpn_score_accuracy: 0.7326 - val_cls_logits_accuracy1: 0.8695 - val_cls_logits_accuracy2: 0.8720 - val_cls_logits_accuracy3: 0.8716 - val_rpn_score_loss: 1.7872 - val_rpn_regress_loss: 0.6401 - val_cls_logits_loss1: 0.0892 - val_cls_regress_loss1: 0.2132 - val_cls_logits_loss2: 0.0459 - val_cls_regress_loss2: 0.1071 - val_cls_logits_loss3: 0.0239 - val_cls_regress_loss3: 0.0495
# Epoch 487/500
# 31/31 [==============================] - 15s 492ms/step - loss: 0.2849 - rpn_score_accuracy: 0.9948 - cls_logits_accuracy1: 0.9482 - cls_logits_accuracy2: 0.9405 - cls_logits_accuracy3: 0.9476 - rpn_score_loss: 0.0105 - rpn_regress_loss: 0.0221 - cls_logits_loss1: 0.0357 - cls_regress_loss1: 0.1114 - cls_logits_loss2: 0.0192 - cls_regress_loss2: 0.0526 - cls_logits_loss3: 0.0094 - cls_regress_loss3: 0.0241 - val_loss: 2.8728 - val_rpn_score_accuracy: 0.7424 - val_cls_logits_accuracy1: 0.9048 - val_cls_logits_accuracy2: 0.8880 - val_cls_logits_accuracy3: 0.9094 - val_rpn_score_loss: 1.7233 - val_rpn_regress_loss: 0.6655 - val_cls_logits_loss1: 0.0601 - val_cls_regress_loss1: 0.2132 - val_cls_logits_loss2: 0.0343 - val_cls_regress_loss2: 0.1078 - val_cls_logits_loss3: 0.0181 - val_cls_regress_loss3: 0.0505
# Epoch 488/500
# 31/31 [==============================] - 16s 498ms/step - loss: 0.2748 - rpn_score_accuracy: 0.9939 - cls_logits_accuracy1: 0.9532 - cls_logits_accuracy2: 0.9524 - cls_logits_accuracy3: 0.9501 - rpn_score_loss: 0.0198 - rpn_regress_loss: 0.0254 - cls_logits_loss1: 0.0361 - cls_regress_loss1: 0.0977 - cls_logits_loss2: 0.0168 - cls_regress_loss2: 0.0479 - cls_logits_loss3: 0.0089 - cls_regress_loss3: 0.0223 - val_loss: 2.8903 - val_rpn_score_accuracy: 0.7583 - val_cls_logits_accuracy1: 0.9230 - val_cls_logits_accuracy2: 0.8780 - val_cls_logits_accuracy3: 0.9200 - val_rpn_score_loss: 1.7701 - val_rpn_regress_loss: 0.6610 - val_cls_logits_loss1: 0.0562 - val_cls_regress_loss1: 0.1888 - val_cls_logits_loss2: 0.0432 - val_cls_regress_loss2: 0.0977 - val_cls_logits_loss3: 0.0276 - val_cls_regress_loss3: 0.0456
# Epoch 489/500
# 31/31 [==============================] - 15s 495ms/step - loss: 0.2560 - rpn_score_accuracy: 0.9959 - cls_logits_accuracy1: 0.9411 - cls_logits_accuracy2: 0.9521 - cls_logits_accuracy3: 0.9517 - rpn_score_loss: 0.0115 - rpn_regress_loss: 0.0238 - cls_logits_loss1: 0.0374 - cls_regress_loss1: 0.0908 - cls_logits_loss2: 0.0182 - cls_regress_loss2: 0.0437 - cls_logits_loss3: 0.0096 - cls_regress_loss3: 0.0208 - val_loss: 3.0893 - val_rpn_score_accuracy: 0.7357 - val_cls_logits_accuracy1: 0.8943 - val_cls_logits_accuracy2: 0.8899 - val_cls_logits_accuracy3: 0.9209 - val_rpn_score_loss: 1.9017 - val_rpn_regress_loss: 0.6762 - val_cls_logits_loss1: 0.0953 - val_cls_regress_loss1: 0.2073 - val_cls_logits_loss2: 0.0497 - val_cls_regress_loss2: 0.1017 - val_cls_logits_loss3: 0.0157 - val_cls_regress_loss3: 0.0417
# Epoch 490/500
# 31/31 [==============================] - 15s 488ms/step - loss: 0.2810 - rpn_score_accuracy: 0.9899 - cls_logits_accuracy1: 0.9449 - cls_logits_accuracy2: 0.9452 - cls_logits_accuracy3: 0.9407 - rpn_score_loss: 0.0223 - rpn_regress_loss: 0.0198 - cls_logits_loss1: 0.0389 - cls_regress_loss1: 0.0980 - cls_logits_loss2: 0.0216 - cls_regress_loss2: 0.0459 - cls_logits_loss3: 0.0127 - cls_regress_loss3: 0.0218 - val_loss: 3.0446 - val_rpn_score_accuracy: 0.7581 - val_cls_logits_accuracy1: 0.9018 - val_cls_logits_accuracy2: 0.8726 - val_cls_logits_accuracy3: 0.8702 - val_rpn_score_loss: 1.8328 - val_rpn_regress_loss: 0.6542 - val_cls_logits_loss1: 0.0983 - val_cls_regress_loss1: 0.2060 - val_cls_logits_loss2: 0.0747 - val_cls_regress_loss2: 0.1072 - val_cls_logits_loss3: 0.0247 - val_cls_regress_loss3: 0.0467
# Epoch 491/500
# 31/31 [==============================] - 15s 493ms/step - loss: 0.2691 - rpn_score_accuracy: 0.9932 - cls_logits_accuracy1: 0.9392 - cls_logits_accuracy2: 0.9459 - cls_logits_accuracy3: 0.9446 - rpn_score_loss: 0.0193 - rpn_regress_loss: 0.0181 - cls_logits_loss1: 0.0385 - cls_regress_loss1: 0.0975 - cls_logits_loss2: 0.0177 - cls_regress_loss2: 0.0471 - cls_logits_loss3: 0.0095 - cls_regress_loss3: 0.0214 - val_loss: 3.1615 - val_rpn_score_accuracy: 0.7210 - val_cls_logits_accuracy1: 0.8817 - val_cls_logits_accuracy2: 0.8596 - val_cls_logits_accuracy3: 0.8486 - val_rpn_score_loss: 1.9656 - val_rpn_regress_loss: 0.6545 - val_cls_logits_loss1: 0.0886 - val_cls_regress_loss1: 0.2154 - val_cls_logits_loss2: 0.0578 - val_cls_regress_loss2: 0.1063 - val_cls_logits_loss3: 0.0234 - val_cls_regress_loss3: 0.0499
# Epoch 492/500
# 31/31 [==============================] - 16s 498ms/step - loss: 0.2727 - rpn_score_accuracy: 0.9801 - cls_logits_accuracy1: 0.9424 - cls_logits_accuracy2: 0.9555 - cls_logits_accuracy3: 0.9454 - rpn_score_loss: 0.0426 - rpn_regress_loss: 0.0216 - cls_logits_loss1: 0.0377 - cls_regress_loss1: 0.0860 - cls_logits_loss2: 0.0166 - cls_regress_loss2: 0.0398 - cls_logits_loss3: 0.0098 - cls_regress_loss3: 0.0187 - val_loss: 3.2758 - val_rpn_score_accuracy: 0.7038 - val_cls_logits_accuracy1: 0.8363 - val_cls_logits_accuracy2: 0.8411 - val_cls_logits_accuracy3: 0.7679 - val_rpn_score_loss: 2.0701 - val_rpn_regress_loss: 0.6670 - val_cls_logits_loss1: 0.0986 - val_cls_regress_loss1: 0.2088 - val_cls_logits_loss2: 0.0677 - val_cls_regress_loss2: 0.1109 - val_cls_logits_loss3: 0.0136 - val_cls_regress_loss3: 0.0391
# Epoch 493/500
# 31/31 [==============================] - 15s 496ms/step - loss: 0.3080 - rpn_score_accuracy: 0.9873 - cls_logits_accuracy1: 0.9363 - cls_logits_accuracy2: 0.9438 - cls_logits_accuracy3: 0.9299 - rpn_score_loss: 0.0487 - rpn_regress_loss: 0.0298 - cls_logits_loss1: 0.0388 - cls_regress_loss1: 0.0958 - cls_logits_loss2: 0.0193 - cls_regress_loss2: 0.0436 - cls_logits_loss3: 0.0124 - cls_regress_loss3: 0.0195 - val_loss: 2.9927 - val_rpn_score_accuracy: 0.7340 - val_cls_logits_accuracy1: 0.8757 - val_cls_logits_accuracy2: 0.8823 - val_cls_logits_accuracy3: 0.8796 - val_rpn_score_loss: 1.8299 - val_rpn_regress_loss: 0.6478 - val_cls_logits_loss1: 0.0734 - val_cls_regress_loss1: 0.2083 - val_cls_logits_loss2: 0.0537 - val_cls_regress_loss2: 0.1053 - val_cls_logits_loss3: 0.0246 - val_cls_regress_loss3: 0.0498
# Epoch 494/500
# 31/31 [==============================] - 15s 494ms/step - loss: 0.3319 - rpn_score_accuracy: 0.9844 - cls_logits_accuracy1: 0.9344 - cls_logits_accuracy2: 0.9411 - cls_logits_accuracy3: 0.9354 - rpn_score_loss: 0.0485 - rpn_regress_loss: 0.0324 - cls_logits_loss1: 0.0411 - cls_regress_loss1: 0.1049 - cls_logits_loss2: 0.0205 - cls_regress_loss2: 0.0492 - cls_logits_loss3: 0.0123 - cls_regress_loss3: 0.0230 - val_loss: 3.4409 - val_rpn_score_accuracy: 0.6579 - val_cls_logits_accuracy1: 0.8863 - val_cls_logits_accuracy2: 0.8839 - val_cls_logits_accuracy3: 0.8869 - val_rpn_score_loss: 2.2676 - val_rpn_regress_loss: 0.6572 - val_cls_logits_loss1: 0.0724 - val_cls_regress_loss1: 0.2146 - val_cls_logits_loss2: 0.0450 - val_cls_regress_loss2: 0.1091 - val_cls_logits_loss3: 0.0254 - val_cls_regress_loss3: 0.0497
# Epoch 495/500
# 31/31 [==============================] - 15s 496ms/step - loss: 0.3391 - rpn_score_accuracy: 0.9908 - cls_logits_accuracy1: 0.9209 - cls_logits_accuracy2: 0.9338 - cls_logits_accuracy3: 0.9338 - rpn_score_loss: 0.0264 - rpn_regress_loss: 0.0361 - cls_logits_loss1: 0.0555 - cls_regress_loss1: 0.1100 - cls_logits_loss2: 0.0225 - cls_regress_loss2: 0.0548 - cls_logits_loss3: 0.0106 - cls_regress_loss3: 0.0232 - val_loss: 3.3608 - val_rpn_score_accuracy: 0.6932 - val_cls_logits_accuracy1: 0.9090 - val_cls_logits_accuracy2: 0.8766 - val_cls_logits_accuracy3: 0.8651 - val_rpn_score_loss: 2.2027 - val_rpn_regress_loss: 0.6546 - val_cls_logits_loss1: 0.0620 - val_cls_regress_loss1: 0.2274 - val_cls_logits_loss2: 0.0418 - val_cls_regress_loss2: 0.1031 - val_cls_logits_loss3: 0.0226 - val_cls_regress_loss3: 0.0466
# Epoch 496/500
# 31/31 [==============================] - 15s 497ms/step - loss: 0.2788 - rpn_score_accuracy: 0.9962 - cls_logits_accuracy1: 0.9346 - cls_logits_accuracy2: 0.9495 - cls_logits_accuracy3: 0.9429 - rpn_score_loss: 0.0156 - rpn_regress_loss: 0.0237 - cls_logits_loss1: 0.0449 - cls_regress_loss1: 0.0964 - cls_logits_loss2: 0.0191 - cls_regress_loss2: 0.0457 - cls_logits_loss3: 0.0102 - cls_regress_loss3: 0.0232 - val_loss: 3.2079 - val_rpn_score_accuracy: 0.7101 - val_cls_logits_accuracy1: 0.8929 - val_cls_logits_accuracy2: 0.8869 - val_cls_logits_accuracy3: 0.9262 - val_rpn_score_loss: 2.0016 - val_rpn_regress_loss: 0.6461 - val_cls_logits_loss1: 0.0807 - val_cls_regress_loss1: 0.2475 - val_cls_logits_loss2: 0.0442 - val_cls_regress_loss2: 0.1224 - val_cls_logits_loss3: 0.0168 - val_cls_regress_loss3: 0.0487
# Epoch 497/500
# 31/31 [==============================] - 15s 496ms/step - loss: 0.2648 - rpn_score_accuracy: 0.9969 - cls_logits_accuracy1: 0.9323 - cls_logits_accuracy2: 0.9376 - cls_logits_accuracy3: 0.9381 - rpn_score_loss: 0.0093 - rpn_regress_loss: 0.0212 - cls_logits_loss1: 0.0438 - cls_regress_loss1: 0.0939 - cls_logits_loss2: 0.0205 - cls_regress_loss2: 0.0451 - cls_logits_loss3: 0.0111 - cls_regress_loss3: 0.0200 - val_loss: 3.2863 - val_rpn_score_accuracy: 0.7053 - val_cls_logits_accuracy1: 0.8844 - val_cls_logits_accuracy2: 0.8714 - val_cls_logits_accuracy3: 0.8661 - val_rpn_score_loss: 2.0543 - val_rpn_regress_loss: 0.6449 - val_cls_logits_loss1: 0.0768 - val_cls_regress_loss1: 0.2640 - val_cls_logits_loss2: 0.0465 - val_cls_regress_loss2: 0.1267 - val_cls_logits_loss3: 0.0192 - val_cls_regress_loss3: 0.0540
# Epoch 498/500
# 31/31 [==============================] - 15s 496ms/step - loss: 0.2830 - rpn_score_accuracy: 0.9951 - cls_logits_accuracy1: 0.9290 - cls_logits_accuracy2: 0.9460 - cls_logits_accuracy3: 0.9342 - rpn_score_loss: 0.0155 - rpn_regress_loss: 0.0253 - cls_logits_loss1: 0.0464 - cls_regress_loss1: 0.0986 - cls_logits_loss2: 0.0186 - cls_regress_loss2: 0.0467 - cls_logits_loss3: 0.0109 - cls_regress_loss3: 0.0210 - val_loss: 3.1077 - val_rpn_score_accuracy: 0.7222 - val_cls_logits_accuracy1: 0.8690 - val_cls_logits_accuracy2: 0.8854 - val_cls_logits_accuracy3: 0.8943 - val_rpn_score_loss: 1.9403 - val_rpn_regress_loss: 0.6432 - val_cls_logits_loss1: 0.0767 - val_cls_regress_loss1: 0.2305 - val_cls_logits_loss2: 0.0337 - val_cls_regress_loss2: 0.1146 - val_cls_logits_loss3: 0.0172 - val_cls_regress_loss3: 0.0517
# Epoch 499/500
# 31/31 [==============================] - 15s 494ms/step - loss: 0.2888 - rpn_score_accuracy: 0.9939 - cls_logits_accuracy1: 0.9438 - cls_logits_accuracy2: 0.9475 - cls_logits_accuracy3: 0.9356 - rpn_score_loss: 0.0254 - rpn_regress_loss: 0.0277 - cls_logits_loss1: 0.0409 - cls_regress_loss1: 0.0982 - cls_logits_loss2: 0.0189 - cls_regress_loss2: 0.0471 - cls_logits_loss3: 0.0098 - cls_regress_loss3: 0.0207 - val_loss: 3.1507 - val_rpn_score_accuracy: 0.7125 - val_cls_logits_accuracy1: 0.8255 - val_cls_logits_accuracy2: 0.8409 - val_cls_logits_accuracy3: 0.8710 - val_rpn_score_loss: 1.8950 - val_rpn_regress_loss: 0.6624 - val_cls_logits_loss1: 0.1038 - val_cls_regress_loss1: 0.2405 - val_cls_logits_loss2: 0.0533 - val_cls_regress_loss2: 0.1151 - val_cls_logits_loss3: 0.0244 - val_cls_regress_loss3: 0.0562
# Epoch 500/500
# 31/31 [==============================] - 15s 497ms/step - loss: 0.2910 - rpn_score_accuracy: 0.9945 - cls_logits_accuracy1: 0.9357 - cls_logits_accuracy2: 0.9379 - cls_logits_accuracy3: 0.9270 - rpn_score_loss: 0.0258 - rpn_regress_loss: 0.0308 - cls_logits_loss1: 0.0421 - cls_regress_loss1: 0.0966 - cls_logits_loss2: 0.0180 - cls_regress_loss2: 0.0451 - cls_logits_loss3: 0.0117 - cls_regress_loss3: 0.0208 - val_loss: 3.1996 - val_rpn_score_accuracy: 0.7027 - val_cls_logits_accuracy1: 0.8670 - val_cls_logits_accuracy2: 0.8289 - val_cls_logits_accuracy3: 0.8304 - val_rpn_score_loss: 1.9159 - val_rpn_regress_loss: 0.6646 - val_cls_logits_loss1: 0.1451 - val_cls_regress_loss1: 0.2242 - val_cls_logits_loss2: 0.0602 - val_cls_regress_loss2: 0.1044 - val_cls_logits_loss3: 0.0358 - val_cls_regress_loss3: 0.0494

# %%
model.save_weights("model.h5")

# %%
x = tf.keras.layers.Input(shape = (512, 512, 3))
feature = tfdet.model.backbone.resnet50(x)
#scale = [32, 64, 128, 256, 512]
scale = [24, 48, 96, 192, 384]
ratio = [0.5, 1, 2]
out = tfdet.model.detector.cascade_rcnn(feature, image_shape = tf.shape(x)[1:3], n_class = 2, mask = False, scale = scale, ratio = ratio, soft_nms = False, neck = neck, proposal_count = 1000)
prediction = tfdet.model.postprocess.rcnn.FilterDetection(proposal_count = 100, iou_threshold = 0.3, score_threshold = 0.7, ensemble = True, soft_nms = False)(out)
model = tf.keras.Model(x, prediction)
model.load_weights("model.h5")

# %%
images = te_x[:1]
logits, proposal = model.predict(images)
images = tfdet.util.draw_bbox(images, proposal, logits, label = ["Background", "Balloon"])

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (10, 10))
plt.imshow(images[0])
