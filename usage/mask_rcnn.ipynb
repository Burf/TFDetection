# %%
import os
# !git clone https://github.com/burf/tfdetection
os.chdir(os.path.join(os.getcwd(), "tfdetection"))
# !python setup.py bdist_wheel
# !pip install ./dist/tfdet-1.0.0-py3-none-any.whl
os.chdir(os.path.dirname(os.getcwd()))
# Out:
# Cloning into 'tfdetection'...
# remote: Enumerating objects: 172, done.
# remote: Counting objects: 100% (172/172), done.
# remote: Compressing objects: 100% (128/128), done.
# remote: Total 172 (delta 68), reused 126 (delta 40), pack-reused 0
# Receiving objects: 100% (172/172), 3.50 MiB | 13.32 MiB/s, done.
# Resolving deltas: 100% (68/68), done.
# running bdist_wheel
# running build
# running build_py
# creating build
# creating build/lib
# creating build/lib/tfdet
# copying tfdet/__init__.py -> build/lib/tfdet
# creating build/lib/tfdet/model
# copying tfdet/model/__init__.py -> build/lib/tfdet/model
# creating build/lib/tfdet/util
# copying tfdet/util/visualize.py -> build/lib/tfdet/util
# copying tfdet/util/metric.py -> build/lib/tfdet/util
# copying tfdet/util/__init__.py -> build/lib/tfdet/util
# creating build/lib/tfdet/core
# copying tfdet/core/__init__.py -> build/lib/tfdet/core
# creating build/lib/tfdet/model/train
# copying tfdet/model/train/yolo.py -> build/lib/tfdet/model/train
# copying tfdet/model/train/fcos.py -> build/lib/tfdet/model/train
# copying tfdet/model/train/rcnn.py -> build/lib/tfdet/model/train
# copying tfdet/model/train/retina.py -> build/lib/tfdet/model/train
# copying tfdet/model/train/__init__.py -> build/lib/tfdet/model/train
# creating build/lib/tfdet/model/backbone
# copying tfdet/model/backbone/densenet.py -> build/lib/tfdet/model/backbone
# copying tfdet/model/backbone/effnet.py -> build/lib/tfdet/model/backbone
# copying tfdet/model/backbone/mobilenet.py -> build/lib/tfdet/model/backbone
# copying tfdet/model/backbone/resnet.py -> build/lib/tfdet/model/backbone
# copying tfdet/model/backbone/swin_transformer.py -> build/lib/tfdet/model/backbone
# copying tfdet/model/backbone/darknet.py -> build/lib/tfdet/model/backbone
# copying tfdet/model/backbone/resnest.py -> build/lib/tfdet/model/backbone
# copying tfdet/model/backbone/resnet_torch.py -> build/lib/tfdet/model/backbone
# copying tfdet/model/backbone/vgg.py -> build/lib/tfdet/model/backbone
# copying tfdet/model/backbone/__init__.py -> build/lib/tfdet/model/backbone
# creating build/lib/tfdet/model/postprocess
# copying tfdet/model/postprocess/yolo.py -> build/lib/tfdet/model/postprocess
# copying tfdet/model/postprocess/rcnn.py -> build/lib/tfdet/model/postprocess
# copying tfdet/model/postprocess/retina.py -> build/lib/tfdet/model/postprocess
# copying tfdet/model/postprocess/__init__.py -> build/lib/tfdet/model/postprocess
# creating build/lib/tfdet/model/detector
# copying tfdet/model/detector/yolo.py -> build/lib/tfdet/model/detector
# copying tfdet/model/detector/effdet.py -> build/lib/tfdet/model/detector
# copying tfdet/model/detector/fcos.py -> build/lib/tfdet/model/detector
# copying tfdet/model/detector/rcnn.py -> build/lib/tfdet/model/detector
# copying tfdet/model/detector/retina.py -> build/lib/tfdet/model/detector
# copying tfdet/model/detector/__init__.py -> build/lib/tfdet/model/detector
# creating build/lib/tfdet/model/head
# copying tfdet/model/head/yolo.py -> build/lib/tfdet/model/head
# copying tfdet/model/head/fcos.py -> build/lib/tfdet/model/head
# copying tfdet/model/head/rcnn.py -> build/lib/tfdet/model/head
# copying tfdet/model/head/retina.py -> build/lib/tfdet/model/head
# copying tfdet/model/head/__init__.py -> build/lib/tfdet/model/head
# creating build/lib/tfdet/model/loss
# copying tfdet/model/loss/common.py -> build/lib/tfdet/model/loss
# copying tfdet/model/loss/yolo.py -> build/lib/tfdet/model/loss
# copying tfdet/model/loss/fcos.py -> build/lib/tfdet/model/loss
# copying tfdet/model/loss/rcnn.py -> build/lib/tfdet/model/loss
# copying tfdet/model/loss/retina.py -> build/lib/tfdet/model/loss
# copying tfdet/model/loss/__init__.py -> build/lib/tfdet/model/loss
# creating build/lib/tfdet/model/neck
# copying tfdet/model/neck/fpn.py -> build/lib/tfdet/model/neck
# copying tfdet/model/neck/__init__.py -> build/lib/tfdet/model/neck
# creating build/lib/tfdet/core/util
# copying tfdet/core/util/tf.py -> build/lib/tfdet/core/util
# copying tfdet/core/util/loss.py -> build/lib/tfdet/core/util
# copying tfdet/core/util/bbox.py -> build/lib/tfdet/core/util
# copying tfdet/core/util/__init__.py -> build/lib/tfdet/core/util
# copying tfdet/core/util/nms.py -> build/lib/tfdet/core/util
# copying tfdet/core/util/overlap.py -> build/lib/tfdet/core/util
# copying tfdet/core/util/anchor.py -> build/lib/tfdet/core/util
# creating build/lib/tfdet/core/target
# copying tfdet/core/target/rcnn_target.py -> build/lib/tfdet/core/target
# copying tfdet/core/target/anchor_target.py -> build/lib/tfdet/core/target
# copying tfdet/core/target/point_target.py -> build/lib/tfdet/core/target
# copying tfdet/core/target/__init__.py -> build/lib/tfdet/core/target
# copying tfdet/core/target/yolo_target.py -> build/lib/tfdet/core/target
# installing to build/bdist.linux-x86_64/wheel
# running install
# running install_lib
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/wheel
# creating build/bdist.linux-x86_64/wheel/tfdet
# creating build/bdist.linux-x86_64/wheel/tfdet/model
# creating build/bdist.linux-x86_64/wheel/tfdet/model/train
# copying build/lib/tfdet/model/train/yolo.py -> build/bdist.linux-x86_64/wheel/tfdet/model/train
# copying build/lib/tfdet/model/train/fcos.py -> build/bdist.linux-x86_64/wheel/tfdet/model/train
# copying build/lib/tfdet/model/train/rcnn.py -> build/bdist.linux-x86_64/wheel/tfdet/model/train
# copying build/lib/tfdet/model/train/retina.py -> build/bdist.linux-x86_64/wheel/tfdet/model/train
# copying build/lib/tfdet/model/train/__init__.py -> build/bdist.linux-x86_64/wheel/tfdet/model/train
# creating build/bdist.linux-x86_64/wheel/tfdet/model/backbone
# copying build/lib/tfdet/model/backbone/densenet.py -> build/bdist.linux-x86_64/wheel/tfdet/model/backbone
# copying build/lib/tfdet/model/backbone/effnet.py -> build/bdist.linux-x86_64/wheel/tfdet/model/backbone
# copying build/lib/tfdet/model/backbone/mobilenet.py -> build/bdist.linux-x86_64/wheel/tfdet/model/backbone
# copying build/lib/tfdet/model/backbone/resnet.py -> build/bdist.linux-x86_64/wheel/tfdet/model/backbone
# copying build/lib/tfdet/model/backbone/swin_transformer.py -> build/bdist.linux-x86_64/wheel/tfdet/model/backbone
# copying build/lib/tfdet/model/backbone/darknet.py -> build/bdist.linux-x86_64/wheel/tfdet/model/backbone
# copying build/lib/tfdet/model/backbone/resnest.py -> build/bdist.linux-x86_64/wheel/tfdet/model/backbone
# copying build/lib/tfdet/model/backbone/resnet_torch.py -> build/bdist.linux-x86_64/wheel/tfdet/model/backbone
# copying build/lib/tfdet/model/backbone/vgg.py -> build/bdist.linux-x86_64/wheel/tfdet/model/backbone
# copying build/lib/tfdet/model/backbone/__init__.py -> build/bdist.linux-x86_64/wheel/tfdet/model/backbone
# creating build/bdist.linux-x86_64/wheel/tfdet/model/postprocess
# copying build/lib/tfdet/model/postprocess/yolo.py -> build/bdist.linux-x86_64/wheel/tfdet/model/postprocess
# copying build/lib/tfdet/model/postprocess/rcnn.py -> build/bdist.linux-x86_64/wheel/tfdet/model/postprocess
# copying build/lib/tfdet/model/postprocess/retina.py -> build/bdist.linux-x86_64/wheel/tfdet/model/postprocess
# copying build/lib/tfdet/model/postprocess/__init__.py -> build/bdist.linux-x86_64/wheel/tfdet/model/postprocess
# creating build/bdist.linux-x86_64/wheel/tfdet/model/detector
# copying build/lib/tfdet/model/detector/yolo.py -> build/bdist.linux-x86_64/wheel/tfdet/model/detector
# copying build/lib/tfdet/model/detector/effdet.py -> build/bdist.linux-x86_64/wheel/tfdet/model/detector
# copying build/lib/tfdet/model/detector/fcos.py -> build/bdist.linux-x86_64/wheel/tfdet/model/detector
# copying build/lib/tfdet/model/detector/rcnn.py -> build/bdist.linux-x86_64/wheel/tfdet/model/detector
# copying build/lib/tfdet/model/detector/retina.py -> build/bdist.linux-x86_64/wheel/tfdet/model/detector
# copying build/lib/tfdet/model/detector/__init__.py -> build/bdist.linux-x86_64/wheel/tfdet/model/detector
# creating build/bdist.linux-x86_64/wheel/tfdet/model/head
# copying build/lib/tfdet/model/head/yolo.py -> build/bdist.linux-x86_64/wheel/tfdet/model/head
# copying build/lib/tfdet/model/head/fcos.py -> build/bdist.linux-x86_64/wheel/tfdet/model/head
# copying build/lib/tfdet/model/head/rcnn.py -> build/bdist.linux-x86_64/wheel/tfdet/model/head
# copying build/lib/tfdet/model/head/retina.py -> build/bdist.linux-x86_64/wheel/tfdet/model/head
# copying build/lib/tfdet/model/head/__init__.py -> build/bdist.linux-x86_64/wheel/tfdet/model/head
# creating build/bdist.linux-x86_64/wheel/tfdet/model/loss
# copying build/lib/tfdet/model/loss/common.py -> build/bdist.linux-x86_64/wheel/tfdet/model/loss
# copying build/lib/tfdet/model/loss/yolo.py -> build/bdist.linux-x86_64/wheel/tfdet/model/loss
# copying build/lib/tfdet/model/loss/fcos.py -> build/bdist.linux-x86_64/wheel/tfdet/model/loss
# copying build/lib/tfdet/model/loss/rcnn.py -> build/bdist.linux-x86_64/wheel/tfdet/model/loss
# copying build/lib/tfdet/model/loss/retina.py -> build/bdist.linux-x86_64/wheel/tfdet/model/loss
# copying build/lib/tfdet/model/loss/__init__.py -> build/bdist.linux-x86_64/wheel/tfdet/model/loss
# copying build/lib/tfdet/model/__init__.py -> build/bdist.linux-x86_64/wheel/tfdet/model
# creating build/bdist.linux-x86_64/wheel/tfdet/model/neck
# copying build/lib/tfdet/model/neck/fpn.py -> build/bdist.linux-x86_64/wheel/tfdet/model/neck
# copying build/lib/tfdet/model/neck/__init__.py -> build/bdist.linux-x86_64/wheel/tfdet/model/neck
# creating build/bdist.linux-x86_64/wheel/tfdet/util
# copying build/lib/tfdet/util/visualize.py -> build/bdist.linux-x86_64/wheel/tfdet/util
# copying build/lib/tfdet/util/metric.py -> build/bdist.linux-x86_64/wheel/tfdet/util
# copying build/lib/tfdet/util/__init__.py -> build/bdist.linux-x86_64/wheel/tfdet/util
# creating build/bdist.linux-x86_64/wheel/tfdet/core
# creating build/bdist.linux-x86_64/wheel/tfdet/core/util
# copying build/lib/tfdet/core/util/tf.py -> build/bdist.linux-x86_64/wheel/tfdet/core/util
# copying build/lib/tfdet/core/util/loss.py -> build/bdist.linux-x86_64/wheel/tfdet/core/util
# copying build/lib/tfdet/core/util/bbox.py -> build/bdist.linux-x86_64/wheel/tfdet/core/util
# copying build/lib/tfdet/core/util/__init__.py -> build/bdist.linux-x86_64/wheel/tfdet/core/util
# copying build/lib/tfdet/core/util/nms.py -> build/bdist.linux-x86_64/wheel/tfdet/core/util
# copying build/lib/tfdet/core/util/overlap.py -> build/bdist.linux-x86_64/wheel/tfdet/core/util
# copying build/lib/tfdet/core/util/anchor.py -> build/bdist.linux-x86_64/wheel/tfdet/core/util
# creating build/bdist.linux-x86_64/wheel/tfdet/core/target
# copying build/lib/tfdet/core/target/rcnn_target.py -> build/bdist.linux-x86_64/wheel/tfdet/core/target
# copying build/lib/tfdet/core/target/anchor_target.py -> build/bdist.linux-x86_64/wheel/tfdet/core/target
# copying build/lib/tfdet/core/target/point_target.py -> build/bdist.linux-x86_64/wheel/tfdet/core/target
# copying build/lib/tfdet/core/target/__init__.py -> build/bdist.linux-x86_64/wheel/tfdet/core/target
# copying build/lib/tfdet/core/target/yolo_target.py -> build/bdist.linux-x86_64/wheel/tfdet/core/target
# copying build/lib/tfdet/core/__init__.py -> build/bdist.linux-x86_64/wheel/tfdet/core
# copying build/lib/tfdet/__init__.py -> build/bdist.linux-x86_64/wheel/tfdet
# running install_egg_info
# running egg_info
# creating tfdet.egg-info
# writing tfdet.egg-info/PKG-INFO
# writing dependency_links to tfdet.egg-info/dependency_links.txt
# writing requirements to tfdet.egg-info/requires.txt
# writing top-level names to tfdet.egg-info/top_level.txt
# writing manifest file 'tfdet.egg-info/SOURCES.txt'
# adding license file 'LICENSE'
# writing manifest file 'tfdet.egg-info/SOURCES.txt'
# Copying tfdet.egg-info to build/bdist.linux-x86_64/wheel/tfdet-1.0.0-py3.7.egg-info
# running install_scripts
# adding license file "LICENSE" (matched pattern "LICEN[CS]E*")
# creating build/bdist.linux-x86_64/wheel/tfdet-1.0.0.dist-info/WHEEL
# creating 'dist/tfdet-1.0.0-py3-none-any.whl' and adding 'build/bdist.linux-x86_64/wheel' to it
# adding 'tfdet/__init__.py'
# adding 'tfdet/core/__init__.py'
# adding 'tfdet/core/target/__init__.py'
# adding 'tfdet/core/target/anchor_target.py'
# adding 'tfdet/core/target/point_target.py'
# adding 'tfdet/core/target/rcnn_target.py'
# adding 'tfdet/core/target/yolo_target.py'
# adding 'tfdet/core/util/__init__.py'
# adding 'tfdet/core/util/anchor.py'
# adding 'tfdet/core/util/bbox.py'
# adding 'tfdet/core/util/loss.py'
# adding 'tfdet/core/util/nms.py'
# adding 'tfdet/core/util/overlap.py'
# adding 'tfdet/core/util/tf.py'
# adding 'tfdet/model/__init__.py'
# adding 'tfdet/model/backbone/__init__.py'
# adding 'tfdet/model/backbone/darknet.py'
# adding 'tfdet/model/backbone/densenet.py'
# adding 'tfdet/model/backbone/effnet.py'
# adding 'tfdet/model/backbone/mobilenet.py'
# adding 'tfdet/model/backbone/resnest.py'
# adding 'tfdet/model/backbone/resnet.py'
# adding 'tfdet/model/backbone/resnet_torch.py'
# adding 'tfdet/model/backbone/swin_transformer.py'
# adding 'tfdet/model/backbone/vgg.py'
# adding 'tfdet/model/detector/__init__.py'
# adding 'tfdet/model/detector/effdet.py'
# adding 'tfdet/model/detector/fcos.py'
# adding 'tfdet/model/detector/rcnn.py'
# adding 'tfdet/model/detector/retina.py'
# adding 'tfdet/model/detector/yolo.py'
# adding 'tfdet/model/head/__init__.py'
# adding 'tfdet/model/head/fcos.py'
# adding 'tfdet/model/head/rcnn.py'
# adding 'tfdet/model/head/retina.py'
# adding 'tfdet/model/head/yolo.py'
# adding 'tfdet/model/loss/__init__.py'
# adding 'tfdet/model/loss/common.py'
# adding 'tfdet/model/loss/fcos.py'
# adding 'tfdet/model/loss/rcnn.py'
# adding 'tfdet/model/loss/retina.py'
# adding 'tfdet/model/loss/yolo.py'
# adding 'tfdet/model/neck/__init__.py'
# adding 'tfdet/model/neck/fpn.py'
# adding 'tfdet/model/postprocess/__init__.py'
# adding 'tfdet/model/postprocess/rcnn.py'
# adding 'tfdet/model/postprocess/retina.py'
# adding 'tfdet/model/postprocess/yolo.py'
# adding 'tfdet/model/train/__init__.py'
# adding 'tfdet/model/train/fcos.py'
# adding 'tfdet/model/train/rcnn.py'
# adding 'tfdet/model/train/retina.py'
# adding 'tfdet/model/train/yolo.py'
# adding 'tfdet/util/__init__.py'
# adding 'tfdet/util/metric.py'
# adding 'tfdet/util/visualize.py'
# adding 'tfdet-1.0.0.dist-info/LICENSE'
# adding 'tfdet-1.0.0.dist-info/METADATA'
# adding 'tfdet-1.0.0.dist-info/WHEEL'
# adding 'tfdet-1.0.0.dist-info/top_level.txt'
# adding 'tfdet-1.0.0.dist-info/RECORD'
# removing build/bdist.linux-x86_64/wheel
# Processing ./dist/tfdet-1.0.0-py3-none-any.whl
# Requirement already satisfied: keras in /usr/local/lib/python3.7/dist-packages (from tfdet==1.0.0) (2.8.0)
# Requirement already satisfied: tensorflow>=2.4 in /usr/local/lib/python3.7/dist-packages (from tfdet==1.0.0) (2.8.0)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.4->tfdet==1.0.0) (2.0)
# Collecting tf-estimator-nightly==2.8.0.dev2021122109
#   Downloading tf_estimator_nightly-2.8.0.dev2021122109-py2.py3-none-any.whl (462 kB)
#      |████████████████████████████████| 462 kB 4.2 MB/s
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.4->tfdet==1.0.0) (3.17.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.4->tfdet==1.0.0) (3.3.0)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.4->tfdet==1.0.0) (1.0.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.4->tfdet==1.0.0) (1.15.0)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.4->tfdet==1.0.0) (1.21.5)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.4->tfdet==1.0.0) (3.1.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.4->tfdet==1.0.0) (1.1.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.4->tfdet==1.0.0) (1.14.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.4->tfdet==1.0.0) (1.1.2)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.4->tfdet==1.0.0) (1.6.3)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.4->tfdet==1.0.0) (13.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.4->tfdet==1.0.0) (57.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.4->tfdet==1.0.0) (3.10.0.2)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.4->tfdet==1.0.0) (0.5.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.4->tfdet==1.0.0) (0.24.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.4->tfdet==1.0.0) (1.44.0)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.4->tfdet==1.0.0) (2.8.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.4->tfdet==1.0.0) (0.2.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow>=2.4->tfdet==1.0.0) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow>=2.4->tfdet==1.0.0) (1.5.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.4->tfdet==1.0.0) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.4->tfdet==1.0.0) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.4->tfdet==1.0.0) (0.6.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.4->tfdet==1.0.0) (1.0.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.4->tfdet==1.0.0) (2.23.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.4->tfdet==1.0.0) (3.3.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.4->tfdet==1.0.0) (1.35.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.4->tfdet==1.0.0) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.4->tfdet==1.0.0) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.4->tfdet==1.0.0) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow>=2.4->tfdet==1.0.0) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow>=2.4->tfdet==1.0.0) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow>=2.4->tfdet==1.0.0) (3.7.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.4->tfdet==1.0.0) (0.4.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow>=2.4->tfdet==1.0.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow>=2.4->tfdet==1.0.0) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow>=2.4->tfdet==1.0.0) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow>=2.4->tfdet==1.0.0) (2021.10.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow>=2.4->tfdet==1.0.0) (3.2.0)
# Installing collected packages: tf-estimator-nightly, tfdet
# Successfully installed tf-estimator-nightly-2.8.0.dev2021122109 tfdet-1.0.0

# %%
# !wget -qq https://github.com/matterport/Mask_RCNN/releases/download/v2.1/balloon_dataset.zip
# !unzip -qq balloon_dataset.zip

import os
import json
import cv2
import skimage.draw
import tensorflow as tf
import numpy as np

def parse(path, target_size = (512, 512), method = cv2.INTER_CUBIC):
    dir_path = os.path.dirname(path)
    with open(path, "r") as file:
        anno = json.loads(file.read())
    anno = [a for a in list(anno.values()) if a["regions"]]

    images = []
    masks = []
    for a in anno:
        if type(a['regions']) is dict:
            polygons = [r['shape_attributes'] for r in a['regions'].values()]
        else:
            polygons = [r['shape_attributes'] for r in a['regions']]
        image = cv2.cvtColor(cv2.imread(os.path.join(dir_path, a["filename"]), -1), cv2.COLOR_BGR2RGB)
        h, w = np.shape(image)[:2]
        mask = np.zeros((h, w, len(polygons)), dtype = np.uint8)
        for i, p in enumerate(polygons):
            rr, cc = skimage.draw.polygon(p['all_points_y'], p['all_points_x'])
            rr = np.clip(rr, 0, h - 1)
            cc = np.clip(cc, 0, w - 1)
            mask[rr, cc, i] = 1
        
        if target_size is not None:
            image = cv2.resize(image, target_size[::-1], interpolation = method)
            mask = cv2.resize(mask, target_size[::-1], interpolation = method)
            if np.ndim(mask) == 2:
                mask = np.expand_dims(mask, axis = -1)
            mask = np.where(mask != 0, 1, 0)

        images.append(image)
        masks.append(np.transpose(mask, [2, 0, 1]))
    return images, masks

def mask2bbox(mask_true, normalize = True, decimal = 4):
    #mask_true = #(padded_num_true, h, w, 1)
    padded_num_true, h, w = np.shape(mask_true)[:3]

    bbox_true = []
    for index in range(padded_num_true):
        mask = mask_true[index]
        if 0 < np.max(mask):
            pos = np.where(0 < mask)[:2]
            bbox = [np.min(pos[1]), np.min(pos[0]), np.max(pos[1]), np.max(pos[0])] #x1, y1, x2, y2
        else:
            bbox = [0, 0, 0, 0]
        bbox_true.append(bbox)
    
    bbox_true = np.round(np.divide(bbox_true, [w, h, w, h]).astype(np.float32), decimal) if normalize else np.array(bbox_true, dtype = np.int32)
    return bbox_true

def pipe(data, func = None, batch_size = 2, shuffle = False):
    dataset = tf.data.Dataset.from_tensor_slices(data)
    if callable(func):
        dataset = dataset.map(func, num_parallel_calls = tf.data.experimental.AUTOTUNE)
    if shuffle:
        dataset = dataset.shuffle(buffer_size = batch_size * 10)
    dataset = dataset.batch(batch_size)
    #dataset = dataset.prefetch((batch_size * 2) + 1)
    dataset = dataset.prefetch(tf.data.experimental.AUTOTUNE)
    return dataset

tr_anno = "./balloon/train/via_region_data.json"
te_anno = "./balloon/val/via_region_data.json"

tr_x, tr_mask = parse(tr_anno, target_size = (512, 512))
te_x, te_mask = parse(te_anno, target_size = (512, 512))

max_cnt = 0
for mask in tr_mask + te_mask:
    if max_cnt < len(mask):
        max_cnt = len(mask)

tr_x = np.array(tr_x, dtype = np.float32) * 1/255
tr_mask = [np.pad(mask, [[0, max_cnt - len(mask)], [0, 0], [0, 0]]) for mask in tr_mask]
tr_mask = np.expand_dims(np.array(tr_mask, dtype = np.float32), axis = -1)
tr_bbox = np.array([mask2bbox(mask) for mask in tr_mask], dtype = np.float32)
tr_y = np.expand_dims(np.where(0 < np.max(tr_bbox, axis = -1), 1., 0.), axis = -1)

te_x = np.array(te_x, dtype = np.float32) * 1/255
te_mask = [np.pad(mask, [[0, max_cnt - len(mask)], [0, 0], [0, 0]]) for mask in te_mask]
te_mask = np.expand_dims(np.array(te_mask, dtype = np.float32), axis = -1)
te_bbox = np.array([mask2bbox(mask) for mask in te_mask], dtype = np.float32)
te_y = np.expand_dims(np.where(0 < np.max(te_bbox, axis = -1), 1., 0.), axis = -1)

# %%
import tfdet
import functools

x = tf.keras.layers.Input(shape = (512, 512, 3))
feature = tfdet.model.backbone.resnet50(x)

scale = [0.03125, 0.0625, 0.125, 0.25, 0.5] #[16, 32, 64, 128, 256]
ratio = [0.5, 1, 2]
bifpn = functools.partial(tfdet.model.neck.bifpn, weighted_add = False)
neck = functools.partial(tfdet.model.neck.FeatureAlign, pre_sampling = False, neck = bifpn)
rpn_assign = functools.partial(tfdet.core.assign.max_iou, positive_threshold = 0.7, negative_threshold = 0.3, min_threshold = 0.3, match_low_quality = True, mode = "normal")
cls_assign = functools.partial(tfdet.core.assign.max_iou, positive_threshold = 0.5, negative_threshold = 0.5, min_threshold = 0.5, match_low_quality = False, mode = "normal")

#sampling_positive_ratio = cls_positive_ratio, sampling_positive_threshold = cls_positive_threshold, sampling_negative_threshold = cls_negative_threshold
out = tfdet.model.detector.mask_rcnn(feature, n_class = 2, image_shape = tf.shape(x)[1:3], mask = True, cascade = False, scale = scale, ratio = ratio, soft_nms = False, neck = neck,
                                       proposal_count = 2000, sampling_assign = cls_assign, sampling_count = 256, sampling_positive_ratio = 0.25)

#out > rpn_score, rpn_regress, cls_logits, cls_regress, proposals, anchors, mask_regress(is removed by mask{=False}), semantic_regress(is removed by semantic_feature{=False}), sampling_tag(is removed by sampling_count{=None or 0})
model = tfdet.model.train.rcnn.train_model(x, *out, rpn_assign = rpn_assign, rpn_positive_ratio = 0.5)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 1s 0us/step
# 94781440/94765736 [==============================] - 1s 0us/step
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/deprecation.py:616: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead

# %%
import albumentations
method = [albumentations.RandomBrightness(0.2, p = 0.5),
          albumentations.RandomContrast(0.2, p = 0.5),
          albumentations.ChannelShuffle(p = 0.5)]
method = albumentations.Compose(method)
    
def aug_func(image):
    return method(image = image)["image"]

key = x.name
def func(dic):
    shape = tf.shape(dic[key])
    dic[key] = tf.reshape(tf.py_function(lambda *args: aug_func(args[0].numpy()), inp = [dic[key]], Tout = tf.float32), shape)
    return dic

batch_size = 2

tr_data = pipe({x.name:tr_x, "y_true":tr_y, "bbox_true":tr_bbox, "mask_true":tr_mask}, func = func, batch_size = batch_size, shuffle = True)
te_data = pipe({x.name:te_x, "y_true":te_y, "bbox_true":te_bbox, "mask_true":te_mask}, batch_size = batch_size, shuffle = False)

# %%
opt = tf.keras.optimizers.SGD(5e-3, momentum = 0.9, nesterov = True)
model.compile(optimizer = opt)
model.fit(tr_data, validation_data = te_data, epochs = 200)
# Out:
# Epoch 1/200
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model_1/cls_target/map/while/gradients/model_1/cls_target/map/while/GatherNd_2_grad/Squeeze:0", shape=(None,), dtype=int64), values=Tensor("gradient_tape/model_1/cls_target/map/while/gradients/model_1/cls_target/map/while/Pad_grad/Slice_1:0", shape=(None, 2), dtype=float32), dense_shape=Tensor("model_1/cls_target/map/while/gradient_tape/model_1/cls_target/map/while/gradients/model_1/cls_target/map/while/GatherNd_2_grad/Shape:0", shape=(2,), dtype=int64))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model_1/cls_target/map/while/gradients/model_1/cls_target/map/while/GatherNd_3_grad/Squeeze:0", shape=(None,), dtype=int64), values=Tensor("gradient_tape/model_1/cls_target/map/while/gradients/model_1/cls_target/map/while/GatherNd_7_grad/ScatterNd:0", shape=(None, 2, 4), dtype=float32), dense_shape=Tensor("model_1/cls_target/map/while/gradient_tape/model_1/cls_target/map/while/gradients/model_1/cls_target/map/while/GatherNd_3_grad/Shape:0", shape=(3,), dtype=int64))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model_1/cls_target/map/while/gradients/model_1/cls_target/map/while/GatherNd_6_grad/Squeeze:0", shape=(None,), dtype=int64), values=Tensor("gradient_tape/model_1/cls_target/map/while/gradients/model_1/cls_target/map/while/transpose_grad/transpose:0", shape=(None, 14, 14, 2), dtype=float32), dense_shape=Tensor("model_1/cls_target/map/while/gradient_tape/model_1/cls_target/map/while/gradients/model_1/cls_target/map/while/GatherNd_6_grad/Shape:0", shape=(4,), dtype=int64))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model_1/roi_align/sub:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model_1/roi_align/GatherV2_2:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("gradient_tape/model_1/roi_align/Shape_2:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model_1/roi_align/sub_1:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model_1/roi_align/GatherV2_5:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("gradient_tape/model_1/roi_align/Shape_3:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model_1/roi_align/sub_2:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model_1/roi_align/GatherV2_8:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("gradient_tape/model_1/roi_align/Shape_4:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model_1/roi_align/sub_3:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model_1/roi_align/GatherV2_11:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("gradient_tape/model_1/roi_align/Shape_5:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# 31/31 [==============================] - 34s 668ms/step - loss: 10.2373 - rpn_score_accuracy: 0.4629 - cls_logits_accuracy: 0.6156 - rpn_score_loss: 0.4029 - rpn_regress_loss: 0.4381 - cls_logits_loss: 3.3383 - cls_regress_loss: 5.5147 - cls_mask_loss: 0.5433 - val_loss: 606630106365952.0000 - val_rpn_score_accuracy: 0.5607 - val_cls_logits_accuracy: 0.0000e+00 - val_rpn_score_loss: 2.3444 - val_rpn_regress_loss: 606630106365952.0000 - val_cls_logits_loss: 0.0000e+00 - val_cls_regress_loss: 0.0000e+00 - val_cls_mask_loss: 0.0000e+00
# Epoch 2/200
# 31/31 [==============================] - 17s 551ms/step - loss: 15.8874 - rpn_score_accuracy: 0.5093 - cls_logits_accuracy: 0.6290 - rpn_score_loss: 0.3980 - rpn_regress_loss: 0.9496 - cls_logits_loss: 3.3796 - cls_regress_loss: 10.6028 - cls_mask_loss: 0.5573 - val_loss: 69053.5547 - val_rpn_score_accuracy: 0.5464 - val_cls_logits_accuracy: 0.0000e+00 - val_rpn_score_loss: 2.5879 - val_rpn_regress_loss: 69050.9688 - val_cls_logits_loss: 0.0000e+00 - val_cls_regress_loss: 0.0000e+00 - val_cls_mask_loss: 0.0000e+00
# Epoch 3/200
# 31/31 [==============================] - 17s 550ms/step - loss: 10.9777 - rpn_score_accuracy: 0.6503 - cls_logits_accuracy: 0.5081 - rpn_score_loss: 0.3850 - rpn_regress_loss: 0.7930 - cls_logits_loss: 2.7297 - cls_regress_loss: 6.6643 - cls_mask_loss: 0.4057 - val_loss: 10582.5732 - val_rpn_score_accuracy: 0.5286 - val_cls_logits_accuracy: 0.0000e+00 - val_rpn_score_loss: 2.8458 - val_rpn_regress_loss: 10579.7275 - val_cls_logits_loss: 0.0000e+00 - val_cls_regress_loss: 0.0000e+00 - val_cls_mask_loss: 0.0000e+00
# Epoch 4/200
# 31/31 [==============================] - 17s 557ms/step - loss: 7.4898 - rpn_score_accuracy: 0.6270 - cls_logits_accuracy: 0.7500 - rpn_score_loss: 0.1816 - rpn_regress_loss: 0.4624 - cls_logits_loss: 4.0171 - cls_regress_loss: 2.2468 - cls_mask_loss: 0.5818 - val_loss: 199.3273 - val_rpn_score_accuracy: 0.5929 - val_cls_logits_accuracy: 0.0000e+00 - val_rpn_score_loss: 1.8643 - val_rpn_regress_loss: 197.4630 - val_cls_logits_loss: 0.0000e+00 - val_cls_regress_loss: 0.0000e+00 - val_cls_mask_loss: 0.0000e+00
# Epoch 5/200
# 31/31 [==============================] - 18s 562ms/step - loss: 6.7582 - rpn_score_accuracy: 0.6524 - cls_logits_accuracy: 0.7500 - rpn_score_loss: 0.1875 - rpn_regress_loss: 0.3467 - cls_logits_loss: 4.0295 - cls_regress_loss: 1.6057 - cls_mask_loss: 0.5888 - val_loss: 6.1507 - val_rpn_score_accuracy: 0.4429 - val_cls_logits_accuracy: 0.1071 - val_rpn_score_loss: 2.5282 - val_rpn_regress_loss: 2.7921 - val_cls_logits_loss: 0.5756 - val_cls_regress_loss: 0.1102 - val_cls_mask_loss: 0.1446
# Epoch 6/200
# 31/31 [==============================] - 18s 565ms/step - loss: 5.9288 - rpn_score_accuracy: 0.6309 - cls_logits_accuracy: 0.7258 - rpn_score_loss: 0.1470 - rpn_regress_loss: 0.3385 - cls_logits_loss: 3.8995 - cls_regress_loss: 0.9872 - cls_mask_loss: 0.5566 - val_loss: 2.1437 - val_rpn_score_accuracy: 0.6643 - val_cls_logits_accuracy: 0.1071 - val_rpn_score_loss: 0.5651 - val_rpn_regress_loss: 0.6384 - val_cls_logits_loss: 0.5756 - val_cls_regress_loss: 0.2885 - val_cls_mask_loss: 0.0761
# Epoch 7/200
# 31/31 [==============================] - 18s 562ms/step - loss: 6.7740 - rpn_score_accuracy: 0.6497 - cls_logits_accuracy: 0.7258 - rpn_score_loss: 0.1092 - rpn_regress_loss: 0.2221 - cls_logits_loss: 3.8417 - cls_regress_loss: 2.0530 - cls_mask_loss: 0.5480 - val_loss: 4.2128 - val_rpn_score_accuracy: 0.6429 - val_cls_logits_accuracy: 0.3214 - val_rpn_score_loss: 0.6209 - val_rpn_regress_loss: 0.9706 - val_cls_logits_loss: 1.7269 - val_cls_regress_loss: 0.6548 - val_cls_mask_loss: 0.2395
# Epoch 8/200
# 31/31 [==============================] - 18s 565ms/step - loss: 5.5498 - rpn_score_accuracy: 0.6971 - cls_logits_accuracy: 0.6461 - rpn_score_loss: 0.1586 - rpn_regress_loss: 1.7823 - cls_logits_loss: 1.8773 - cls_regress_loss: 1.1772 - cls_mask_loss: 0.5544 - val_loss: 4.8062 - val_rpn_score_accuracy: 0.6000 - val_cls_logits_accuracy: 0.6429 - val_rpn_score_loss: 0.5207 - val_rpn_regress_loss: 0.3565 - val_cls_logits_loss: 2.7418 - val_cls_regress_loss: 0.6745 - val_cls_mask_loss: 0.5128
# Epoch 9/200
# 31/31 [==============================] - 18s 568ms/step - loss: 4.4301 - rpn_score_accuracy: 0.7039 - cls_logits_accuracy: 0.6202 - rpn_score_loss: 0.1652 - rpn_regress_loss: 0.6657 - cls_logits_loss: 1.9906 - cls_regress_loss: 1.0667 - cls_mask_loss: 0.5419 - val_loss: 2.6528 - val_rpn_score_accuracy: 0.5321 - val_cls_logits_accuracy: 0.2500 - val_rpn_score_loss: 0.5123 - val_rpn_regress_loss: 0.3143 - val_cls_logits_loss: 0.4463 - val_cls_regress_loss: 0.7901 - val_cls_mask_loss: 0.5898
# Epoch 10/200
# 31/31 [==============================] - 18s 570ms/step - loss: 3.2629 - rpn_score_accuracy: 0.7048 - cls_logits_accuracy: 0.6544 - rpn_score_loss: 0.2043 - rpn_regress_loss: 0.4034 - cls_logits_loss: 1.2172 - cls_regress_loss: 0.8978 - cls_mask_loss: 0.5402 - val_loss: 2.1649 - val_rpn_score_accuracy: 0.5857 - val_cls_logits_accuracy: 0.4797 - val_rpn_score_loss: 0.5193 - val_rpn_regress_loss: 0.3892 - val_cls_logits_loss: 0.1499 - val_cls_regress_loss: 0.6134 - val_cls_mask_loss: 0.4931
# Epoch 11/200
# 31/31 [==============================] - 18s 569ms/step - loss: 4.9749 - rpn_score_accuracy: 0.5964 - cls_logits_accuracy: 0.5945 - rpn_score_loss: 0.1259 - rpn_regress_loss: 2.2255 - cls_logits_loss: 0.9523 - cls_regress_loss: 1.1363 - cls_mask_loss: 0.5349 - val_loss: 6.8920 - val_rpn_score_accuracy: 0.6179 - val_cls_logits_accuracy: 0.7500 - val_rpn_score_loss: 0.6903 - val_rpn_regress_loss: 3.6678 - val_cls_logits_loss: 0.9260 - val_cls_regress_loss: 1.0366 - val_cls_mask_loss: 0.5713
# Epoch 12/200
# 31/31 [==============================] - 18s 567ms/step - loss: 4.8799 - rpn_score_accuracy: 0.6525 - cls_logits_accuracy: 0.5677 - rpn_score_loss: 0.1465 - rpn_regress_loss: 1.8734 - cls_logits_loss: 1.2934 - cls_regress_loss: 1.0491 - cls_mask_loss: 0.5175 - val_loss: 20.3561 - val_rpn_score_accuracy: 0.6143 - val_cls_logits_accuracy: 0.5357 - val_rpn_score_loss: 0.8346 - val_rpn_regress_loss: 17.4610 - val_cls_logits_loss: 0.9237 - val_cls_regress_loss: 0.7196 - val_cls_mask_loss: 0.4173
# Epoch 13/200
# 31/31 [==============================] - 18s 569ms/step - loss: 12.0405 - rpn_score_accuracy: 0.7306 - cls_logits_accuracy: 0.7258 - rpn_score_loss: 0.2487 - rpn_regress_loss: 6.3466 - cls_logits_loss: 3.7226 - cls_regress_loss: 1.1615 - cls_mask_loss: 0.5611 - val_loss: 12.6134 - val_rpn_score_accuracy: 0.6357 - val_cls_logits_accuracy: 0.5357 - val_rpn_score_loss: 0.7237 - val_rpn_regress_loss: 7.9456 - val_cls_logits_loss: 2.8782 - val_cls_regress_loss: 0.6608 - val_cls_mask_loss: 0.4050
# Epoch 14/200
# 31/31 [==============================] - 18s 567ms/step - loss: 6.4156 - rpn_score_accuracy: 0.6806 - cls_logits_accuracy: 0.7219 - rpn_score_loss: 0.1534 - rpn_regress_loss: 1.2588 - cls_logits_loss: 3.5300 - cls_regress_loss: 0.9282 - cls_mask_loss: 0.5453 - val_loss: 19.9449 - val_rpn_score_accuracy: 0.6536 - val_cls_logits_accuracy: 0.4286 - val_rpn_score_loss: 0.3876 - val_rpn_regress_loss: 17.2163 - val_cls_logits_loss: 1.3813 - val_cls_regress_loss: 0.5792 - val_cls_mask_loss: 0.3806
# Epoch 15/200
# 31/31 [==============================] - 18s 563ms/step - loss: 4.4435 - rpn_score_accuracy: 0.7226 - cls_logits_accuracy: 0.5873 - rpn_score_loss: 0.2443 - rpn_regress_loss: 0.5818 - cls_logits_loss: 1.6188 - cls_regress_loss: 1.4537 - cls_mask_loss: 0.5449 - val_loss: 14.1081 - val_rpn_score_accuracy: 0.6714 - val_cls_logits_accuracy: 0.2500 - val_rpn_score_loss: 0.3016 - val_rpn_regress_loss: 8.6331 - val_cls_logits_loss: 3.3037 - val_cls_regress_loss: 1.2920 - val_cls_mask_loss: 0.5777
# Epoch 16/200
# 31/31 [==============================] - 18s 566ms/step - loss: 3.0223 - rpn_score_accuracy: 0.7330 - cls_logits_accuracy: 0.6059 - rpn_score_loss: 0.2216 - rpn_regress_loss: 0.3322 - cls_logits_loss: 0.7371 - cls_regress_loss: 1.1953 - cls_mask_loss: 0.5361 - val_loss: 13.8475 - val_rpn_score_accuracy: 0.6107 - val_cls_logits_accuracy: 0.2551 - val_rpn_score_loss: 0.4101 - val_rpn_regress_loss: 4.2382 - val_cls_logits_loss: 7.5075 - val_cls_regress_loss: 1.1325 - val_cls_mask_loss: 0.5592
# Epoch 17/200
# 31/31 [==============================] - 18s 570ms/step - loss: 2.8214 - rpn_score_accuracy: 0.7238 - cls_logits_accuracy: 0.6266 - rpn_score_loss: 0.1700 - rpn_regress_loss: 0.2392 - cls_logits_loss: 1.0117 - cls_regress_loss: 0.8554 - cls_mask_loss: 0.5452 - val_loss: 4.8416 - val_rpn_score_accuracy: 0.6286 - val_cls_logits_accuracy: 0.6829 - val_rpn_score_loss: 0.3934 - val_rpn_regress_loss: 2.9708 - val_cls_logits_loss: 0.1557 - val_cls_regress_loss: 0.7130 - val_cls_mask_loss: 0.6087
# Epoch 18/200
# 31/31 [==============================] - 18s 567ms/step - loss: 2.3719 - rpn_score_accuracy: 0.7289 - cls_logits_accuracy: 0.5875 - rpn_score_loss: 0.0547 - rpn_regress_loss: 0.1382 - cls_logits_loss: 0.7724 - cls_regress_loss: 0.8574 - cls_mask_loss: 0.5492 - val_loss: 5.5896 - val_rpn_score_accuracy: 0.6643 - val_cls_logits_accuracy: 0.7500 - val_rpn_score_loss: 0.3481 - val_rpn_regress_loss: 2.5530 - val_cls_logits_loss: 0.9505 - val_cls_regress_loss: 1.1739 - val_cls_mask_loss: 0.5641
# Epoch 19/200
# 31/31 [==============================] - 18s 568ms/step - loss: 3.7926 - rpn_score_accuracy: 0.6825 - cls_logits_accuracy: 0.6509 - rpn_score_loss: 0.1218 - rpn_regress_loss: 0.8341 - cls_logits_loss: 1.1800 - cls_regress_loss: 1.0966 - cls_mask_loss: 0.5600 - val_loss: 4.0099 - val_rpn_score_accuracy: 0.6536 - val_cls_logits_accuracy: 0.7500 - val_rpn_score_loss: 0.4100 - val_rpn_regress_loss: 1.3310 - val_cls_logits_loss: 0.8940 - val_cls_regress_loss: 0.8113 - val_cls_mask_loss: 0.5636
# Epoch 20/200
# 31/31 [==============================] - 18s 564ms/step - loss: 2.8091 - rpn_score_accuracy: 0.6915 - cls_logits_accuracy: 0.6205 - rpn_score_loss: 0.1086 - rpn_regress_loss: 0.1681 - cls_logits_loss: 1.1153 - cls_regress_loss: 0.8605 - cls_mask_loss: 0.5565 - val_loss: 4.1419 - val_rpn_score_accuracy: 0.6643 - val_cls_logits_accuracy: 0.7500 - val_rpn_score_loss: 0.4430 - val_rpn_regress_loss: 1.0899 - val_cls_logits_loss: 0.7099 - val_cls_regress_loss: 1.3377 - val_cls_mask_loss: 0.5614
# Epoch 21/200
# 31/31 [==============================] - 18s 564ms/step - loss: 2.4489 - rpn_score_accuracy: 0.7806 - cls_logits_accuracy: 0.6052 - rpn_score_loss: 0.1199 - rpn_regress_loss: 0.1539 - cls_logits_loss: 0.8270 - cls_regress_loss: 0.8051 - cls_mask_loss: 0.5429 - val_loss: 3.4491 - val_rpn_score_accuracy: 0.6464 - val_cls_logits_accuracy: 0.7500 - val_rpn_score_loss: 0.3818 - val_rpn_regress_loss: 1.1560 - val_cls_logits_loss: 0.4882 - val_cls_regress_loss: 0.8351 - val_cls_mask_loss: 0.5879
# Epoch 22/200
# 31/31 [==============================] - 18s 569ms/step - loss: 2.2272 - rpn_score_accuracy: 0.7366 - cls_logits_accuracy: 0.6428 - rpn_score_loss: 0.0845 - rpn_regress_loss: 0.1507 - cls_logits_loss: 0.5762 - cls_regress_loss: 0.8607 - cls_mask_loss: 0.5550 - val_loss: 4.6624 - val_rpn_score_accuracy: 0.6464 - val_cls_logits_accuracy: 0.2500 - val_rpn_score_loss: 0.4002 - val_rpn_regress_loss: 1.0675 - val_cls_logits_loss: 1.7682 - val_cls_regress_loss: 0.8454 - val_cls_mask_loss: 0.5810
# Epoch 23/200
# 31/31 [==============================] - 18s 562ms/step - loss: 2.1840 - rpn_score_accuracy: 0.6889 - cls_logits_accuracy: 0.6135 - rpn_score_loss: 0.1652 - rpn_regress_loss: 0.1324 - cls_logits_loss: 0.4718 - cls_regress_loss: 0.8709 - cls_mask_loss: 0.5436 - val_loss: 3.0216 - val_rpn_score_accuracy: 0.6393 - val_cls_logits_accuracy: 0.7500 - val_rpn_score_loss: 0.4126 - val_rpn_regress_loss: 0.9090 - val_cls_logits_loss: 0.4091 - val_cls_regress_loss: 0.7021 - val_cls_mask_loss: 0.5888
# Epoch 24/200
# 31/31 [==============================] - 18s 565ms/step - loss: 2.7550 - rpn_score_accuracy: 0.7081 - cls_logits_accuracy: 0.5982 - rpn_score_loss: 0.1097 - rpn_regress_loss: 0.5085 - cls_logits_loss: 0.6408 - cls_regress_loss: 0.9466 - cls_mask_loss: 0.5494 - val_loss: 4.1211 - val_rpn_score_accuracy: 0.6571 - val_cls_logits_accuracy: 0.7500 - val_rpn_score_loss: 0.4233 - val_rpn_regress_loss: 0.8303 - val_cls_logits_loss: 1.5319 - val_cls_regress_loss: 0.7499 - val_cls_mask_loss: 0.5857
# Epoch 25/200
# 31/31 [==============================] - 18s 568ms/step - loss: 4.9662 - rpn_score_accuracy: 0.6228 - cls_logits_accuracy: 0.7429 - rpn_score_loss: 0.1167 - rpn_regress_loss: 0.1147 - cls_logits_loss: 3.1711 - cls_regress_loss: 1.0128 - cls_mask_loss: 0.5509 - val_loss: 6.2121 - val_rpn_score_accuracy: 0.6643 - val_cls_logits_accuracy: 0.7500 - val_rpn_score_loss: 0.4082 - val_rpn_regress_loss: 0.8424 - val_cls_logits_loss: 3.5812 - val_cls_regress_loss: 0.7710 - val_cls_mask_loss: 0.6093
# Epoch 26/200
# 31/31 [==============================] - 18s 570ms/step - loss: 4.3250 - rpn_score_accuracy: 0.7031 - cls_logits_accuracy: 0.6017 - rpn_score_loss: 0.0942 - rpn_regress_loss: 0.4314 - cls_logits_loss: 1.8469 - cls_regress_loss: 1.4157 - cls_mask_loss: 0.5368 - val_loss: 3.8003 - val_rpn_score_accuracy: 0.6571 - val_cls_logits_accuracy: 0.7500 - val_rpn_score_loss: 0.3501 - val_rpn_regress_loss: 0.5123 - val_cls_logits_loss: 0.2373 - val_cls_regress_loss: 2.1049 - val_cls_mask_loss: 0.5956
# Epoch 27/200
# 31/31 [==============================] - 18s 564ms/step - loss: 2.7466 - rpn_score_accuracy: 0.7443 - cls_logits_accuracy: 0.6086 - rpn_score_loss: 0.1045 - rpn_regress_loss: 0.2189 - cls_logits_loss: 0.7257 - cls_regress_loss: 1.1710 - cls_mask_loss: 0.5265 - val_loss: 6.4796 - val_rpn_score_accuracy: 0.6071 - val_cls_logits_accuracy: 0.2500 - val_rpn_score_loss: 0.4462 - val_rpn_regress_loss: 0.3661 - val_cls_logits_loss: 0.6089 - val_cls_regress_loss: 4.4203 - val_cls_mask_loss: 0.6381
# Epoch 28/200
# 31/31 [==============================] - 18s 565ms/step - loss: 3.7874 - rpn_score_accuracy: 0.6651 - cls_logits_accuracy: 0.6104 - rpn_score_loss: 0.1399 - rpn_regress_loss: 1.4528 - cls_logits_loss: 0.7920 - cls_regress_loss: 0.8600 - cls_mask_loss: 0.5426 - val_loss: 32.8144 - val_rpn_score_accuracy: 0.6107 - val_cls_logits_accuracy: 0.7500 - val_rpn_score_loss: 0.4926 - val_rpn_regress_loss: 28.9098 - val_cls_logits_loss: 0.4832 - val_cls_regress_loss: 2.3364 - val_cls_mask_loss: 0.5923
# Epoch 29/200
# 31/31 [==============================] - 18s 566ms/step - loss: 3.3290 - rpn_score_accuracy: 0.7393 - cls_logits_accuracy: 0.6124 - rpn_score_loss: 0.1215 - rpn_regress_loss: 1.2625 - cls_logits_loss: 0.5911 - cls_regress_loss: 0.8183 - cls_mask_loss: 0.5355 - val_loss: 9.3076 - val_rpn_score_accuracy: 0.6286 - val_cls_logits_accuracy: 0.2778 - val_rpn_score_loss: 0.5602 - val_rpn_regress_loss: 4.7061 - val_cls_logits_loss: 0.9570 - val_cls_regress_loss: 2.4599 - val_cls_mask_loss: 0.6244
# Epoch 30/200
# 31/31 [==============================] - 18s 564ms/step - loss: 2.0927 - rpn_score_accuracy: 0.7118 - cls_logits_accuracy: 0.5982 - rpn_score_loss: 0.0991 - rpn_regress_loss: 0.1773 - cls_logits_loss: 0.5414 - cls_regress_loss: 0.7568 - cls_mask_loss: 0.5181 - val_loss: 5.6548 - val_rpn_score_accuracy: 0.6393 - val_cls_logits_accuracy: 0.2497 - val_rpn_score_loss: 0.4838 - val_rpn_regress_loss: 2.2511 - val_cls_logits_loss: 0.5353 - val_cls_regress_loss: 1.7647 - val_cls_mask_loss: 0.6199
# Epoch 31/200
# 31/31 [==============================] - 18s 568ms/step - loss: 1.9102 - rpn_score_accuracy: 0.7031 - cls_logits_accuracy: 0.6734 - rpn_score_loss: 0.1616 - rpn_regress_loss: 0.1773 - cls_logits_loss: 0.2643 - cls_regress_loss: 0.7695 - cls_mask_loss: 0.5375 - val_loss: 4.1388 - val_rpn_score_accuracy: 0.6214 - val_cls_logits_accuracy: 0.5936 - val_rpn_score_loss: 0.5718 - val_rpn_regress_loss: 1.5826 - val_cls_logits_loss: 0.1611 - val_cls_regress_loss: 1.2463 - val_cls_mask_loss: 0.5770
# Epoch 32/200
# 31/31 [==============================] - 18s 568ms/step - loss: 2.2161 - rpn_score_accuracy: 0.6780 - cls_logits_accuracy: 0.6491 - rpn_score_loss: 0.0950 - rpn_regress_loss: 0.5693 - cls_logits_loss: 0.2175 - cls_regress_loss: 0.7890 - cls_mask_loss: 0.5453 - val_loss: 4.3058 - val_rpn_score_accuracy: 0.5786 - val_cls_logits_accuracy: 0.2500 - val_rpn_score_loss: 0.5716 - val_rpn_regress_loss: 1.9127 - val_cls_logits_loss: 0.2922 - val_cls_regress_loss: 0.9387 - val_cls_mask_loss: 0.5905
# Epoch 33/200
# 31/31 [==============================] - 18s 564ms/step - loss: 3.7891 - rpn_score_accuracy: 0.6168 - cls_logits_accuracy: 0.6107 - rpn_score_loss: 0.1071 - rpn_regress_loss: 2.0070 - cls_logits_loss: 0.2781 - cls_regress_loss: 0.8613 - cls_mask_loss: 0.5356 - val_loss: 2.5730 - val_rpn_score_accuracy: 0.6500 - val_cls_logits_accuracy: 0.7401 - val_rpn_score_loss: 0.4964 - val_rpn_regress_loss: 0.6469 - val_cls_logits_loss: 0.1592 - val_cls_regress_loss: 0.6858 - val_cls_mask_loss: 0.5847
# Epoch 34/200
# 31/31 [==============================] - 18s 565ms/step - loss: 1.8368 - rpn_score_accuracy: 0.6899 - cls_logits_accuracy: 0.5943 - rpn_score_loss: 0.0835 - rpn_regress_loss: 0.1985 - cls_logits_loss: 0.2876 - cls_regress_loss: 0.7502 - cls_mask_loss: 0.5169 - val_loss: 2.6068 - val_rpn_score_accuracy: 0.6071 - val_cls_logits_accuracy: 0.7197 - val_rpn_score_loss: 0.5155 - val_rpn_regress_loss: 0.4399 - val_cls_logits_loss: 0.1583 - val_cls_regress_loss: 0.8859 - val_cls_mask_loss: 0.6071
# Epoch 35/200
# 31/31 [==============================] - 18s 569ms/step - loss: 1.6773 - rpn_score_accuracy: 0.6066 - cls_logits_accuracy: 0.7052 - rpn_score_loss: 0.1600 - rpn_regress_loss: 0.1057 - cls_logits_loss: 0.1838 - cls_regress_loss: 0.7032 - cls_mask_loss: 0.5246 - val_loss: 2.3576 - val_rpn_score_accuracy: 0.6536 - val_cls_logits_accuracy: 0.7500 - val_rpn_score_loss: 0.4442 - val_rpn_regress_loss: 0.4547 - val_cls_logits_loss: 0.1428 - val_cls_regress_loss: 0.7089 - val_cls_mask_loss: 0.6071
# Epoch 36/200
# 31/31 [==============================] - 18s 568ms/step - loss: 1.6527 - rpn_score_accuracy: 0.6972 - cls_logits_accuracy: 0.7215 - rpn_score_loss: 0.1204 - rpn_regress_loss: 0.1337 - cls_logits_loss: 0.1769 - cls_regress_loss: 0.7014 - cls_mask_loss: 0.5203 - val_loss: 2.3374 - val_rpn_score_accuracy: 0.6500 - val_cls_logits_accuracy: 0.7461 - val_rpn_score_loss: 0.4737 - val_rpn_regress_loss: 0.4745 - val_cls_logits_loss: 0.1510 - val_cls_regress_loss: 0.6931 - val_cls_mask_loss: 0.5450
# Epoch 37/200
# 31/31 [==============================] - 18s 564ms/step - loss: 1.5770 - rpn_score_accuracy: 0.7072 - cls_logits_accuracy: 0.7123 - rpn_score_loss: 0.0990 - rpn_regress_loss: 0.1281 - cls_logits_loss: 0.1496 - cls_regress_loss: 0.6744 - cls_mask_loss: 0.5259 - val_loss: 2.3957 - val_rpn_score_accuracy: 0.6500 - val_cls_logits_accuracy: 0.7500 - val_rpn_score_loss: 0.4769 - val_rpn_regress_loss: 0.4614 - val_cls_logits_loss: 0.1501 - val_cls_regress_loss: 0.7230 - val_cls_mask_loss: 0.5843
# Epoch 38/200
# 31/31 [==============================] - 18s 565ms/step - loss: 1.5840 - rpn_score_accuracy: 0.6731 - cls_logits_accuracy: 0.7354 - rpn_score_loss: 0.0926 - rpn_regress_loss: 0.1101 - cls_logits_loss: 0.1681 - cls_regress_loss: 0.6849 - cls_mask_loss: 0.5283 - val_loss: 2.4623 - val_rpn_score_accuracy: 0.6500 - val_cls_logits_accuracy: 0.2500 - val_rpn_score_loss: 0.4863 - val_rpn_regress_loss: 0.4689 - val_cls_logits_loss: 0.2415 - val_cls_regress_loss: 0.7060 - val_cls_mask_loss: 0.5596
# Epoch 39/200
# 31/31 [==============================] - 18s 570ms/step - loss: 1.7172 - rpn_score_accuracy: 0.6809 - cls_logits_accuracy: 0.6167 - rpn_score_loss: 0.0620 - rpn_regress_loss: 0.1110 - cls_logits_loss: 0.2796 - cls_regress_loss: 0.7161 - cls_mask_loss: 0.5486 - val_loss: 2.4950 - val_rpn_score_accuracy: 0.6357 - val_cls_logits_accuracy: 0.2500 - val_rpn_score_loss: 0.4832 - val_rpn_regress_loss: 0.4700 - val_cls_logits_loss: 0.2469 - val_cls_regress_loss: 0.7346 - val_cls_mask_loss: 0.5603
# Epoch 40/200
# 31/31 [==============================] - 18s 569ms/step - loss: 1.5806 - rpn_score_accuracy: 0.6915 - cls_logits_accuracy: 0.6135 - rpn_score_loss: 0.0581 - rpn_regress_loss: 0.1240 - cls_logits_loss: 0.2010 - cls_regress_loss: 0.6880 - cls_mask_loss: 0.5094 - val_loss: 2.5635 - val_rpn_score_accuracy: 0.6500 - val_cls_logits_accuracy: 0.3881 - val_rpn_score_loss: 0.4997 - val_rpn_regress_loss: 0.4914 - val_cls_logits_loss: 0.1870 - val_cls_regress_loss: 0.8235 - val_cls_mask_loss: 0.5618
# Epoch 41/200
# 31/31 [==============================] - 18s 571ms/step - loss: 1.7320 - rpn_score_accuracy: 0.5744 - cls_logits_accuracy: 0.6573 - rpn_score_loss: 0.1090 - rpn_regress_loss: 0.1001 - cls_logits_loss: 0.2134 - cls_regress_loss: 0.7852 - cls_mask_loss: 0.5242 - val_loss: 2.6573 - val_rpn_score_accuracy: 0.6500 - val_cls_logits_accuracy: 0.2518 - val_rpn_score_loss: 0.4839 - val_rpn_regress_loss: 0.4576 - val_cls_logits_loss: 0.3262 - val_cls_regress_loss: 0.8136 - val_cls_mask_loss: 0.5760
# Epoch 42/200
# 31/31 [==============================] - 18s 566ms/step - loss: 1.7288 - rpn_score_accuracy: 0.6677 - cls_logits_accuracy: 0.7037 - rpn_score_loss: 0.1099 - rpn_regress_loss: 0.1191 - cls_logits_loss: 0.1825 - cls_regress_loss: 0.7806 - cls_mask_loss: 0.5368 - val_loss: 2.4570 - val_rpn_score_accuracy: 0.5929 - val_cls_logits_accuracy: 0.7500 - val_rpn_score_loss: 0.5546 - val_rpn_regress_loss: 0.4296 - val_cls_logits_loss: 0.1418 - val_cls_regress_loss: 0.7190 - val_cls_mask_loss: 0.6120
# Epoch 43/200
# 31/31 [==============================] - 18s 568ms/step - loss: 1.4774 - rpn_score_accuracy: 0.7534 - cls_logits_accuracy: 0.7098 - rpn_score_loss: 0.0463 - rpn_regress_loss: 0.1105 - cls_logits_loss: 0.1497 - cls_regress_loss: 0.6591 - cls_mask_loss: 0.5117 - val_loss: 2.3206 - val_rpn_score_accuracy: 0.6571 - val_cls_logits_accuracy: 0.7500 - val_rpn_score_loss: 0.4745 - val_rpn_regress_loss: 0.4272 - val_cls_logits_loss: 0.1369 - val_cls_regress_loss: 0.7097 - val_cls_mask_loss: 0.5722
# Epoch 44/200
# 31/31 [==============================] - 18s 566ms/step - loss: 1.5845 - rpn_score_accuracy: 0.7548 - cls_logits_accuracy: 0.7157 - rpn_score_loss: 0.0548 - rpn_regress_loss: 0.1358 - cls_logits_loss: 0.1889 - cls_regress_loss: 0.6946 - cls_mask_loss: 0.5104 - val_loss: 2.4882 - val_rpn_score_accuracy: 0.6286 - val_cls_logits_accuracy: 0.2483 - val_rpn_score_loss: 0.5147 - val_rpn_regress_loss: 0.4306 - val_cls_logits_loss: 0.2354 - val_cls_regress_loss: 0.7390 - val_cls_mask_loss: 0.5685
# Epoch 45/200
# 31/31 [==============================] - 18s 567ms/step - loss: 1.6164 - rpn_score_accuracy: 0.6653 - cls_logits_accuracy: 0.6439 - rpn_score_loss: 0.0921 - rpn_regress_loss: 0.1281 - cls_logits_loss: 0.2186 - cls_regress_loss: 0.6822 - cls_mask_loss: 0.4954 - val_loss: 2.3906 - val_rpn_score_accuracy: 0.6571 - val_cls_logits_accuracy: 0.7500 - val_rpn_score_loss: 0.4808 - val_rpn_regress_loss: 0.4096 - val_cls_logits_loss: 0.2137 - val_cls_regress_loss: 0.7163 - val_cls_mask_loss: 0.5703
# Epoch 46/200
# 31/31 [==============================] - 18s 566ms/step - loss: 1.5838 - rpn_score_accuracy: 0.7462 - cls_logits_accuracy: 0.6618 - rpn_score_loss: 0.0783 - rpn_regress_loss: 0.1304 - cls_logits_loss: 0.1862 - cls_regress_loss: 0.6874 - cls_mask_loss: 0.5015 - val_loss: 2.6507 - val_rpn_score_accuracy: 0.6071 - val_cls_logits_accuracy: 0.7500 - val_rpn_score_loss: 0.6222 - val_rpn_regress_loss: 0.4019 - val_cls_logits_loss: 0.3339 - val_cls_regress_loss: 0.7386 - val_cls_mask_loss: 0.5541
# Epoch 47/200
# 31/31 [==============================] - 18s 569ms/step - loss: 1.9773 - rpn_score_accuracy: 0.6887 - cls_logits_accuracy: 0.6648 - rpn_score_loss: 0.0855 - rpn_regress_loss: 0.1192 - cls_logits_loss: 0.3789 - cls_regress_loss: 0.8716 - cls_mask_loss: 0.5220 - val_loss: 2.3886 - val_rpn_score_accuracy: 0.6321 - val_cls_logits_accuracy: 0.7500 - val_rpn_score_loss: 0.5584 - val_rpn_regress_loss: 0.4212 - val_cls_logits_loss: 0.1368 - val_cls_regress_loss: 0.7142 - val_cls_mask_loss: 0.5581
# Epoch 48/200
# 31/31 [==============================] - 18s 569ms/step - loss: 1.5612 - rpn_score_accuracy: 0.6973 - cls_logits_accuracy: 0.6986 - rpn_score_loss: 0.0400 - rpn_regress_loss: 0.1164 - cls_logits_loss: 0.1500 - cls_regress_loss: 0.7545 - cls_mask_loss: 0.5002 - val_loss: 2.3622 - val_rpn_score_accuracy: 0.6643 - val_cls_logits_accuracy: 0.7323 - val_rpn_score_loss: 0.4869 - val_rpn_regress_loss: 0.4108 - val_cls_logits_loss: 0.1465 - val_cls_regress_loss: 0.7421 - val_cls_mask_loss: 0.5758
# Epoch 49/200
# 31/31 [==============================] - 18s 566ms/step - loss: 1.6180 - rpn_score_accuracy: 0.6895 - cls_logits_accuracy: 0.7250 - rpn_score_loss: 0.1623 - rpn_regress_loss: 0.1113 - cls_logits_loss: 0.1634 - cls_regress_loss: 0.6871 - cls_mask_loss: 0.4938 - val_loss: 2.3824 - val_rpn_score_accuracy: 0.6571 - val_cls_logits_accuracy: 0.7165 - val_rpn_score_loss: 0.5010 - val_rpn_regress_loss: 0.4241 - val_cls_logits_loss: 0.1738 - val_cls_regress_loss: 0.7312 - val_cls_mask_loss: 0.5524
# Epoch 50/200
# 31/31 [==============================] - 18s 565ms/step - loss: 1.9598 - rpn_score_accuracy: 0.6477 - cls_logits_accuracy: 0.6839 - rpn_score_loss: 0.1985 - rpn_regress_loss: 0.1178 - cls_logits_loss: 0.2322 - cls_regress_loss: 0.8679 - cls_mask_loss: 0.5434 - val_loss: 2.3453 - val_rpn_score_accuracy: 0.6571 - val_cls_logits_accuracy: 0.7500 - val_rpn_score_loss: 0.5233 - val_rpn_regress_loss: 0.4214 - val_cls_logits_loss: 0.1535 - val_cls_regress_loss: 0.6780 - val_cls_mask_loss: 0.5691
# Epoch 51/200
# 31/31 [==============================] - 18s 567ms/step - loss: 1.7294 - rpn_score_accuracy: 0.6923 - cls_logits_accuracy: 0.7297 - rpn_score_loss: 0.1363 - rpn_regress_loss: 0.1219 - cls_logits_loss: 0.1556 - cls_regress_loss: 0.7986 - cls_mask_loss: 0.5171 - val_loss: 2.4615 - val_rpn_score_accuracy: 0.6143 - val_cls_logits_accuracy: 0.7500 - val_rpn_score_loss: 0.5612 - val_rpn_regress_loss: 0.4249 - val_cls_logits_loss: 0.1428 - val_cls_regress_loss: 0.7628 - val_cls_mask_loss: 0.5697
# Epoch 52/200
# 31/31 [==============================] - 18s 566ms/step - loss: 1.4290 - rpn_score_accuracy: 0.6695 - cls_logits_accuracy: 0.7177 - rpn_score_loss: 0.0484 - rpn_regress_loss: 0.1176 - cls_logits_loss: 0.1417 - cls_regress_loss: 0.6325 - cls_mask_loss: 0.4888 - val_loss: 2.3779 - val_rpn_score_accuracy: 0.6500 - val_cls_logits_accuracy: 0.7484 - val_rpn_score_loss: 0.5167 - val_rpn_regress_loss: 0.4260 - val_cls_logits_loss: 0.1503 - val_cls_regress_loss: 0.7280 - val_cls_mask_loss: 0.5570
# Epoch 53/200
# 31/31 [==============================] - 18s 569ms/step - loss: 1.5401 - rpn_score_accuracy: 0.7016 - cls_logits_accuracy: 0.7195 - rpn_score_loss: 0.0368 - rpn_regress_loss: 0.1015 - cls_logits_loss: 0.1858 - cls_regress_loss: 0.6902 - cls_mask_loss: 0.5257 - val_loss: 2.4276 - val_rpn_score_accuracy: 0.6500 - val_cls_logits_accuracy: 0.7545 - val_rpn_score_loss: 0.5033 - val_rpn_regress_loss: 0.4378 - val_cls_logits_loss: 0.1619 - val_cls_regress_loss: 0.7579 - val_cls_mask_loss: 0.5666
# Epoch 54/200
# 31/31 [==============================] - 18s 568ms/step - loss: 1.5808 - rpn_score_accuracy: 0.7513 - cls_logits_accuracy: 0.6969 - rpn_score_loss: 0.0762 - rpn_regress_loss: 0.1229 - cls_logits_loss: 0.1811 - cls_regress_loss: 0.6941 - cls_mask_loss: 0.5065 - val_loss: 2.3938 - val_rpn_score_accuracy: 0.6571 - val_cls_logits_accuracy: 0.7500 - val_rpn_score_loss: 0.4938 - val_rpn_regress_loss: 0.4305 - val_cls_logits_loss: 0.1543 - val_cls_regress_loss: 0.7482 - val_cls_mask_loss: 0.5669
# Epoch 55/200
# 31/31 [==============================] - 18s 565ms/step - loss: 1.5538 - rpn_score_accuracy: 0.7474 - cls_logits_accuracy: 0.7178 - rpn_score_loss: 0.0538 - rpn_regress_loss: 0.1186 - cls_logits_loss: 0.1914 - cls_regress_loss: 0.6722 - cls_mask_loss: 0.5178 - val_loss: 2.3822 - val_rpn_score_accuracy: 0.6500 - val_cls_logits_accuracy: 0.6772 - val_rpn_score_loss: 0.5085 - val_rpn_regress_loss: 0.4130 - val_cls_logits_loss: 0.1716 - val_cls_regress_loss: 0.7216 - val_cls_mask_loss: 0.5673
# Epoch 56/200
# 31/31 [==============================] - 18s 570ms/step - loss: 1.6352 - rpn_score_accuracy: 0.7243 - cls_logits_accuracy: 0.6765 - rpn_score_loss: 0.0530 - rpn_regress_loss: 0.1139 - cls_logits_loss: 0.2343 - cls_regress_loss: 0.7171 - cls_mask_loss: 0.5168 - val_loss: 2.4323 - val_rpn_score_accuracy: 0.6321 - val_cls_logits_accuracy: 0.7415 - val_rpn_score_loss: 0.5027 - val_rpn_regress_loss: 0.4373 - val_cls_logits_loss: 0.1565 - val_cls_regress_loss: 0.7755 - val_cls_mask_loss: 0.5603
# Epoch 57/200
# 31/31 [==============================] - 18s 567ms/step - loss: 1.5244 - rpn_score_accuracy: 0.6991 - cls_logits_accuracy: 0.7039 - rpn_score_loss: 0.1043 - rpn_regress_loss: 0.1058 - cls_logits_loss: 0.1700 - cls_regress_loss: 0.6679 - cls_mask_loss: 0.4763 - val_loss: 2.4139 - val_rpn_score_accuracy: 0.6393 - val_cls_logits_accuracy: 0.7434 - val_rpn_score_loss: 0.5550 - val_rpn_regress_loss: 0.4283 - val_cls_logits_loss: 0.1577 - val_cls_regress_loss: 0.7112 - val_cls_mask_loss: 0.5616
# Epoch 58/200
# 31/31 [==============================] - 18s 569ms/step - loss: 1.5451 - rpn_score_accuracy: 0.6919 - cls_logits_accuracy: 0.7339 - rpn_score_loss: 0.1248 - rpn_regress_loss: 0.1187 - cls_logits_loss: 0.1512 - cls_regress_loss: 0.6597 - cls_mask_loss: 0.4907 - val_loss: 2.4262 - val_rpn_score_accuracy: 0.6321 - val_cls_logits_accuracy: 0.7500 - val_rpn_score_loss: 0.5566 - val_rpn_regress_loss: 0.4199 - val_cls_logits_loss: 0.1414 - val_cls_regress_loss: 0.7576 - val_cls_mask_loss: 0.5506
# Epoch 59/200
# 31/31 [==============================] - 18s 565ms/step - loss: 1.5916 - rpn_score_accuracy: 0.7099 - cls_logits_accuracy: 0.7202 - rpn_score_loss: 0.1017 - rpn_regress_loss: 0.1262 - cls_logits_loss: 0.1653 - cls_regress_loss: 0.7044 - cls_mask_loss: 0.4940 - val_loss: 2.3491 - val_rpn_score_accuracy: 0.6643 - val_cls_logits_accuracy: 0.7500 - val_rpn_score_loss: 0.5004 - val_rpn_regress_loss: 0.4052 - val_cls_logits_loss: 0.1412 - val_cls_regress_loss: 0.6873 - val_cls_mask_loss: 0.6149
# Epoch 60/200
# 31/31 [==============================] - 18s 567ms/step - loss: 1.5463 - rpn_score_accuracy: 0.7731 - cls_logits_accuracy: 0.7454 - rpn_score_loss: 0.0772 - rpn_regress_loss: 0.1296 - cls_logits_loss: 0.1481 - cls_regress_loss: 0.6897 - cls_mask_loss: 0.5016 - val_loss: 2.4078 - val_rpn_score_accuracy: 0.6214 - val_cls_logits_accuracy: 0.7047 - val_rpn_score_loss: 0.5678 - val_rpn_regress_loss: 0.4094 - val_cls_logits_loss: 0.1579 - val_cls_regress_loss: 0.7151 - val_cls_mask_loss: 0.5576
# Epoch 61/200
# 31/31 [==============================] - 18s 570ms/step - loss: 1.4627 - rpn_score_accuracy: 0.7081 - cls_logits_accuracy: 0.7399 - rpn_score_loss: 0.0975 - rpn_regress_loss: 0.1075 - cls_logits_loss: 0.1359 - cls_regress_loss: 0.6452 - cls_mask_loss: 0.4766 - val_loss: 2.3976 - val_rpn_score_accuracy: 0.6286 - val_cls_logits_accuracy: 0.7038 - val_rpn_score_loss: 0.5109 - val_rpn_regress_loss: 0.3943 - val_cls_logits_loss: 0.1547 - val_cls_regress_loss: 0.7724 - val_cls_mask_loss: 0.5653
# Epoch 62/200
# 31/31 [==============================] - 18s 566ms/step - loss: 1.5471 - rpn_score_accuracy: 0.7661 - cls_logits_accuracy: 0.7657 - rpn_score_loss: 0.1383 - rpn_regress_loss: 0.1199 - cls_logits_loss: 0.1345 - cls_regress_loss: 0.6752 - cls_mask_loss: 0.4793 - val_loss: 2.2730 - val_rpn_score_accuracy: 0.6393 - val_cls_logits_accuracy: 0.7500 - val_rpn_score_loss: 0.5434 - val_rpn_regress_loss: 0.3648 - val_cls_logits_loss: 0.1378 - val_cls_regress_loss: 0.6868 - val_cls_mask_loss: 0.5403
# Epoch 63/200
# 31/31 [==============================] - 18s 569ms/step - loss: 1.4667 - rpn_score_accuracy: 0.7232 - cls_logits_accuracy: 0.7432 - rpn_score_loss: 0.0639 - rpn_regress_loss: 0.1087 - cls_logits_loss: 0.1336 - cls_regress_loss: 0.6715 - cls_mask_loss: 0.4890 - val_loss: 2.3231 - val_rpn_score_accuracy: 0.6393 - val_cls_logits_accuracy: 0.7459 - val_rpn_score_loss: 0.5663 - val_rpn_regress_loss: 0.3730 - val_cls_logits_loss: 0.1409 - val_cls_regress_loss: 0.6987 - val_cls_mask_loss: 0.5442
# Epoch 64/200
# 31/31 [==============================] - 18s 565ms/step - loss: 1.4589 - rpn_score_accuracy: 0.7129 - cls_logits_accuracy: 0.7354 - rpn_score_loss: 0.0633 - rpn_regress_loss: 0.1137 - cls_logits_loss: 0.1387 - cls_regress_loss: 0.6456 - cls_mask_loss: 0.4975 - val_loss: 2.2946 - val_rpn_score_accuracy: 0.6500 - val_cls_logits_accuracy: 0.7474 - val_rpn_score_loss: 0.5209 - val_rpn_regress_loss: 0.3801 - val_cls_logits_loss: 0.1407 - val_cls_regress_loss: 0.6892 - val_cls_mask_loss: 0.5636
# Epoch 65/200
# 31/31 [==============================] - 18s 565ms/step - loss: 1.5641 - rpn_score_accuracy: 0.7593 - cls_logits_accuracy: 0.7249 - rpn_score_loss: 0.1506 - rpn_regress_loss: 0.1331 - cls_logits_loss: 0.1510 - cls_regress_loss: 0.6568 - cls_mask_loss: 0.4727 - val_loss: 2.2280 - val_rpn_score_accuracy: 0.6571 - val_cls_logits_accuracy: 0.7500 - val_rpn_score_loss: 0.5090 - val_rpn_regress_loss: 0.3908 - val_cls_logits_loss: 0.1391 - val_cls_regress_loss: 0.6709 - val_cls_mask_loss: 0.5182
# Epoch 66/200
# 31/31 [==============================] - 18s 567ms/step - loss: 1.5205 - rpn_score_accuracy: 0.7007 - cls_logits_accuracy: 0.7488 - rpn_score_loss: 0.0943 - rpn_regress_loss: 0.1408 - cls_logits_loss: 0.1344 - cls_regress_loss: 0.6863 - cls_mask_loss: 0.4646 - val_loss: 2.2636 - val_rpn_score_accuracy: 0.6214 - val_cls_logits_accuracy: 0.7464 - val_rpn_score_loss: 0.5599 - val_rpn_regress_loss: 0.3596 - val_cls_logits_loss: 0.1450 - val_cls_regress_loss: 0.6837 - val_cls_mask_loss: 0.5155
# Epoch 67/200
# 31/31 [==============================] - 18s 566ms/step - loss: 1.5623 - rpn_score_accuracy: 0.6546 - cls_logits_accuracy: 0.7349 - rpn_score_loss: 0.1161 - rpn_regress_loss: 0.1087 - cls_logits_loss: 0.1503 - cls_regress_loss: 0.6862 - cls_mask_loss: 0.5011 - val_loss: 2.2410 - val_rpn_score_accuracy: 0.6571 - val_cls_logits_accuracy: 0.7464 - val_rpn_score_loss: 0.5203 - val_rpn_regress_loss: 0.3571 - val_cls_logits_loss: 0.1368 - val_cls_regress_loss: 0.7198 - val_cls_mask_loss: 0.5070
# Epoch 68/200
# 31/31 [==============================] - 18s 567ms/step - loss: 1.4411 - rpn_score_accuracy: 0.6545 - cls_logits_accuracy: 0.7752 - rpn_score_loss: 0.0627 - rpn_regress_loss: 0.1018 - cls_logits_loss: 0.1388 - cls_regress_loss: 0.6717 - cls_mask_loss: 0.4661 - val_loss: 2.2100 - val_rpn_score_accuracy: 0.6500 - val_cls_logits_accuracy: 0.7482 - val_rpn_score_loss: 0.5244 - val_rpn_regress_loss: 0.3686 - val_cls_logits_loss: 0.1362 - val_cls_regress_loss: 0.6687 - val_cls_mask_loss: 0.5121
# Epoch 69/200
# 31/31 [==============================] - 18s 567ms/step - loss: 1.4700 - rpn_score_accuracy: 0.7194 - cls_logits_accuracy: 0.7398 - rpn_score_loss: 0.0645 - rpn_regress_loss: 0.1097 - cls_logits_loss: 0.1349 - cls_regress_loss: 0.6707 - cls_mask_loss: 0.4901 - val_loss: 2.2866 - val_rpn_score_accuracy: 0.6500 - val_cls_logits_accuracy: 0.7517 - val_rpn_score_loss: 0.5136 - val_rpn_regress_loss: 0.3634 - val_cls_logits_loss: 0.1518 - val_cls_regress_loss: 0.6874 - val_cls_mask_loss: 0.5703
# Epoch 70/200
# 31/31 [==============================] - 18s 568ms/step - loss: 1.4275 - rpn_score_accuracy: 0.6915 - cls_logits_accuracy: 0.7429 - rpn_score_loss: 0.1021 - rpn_regress_loss: 0.1269 - cls_logits_loss: 0.1337 - cls_regress_loss: 0.6181 - cls_mask_loss: 0.4467 - val_loss: 2.3844 - val_rpn_score_accuracy: 0.5607 - val_cls_logits_accuracy: 0.7408 - val_rpn_score_loss: 0.5920 - val_rpn_regress_loss: 0.3701 - val_cls_logits_loss: 0.1426 - val_cls_regress_loss: 0.7415 - val_cls_mask_loss: 0.5382
# Epoch 71/200
# 31/31 [==============================] - 18s 568ms/step - loss: 1.4374 - rpn_score_accuracy: 0.7556 - cls_logits_accuracy: 0.7600 - rpn_score_loss: 0.0644 - rpn_regress_loss: 0.1226 - cls_logits_loss: 0.1322 - cls_regress_loss: 0.6516 - cls_mask_loss: 0.4667 - val_loss: 2.2625 - val_rpn_score_accuracy: 0.6429 - val_cls_logits_accuracy: 0.7726 - val_rpn_score_loss: 0.5163 - val_rpn_regress_loss: 0.3570 - val_cls_logits_loss: 0.1486 - val_cls_regress_loss: 0.7182 - val_cls_mask_loss: 0.5224
# Epoch 72/200
# 31/31 [==============================] - 18s 564ms/step - loss: 1.4019 - rpn_score_accuracy: 0.6660 - cls_logits_accuracy: 0.7725 - rpn_score_loss: 0.0520 - rpn_regress_loss: 0.1021 - cls_logits_loss: 0.1320 - cls_regress_loss: 0.6366 - cls_mask_loss: 0.4791 - val_loss: 2.2895 - val_rpn_score_accuracy: 0.6571 - val_cls_logits_accuracy: 0.6884 - val_rpn_score_loss: 0.4915 - val_rpn_regress_loss: 0.3623 - val_cls_logits_loss: 0.1571 - val_cls_regress_loss: 0.7065 - val_cls_mask_loss: 0.5721
# Epoch 73/200
# 31/31 [==============================] - 18s 567ms/step - loss: 1.3432 - rpn_score_accuracy: 0.7800 - cls_logits_accuracy: 0.6947 - rpn_score_loss: 0.0619 - rpn_regress_loss: 0.1198 - cls_logits_loss: 0.1244 - cls_regress_loss: 0.6028 - cls_mask_loss: 0.4343 - val_loss: 2.3538 - val_rpn_score_accuracy: 0.5429 - val_cls_logits_accuracy: 0.7562 - val_rpn_score_loss: 0.6180 - val_rpn_regress_loss: 0.3603 - val_cls_logits_loss: 0.1346 - val_cls_regress_loss: 0.7222 - val_cls_mask_loss: 0.5186
# Epoch 74/200
# 31/31 [==============================] - 18s 568ms/step - loss: 1.4053 - rpn_score_accuracy: 0.6815 - cls_logits_accuracy: 0.7784 - rpn_score_loss: 0.0660 - rpn_regress_loss: 0.1102 - cls_logits_loss: 0.1262 - cls_regress_loss: 0.6389 - cls_mask_loss: 0.4641 - val_loss: 2.1820 - val_rpn_score_accuracy: 0.6429 - val_cls_logits_accuracy: 0.7603 - val_rpn_score_loss: 0.4913 - val_rpn_regress_loss: 0.3416 - val_cls_logits_loss: 0.1330 - val_cls_regress_loss: 0.7040 - val_cls_mask_loss: 0.5121
# Epoch 75/200
# 31/31 [==============================] - 18s 569ms/step - loss: 1.3815 - rpn_score_accuracy: 0.7029 - cls_logits_accuracy: 0.7896 - rpn_score_loss: 0.0401 - rpn_regress_loss: 0.1093 - cls_logits_loss: 0.1214 - cls_regress_loss: 0.6541 - cls_mask_loss: 0.4566 - val_loss: 2.2067 - val_rpn_score_accuracy: 0.6571 - val_cls_logits_accuracy: 0.7489 - val_rpn_score_loss: 0.4810 - val_rpn_regress_loss: 0.3426 - val_cls_logits_loss: 0.1301 - val_cls_regress_loss: 0.7408 - val_cls_mask_loss: 0.5122
# Epoch 76/200
# 31/31 [==============================] - 18s 570ms/step - loss: 1.3743 - rpn_score_accuracy: 0.6928 - cls_logits_accuracy: 0.7826 - rpn_score_loss: 0.0869 - rpn_regress_loss: 0.1175 - cls_logits_loss: 0.1083 - cls_regress_loss: 0.6242 - cls_mask_loss: 0.4374 - val_loss: 2.2046 - val_rpn_score_accuracy: 0.6500 - val_cls_logits_accuracy: 0.7812 - val_rpn_score_loss: 0.5098 - val_rpn_regress_loss: 0.3392 - val_cls_logits_loss: 0.1341 - val_cls_regress_loss: 0.7154 - val_cls_mask_loss: 0.5061
# Epoch 77/200
# 31/31 [==============================] - 18s 567ms/step - loss: 1.4475 - rpn_score_accuracy: 0.7561 - cls_logits_accuracy: 0.7959 - rpn_score_loss: 0.1110 - rpn_regress_loss: 0.1196 - cls_logits_loss: 0.1231 - cls_regress_loss: 0.6376 - cls_mask_loss: 0.4561 - val_loss: 2.2562 - val_rpn_score_accuracy: 0.6321 - val_cls_logits_accuracy: 0.7467 - val_rpn_score_loss: 0.5570 - val_rpn_regress_loss: 0.3344 - val_cls_logits_loss: 0.1322 - val_cls_regress_loss: 0.7299 - val_cls_mask_loss: 0.5026
# Epoch 78/200
# 31/31 [==============================] - 18s 565ms/step - loss: 1.4206 - rpn_score_accuracy: 0.7015 - cls_logits_accuracy: 0.7567 - rpn_score_loss: 0.1157 - rpn_regress_loss: 0.1202 - cls_logits_loss: 0.1136 - cls_regress_loss: 0.6699 - cls_mask_loss: 0.4011 - val_loss: 2.1816 - val_rpn_score_accuracy: 0.6571 - val_cls_logits_accuracy: 0.7475 - val_rpn_score_loss: 0.5251 - val_rpn_regress_loss: 0.3436 - val_cls_logits_loss: 0.1293 - val_cls_regress_loss: 0.6938 - val_cls_mask_loss: 0.4899
# Epoch 79/200
# 31/31 [==============================] - 18s 566ms/step - loss: 1.3545 - rpn_score_accuracy: 0.7248 - cls_logits_accuracy: 0.7721 - rpn_score_loss: 0.0449 - rpn_regress_loss: 0.1168 - cls_logits_loss: 0.1513 - cls_regress_loss: 0.6099 - cls_mask_loss: 0.4316 - val_loss: 2.5523 - val_rpn_score_accuracy: 0.6500 - val_cls_logits_accuracy: 0.7500 - val_rpn_score_loss: 0.5298 - val_rpn_regress_loss: 0.3600 - val_cls_logits_loss: 0.4422 - val_cls_regress_loss: 0.6916 - val_cls_mask_loss: 0.5288
# Epoch 80/200
# 31/31 [==============================] - 18s 567ms/step - loss: 1.4089 - rpn_score_accuracy: 0.6302 - cls_logits_accuracy: 0.7646 - rpn_score_loss: 0.1040 - rpn_regress_loss: 0.1141 - cls_logits_loss: 0.1751 - cls_regress_loss: 0.6030 - cls_mask_loss: 0.4126 - val_loss: 2.3706 - val_rpn_score_accuracy: 0.6321 - val_cls_logits_accuracy: 0.8279 - val_rpn_score_loss: 0.6489 - val_rpn_regress_loss: 0.3555 - val_cls_logits_loss: 0.1494 - val_cls_regress_loss: 0.6973 - val_cls_mask_loss: 0.5196
# Epoch 81/200
# 31/31 [==============================] - 18s 568ms/step - loss: 1.3198 - rpn_score_accuracy: 0.7485 - cls_logits_accuracy: 0.8082 - rpn_score_loss: 0.0857 - rpn_regress_loss: 0.1203 - cls_logits_loss: 0.1154 - cls_regress_loss: 0.5729 - cls_mask_loss: 0.4254 - val_loss: 2.2473 - val_rpn_score_accuracy: 0.6571 - val_cls_logits_accuracy: 0.7820 - val_rpn_score_loss: 0.5409 - val_rpn_regress_loss: 0.3568 - val_cls_logits_loss: 0.1340 - val_cls_regress_loss: 0.7092 - val_cls_mask_loss: 0.5063
# Epoch 82/200
# 31/31 [==============================] - 18s 569ms/step - loss: 1.3011 - rpn_score_accuracy: 0.7441 - cls_logits_accuracy: 0.8069 - rpn_score_loss: 0.0678 - rpn_regress_loss: 0.1138 - cls_logits_loss: 0.1139 - cls_regress_loss: 0.5943 - cls_mask_loss: 0.4112 - val_loss: 2.2408 - val_rpn_score_accuracy: 0.6571 - val_cls_logits_accuracy: 0.7643 - val_rpn_score_loss: 0.5367 - val_rpn_regress_loss: 0.3411 - val_cls_logits_loss: 0.1417 - val_cls_regress_loss: 0.7080 - val_cls_mask_loss: 0.5132
# Epoch 83/200
# 31/31 [==============================] - 18s 567ms/step - loss: 1.3640 - rpn_score_accuracy: 0.7091 - cls_logits_accuracy: 0.7822 - rpn_score_loss: 0.1075 - rpn_regress_loss: 0.1255 - cls_logits_loss: 0.1113 - cls_regress_loss: 0.6355 - cls_mask_loss: 0.3842 - val_loss: 2.1386 - val_rpn_score_accuracy: 0.6500 - val_cls_logits_accuracy: 0.7627 - val_rpn_score_loss: 0.5614 - val_rpn_regress_loss: 0.3409 - val_cls_logits_loss: 0.1218 - val_cls_regress_loss: 0.6290 - val_cls_mask_loss: 0.4854
# Epoch 84/200
# 31/31 [==============================] - 18s 568ms/step - loss: 1.3122 - rpn_score_accuracy: 0.7780 - cls_logits_accuracy: 0.8219 - rpn_score_loss: 0.0654 - rpn_regress_loss: 0.1254 - cls_logits_loss: 0.1093 - cls_regress_loss: 0.6060 - cls_mask_loss: 0.4061 - val_loss: 2.3358 - val_rpn_score_accuracy: 0.6143 - val_cls_logits_accuracy: 0.7879 - val_rpn_score_loss: 0.7276 - val_rpn_regress_loss: 0.3289 - val_cls_logits_loss: 0.1300 - val_cls_regress_loss: 0.6592 - val_cls_mask_loss: 0.4901
# Epoch 85/200
# 31/31 [==============================] - 18s 567ms/step - loss: 1.2604 - rpn_score_accuracy: 0.7023 - cls_logits_accuracy: 0.8183 - rpn_score_loss: 0.0436 - rpn_regress_loss: 0.1154 - cls_logits_loss: 0.1077 - cls_regress_loss: 0.5994 - cls_mask_loss: 0.3943 - val_loss: 2.1624 - val_rpn_score_accuracy: 0.6500 - val_cls_logits_accuracy: 0.8308 - val_rpn_score_loss: 0.5420 - val_rpn_regress_loss: 0.3331 - val_cls_logits_loss: 0.1296 - val_cls_regress_loss: 0.6844 - val_cls_mask_loss: 0.4734
# Epoch 86/200
# ...
# Epoch 170/200
# 31/31 [==============================] - 18s 572ms/step - loss: 0.8229 - rpn_score_accuracy: 0.7293 - cls_logits_accuracy: 0.8703 - rpn_score_loss: 0.0357 - rpn_regress_loss: 0.1018 - cls_logits_loss: 0.0877 - cls_regress_loss: 0.3617 - cls_mask_loss: 0.2361 - val_loss: 2.1722 - val_rpn_score_accuracy: 0.5964 - val_cls_logits_accuracy: 0.8680 - val_rpn_score_loss: 0.7981 - val_rpn_regress_loss: 0.3300 - val_cls_logits_loss: 0.1071 - val_cls_regress_loss: 0.5281 - val_cls_mask_loss: 0.4089
# Epoch 171/200
# 31/31 [==============================] - 18s 572ms/step - loss: 0.8228 - rpn_score_accuracy: 0.6516 - cls_logits_accuracy: 0.8685 - rpn_score_loss: 0.0431 - rpn_regress_loss: 0.0788 - cls_logits_loss: 0.0836 - cls_regress_loss: 0.3626 - cls_mask_loss: 0.2548 - val_loss: 2.1178 - val_rpn_score_accuracy: 0.6071 - val_cls_logits_accuracy: 0.8604 - val_rpn_score_loss: 0.7414 - val_rpn_regress_loss: 0.3221 - val_cls_logits_loss: 0.0957 - val_cls_regress_loss: 0.5405 - val_cls_mask_loss: 0.4181
# Epoch 172/200
# 31/31 [==============================] - 18s 572ms/step - loss: 0.7938 - rpn_score_accuracy: 0.6694 - cls_logits_accuracy: 0.8716 - rpn_score_loss: 0.0211 - rpn_regress_loss: 0.0778 - cls_logits_loss: 0.0834 - cls_regress_loss: 0.3646 - cls_mask_loss: 0.2470 - val_loss: 2.0821 - val_rpn_score_accuracy: 0.6071 - val_cls_logits_accuracy: 0.8480 - val_rpn_score_loss: 0.7242 - val_rpn_regress_loss: 0.3317 - val_cls_logits_loss: 0.0928 - val_cls_regress_loss: 0.5140 - val_cls_mask_loss: 0.4194
# Epoch 173/200
# 31/31 [==============================] - 18s 575ms/step - loss: 0.9006 - rpn_score_accuracy: 0.6473 - cls_logits_accuracy: 0.8721 - rpn_score_loss: 0.1205 - rpn_regress_loss: 0.0813 - cls_logits_loss: 0.0809 - cls_regress_loss: 0.3745 - cls_mask_loss: 0.2435 - val_loss: 2.1951 - val_rpn_score_accuracy: 0.6071 - val_cls_logits_accuracy: 0.8485 - val_rpn_score_loss: 0.7483 - val_rpn_regress_loss: 0.3367 - val_cls_logits_loss: 0.0974 - val_cls_regress_loss: 0.5342 - val_cls_mask_loss: 0.4785
# Epoch 174/200
# 31/31 [==============================] - 18s 574ms/step - loss: 0.8483 - rpn_score_accuracy: 0.7634 - cls_logits_accuracy: 0.8733 - rpn_score_loss: 0.0815 - rpn_regress_loss: 0.1010 - cls_logits_loss: 0.0814 - cls_regress_loss: 0.3504 - cls_mask_loss: 0.2340 - val_loss: 2.1019 - val_rpn_score_accuracy: 0.6143 - val_cls_logits_accuracy: 0.8517 - val_rpn_score_loss: 0.7258 - val_rpn_regress_loss: 0.3442 - val_cls_logits_loss: 0.1054 - val_cls_regress_loss: 0.5180 - val_cls_mask_loss: 0.4086
# Epoch 175/200
# 31/31 [==============================] - 18s 572ms/step - loss: 0.8828 - rpn_score_accuracy: 0.6588 - cls_logits_accuracy: 0.8673 - rpn_score_loss: 0.0950 - rpn_regress_loss: 0.0825 - cls_logits_loss: 0.0845 - cls_regress_loss: 0.3840 - cls_mask_loss: 0.2368 - val_loss: 2.1602 - val_rpn_score_accuracy: 0.5929 - val_cls_logits_accuracy: 0.8461 - val_rpn_score_loss: 0.7641 - val_rpn_regress_loss: 0.3634 - val_cls_logits_loss: 0.0974 - val_cls_regress_loss: 0.5380 - val_cls_mask_loss: 0.3972
# Epoch 176/200
# 31/31 [==============================] - 18s 575ms/step - loss: 0.7708 - rpn_score_accuracy: 0.7056 - cls_logits_accuracy: 0.8692 - rpn_score_loss: 0.0239 - rpn_regress_loss: 0.0749 - cls_logits_loss: 0.0779 - cls_regress_loss: 0.3682 - cls_mask_loss: 0.2258 - val_loss: 2.1811 - val_rpn_score_accuracy: 0.6250 - val_cls_logits_accuracy: 0.8542 - val_rpn_score_loss: 0.7340 - val_rpn_regress_loss: 0.3725 - val_cls_logits_loss: 0.0900 - val_cls_regress_loss: 0.5254 - val_cls_mask_loss: 0.4592
# Epoch 177/200
# 31/31 [==============================] - 18s 575ms/step - loss: 0.8432 - rpn_score_accuracy: 0.7470 - cls_logits_accuracy: 0.8607 - rpn_score_loss: 0.0498 - rpn_regress_loss: 0.1012 - cls_logits_loss: 0.0851 - cls_regress_loss: 0.3784 - cls_mask_loss: 0.2286 - val_loss: 2.2671 - val_rpn_score_accuracy: 0.6071 - val_cls_logits_accuracy: 0.8511 - val_rpn_score_loss: 0.7640 - val_rpn_regress_loss: 0.3753 - val_cls_logits_loss: 0.1026 - val_cls_regress_loss: 0.5379 - val_cls_mask_loss: 0.4873
# Epoch 178/200
# 31/31 [==============================] - 18s 573ms/step - loss: 0.7713 - rpn_score_accuracy: 0.8017 - cls_logits_accuracy: 0.8653 - rpn_score_loss: 0.0245 - rpn_regress_loss: 0.0958 - cls_logits_loss: 0.0815 - cls_regress_loss: 0.3559 - cls_mask_loss: 0.2135 - val_loss: 2.3467 - val_rpn_score_accuracy: 0.6143 - val_cls_logits_accuracy: 0.8509 - val_rpn_score_loss: 0.7725 - val_rpn_regress_loss: 0.3725 - val_cls_logits_loss: 0.0952 - val_cls_regress_loss: 0.5446 - val_cls_mask_loss: 0.5618
# Epoch 179/200
# 31/31 [==============================] - 18s 576ms/step - loss: 0.8288 - rpn_score_accuracy: 0.6559 - cls_logits_accuracy: 0.8690 - rpn_score_loss: 0.0658 - rpn_regress_loss: 0.0757 - cls_logits_loss: 0.0784 - cls_regress_loss: 0.3898 - cls_mask_loss: 0.2190 - val_loss: 2.1324 - val_rpn_score_accuracy: 0.6571 - val_cls_logits_accuracy: 0.8202 - val_rpn_score_loss: 0.6705 - val_rpn_regress_loss: 0.3607 - val_cls_logits_loss: 0.1070 - val_cls_regress_loss: 0.5241 - val_cls_mask_loss: 0.4700
# Epoch 180/200
# 31/31 [==============================] - 18s 574ms/step - loss: 0.8036 - rpn_score_accuracy: 0.7030 - cls_logits_accuracy: 0.8599 - rpn_score_loss: 0.0248 - rpn_regress_loss: 0.0823 - cls_logits_loss: 0.0859 - cls_regress_loss: 0.3860 - cls_mask_loss: 0.2246 - val_loss: 2.1683 - val_rpn_score_accuracy: 0.6250 - val_cls_logits_accuracy: 0.8276 - val_rpn_score_loss: 0.6856 - val_rpn_regress_loss: 0.3665 - val_cls_logits_loss: 0.1026 - val_cls_regress_loss: 0.5351 - val_cls_mask_loss: 0.4784
# Epoch 181/200
# 31/31 [==============================] - 18s 571ms/step - loss: 0.8221 - rpn_score_accuracy: 0.7477 - cls_logits_accuracy: 0.8741 - rpn_score_loss: 0.0580 - rpn_regress_loss: 0.0968 - cls_logits_loss: 0.0809 - cls_regress_loss: 0.3539 - cls_mask_loss: 0.2325 - val_loss: 2.0821 - val_rpn_score_accuracy: 0.6143 - val_cls_logits_accuracy: 0.8571 - val_rpn_score_loss: 0.7292 - val_rpn_regress_loss: 0.3598 - val_cls_logits_loss: 0.0922 - val_cls_regress_loss: 0.4841 - val_cls_mask_loss: 0.4168
# Epoch 182/200
# 31/31 [==============================] - 18s 573ms/step - loss: 0.8379 - rpn_score_accuracy: 0.7631 - cls_logits_accuracy: 0.8622 - rpn_score_loss: 0.0416 - rpn_regress_loss: 0.1064 - cls_logits_loss: 0.0880 - cls_regress_loss: 0.3731 - cls_mask_loss: 0.2288 - val_loss: 2.2705 - val_rpn_score_accuracy: 0.5714 - val_cls_logits_accuracy: 0.8430 - val_rpn_score_loss: 0.8521 - val_rpn_regress_loss: 0.3660 - val_cls_logits_loss: 0.0967 - val_cls_regress_loss: 0.4897 - val_cls_mask_loss: 0.4659
# Epoch 183/200
# 31/31 [==============================] - 18s 572ms/step - loss: 0.7701 - rpn_score_accuracy: 0.7515 - cls_logits_accuracy: 0.8732 - rpn_score_loss: 0.0446 - rpn_regress_loss: 0.0850 - cls_logits_loss: 0.0851 - cls_regress_loss: 0.3384 - cls_mask_loss: 0.2168 - val_loss: 2.1523 - val_rpn_score_accuracy: 0.6071 - val_cls_logits_accuracy: 0.8485 - val_rpn_score_loss: 0.7323 - val_rpn_regress_loss: 0.3562 - val_cls_logits_loss: 0.1047 - val_cls_regress_loss: 0.5144 - val_cls_mask_loss: 0.4447
# Epoch 184/200
# 31/31 [==============================] - 18s 574ms/step - loss: 0.8383 - rpn_score_accuracy: 0.7199 - cls_logits_accuracy: 0.8699 - rpn_score_loss: 0.0525 - rpn_regress_loss: 0.0942 - cls_logits_loss: 0.0821 - cls_regress_loss: 0.3688 - cls_mask_loss: 0.2407 - val_loss: 2.1425 - val_rpn_score_accuracy: 0.6071 - val_cls_logits_accuracy: 0.8621 - val_rpn_score_loss: 0.7255 - val_rpn_regress_loss: 0.3724 - val_cls_logits_loss: 0.1005 - val_cls_regress_loss: 0.5257 - val_cls_mask_loss: 0.4184
# Epoch 185/200
# 31/31 [==============================] - 18s 572ms/step - loss: 0.7645 - rpn_score_accuracy: 0.8005 - cls_logits_accuracy: 0.8814 - rpn_score_loss: 0.0145 - rpn_regress_loss: 0.0931 - cls_logits_loss: 0.0794 - cls_regress_loss: 0.3578 - cls_mask_loss: 0.2197 - val_loss: 2.1425 - val_rpn_score_accuracy: 0.6071 - val_cls_logits_accuracy: 0.8676 - val_rpn_score_loss: 0.7013 - val_rpn_regress_loss: 0.3804 - val_cls_logits_loss: 0.0980 - val_cls_regress_loss: 0.5222 - val_cls_mask_loss: 0.4406
# Epoch 186/200
# 31/31 [==============================] - 18s 575ms/step - loss: 0.8969 - rpn_score_accuracy: 0.7763 - cls_logits_accuracy: 0.8731 - rpn_score_loss: 0.1552 - rpn_regress_loss: 0.0898 - cls_logits_loss: 0.0805 - cls_regress_loss: 0.3504 - cls_mask_loss: 0.2209 - val_loss: 2.2600 - val_rpn_score_accuracy: 0.5714 - val_cls_logits_accuracy: 0.8708 - val_rpn_score_loss: 0.8141 - val_rpn_regress_loss: 0.3815 - val_cls_logits_loss: 0.0876 - val_cls_regress_loss: 0.5163 - val_cls_mask_loss: 0.4604
# Epoch 187/200
# 31/31 [==============================] - 18s 573ms/step - loss: 0.8106 - rpn_score_accuracy: 0.7605 - cls_logits_accuracy: 0.8734 - rpn_score_loss: 0.0575 - rpn_regress_loss: 0.1071 - cls_logits_loss: 0.0801 - cls_regress_loss: 0.3423 - cls_mask_loss: 0.2236 - val_loss: 2.2200 - val_rpn_score_accuracy: 0.6071 - val_cls_logits_accuracy: 0.8597 - val_rpn_score_loss: 0.7889 - val_rpn_regress_loss: 0.3830 - val_cls_logits_loss: 0.0963 - val_cls_regress_loss: 0.5016 - val_cls_mask_loss: 0.4501
# Epoch 188/200
# 31/31 [==============================] - 18s 570ms/step - loss: 0.7790 - rpn_score_accuracy: 0.7352 - cls_logits_accuracy: 0.8789 - rpn_score_loss: 0.0343 - rpn_regress_loss: 0.1003 - cls_logits_loss: 0.0804 - cls_regress_loss: 0.3427 - cls_mask_loss: 0.2213 - val_loss: 2.1690 - val_rpn_score_accuracy: 0.6429 - val_cls_logits_accuracy: 0.8842 - val_rpn_score_loss: 0.7353 - val_rpn_regress_loss: 0.3917 - val_cls_logits_loss: 0.0999 - val_cls_regress_loss: 0.5231 - val_cls_mask_loss: 0.4188
# Epoch 189/200
# 31/31 [==============================] - 18s 574ms/step - loss: 0.7451 - rpn_score_accuracy: 0.7360 - cls_logits_accuracy: 0.8804 - rpn_score_loss: 0.0253 - rpn_regress_loss: 0.0945 - cls_logits_loss: 0.0796 - cls_regress_loss: 0.3312 - cls_mask_loss: 0.2145 - val_loss: 2.1953 - val_rpn_score_accuracy: 0.6286 - val_cls_logits_accuracy: 0.8490 - val_rpn_score_loss: 0.7551 - val_rpn_regress_loss: 0.3856 - val_cls_logits_loss: 0.1005 - val_cls_regress_loss: 0.5146 - val_cls_mask_loss: 0.4396
# Epoch 190/200
# 31/31 [==============================] - 18s 571ms/step - loss: 0.7401 - rpn_score_accuracy: 0.6978 - cls_logits_accuracy: 0.8934 - rpn_score_loss: 0.0307 - rpn_regress_loss: 0.0883 - cls_logits_loss: 0.0736 - cls_regress_loss: 0.3385 - cls_mask_loss: 0.2090 - val_loss: 2.0868 - val_rpn_score_accuracy: 0.6429 - val_cls_logits_accuracy: 0.8585 - val_rpn_score_loss: 0.7141 - val_rpn_regress_loss: 0.3631 - val_cls_logits_loss: 0.0980 - val_cls_regress_loss: 0.5042 - val_cls_mask_loss: 0.4074
# Epoch 191/200
# 31/31 [==============================] - 18s 575ms/step - loss: 0.8014 - rpn_score_accuracy: 0.7738 - cls_logits_accuracy: 0.8778 - rpn_score_loss: 0.0961 - rpn_regress_loss: 0.1046 - cls_logits_loss: 0.0743 - cls_regress_loss: 0.3328 - cls_mask_loss: 0.1937 - val_loss: 2.1189 - val_rpn_score_accuracy: 0.6071 - val_cls_logits_accuracy: 0.8461 - val_rpn_score_loss: 0.7452 - val_rpn_regress_loss: 0.3518 - val_cls_logits_loss: 0.1112 - val_cls_regress_loss: 0.5003 - val_cls_mask_loss: 0.4103
# Epoch 192/200
# 31/31 [==============================] - 18s 570ms/step - loss: 0.7202 - rpn_score_accuracy: 0.7333 - cls_logits_accuracy: 0.8747 - rpn_score_loss: 0.0334 - rpn_regress_loss: 0.0955 - cls_logits_loss: 0.0753 - cls_regress_loss: 0.3218 - cls_mask_loss: 0.1943 - val_loss: 2.2019 - val_rpn_score_accuracy: 0.5393 - val_cls_logits_accuracy: 0.8560 - val_rpn_score_loss: 0.8271 - val_rpn_regress_loss: 0.3705 - val_cls_logits_loss: 0.1018 - val_cls_regress_loss: 0.4906 - val_cls_mask_loss: 0.4119
# Epoch 193/200
# 31/31 [==============================] - 18s 571ms/step - loss: 0.7521 - rpn_score_accuracy: 0.6965 - cls_logits_accuracy: 0.8754 - rpn_score_loss: 0.0489 - rpn_regress_loss: 0.0913 - cls_logits_loss: 0.0765 - cls_regress_loss: 0.3299 - cls_mask_loss: 0.2056 - val_loss: 2.1244 - val_rpn_score_accuracy: 0.6071 - val_cls_logits_accuracy: 0.8670 - val_rpn_score_loss: 0.7472 - val_rpn_regress_loss: 0.3872 - val_cls_logits_loss: 0.0957 - val_cls_regress_loss: 0.4977 - val_cls_mask_loss: 0.3965
# Epoch 194/200
# 31/31 [==============================] - 18s 573ms/step - loss: 0.7856 - rpn_score_accuracy: 0.7175 - cls_logits_accuracy: 0.8797 - rpn_score_loss: 0.0697 - rpn_regress_loss: 0.0976 - cls_logits_loss: 0.0792 - cls_regress_loss: 0.3360 - cls_mask_loss: 0.2031 - val_loss: 2.2133 - val_rpn_score_accuracy: 0.6071 - val_cls_logits_accuracy: 0.8552 - val_rpn_score_loss: 0.7713 - val_rpn_regress_loss: 0.4089 - val_cls_logits_loss: 0.1012 - val_cls_regress_loss: 0.4618 - val_cls_mask_loss: 0.4702
# Epoch 195/200
# 31/31 [==============================] - 18s 575ms/step - loss: 0.7654 - rpn_score_accuracy: 0.7656 - cls_logits_accuracy: 0.8769 - rpn_score_loss: 0.0261 - rpn_regress_loss: 0.0942 - cls_logits_loss: 0.0760 - cls_regress_loss: 0.3625 - cls_mask_loss: 0.2065 - val_loss: 2.3170 - val_rpn_score_accuracy: 0.6071 - val_cls_logits_accuracy: 0.8469 - val_rpn_score_loss: 0.7913 - val_rpn_regress_loss: 0.3834 - val_cls_logits_loss: 0.1080 - val_cls_regress_loss: 0.4925 - val_cls_mask_loss: 0.5417
# Epoch 196/200
# 31/31 [==============================] - 18s 575ms/step - loss: 0.8096 - rpn_score_accuracy: 0.7559 - cls_logits_accuracy: 0.8920 - rpn_score_loss: 0.0473 - rpn_regress_loss: 0.0938 - cls_logits_loss: 0.0672 - cls_regress_loss: 0.3729 - cls_mask_loss: 0.2283 - val_loss: 2.2796 - val_rpn_score_accuracy: 0.6071 - val_cls_logits_accuracy: 0.8481 - val_rpn_score_loss: 0.7837 - val_rpn_regress_loss: 0.3906 - val_cls_logits_loss: 0.1041 - val_cls_regress_loss: 0.5602 - val_cls_mask_loss: 0.4410
# Epoch 197/200
# 31/31 [==============================] - 18s 573ms/step - loss: 0.7387 - rpn_score_accuracy: 0.6923 - cls_logits_accuracy: 0.8925 - rpn_score_loss: 0.0318 - rpn_regress_loss: 0.0836 - cls_logits_loss: 0.0737 - cls_regress_loss: 0.3302 - cls_mask_loss: 0.2193 - val_loss: 2.3114 - val_rpn_score_accuracy: 0.6071 - val_cls_logits_accuracy: 0.8542 - val_rpn_score_loss: 0.8034 - val_rpn_regress_loss: 0.3982 - val_cls_logits_loss: 0.0977 - val_cls_regress_loss: 0.5436 - val_cls_mask_loss: 0.4685
# Epoch 198/200
# 31/31 [==============================] - 18s 576ms/step - loss: 0.7753 - rpn_score_accuracy: 0.7217 - cls_logits_accuracy: 0.8930 - rpn_score_loss: 0.0599 - rpn_regress_loss: 0.0857 - cls_logits_loss: 0.0761 - cls_regress_loss: 0.3413 - cls_mask_loss: 0.2123 - val_loss: 2.2896 - val_rpn_score_accuracy: 0.6071 - val_cls_logits_accuracy: 0.8510 - val_rpn_score_loss: 0.8346 - val_rpn_regress_loss: 0.4136 - val_cls_logits_loss: 0.0902 - val_cls_regress_loss: 0.5342 - val_cls_mask_loss: 0.4170
# Epoch 199/200
# 31/31 [==============================] - 18s 577ms/step - loss: 0.7113 - rpn_score_accuracy: 0.6675 - cls_logits_accuracy: 0.8762 - rpn_score_loss: 0.0261 - rpn_regress_loss: 0.0787 - cls_logits_loss: 0.0750 - cls_regress_loss: 0.3229 - cls_mask_loss: 0.2086 - val_loss: 2.2547 - val_rpn_score_accuracy: 0.6429 - val_cls_logits_accuracy: 0.8508 - val_rpn_score_loss: 0.7737 - val_rpn_regress_loss: 0.4314 - val_cls_logits_loss: 0.1074 - val_cls_regress_loss: 0.5092 - val_cls_mask_loss: 0.4331
# Epoch 200/200
# 31/31 [==============================] - 18s 574ms/step - loss: 0.7124 - rpn_score_accuracy: 0.7312 - cls_logits_accuracy: 0.8527 - rpn_score_loss: 0.0652 - rpn_regress_loss: 0.0851 - cls_logits_loss: 0.0747 - cls_regress_loss: 0.2990 - cls_mask_loss: 0.1884 - val_loss: 2.2524 - val_rpn_score_accuracy: 0.6429 - val_cls_logits_accuracy: 0.8620 - val_rpn_score_loss: 0.7540 - val_rpn_regress_loss: 0.3920 - val_cls_logits_loss: 0.0903 - val_cls_regress_loss: 0.5298 - val_cls_mask_loss: 0.4864

# %%
model.save_weights("model.h5")

# %%
x = tf.keras.layers.Input(shape = (512, 512, 3))
feature = tfdet.model.backbone.resnet50(x)
scale = [0.03125, 0.0625, 0.125, 0.25, 0.5] #[16, 32, 64, 128, 256]
ratio = [0.5, 1, 2]
bifpn = functools.partial(tfdet.model.neck.bifpn, weighted_add = False)
neck = functools.partial(tfdet.model.neck.FeatureAlign, pre_sampling = False, neck = bifpn)
out = tfdet.model.detector.mask_rcnn(feature, n_class = 2, image_shape = tf.shape(x)[1:3], mask = True, cascade = False, scale = scale, ratio = ratio, soft_nms = False, neck = neck, proposal_count = 1000)
prediction = tfdet.model.postprocess.rcnn.FilterDetection(proposal_count = 100, iou_threshold = 0.3, score_threshold = 0.7, soft_nms = False)(out)
model = tf.keras.Model(x, prediction)
model.load_weights("model.h5")

# %%
images = te_x[:1]
logits, proposal, mask = model.predict(images)
images = tfdet.util.draw_bbox(images, proposal, logits, mask, label = ["Background", "Balloon"])

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (10, 10))
plt.imshow(images[0])
