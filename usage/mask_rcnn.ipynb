# %%
import os, shutil
if os.path.exists(os.path.join(os.getcwd(),"tfdetection")):
    shutil.rmtree(os.path.join(os.getcwd(),"tfdetection"))
if os.path.exists(os.path.join(os.getcwd(),"tfdet")):
    shutil.rmtree(os.path.join(os.getcwd(),"tfdet"))
# !git clone https://github.com/burf/tfdetection
shutil.copytree(os.path.join(os.getcwd(),"tfdetection", "tfdet"), os.path.join(os.getcwd(),"tfdet"))
# Out:
# Cloning into 'tfdetection'...
# remote: Enumerating objects: 788, done.
# remote: Counting objects: 100% (401/401), done.
# remote: Compressing objects: 100% (246/246), done.
# remote: Total 788 (delta 240), reused 276 (delta 155), pack-reused 387
# Receiving objects: 100% (788/788), 8.62 MiB | 21.23 MiB/s, done.
# Resolving deltas: 100% (449/449), done.
# '/content/tfdet'

# %%
# !wget -qq https://github.com/matterport/Mask_RCNN/releases/download/v2.1/balloon_dataset.zip
# !unzip -qq balloon_dataset.zip

import os
import json
import cv2
import skimage.draw
import tensorflow as tf
import numpy as np

def parse(path, target_size = (512, 512), method = cv2.INTER_CUBIC):
    dir_path = os.path.dirname(path)
    with open(path, "r") as file:
        anno = json.loads(file.read())
    anno = [a for a in list(anno.values()) if a["regions"]]

    images = []
    masks = []
    for a in anno:
        if type(a['regions']) is dict:
            polygons = [r['shape_attributes'] for r in a['regions'].values()]
        else:
            polygons = [r['shape_attributes'] for r in a['regions']]
        image = cv2.cvtColor(cv2.imread(os.path.join(dir_path, a["filename"]), -1), cv2.COLOR_BGR2RGB)
        h, w = np.shape(image)[:2]
        mask = np.zeros((h, w, len(polygons)), dtype = np.uint8)
        for i, p in enumerate(polygons):
            rr, cc = skimage.draw.polygon(p['all_points_y'], p['all_points_x'])
            rr = np.clip(rr, 0, h - 1)
            cc = np.clip(cc, 0, w - 1)
            mask[rr, cc, i] = 1
        
        if target_size is not None:
            image = cv2.resize(image, target_size[::-1], interpolation = method)
            mask = cv2.resize(mask, target_size[::-1], interpolation = method)
            if np.ndim(mask) == 2:
                mask = np.expand_dims(mask, axis = -1)
            mask = np.where(mask != 0, 1, 0)

        images.append(image)
        masks.append(np.transpose(mask, [2, 0, 1]))
    return images, masks

def mask2bbox(mask_true, normalize = True, decimal = 4):
    #mask_true = #(padded_num_true, h, w, 1)
    padded_num_true, h, w = np.shape(mask_true)[:3]

    bbox_true = []
    for index in range(padded_num_true):
        mask = mask_true[index]
        if 0 < np.max(mask):
            pos = np.where(0 < mask)[:2]
            bbox = [np.min(pos[1]), np.min(pos[0]), np.max(pos[1]), np.max(pos[0])] #x1, y1, x2, y2
        else:
            bbox = [0, 0, 0, 0]
        bbox_true.append(bbox)
    
    bbox_true = np.round(np.divide(bbox_true, [w, h, w, h]).astype(np.float32), decimal) if normalize else np.array(bbox_true, dtype = np.int32)
    return bbox_true

def pipe(data, func = None, batch_size = 2, shuffle = False):
    dataset = tf.data.Dataset.from_tensor_slices(data)
    if callable(func):
        dataset = dataset.map(func, num_parallel_calls = tf.data.experimental.AUTOTUNE)
    if shuffle:
        dataset = dataset.shuffle(buffer_size = batch_size * 10)
    dataset = dataset.batch(batch_size)
    #dataset = dataset.prefetch((batch_size * 2) + 1)
    dataset = dataset.prefetch(tf.data.experimental.AUTOTUNE)
    return dataset

tr_anno = "./balloon/train/via_region_data.json"
te_anno = "./balloon/val/via_region_data.json"

tr_x, tr_mask = parse(tr_anno, target_size = (512, 512))
te_x, te_mask = parse(te_anno, target_size = (512, 512))

max_cnt = 0
for mask in tr_mask + te_mask:
    if max_cnt < len(mask):
        max_cnt = len(mask)

tr_x = np.array(tr_x, dtype = np.float32) * 1/255
tr_mask = [np.pad(mask, [[0, max_cnt - len(mask)], [0, 0], [0, 0]]) for mask in tr_mask]
tr_mask = np.expand_dims(np.array(tr_mask, dtype = np.float32), axis = -1)
tr_bbox = np.array([mask2bbox(mask) for mask in tr_mask], dtype = np.float32)
tr_y = np.expand_dims(np.where(0 < np.max(tr_bbox, axis = -1), 1., 0.), axis = -1)

te_x = np.array(te_x, dtype = np.float32) * 1/255
te_mask = [np.pad(mask, [[0, max_cnt - len(mask)], [0, 0], [0, 0]]) for mask in te_mask]
te_mask = np.expand_dims(np.array(te_mask, dtype = np.float32), axis = -1)
te_bbox = np.array([mask2bbox(mask) for mask in te_mask], dtype = np.float32)
te_y = np.expand_dims(np.where(0 < np.max(te_bbox, axis = -1), 1., 0.), axis = -1)

# %%
import tfdet
import functools

x = tf.keras.layers.Input(shape = (512, 512, 3))
feature = tfdet.model.backbone.resnet50(x)

#scale = [32, 64, 128, 256, 512]
scale = [24, 48, 96, 192, 384]
ratio = [0.5, 1, 2]

bifpn = functools.partial(tfdet.model.neck.bifpn, weighted_add = False)
neck = functools.partial(tfdet.model.neck.FeatureAlign, pre_sampling = False, neck = bifpn)
rpn_assign = functools.partial(tfdet.core.assign.max_iou, positive_threshold = 0.7, negative_threshold = 0.3, min_threshold = 0.3, match_low_quality = True, mode = "normal")
cls_assign = functools.partial(tfdet.core.assign.max_iou, positive_threshold = 0.5, negative_threshold = 0.5, min_threshold = 0.5, match_low_quality = False, mode = "normal")

#sampling_positive_ratio = cls_positive_ratio, sampling_positive_threshold = cls_positive_threshold, sampling_negative_threshold = cls_negative_threshold
out = tfdet.model.detector.mask_rcnn(feature, n_class = 2, image_shape = tf.shape(x)[1:3], scale = scale, ratio = ratio, soft_nms = False, neck = neck,
                                       proposal_count = 2000, sampling_assign = cls_assign, sampling_count = 256, sampling_positive_ratio = 0.25)

#out > rpn_score, rpn_regress, cls_logits, cls_regress, proposals, anchors, mask_regress(is removed by mask{=False}), semantic_regress(is removed by semantic_feature{=False}), sampling_tag(is removed by sampling_count{=None or 0})
model = tfdet.model.train.rcnn.train_model(x, *out, rpn_assign = rpn_assign, rpn_positive_ratio = 0.5)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 0s 0us/step
# 94781440/94765736 [==============================] - 0s 0us/step
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/deprecation.py:616: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead

# %%
import albumentations
method = [albumentations.RandomBrightness(0.2, p = 0.5),
          albumentations.RandomContrast(0.2, p = 0.5),
          albumentations.ChannelShuffle(p = 0.5)]
method = albumentations.Compose(method)
    
def aug_func(image):
    return method(image = image)["image"]

key = x.name
def func(dic):
    shape = tf.shape(dic[key])
    dic[key] = tf.reshape(tf.py_function(lambda *args: aug_func(args[0].numpy()), inp = [dic[key]], Tout = tf.float32), shape)
    return dic

batch_size = 2

tr_data = pipe({x.name:tr_x, "y_true":tr_y, "bbox_true":tr_bbox, "mask_true":tr_mask}, func = func, batch_size = batch_size, shuffle = True)
te_data = pipe({x.name:te_x, "y_true":te_y, "bbox_true":te_bbox, "mask_true":te_mask}, batch_size = batch_size, shuffle = False)

# %%
opt = tf.keras.optimizers.SGD(5e-3, momentum = 0.9, nesterov = True)
model.compile(optimizer = opt)
model.fit(tr_data, validation_data = te_data, epochs = 100)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/cls_target/map/while/gradients/model/cls_target/map/while/GatherNd_2_grad/Squeeze:0", shape=(None,), dtype=int64), values=Tensor("gradient_tape/model/cls_target/map/while/gradients/model/cls_target/map/while/Pad_grad/Slice_1:0", shape=(None, 2), dtype=float32), dense_shape=Tensor("model/cls_target/map/while/gradient_tape/model/cls_target/map/while/gradients/model/cls_target/map/while/GatherNd_2_grad/Shape:0", shape=(2,), dtype=int64))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/cls_target/map/while/gradients/model/cls_target/map/while/GatherNd_3_grad/Squeeze:0", shape=(None,), dtype=int64), values=Tensor("gradient_tape/model/cls_target/map/while/gradients/model/cls_target/map/while/GatherNd_7_grad/ScatterNd:0", shape=(None, 2, 4), dtype=float32), dense_shape=Tensor("model/cls_target/map/while/gradient_tape/model/cls_target/map/while/gradients/model/cls_target/map/while/GatherNd_3_grad/Shape:0", shape=(3,), dtype=int64))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/cls_target/map/while/gradients/model/cls_target/map/while/GatherNd_6_grad/Squeeze:0", shape=(None,), dtype=int64), values=Tensor("gradient_tape/model/cls_target/map/while/gradients/model/cls_target/map/while/transpose_grad/transpose:0", shape=(None, 14, 14, 2), dtype=float32), dense_shape=Tensor("model/cls_target/map/while/gradient_tape/model/cls_target/map/while/gradients/model/cls_target/map/while/GatherNd_6_grad/Shape:0", shape=(4,), dtype=int64))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/roi_align/sub:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/roi_align/GatherV2_2:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("gradient_tape/model/roi_align/Shape_2:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/roi_align/sub_1:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/roi_align/GatherV2_5:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("gradient_tape/model/roi_align/Shape_3:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/roi_align/sub_2:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/roi_align/GatherV2_8:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("gradient_tape/model/roi_align/Shape_4:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/roi_align/sub_3:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/roi_align/GatherV2_11:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("gradient_tape/model/roi_align/Shape_5:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/roi_align_1/sub:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/roi_align_1/GatherV2_2:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("gradient_tape/model/roi_align_1/Shape_2:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/roi_align_1/sub_1:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/roi_align_1/GatherV2_5:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("gradient_tape/model/roi_align_1/Shape_3:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/roi_align_1/sub_2:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/roi_align_1/GatherV2_8:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("gradient_tape/model/roi_align_1/Shape_4:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/roi_align_1/sub_3:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/roi_align_1/GatherV2_11:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("gradient_tape/model/roi_align_1/Shape_5:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# 31/31 [==============================] - 64s 853ms/step - loss: 14.7325 - rpn_score_accuracy: 0.6957 - cls_logits_accuracy: 0.7057 - rpn_score_loss: 0.6212 - rpn_regress_loss: 1.2996 - cls_logits_loss: 3.8705 - cls_regress_loss: 8.2094 - cls_mask_loss: 0.7318 - val_loss: 496771855810560.0000 - val_rpn_score_accuracy: 0.5948 - val_cls_logits_accuracy: 0.0000e+00 - val_rpn_score_loss: 6.2104 - val_rpn_regress_loss: 496771855810560.0000 - val_cls_logits_loss: 0.0000e+00 - val_cls_regress_loss: 0.0000e+00 - val_cls_mask_loss: 0.0000e+00
# Epoch 2/100
# 31/31 [==============================] - 17s 552ms/step - loss: 7.4671 - rpn_score_accuracy: 0.8392 - cls_logits_accuracy: 0.6284 - rpn_score_loss: 0.5281 - rpn_regress_loss: 1.0423 - cls_logits_loss: 1.5697 - cls_regress_loss: 3.7219 - cls_mask_loss: 0.6051 - val_loss: 84584.8828 - val_rpn_score_accuracy: 0.7940 - val_cls_logits_accuracy: 0.0000e+00 - val_rpn_score_loss: 3.1680 - val_rpn_regress_loss: 84581.7109 - val_cls_logits_loss: 0.0000e+00 - val_cls_regress_loss: 0.0000e+00 - val_cls_mask_loss: 0.0000e+00
# Epoch 3/100
# 31/31 [==============================] - 18s 567ms/step - loss: 4.3585 - rpn_score_accuracy: 0.8354 - cls_logits_accuracy: 0.6501 - rpn_score_loss: 0.4358 - rpn_regress_loss: 0.7244 - cls_logits_loss: 1.6856 - cls_regress_loss: 0.9441 - cls_mask_loss: 0.5686 - val_loss: 2.9764 - val_rpn_score_accuracy: 0.6726 - val_cls_logits_accuracy: 0.3214 - val_rpn_score_loss: 0.6986 - val_rpn_regress_loss: 0.7078 - val_cls_logits_loss: 0.8896 - val_cls_regress_loss: 0.3885 - val_cls_mask_loss: 0.2919
# Epoch 4/100
# 31/31 [==============================] - 18s 576ms/step - loss: 3.3948 - rpn_score_accuracy: 0.8750 - cls_logits_accuracy: 0.6467 - rpn_score_loss: 0.3305 - rpn_regress_loss: 0.6383 - cls_logits_loss: 0.9837 - cls_regress_loss: 0.8728 - cls_mask_loss: 0.5695 - val_loss: 3.2746 - val_rpn_score_accuracy: 0.7701 - val_cls_logits_accuracy: 0.2500 - val_rpn_score_loss: 0.6323 - val_rpn_regress_loss: 0.6928 - val_cls_logits_loss: 0.3768 - val_cls_regress_loss: 0.9828 - val_cls_mask_loss: 0.5900
# Epoch 5/100
# 31/31 [==============================] - 18s 589ms/step - loss: 4.9673 - rpn_score_accuracy: 0.8810 - cls_logits_accuracy: 0.5834 - rpn_score_loss: 0.3315 - rpn_regress_loss: 0.4878 - cls_logits_loss: 1.5284 - cls_regress_loss: 2.0642 - cls_mask_loss: 0.5553 - val_loss: 6.4876 - val_rpn_score_accuracy: 0.8090 - val_cls_logits_accuracy: 0.7500 - val_rpn_score_loss: 0.5062 - val_rpn_regress_loss: 0.6275 - val_cls_logits_loss: 3.3938 - val_cls_regress_loss: 1.3809 - val_cls_mask_loss: 0.5792
# Epoch 6/100
# 31/31 [==============================] - 18s 593ms/step - loss: 8.1853 - rpn_score_accuracy: 0.8904 - cls_logits_accuracy: 0.7500 - rpn_score_loss: 0.2934 - rpn_regress_loss: 0.5243 - cls_logits_loss: 3.9554 - cls_regress_loss: 2.8306 - cls_mask_loss: 0.5815 - val_loss: 7.0097 - val_rpn_score_accuracy: 0.8236 - val_cls_logits_accuracy: 0.7500 - val_rpn_score_loss: 0.5330 - val_rpn_regress_loss: 0.6886 - val_cls_logits_loss: 4.0295 - val_cls_regress_loss: 1.1681 - val_cls_mask_loss: 0.5904
# Epoch 7/100
# 31/31 [==============================] - 18s 588ms/step - loss: 6.5893 - rpn_score_accuracy: 0.8929 - cls_logits_accuracy: 0.7500 - rpn_score_loss: 0.3065 - rpn_regress_loss: 0.7471 - cls_logits_loss: 4.0295 - cls_regress_loss: 0.9518 - cls_mask_loss: 0.5543 - val_loss: 6.4855 - val_rpn_score_accuracy: 0.8096 - val_cls_logits_accuracy: 0.7500 - val_rpn_score_loss: 0.5567 - val_rpn_regress_loss: 0.6540 - val_cls_logits_loss: 4.0295 - val_cls_regress_loss: 0.6709 - val_cls_mask_loss: 0.5743
# Epoch 8/100
# 31/31 [==============================] - 18s 574ms/step - loss: 6.5996 - rpn_score_accuracy: 0.8524 - cls_logits_accuracy: 0.7258 - rpn_score_loss: 0.4875 - rpn_regress_loss: 0.6741 - cls_logits_loss: 3.8995 - cls_regress_loss: 0.9896 - cls_mask_loss: 0.5489 - val_loss: 7.2420 - val_rpn_score_accuracy: 0.7827 - val_cls_logits_accuracy: 0.7500 - val_rpn_score_loss: 0.6497 - val_rpn_regress_loss: 0.7505 - val_cls_logits_loss: 4.0295 - val_cls_regress_loss: 1.2351 - val_cls_mask_loss: 0.5772
# Epoch 9/100
# 31/31 [==============================] - 18s 579ms/step - loss: 6.5538 - rpn_score_accuracy: 0.8903 - cls_logits_accuracy: 0.7258 - rpn_score_loss: 0.3176 - rpn_regress_loss: 0.6163 - cls_logits_loss: 3.8996 - cls_regress_loss: 1.1852 - cls_mask_loss: 0.5351 - val_loss: 6.6865 - val_rpn_score_accuracy: 0.8016 - val_cls_logits_accuracy: 0.7500 - val_rpn_score_loss: 0.6004 - val_rpn_regress_loss: 0.7570 - val_cls_logits_loss: 4.0295 - val_cls_regress_loss: 0.7523 - val_cls_mask_loss: 0.5473
# Epoch 10/100
# 31/31 [==============================] - 18s 581ms/step - loss: 6.3119 - rpn_score_accuracy: 0.8683 - cls_logits_accuracy: 0.7498 - rpn_score_loss: 0.3181 - rpn_regress_loss: 0.6134 - cls_logits_loss: 4.0272 - cls_regress_loss: 0.8074 - cls_mask_loss: 0.5458 - val_loss: 6.8423 - val_rpn_score_accuracy: 0.8289 - val_cls_logits_accuracy: 0.7500 - val_rpn_score_loss: 0.5298 - val_rpn_regress_loss: 0.8786 - val_cls_logits_loss: 4.0295 - val_cls_regress_loss: 0.8530 - val_cls_mask_loss: 0.5513
# Epoch 11/100
# 31/31 [==============================] - 18s 580ms/step - loss: 6.1066 - rpn_score_accuracy: 0.8901 - cls_logits_accuracy: 0.7500 - rpn_score_loss: 0.2879 - rpn_regress_loss: 0.4748 - cls_logits_loss: 4.0295 - cls_regress_loss: 0.7675 - cls_mask_loss: 0.5468 - val_loss: 7.1895 - val_rpn_score_accuracy: 0.8102 - val_cls_logits_accuracy: 0.7500 - val_rpn_score_loss: 0.6201 - val_rpn_regress_loss: 0.8066 - val_cls_logits_loss: 4.0295 - val_cls_regress_loss: 1.2018 - val_cls_mask_loss: 0.5314
# Epoch 12/100
# 31/31 [==============================] - 18s 586ms/step - loss: 6.1955 - rpn_score_accuracy: 0.9158 - cls_logits_accuracy: 0.7493 - rpn_score_loss: 0.2324 - rpn_regress_loss: 0.5342 - cls_logits_loss: 4.0305 - cls_regress_loss: 0.8494 - cls_mask_loss: 0.5488 - val_loss: 6.5576 - val_rpn_score_accuracy: 0.8236 - val_cls_logits_accuracy: 0.7500 - val_rpn_score_loss: 0.5053 - val_rpn_regress_loss: 0.7267 - val_cls_logits_loss: 4.0295 - val_cls_regress_loss: 0.7606 - val_cls_mask_loss: 0.5354
# Epoch 13/100
# 31/31 [==============================] - 18s 587ms/step - loss: 6.1851 - rpn_score_accuracy: 0.9031 - cls_logits_accuracy: 0.7500 - rpn_score_loss: 0.2768 - rpn_regress_loss: 0.5490 - cls_logits_loss: 4.0295 - cls_regress_loss: 0.7928 - cls_mask_loss: 0.5370 - val_loss: 8.4614 - val_rpn_score_accuracy: 0.7771 - val_cls_logits_accuracy: 0.7500 - val_rpn_score_loss: 0.5275 - val_rpn_regress_loss: 0.7348 - val_cls_logits_loss: 4.0295 - val_cls_regress_loss: 2.6506 - val_cls_mask_loss: 0.5190
# Epoch 14/100
# 31/31 [==============================] - 18s 578ms/step - loss: 6.8204 - rpn_score_accuracy: 0.9039 - cls_logits_accuracy: 0.7491 - rpn_score_loss: 0.2465 - rpn_regress_loss: 0.4930 - cls_logits_loss: 4.0294 - cls_regress_loss: 1.4990 - cls_mask_loss: 0.5525 - val_loss: 7.1906 - val_rpn_score_accuracy: 0.7966 - val_cls_logits_accuracy: 0.7500 - val_rpn_score_loss: 0.5459 - val_rpn_regress_loss: 0.6847 - val_cls_logits_loss: 4.0295 - val_cls_regress_loss: 1.3701 - val_cls_mask_loss: 0.5603
# Epoch 15/100
# 31/31 [==============================] - 18s 575ms/step - loss: 5.7130 - rpn_score_accuracy: 0.8789 - cls_logits_accuracy: 0.7240 - rpn_score_loss: 0.3361 - rpn_regress_loss: 0.5288 - cls_logits_loss: 2.5697 - cls_regress_loss: 1.7095 - cls_mask_loss: 0.5688 - val_loss: 6.9949 - val_rpn_score_accuracy: 0.7872 - val_cls_logits_accuracy: 0.7500 - val_rpn_score_loss: 0.7447 - val_rpn_regress_loss: 0.7493 - val_cls_logits_loss: 4.0295 - val_cls_regress_loss: 0.9444 - val_cls_mask_loss: 0.5268
# Epoch 16/100
# 31/31 [==============================] - 18s 574ms/step - loss: 5.5481 - rpn_score_accuracy: 0.8689 - cls_logits_accuracy: 0.7112 - rpn_score_loss: 0.3622 - rpn_regress_loss: 0.5152 - cls_logits_loss: 2.5730 - cls_regress_loss: 1.5232 - cls_mask_loss: 0.5745 - val_loss: 6.7721 - val_rpn_score_accuracy: 0.7573 - val_cls_logits_accuracy: 0.7500 - val_rpn_score_loss: 0.6240 - val_rpn_regress_loss: 0.6525 - val_cls_logits_loss: 4.0295 - val_cls_regress_loss: 0.9135 - val_cls_mask_loss: 0.5525
# Epoch 17/100
# 31/31 [==============================] - 18s 577ms/step - loss: 4.3838 - rpn_score_accuracy: 0.8745 - cls_logits_accuracy: 0.6469 - rpn_score_loss: 0.3873 - rpn_regress_loss: 0.6149 - cls_logits_loss: 1.5777 - cls_regress_loss: 1.2685 - cls_mask_loss: 0.5354 - val_loss: 6.5558 - val_rpn_score_accuracy: 0.8107 - val_cls_logits_accuracy: 0.7500 - val_rpn_score_loss: 0.5767 - val_rpn_regress_loss: 0.6321 - val_cls_logits_loss: 4.0295 - val_cls_regress_loss: 0.7659 - val_cls_mask_loss: 0.5515
# Epoch 18/100
# 31/31 [==============================] - 18s 583ms/step - loss: 4.3401 - rpn_score_accuracy: 0.8985 - cls_logits_accuracy: 0.6248 - rpn_score_loss: 0.2864 - rpn_regress_loss: 0.5473 - cls_logits_loss: 1.3722 - cls_regress_loss: 1.5946 - cls_mask_loss: 0.5395 - val_loss: 6.4993 - val_rpn_score_accuracy: 0.8204 - val_cls_logits_accuracy: 0.7500 - val_rpn_score_loss: 0.4720 - val_rpn_regress_loss: 0.7111 - val_cls_logits_loss: 4.0295 - val_cls_regress_loss: 0.7162 - val_cls_mask_loss: 0.5705
# Epoch 19/100
# 31/31 [==============================] - 18s 584ms/step - loss: 3.4326 - rpn_score_accuracy: 0.8839 - cls_logits_accuracy: 0.6807 - rpn_score_loss: 0.3364 - rpn_regress_loss: 0.4482 - cls_logits_loss: 1.2135 - cls_regress_loss: 0.9009 - cls_mask_loss: 0.5336 - val_loss: 6.6114 - val_rpn_score_accuracy: 0.8112 - val_cls_logits_accuracy: 0.7500 - val_rpn_score_loss: 0.5930 - val_rpn_regress_loss: 0.6966 - val_cls_logits_loss: 4.0295 - val_cls_regress_loss: 0.7156 - val_cls_mask_loss: 0.5766
# Epoch 20/100
# 31/31 [==============================] - 18s 571ms/step - loss: 2.8617 - rpn_score_accuracy: 0.8582 - cls_logits_accuracy: 0.6552 - rpn_score_loss: 0.4036 - rpn_regress_loss: 0.4654 - cls_logits_loss: 0.7743 - cls_regress_loss: 0.7281 - cls_mask_loss: 0.4903 - val_loss: 6.4793 - val_rpn_score_accuracy: 0.8225 - val_cls_logits_accuracy: 0.7500 - val_rpn_score_loss: 0.5537 - val_rpn_regress_loss: 0.6908 - val_cls_logits_loss: 4.0082 - val_cls_regress_loss: 0.6580 - val_cls_mask_loss: 0.5685
# Epoch 21/100
# 31/31 [==============================] - 18s 579ms/step - loss: 2.7254 - rpn_score_accuracy: 0.8902 - cls_logits_accuracy: 0.7042 - rpn_score_loss: 0.3374 - rpn_regress_loss: 0.5761 - cls_logits_loss: 0.4084 - cls_regress_loss: 0.8657 - cls_mask_loss: 0.5378 - val_loss: 5.6806 - val_rpn_score_accuracy: 0.8264 - val_cls_logits_accuracy: 0.7500 - val_rpn_score_loss: 0.4456 - val_rpn_regress_loss: 0.6636 - val_cls_logits_loss: 3.2776 - val_cls_regress_loss: 0.7194 - val_cls_mask_loss: 0.5743
# Epoch 22/100
# 31/31 [==============================] - 18s 580ms/step - loss: 2.2165 - rpn_score_accuracy: 0.8928 - cls_logits_accuracy: 0.6531 - rpn_score_loss: 0.2484 - rpn_regress_loss: 0.4631 - cls_logits_loss: 0.2846 - cls_regress_loss: 0.6978 - cls_mask_loss: 0.5225 - val_loss: 4.7498 - val_rpn_score_accuracy: 0.8349 - val_cls_logits_accuracy: 0.7500 - val_rpn_score_loss: 0.4338 - val_rpn_regress_loss: 0.6298 - val_cls_logits_loss: 2.4127 - val_cls_regress_loss: 0.6898 - val_cls_mask_loss: 0.5837
# Epoch 23/100
# 31/31 [==============================] - 18s 577ms/step - loss: 2.3806 - rpn_score_accuracy: 0.9079 - cls_logits_accuracy: 0.6872 - rpn_score_loss: 0.2475 - rpn_regress_loss: 0.4430 - cls_logits_loss: 0.3960 - cls_regress_loss: 0.7627 - cls_mask_loss: 0.5313 - val_loss: 3.6917 - val_rpn_score_accuracy: 0.8424 - val_cls_logits_accuracy: 0.7500 - val_rpn_score_loss: 0.3974 - val_rpn_regress_loss: 0.6225 - val_cls_logits_loss: 1.4392 - val_cls_regress_loss: 0.6539 - val_cls_mask_loss: 0.5788
# Epoch 24/100
# 31/31 [==============================] - 18s 579ms/step - loss: 2.2251 - rpn_score_accuracy: 0.9085 - cls_logits_accuracy: 0.7008 - rpn_score_loss: 0.2256 - rpn_regress_loss: 0.4245 - cls_logits_loss: 0.3002 - cls_regress_loss: 0.7504 - cls_mask_loss: 0.5243 - val_loss: 3.1304 - val_rpn_score_accuracy: 0.8127 - val_cls_logits_accuracy: 0.7500 - val_rpn_score_loss: 0.4646 - val_rpn_regress_loss: 0.6466 - val_cls_logits_loss: 0.7894 - val_cls_regress_loss: 0.6758 - val_cls_mask_loss: 0.5540
# Epoch 25/100
# 31/31 [==============================] - 18s 578ms/step - loss: 2.3021 - rpn_score_accuracy: 0.8807 - cls_logits_accuracy: 0.6481 - rpn_score_loss: 0.3185 - rpn_regress_loss: 0.4067 - cls_logits_loss: 0.3203 - cls_regress_loss: 0.7386 - cls_mask_loss: 0.5178 - val_loss: 2.9253 - val_rpn_score_accuracy: 0.7764 - val_cls_logits_accuracy: 0.7500 - val_rpn_score_loss: 0.5053 - val_rpn_regress_loss: 0.6368 - val_cls_logits_loss: 0.5033 - val_cls_regress_loss: 0.7341 - val_cls_mask_loss: 0.5458
# Epoch 26/100
# 31/31 [==============================] - 18s 577ms/step - loss: 2.0360 - rpn_score_accuracy: 0.9058 - cls_logits_accuracy: 0.7266 - rpn_score_loss: 0.2377 - rpn_regress_loss: 0.4398 - cls_logits_loss: 0.1954 - cls_regress_loss: 0.6546 - cls_mask_loss: 0.5084 - val_loss: 2.4411 - val_rpn_score_accuracy: 0.8538 - val_cls_logits_accuracy: 0.7355 - val_rpn_score_loss: 0.4333 - val_rpn_regress_loss: 0.6355 - val_cls_logits_loss: 0.1459 - val_cls_regress_loss: 0.6894 - val_cls_mask_loss: 0.5370
# Epoch 27/100
# 31/31 [==============================] - 18s 577ms/step - loss: 2.0057 - rpn_score_accuracy: 0.8849 - cls_logits_accuracy: 0.7227 - rpn_score_loss: 0.2619 - rpn_regress_loss: 0.4002 - cls_logits_loss: 0.1981 - cls_regress_loss: 0.6503 - cls_mask_loss: 0.4952 - val_loss: 2.4767 - val_rpn_score_accuracy: 0.8470 - val_cls_logits_accuracy: 0.7500 - val_rpn_score_loss: 0.4803 - val_rpn_regress_loss: 0.6282 - val_cls_logits_loss: 0.1388 - val_cls_regress_loss: 0.7066 - val_cls_mask_loss: 0.5228
# Epoch 28/100
# 31/31 [==============================] - 18s 575ms/step - loss: 2.0292 - rpn_score_accuracy: 0.9172 - cls_logits_accuracy: 0.7180 - rpn_score_loss: 0.2400 - rpn_regress_loss: 0.4015 - cls_logits_loss: 0.1985 - cls_regress_loss: 0.6684 - cls_mask_loss: 0.5207 - val_loss: 2.4879 - val_rpn_score_accuracy: 0.8478 - val_cls_logits_accuracy: 0.7471 - val_rpn_score_loss: 0.5001 - val_rpn_regress_loss: 0.6512 - val_cls_logits_loss: 0.1356 - val_cls_regress_loss: 0.6861 - val_cls_mask_loss: 0.5149
# Epoch 29/100
# 31/31 [==============================] - 18s 578ms/step - loss: 2.1139 - rpn_score_accuracy: 0.9228 - cls_logits_accuracy: 0.7306 - rpn_score_loss: 0.2208 - rpn_regress_loss: 0.3825 - cls_logits_loss: 0.1988 - cls_regress_loss: 0.8047 - cls_mask_loss: 0.5070 - val_loss: 2.4363 - val_rpn_score_accuracy: 0.8229 - val_cls_logits_accuracy: 0.7457 - val_rpn_score_loss: 0.4793 - val_rpn_regress_loss: 0.5969 - val_cls_logits_loss: 0.1448 - val_cls_regress_loss: 0.7065 - val_cls_mask_loss: 0.5088
# Epoch 30/100
# 31/31 [==============================] - 18s 578ms/step - loss: 1.9279 - rpn_score_accuracy: 0.9214 - cls_logits_accuracy: 0.7332 - rpn_score_loss: 0.2203 - rpn_regress_loss: 0.4130 - cls_logits_loss: 0.1751 - cls_regress_loss: 0.6373 - cls_mask_loss: 0.4822 - val_loss: 2.3443 - val_rpn_score_accuracy: 0.8396 - val_cls_logits_accuracy: 0.7386 - val_rpn_score_loss: 0.4124 - val_rpn_regress_loss: 0.6162 - val_cls_logits_loss: 0.1452 - val_cls_regress_loss: 0.6760 - val_cls_mask_loss: 0.4944
# Epoch 31/100
# 31/31 [==============================] - 18s 576ms/step - loss: 1.9473 - rpn_score_accuracy: 0.9126 - cls_logits_accuracy: 0.7302 - rpn_score_loss: 0.2314 - rpn_regress_loss: 0.3410 - cls_logits_loss: 0.2400 - cls_regress_loss: 0.6416 - cls_mask_loss: 0.4933 - val_loss: 2.4908 - val_rpn_score_accuracy: 0.7940 - val_cls_logits_accuracy: 0.7500 - val_rpn_score_loss: 0.5262 - val_rpn_regress_loss: 0.6119 - val_cls_logits_loss: 0.1347 - val_cls_regress_loss: 0.7192 - val_cls_mask_loss: 0.4988
# Epoch 32/100
# 31/31 [==============================] - 18s 577ms/step - loss: 1.8667 - rpn_score_accuracy: 0.8973 - cls_logits_accuracy: 0.7284 - rpn_score_loss: 0.2383 - rpn_regress_loss: 0.3442 - cls_logits_loss: 0.1478 - cls_regress_loss: 0.6543 - cls_mask_loss: 0.4821 - val_loss: 2.4203 - val_rpn_score_accuracy: 0.8091 - val_cls_logits_accuracy: 0.7404 - val_rpn_score_loss: 0.4970 - val_rpn_regress_loss: 0.6161 - val_cls_logits_loss: 0.1428 - val_cls_regress_loss: 0.6782 - val_cls_mask_loss: 0.4861
# Epoch 33/100
# 31/31 [==============================] - 18s 578ms/step - loss: 1.8396 - rpn_score_accuracy: 0.9245 - cls_logits_accuracy: 0.7504 - rpn_score_loss: 0.1958 - rpn_regress_loss: 0.3871 - cls_logits_loss: 0.1432 - cls_regress_loss: 0.6358 - cls_mask_loss: 0.4776 - val_loss: 2.4371 - val_rpn_score_accuracy: 0.8167 - val_cls_logits_accuracy: 0.7500 - val_rpn_score_loss: 0.5174 - val_rpn_regress_loss: 0.6193 - val_cls_logits_loss: 0.1337 - val_cls_regress_loss: 0.6779 - val_cls_mask_loss: 0.4890
# Epoch 34/100
# 31/31 [==============================] - 18s 576ms/step - loss: 1.9868 - rpn_score_accuracy: 0.8818 - cls_logits_accuracy: 0.7453 - rpn_score_loss: 0.2882 - rpn_regress_loss: 0.4005 - cls_logits_loss: 0.1789 - cls_regress_loss: 0.6519 - cls_mask_loss: 0.4673 - val_loss: 2.6909 - val_rpn_score_accuracy: 0.8019 - val_cls_logits_accuracy: 0.7125 - val_rpn_score_loss: 0.7604 - val_rpn_regress_loss: 0.6037 - val_cls_logits_loss: 0.1409 - val_cls_regress_loss: 0.6931 - val_cls_mask_loss: 0.4928
# Epoch 35/100
# 31/31 [==============================] - 18s 574ms/step - loss: 2.0544 - rpn_score_accuracy: 0.8979 - cls_logits_accuracy: 0.7371 - rpn_score_loss: 0.3250 - rpn_regress_loss: 0.3785 - cls_logits_loss: 0.2487 - cls_regress_loss: 0.6482 - cls_mask_loss: 0.4540 - val_loss: 2.6414 - val_rpn_score_accuracy: 0.8036 - val_cls_logits_accuracy: 0.7376 - val_rpn_score_loss: 0.7007 - val_rpn_regress_loss: 0.6379 - val_cls_logits_loss: 0.1403 - val_cls_regress_loss: 0.6784 - val_cls_mask_loss: 0.4841
# Epoch 36/100
# 31/31 [==============================] - 18s 577ms/step - loss: 1.7952 - rpn_score_accuracy: 0.9052 - cls_logits_accuracy: 0.7361 - rpn_score_loss: 0.2495 - rpn_regress_loss: 0.3302 - cls_logits_loss: 0.1294 - cls_regress_loss: 0.6377 - cls_mask_loss: 0.4484 - val_loss: 2.3395 - val_rpn_score_accuracy: 0.8136 - val_cls_logits_accuracy: 0.7280 - val_rpn_score_loss: 0.5033 - val_rpn_regress_loss: 0.5937 - val_cls_logits_loss: 0.1354 - val_cls_regress_loss: 0.6795 - val_cls_mask_loss: 0.4276
# Epoch 37/100
# 31/31 [==============================] - 18s 579ms/step - loss: 1.8658 - rpn_score_accuracy: 0.9195 - cls_logits_accuracy: 0.7524 - rpn_score_loss: 0.2191 - rpn_regress_loss: 0.3328 - cls_logits_loss: 0.2011 - cls_regress_loss: 0.6485 - cls_mask_loss: 0.4644 - val_loss: 2.3015 - val_rpn_score_accuracy: 0.8297 - val_cls_logits_accuracy: 0.7506 - val_rpn_score_loss: 0.4499 - val_rpn_regress_loss: 0.6096 - val_cls_logits_loss: 0.1341 - val_cls_regress_loss: 0.6576 - val_cls_mask_loss: 0.4503
# Epoch 38/100
# 31/31 [==============================] - 18s 578ms/step - loss: 1.7761 - rpn_score_accuracy: 0.9283 - cls_logits_accuracy: 0.7618 - rpn_score_loss: 0.2137 - rpn_regress_loss: 0.3370 - cls_logits_loss: 0.1424 - cls_regress_loss: 0.6300 - cls_mask_loss: 0.4530 - val_loss: 2.3239 - val_rpn_score_accuracy: 0.8126 - val_cls_logits_accuracy: 0.6957 - val_rpn_score_loss: 0.4647 - val_rpn_regress_loss: 0.6176 - val_cls_logits_loss: 0.1415 - val_cls_regress_loss: 0.6614 - val_cls_mask_loss: 0.4387
# Epoch 39/100
# 31/31 [==============================] - 18s 578ms/step - loss: 1.9575 - rpn_score_accuracy: 0.8883 - cls_logits_accuracy: 0.7607 - rpn_score_loss: 0.2468 - rpn_regress_loss: 0.3646 - cls_logits_loss: 0.2556 - cls_regress_loss: 0.6337 - cls_mask_loss: 0.4567 - val_loss: 2.3367 - val_rpn_score_accuracy: 0.7887 - val_cls_logits_accuracy: 0.7371 - val_rpn_score_loss: 0.4860 - val_rpn_regress_loss: 0.5849 - val_cls_logits_loss: 0.1378 - val_cls_regress_loss: 0.6823 - val_cls_mask_loss: 0.4457
# Epoch 40/100
# 31/31 [==============================] - 18s 581ms/step - loss: 1.7933 - rpn_score_accuracy: 0.9148 - cls_logits_accuracy: 0.7483 - rpn_score_loss: 0.2159 - rpn_regress_loss: 0.3171 - cls_logits_loss: 0.1858 - cls_regress_loss: 0.6355 - cls_mask_loss: 0.4391 - val_loss: 2.4093 - val_rpn_score_accuracy: 0.8224 - val_cls_logits_accuracy: 0.6978 - val_rpn_score_loss: 0.5085 - val_rpn_regress_loss: 0.6485 - val_cls_logits_loss: 0.1421 - val_cls_regress_loss: 0.6634 - val_cls_mask_loss: 0.4468
# Epoch 41/100
# 31/31 [==============================] - 18s 578ms/step - loss: 1.7599 - rpn_score_accuracy: 0.9127 - cls_logits_accuracy: 0.7372 - rpn_score_loss: 0.2173 - rpn_regress_loss: 0.3414 - cls_logits_loss: 0.1246 - cls_regress_loss: 0.6312 - cls_mask_loss: 0.4453 - val_loss: 2.3545 - val_rpn_score_accuracy: 0.8083 - val_cls_logits_accuracy: 0.7642 - val_rpn_score_loss: 0.4876 - val_rpn_regress_loss: 0.6327 - val_cls_logits_loss: 0.1346 - val_cls_regress_loss: 0.6663 - val_cls_mask_loss: 0.4333
# Epoch 42/100
# 31/31 [==============================] - 18s 581ms/step - loss: 1.7562 - rpn_score_accuracy: 0.9137 - cls_logits_accuracy: 0.7636 - rpn_score_loss: 0.2218 - rpn_regress_loss: 0.3195 - cls_logits_loss: 0.1335 - cls_regress_loss: 0.6318 - cls_mask_loss: 0.4495 - val_loss: 2.3253 - val_rpn_score_accuracy: 0.8365 - val_cls_logits_accuracy: 0.7699 - val_rpn_score_loss: 0.4898 - val_rpn_regress_loss: 0.6188 - val_cls_logits_loss: 0.1251 - val_cls_regress_loss: 0.6861 - val_cls_mask_loss: 0.4055
# Epoch 43/100
# 31/31 [==============================] - 18s 581ms/step - loss: 1.7180 - rpn_score_accuracy: 0.9226 - cls_logits_accuracy: 0.7705 - rpn_score_loss: 0.1973 - rpn_regress_loss: 0.3118 - cls_logits_loss: 0.1328 - cls_regress_loss: 0.6283 - cls_mask_loss: 0.4478 - val_loss: 2.3868 - val_rpn_score_accuracy: 0.8199 - val_cls_logits_accuracy: 0.7784 - val_rpn_score_loss: 0.4939 - val_rpn_regress_loss: 0.5979 - val_cls_logits_loss: 0.1266 - val_cls_regress_loss: 0.6731 - val_cls_mask_loss: 0.4952
# Epoch 44/100
# 31/31 [==============================] - 18s 582ms/step - loss: 1.7418 - rpn_score_accuracy: 0.9337 - cls_logits_accuracy: 0.7593 - rpn_score_loss: 0.2109 - rpn_regress_loss: 0.3090 - cls_logits_loss: 0.1709 - cls_regress_loss: 0.6292 - cls_mask_loss: 0.4219 - val_loss: 2.3829 - val_rpn_score_accuracy: 0.8242 - val_cls_logits_accuracy: 0.7681 - val_rpn_score_loss: 0.4949 - val_rpn_regress_loss: 0.6371 - val_cls_logits_loss: 0.1311 - val_cls_regress_loss: 0.7075 - val_cls_mask_loss: 0.4122
# Epoch 45/100
# 31/31 [==============================] - 18s 582ms/step - loss: 1.7323 - rpn_score_accuracy: 0.9108 - cls_logits_accuracy: 0.7716 - rpn_score_loss: 0.2132 - rpn_regress_loss: 0.3170 - cls_logits_loss: 0.1881 - cls_regress_loss: 0.6145 - cls_mask_loss: 0.3994 - val_loss: 2.4898 - val_rpn_score_accuracy: 0.7901 - val_cls_logits_accuracy: 0.6894 - val_rpn_score_loss: 0.5771 - val_rpn_regress_loss: 0.6264 - val_cls_logits_loss: 0.1397 - val_cls_regress_loss: 0.6940 - val_cls_mask_loss: 0.4526
# Epoch 46/100
# 31/31 [==============================] - 18s 581ms/step - loss: 1.6593 - rpn_score_accuracy: 0.9395 - cls_logits_accuracy: 0.7578 - rpn_score_loss: 0.1833 - rpn_regress_loss: 0.3059 - cls_logits_loss: 0.1340 - cls_regress_loss: 0.6126 - cls_mask_loss: 0.4235 - val_loss: 2.4487 - val_rpn_score_accuracy: 0.8134 - val_cls_logits_accuracy: 0.7671 - val_rpn_score_loss: 0.5222 - val_rpn_regress_loss: 0.5948 - val_cls_logits_loss: 0.1311 - val_cls_regress_loss: 0.7011 - val_cls_mask_loss: 0.4995
# Epoch 47/100
# 31/31 [==============================] - 18s 583ms/step - loss: 1.6739 - rpn_score_accuracy: 0.9347 - cls_logits_accuracy: 0.7971 - rpn_score_loss: 0.1922 - rpn_regress_loss: 0.2981 - cls_logits_loss: 0.1491 - cls_regress_loss: 0.6275 - cls_mask_loss: 0.4070 - val_loss: 2.4451 - val_rpn_score_accuracy: 0.7917 - val_cls_logits_accuracy: 0.7549 - val_rpn_score_loss: 0.5230 - val_rpn_regress_loss: 0.6288 - val_cls_logits_loss: 0.1323 - val_cls_regress_loss: 0.7152 - val_cls_mask_loss: 0.4458
# Epoch 48/100
# 31/31 [==============================] - 18s 582ms/step - loss: 1.6646 - rpn_score_accuracy: 0.9318 - cls_logits_accuracy: 0.7620 - rpn_score_loss: 0.1827 - rpn_regress_loss: 0.3078 - cls_logits_loss: 0.1400 - cls_regress_loss: 0.6132 - cls_mask_loss: 0.4209 - val_loss: 2.4198 - val_rpn_score_accuracy: 0.8445 - val_cls_logits_accuracy: 0.7751 - val_rpn_score_loss: 0.5311 - val_rpn_regress_loss: 0.6106 - val_cls_logits_loss: 0.1330 - val_cls_regress_loss: 0.6890 - val_cls_mask_loss: 0.4560
# Epoch 49/100
# 31/31 [==============================] - 18s 584ms/step - loss: 1.6517 - rpn_score_accuracy: 0.9362 - cls_logits_accuracy: 0.7761 - rpn_score_loss: 0.1631 - rpn_regress_loss: 0.2927 - cls_logits_loss: 0.1548 - cls_regress_loss: 0.6337 - cls_mask_loss: 0.4074 - val_loss: 2.3605 - val_rpn_score_accuracy: 0.8357 - val_cls_logits_accuracy: 0.7451 - val_rpn_score_loss: 0.5058 - val_rpn_regress_loss: 0.6006 - val_cls_logits_loss: 0.1354 - val_cls_regress_loss: 0.6783 - val_cls_mask_loss: 0.4405
# Epoch 50/100
# 31/31 [==============================] - 18s 582ms/step - loss: 1.5863 - rpn_score_accuracy: 0.9435 - cls_logits_accuracy: 0.7696 - rpn_score_loss: 0.1510 - rpn_regress_loss: 0.2555 - cls_logits_loss: 0.1421 - cls_regress_loss: 0.6187 - cls_mask_loss: 0.4191 - val_loss: 2.3474 - val_rpn_score_accuracy: 0.8312 - val_cls_logits_accuracy: 0.7884 - val_rpn_score_loss: 0.4694 - val_rpn_regress_loss: 0.6259 - val_cls_logits_loss: 0.1261 - val_cls_regress_loss: 0.6811 - val_cls_mask_loss: 0.4449
# Epoch 51/100
# 31/31 [==============================] - 18s 585ms/step - loss: 1.6282 - rpn_score_accuracy: 0.9201 - cls_logits_accuracy: 0.7828 - rpn_score_loss: 0.2153 - rpn_regress_loss: 0.2615 - cls_logits_loss: 0.1266 - cls_regress_loss: 0.6250 - cls_mask_loss: 0.3998 - val_loss: 2.3146 - val_rpn_score_accuracy: 0.8492 - val_cls_logits_accuracy: 0.7398 - val_rpn_score_loss: 0.4880 - val_rpn_regress_loss: 0.5981 - val_cls_logits_loss: 0.1275 - val_cls_regress_loss: 0.6630 - val_cls_mask_loss: 0.4380
# Epoch 52/100
# 31/31 [==============================] - 18s 585ms/step - loss: 1.6751 - rpn_score_accuracy: 0.9358 - cls_logits_accuracy: 0.7594 - rpn_score_loss: 0.1812 - rpn_regress_loss: 0.2832 - cls_logits_loss: 0.1340 - cls_regress_loss: 0.6432 - cls_mask_loss: 0.4335 - val_loss: 2.3449 - val_rpn_score_accuracy: 0.8172 - val_cls_logits_accuracy: 0.7646 - val_rpn_score_loss: 0.4713 - val_rpn_regress_loss: 0.6088 - val_cls_logits_loss: 0.1306 - val_cls_regress_loss: 0.6593 - val_cls_mask_loss: 0.4749
# Epoch 53/100
# 31/31 [==============================] - 18s 586ms/step - loss: 1.5881 - rpn_score_accuracy: 0.9319 - cls_logits_accuracy: 0.7810 - rpn_score_loss: 0.1745 - rpn_regress_loss: 0.2648 - cls_logits_loss: 0.1223 - cls_regress_loss: 0.6179 - cls_mask_loss: 0.4086 - val_loss: 2.2157 - val_rpn_score_accuracy: 0.8429 - val_cls_logits_accuracy: 0.7883 - val_rpn_score_loss: 0.4773 - val_rpn_regress_loss: 0.5872 - val_cls_logits_loss: 0.1218 - val_cls_regress_loss: 0.6554 - val_cls_mask_loss: 0.3740
# Epoch 54/100
# 31/31 [==============================] - 18s 585ms/step - loss: 1.5843 - rpn_score_accuracy: 0.9380 - cls_logits_accuracy: 0.7560 - rpn_score_loss: 0.1718 - rpn_regress_loss: 0.2471 - cls_logits_loss: 0.1511 - cls_regress_loss: 0.6162 - cls_mask_loss: 0.3981 - val_loss: 2.2363 - val_rpn_score_accuracy: 0.8605 - val_cls_logits_accuracy: 0.7855 - val_rpn_score_loss: 0.4340 - val_rpn_regress_loss: 0.5912 - val_cls_logits_loss: 0.1265 - val_cls_regress_loss: 0.6795 - val_cls_mask_loss: 0.4052
# Epoch 55/100
# 31/31 [==============================] - 18s 587ms/step - loss: 1.6161 - rpn_score_accuracy: 0.9338 - cls_logits_accuracy: 0.7846 - rpn_score_loss: 0.1796 - rpn_regress_loss: 0.2924 - cls_logits_loss: 0.1278 - cls_regress_loss: 0.6340 - cls_mask_loss: 0.3823 - val_loss: 2.2613 - val_rpn_score_accuracy: 0.8237 - val_cls_logits_accuracy: 0.7936 - val_rpn_score_loss: 0.5027 - val_rpn_regress_loss: 0.5974 - val_cls_logits_loss: 0.1194 - val_cls_regress_loss: 0.6518 - val_cls_mask_loss: 0.3899
# Epoch 56/100
# 31/31 [==============================] - 18s 584ms/step - loss: 1.6108 - rpn_score_accuracy: 0.9327 - cls_logits_accuracy: 0.7986 - rpn_score_loss: 0.1650 - rpn_regress_loss: 0.3322 - cls_logits_loss: 0.1207 - cls_regress_loss: 0.6154 - cls_mask_loss: 0.3775 - val_loss: 2.3070 - val_rpn_score_accuracy: 0.8267 - val_cls_logits_accuracy: 0.7792 - val_rpn_score_loss: 0.4759 - val_rpn_regress_loss: 0.6328 - val_cls_logits_loss: 0.1248 - val_cls_regress_loss: 0.6639 - val_cls_mask_loss: 0.4095
# Epoch 57/100
# 31/31 [==============================] - 18s 586ms/step - loss: 1.6063 - rpn_score_accuracy: 0.9413 - cls_logits_accuracy: 0.8009 - rpn_score_loss: 0.1680 - rpn_regress_loss: 0.2797 - cls_logits_loss: 0.1264 - cls_regress_loss: 0.6287 - cls_mask_loss: 0.4034 - val_loss: 2.4446 - val_rpn_score_accuracy: 0.8185 - val_cls_logits_accuracy: 0.7646 - val_rpn_score_loss: 0.5427 - val_rpn_regress_loss: 0.6260 - val_cls_logits_loss: 0.1280 - val_cls_regress_loss: 0.6929 - val_cls_mask_loss: 0.4550
# Epoch 58/100
# 31/31 [==============================] - 18s 584ms/step - loss: 1.5269 - rpn_score_accuracy: 0.9486 - cls_logits_accuracy: 0.7812 - rpn_score_loss: 0.1391 - rpn_regress_loss: 0.2697 - cls_logits_loss: 0.1329 - cls_regress_loss: 0.6093 - cls_mask_loss: 0.3759 - val_loss: 2.3000 - val_rpn_score_accuracy: 0.8510 - val_cls_logits_accuracy: 0.7545 - val_rpn_score_loss: 0.4444 - val_rpn_regress_loss: 0.6407 - val_cls_logits_loss: 0.1287 - val_cls_regress_loss: 0.6913 - val_cls_mask_loss: 0.3950
# Epoch 59/100
# 31/31 [==============================] - 18s 584ms/step - loss: 1.5112 - rpn_score_accuracy: 0.9421 - cls_logits_accuracy: 0.8137 - rpn_score_loss: 0.1511 - rpn_regress_loss: 0.2633 - cls_logits_loss: 0.1218 - cls_regress_loss: 0.6005 - cls_mask_loss: 0.3745 - val_loss: 2.3465 - val_rpn_score_accuracy: 0.8573 - val_cls_logits_accuracy: 0.7356 - val_rpn_score_loss: 0.5125 - val_rpn_regress_loss: 0.6212 - val_cls_logits_loss: 0.1314 - val_cls_regress_loss: 0.6706 - val_cls_mask_loss: 0.4109
# Epoch 60/100
# 31/31 [==============================] - 18s 587ms/step - loss: 1.4848 - rpn_score_accuracy: 0.9357 - cls_logits_accuracy: 0.7886 - rpn_score_loss: 0.1604 - rpn_regress_loss: 0.2298 - cls_logits_loss: 0.1208 - cls_regress_loss: 0.6008 - cls_mask_loss: 0.3730 - val_loss: 2.3188 - val_rpn_score_accuracy: 0.8617 - val_cls_logits_accuracy: 0.8037 - val_rpn_score_loss: 0.4962 - val_rpn_regress_loss: 0.6480 - val_cls_logits_loss: 0.1158 - val_cls_regress_loss: 0.6776 - val_cls_mask_loss: 0.3813
# Epoch 61/100
# 31/31 [==============================] - 18s 588ms/step - loss: 1.5238 - rpn_score_accuracy: 0.9281 - cls_logits_accuracy: 0.8132 - rpn_score_loss: 0.2048 - rpn_regress_loss: 0.2532 - cls_logits_loss: 0.1107 - cls_regress_loss: 0.6058 - cls_mask_loss: 0.3494 - val_loss: 2.3050 - val_rpn_score_accuracy: 0.8484 - val_cls_logits_accuracy: 0.7905 - val_rpn_score_loss: 0.4900 - val_rpn_regress_loss: 0.6431 - val_cls_logits_loss: 0.1247 - val_cls_regress_loss: 0.6321 - val_cls_mask_loss: 0.4151
# Epoch 62/100
# 31/31 [==============================] - 18s 587ms/step - loss: 1.4616 - rpn_score_accuracy: 0.9292 - cls_logits_accuracy: 0.8165 - rpn_score_loss: 0.1803 - rpn_regress_loss: 0.2360 - cls_logits_loss: 0.1062 - cls_regress_loss: 0.5810 - cls_mask_loss: 0.3581 - val_loss: 2.3553 - val_rpn_score_accuracy: 0.8243 - val_cls_logits_accuracy: 0.7743 - val_rpn_score_loss: 0.5501 - val_rpn_regress_loss: 0.6209 - val_cls_logits_loss: 0.1293 - val_cls_regress_loss: 0.6640 - val_cls_mask_loss: 0.3910
# Epoch 63/100
# 31/31 [==============================] - 18s 590ms/step - loss: 1.4093 - rpn_score_accuracy: 0.9486 - cls_logits_accuracy: 0.8161 - rpn_score_loss: 0.1593 - rpn_regress_loss: 0.2343 - cls_logits_loss: 0.1088 - cls_regress_loss: 0.5689 - cls_mask_loss: 0.3380 - val_loss: 2.2537 - val_rpn_score_accuracy: 0.8462 - val_cls_logits_accuracy: 0.8214 - val_rpn_score_loss: 0.4939 - val_rpn_regress_loss: 0.6304 - val_cls_logits_loss: 0.1137 - val_cls_regress_loss: 0.6455 - val_cls_mask_loss: 0.3701
# Epoch 64/100
# 31/31 [==============================] - 18s 591ms/step - loss: 1.4740 - rpn_score_accuracy: 0.9365 - cls_logits_accuracy: 0.8244 - rpn_score_loss: 0.1594 - rpn_regress_loss: 0.2492 - cls_logits_loss: 0.1042 - cls_regress_loss: 0.5813 - cls_mask_loss: 0.3799 - val_loss: 2.3358 - val_rpn_score_accuracy: 0.8005 - val_cls_logits_accuracy: 0.8211 - val_rpn_score_loss: 0.5215 - val_rpn_regress_loss: 0.6215 - val_cls_logits_loss: 0.1172 - val_cls_regress_loss: 0.6430 - val_cls_mask_loss: 0.4326
# Epoch 65/100
# 31/31 [==============================] - 18s 587ms/step - loss: 1.3853 - rpn_score_accuracy: 0.9441 - cls_logits_accuracy: 0.8303 - rpn_score_loss: 0.1481 - rpn_regress_loss: 0.2469 - cls_logits_loss: 0.1070 - cls_regress_loss: 0.5584 - cls_mask_loss: 0.3248 - val_loss: 2.2335 - val_rpn_score_accuracy: 0.8412 - val_cls_logits_accuracy: 0.7816 - val_rpn_score_loss: 0.4419 - val_rpn_regress_loss: 0.6146 - val_cls_logits_loss: 0.1268 - val_cls_regress_loss: 0.6502 - val_cls_mask_loss: 0.4000
# Epoch 66/100
# 31/31 [==============================] - 18s 589ms/step - loss: 1.4104 - rpn_score_accuracy: 0.9583 - cls_logits_accuracy: 0.8095 - rpn_score_loss: 0.1385 - rpn_regress_loss: 0.2208 - cls_logits_loss: 0.1321 - cls_regress_loss: 0.5871 - cls_mask_loss: 0.3318 - val_loss: 2.1735 - val_rpn_score_accuracy: 0.8639 - val_cls_logits_accuracy: 0.8095 - val_rpn_score_loss: 0.4146 - val_rpn_regress_loss: 0.6194 - val_cls_logits_loss: 0.1197 - val_cls_regress_loss: 0.6366 - val_cls_mask_loss: 0.3831
# Epoch 67/100
# 31/31 [==============================] - 18s 587ms/step - loss: 1.4264 - rpn_score_accuracy: 0.9459 - cls_logits_accuracy: 0.8288 - rpn_score_loss: 0.1545 - rpn_regress_loss: 0.2182 - cls_logits_loss: 0.1109 - cls_regress_loss: 0.5920 - cls_mask_loss: 0.3508 - val_loss: 2.2025 - val_rpn_score_accuracy: 0.8662 - val_cls_logits_accuracy: 0.8215 - val_rpn_score_loss: 0.4635 - val_rpn_regress_loss: 0.6139 - val_cls_logits_loss: 0.1127 - val_cls_regress_loss: 0.6385 - val_cls_mask_loss: 0.3739
# Epoch 68/100
# 31/31 [==============================] - 18s 588ms/step - loss: 1.3964 - rpn_score_accuracy: 0.9302 - cls_logits_accuracy: 0.8214 - rpn_score_loss: 0.1696 - rpn_regress_loss: 0.2154 - cls_logits_loss: 0.1067 - cls_regress_loss: 0.5544 - cls_mask_loss: 0.3504 - val_loss: 2.3452 - val_rpn_score_accuracy: 0.8285 - val_cls_logits_accuracy: 0.7654 - val_rpn_score_loss: 0.5835 - val_rpn_regress_loss: 0.6389 - val_cls_logits_loss: 0.1290 - val_cls_regress_loss: 0.6343 - val_cls_mask_loss: 0.3594
# Epoch 69/100
# 31/31 [==============================] - 18s 587ms/step - loss: 1.2989 - rpn_score_accuracy: 0.9490 - cls_logits_accuracy: 0.8347 - rpn_score_loss: 0.1264 - rpn_regress_loss: 0.2152 - cls_logits_loss: 0.1091 - cls_regress_loss: 0.5326 - cls_mask_loss: 0.3156 - val_loss: 2.3421 - val_rpn_score_accuracy: 0.8270 - val_cls_logits_accuracy: 0.8142 - val_rpn_score_loss: 0.5384 - val_rpn_regress_loss: 0.6552 - val_cls_logits_loss: 0.1142 - val_cls_regress_loss: 0.6392 - val_cls_mask_loss: 0.3952
# Epoch 70/100
# 31/31 [==============================] - 18s 586ms/step - loss: 1.3275 - rpn_score_accuracy: 0.9387 - cls_logits_accuracy: 0.8263 - rpn_score_loss: 0.1557 - rpn_regress_loss: 0.1938 - cls_logits_loss: 0.1137 - cls_regress_loss: 0.5205 - cls_mask_loss: 0.3438 - val_loss: 2.2689 - val_rpn_score_accuracy: 0.8304 - val_cls_logits_accuracy: 0.8303 - val_rpn_score_loss: 0.5192 - val_rpn_regress_loss: 0.6773 - val_cls_logits_loss: 0.1094 - val_cls_regress_loss: 0.6142 - val_cls_mask_loss: 0.3488
# Epoch 71/100
# 31/31 [==============================] - 18s 586ms/step - loss: 1.3508 - rpn_score_accuracy: 0.9420 - cls_logits_accuracy: 0.8486 - rpn_score_loss: 0.1587 - rpn_regress_loss: 0.2292 - cls_logits_loss: 0.1026 - cls_regress_loss: 0.5357 - cls_mask_loss: 0.3246 - val_loss: 2.2204 - val_rpn_score_accuracy: 0.8410 - val_cls_logits_accuracy: 0.8192 - val_rpn_score_loss: 0.5378 - val_rpn_regress_loss: 0.6545 - val_cls_logits_loss: 0.1138 - val_cls_regress_loss: 0.5732 - val_cls_mask_loss: 0.3411
# Epoch 72/100
# 31/31 [==============================] - 18s 589ms/step - loss: 1.3012 - rpn_score_accuracy: 0.9487 - cls_logits_accuracy: 0.8358 - rpn_score_loss: 0.1354 - rpn_regress_loss: 0.2332 - cls_logits_loss: 0.0973 - cls_regress_loss: 0.5266 - cls_mask_loss: 0.3086 - val_loss: 2.2290 - val_rpn_score_accuracy: 0.8348 - val_cls_logits_accuracy: 0.8395 - val_rpn_score_loss: 0.5217 - val_rpn_regress_loss: 0.6455 - val_cls_logits_loss: 0.1058 - val_cls_regress_loss: 0.5908 - val_cls_mask_loss: 0.3651
# Epoch 73/100
# 31/31 [==============================] - 18s 586ms/step - loss: 1.2784 - rpn_score_accuracy: 0.9540 - cls_logits_accuracy: 0.8502 - rpn_score_loss: 0.1291 - rpn_regress_loss: 0.2049 - cls_logits_loss: 0.1275 - cls_regress_loss: 0.5018 - cls_mask_loss: 0.3150 - val_loss: 2.2767 - val_rpn_score_accuracy: 0.8285 - val_cls_logits_accuracy: 0.8403 - val_rpn_score_loss: 0.5972 - val_rpn_regress_loss: 0.6306 - val_cls_logits_loss: 0.1102 - val_cls_regress_loss: 0.5786 - val_cls_mask_loss: 0.3601
# Epoch 74/100
# 31/31 [==============================] - 18s 589ms/step - loss: 1.3135 - rpn_score_accuracy: 0.9445 - cls_logits_accuracy: 0.8359 - rpn_score_loss: 0.1550 - rpn_regress_loss: 0.2037 - cls_logits_loss: 0.1148 - cls_regress_loss: 0.5179 - cls_mask_loss: 0.3221 - val_loss: 2.2878 - val_rpn_score_accuracy: 0.8555 - val_cls_logits_accuracy: 0.7757 - val_rpn_score_loss: 0.4834 - val_rpn_regress_loss: 0.6529 - val_cls_logits_loss: 0.1263 - val_cls_regress_loss: 0.6025 - val_cls_mask_loss: 0.4227
# Epoch 75/100
# 31/31 [==============================] - 18s 592ms/step - loss: 1.3116 - rpn_score_accuracy: 0.9421 - cls_logits_accuracy: 0.8254 - rpn_score_loss: 0.1419 - rpn_regress_loss: 0.2044 - cls_logits_loss: 0.1317 - cls_regress_loss: 0.5059 - cls_mask_loss: 0.3277 - val_loss: 2.2031 - val_rpn_score_accuracy: 0.8510 - val_cls_logits_accuracy: 0.8261 - val_rpn_score_loss: 0.5296 - val_rpn_regress_loss: 0.6284 - val_cls_logits_loss: 0.1078 - val_cls_regress_loss: 0.5716 - val_cls_mask_loss: 0.3657
# Epoch 76/100
# 31/31 [==============================] - 18s 592ms/step - loss: 1.2556 - rpn_score_accuracy: 0.9322 - cls_logits_accuracy: 0.8356 - rpn_score_loss: 0.1568 - rpn_regress_loss: 0.1907 - cls_logits_loss: 0.1015 - cls_regress_loss: 0.5087 - cls_mask_loss: 0.2978 - val_loss: 2.3224 - val_rpn_score_accuracy: 0.8151 - val_cls_logits_accuracy: 0.8077 - val_rpn_score_loss: 0.6046 - val_rpn_regress_loss: 0.6457 - val_cls_logits_loss: 0.1100 - val_cls_regress_loss: 0.5969 - val_cls_mask_loss: 0.3652
# Epoch 77/100
# 31/31 [==============================] - 18s 594ms/step - loss: 1.3518 - rpn_score_accuracy: 0.9358 - cls_logits_accuracy: 0.8283 - rpn_score_loss: 0.1637 - rpn_regress_loss: 0.2077 - cls_logits_loss: 0.1255 - cls_regress_loss: 0.5327 - cls_mask_loss: 0.3221 - val_loss: 2.2462 - val_rpn_score_accuracy: 0.8522 - val_cls_logits_accuracy: 0.8069 - val_rpn_score_loss: 0.5644 - val_rpn_regress_loss: 0.6376 - val_cls_logits_loss: 0.1102 - val_cls_regress_loss: 0.5718 - val_cls_mask_loss: 0.3622
# Epoch 78/100
# 31/31 [==============================] - 18s 589ms/step - loss: 1.3560 - rpn_score_accuracy: 0.9418 - cls_logits_accuracy: 0.8307 - rpn_score_loss: 0.1698 - rpn_regress_loss: 0.2433 - cls_logits_loss: 0.1230 - cls_regress_loss: 0.5106 - cls_mask_loss: 0.3093 - val_loss: 2.2728 - val_rpn_score_accuracy: 0.8564 - val_cls_logits_accuracy: 0.7975 - val_rpn_score_loss: 0.5322 - val_rpn_regress_loss: 0.6381 - val_cls_logits_loss: 0.1143 - val_cls_regress_loss: 0.5903 - val_cls_mask_loss: 0.3978
# Epoch 79/100
# 31/31 [==============================] - 18s 590ms/step - loss: 1.3314 - rpn_score_accuracy: 0.9406 - cls_logits_accuracy: 0.8379 - rpn_score_loss: 0.1773 - rpn_regress_loss: 0.2321 - cls_logits_loss: 0.1120 - cls_regress_loss: 0.5097 - cls_mask_loss: 0.3004 - val_loss: 2.1887 - val_rpn_score_accuracy: 0.8461 - val_cls_logits_accuracy: 0.7996 - val_rpn_score_loss: 0.4662 - val_rpn_regress_loss: 0.6646 - val_cls_logits_loss: 0.1192 - val_cls_regress_loss: 0.5750 - val_cls_mask_loss: 0.3637
# Epoch 80/100
# 31/31 [==============================] - 18s 590ms/step - loss: 1.2322 - rpn_score_accuracy: 0.9589 - cls_logits_accuracy: 0.8430 - rpn_score_loss: 0.1409 - rpn_regress_loss: 0.2069 - cls_logits_loss: 0.0968 - cls_regress_loss: 0.4899 - cls_mask_loss: 0.2976 - val_loss: 2.1756 - val_rpn_score_accuracy: 0.8514 - val_cls_logits_accuracy: 0.8078 - val_rpn_score_loss: 0.5473 - val_rpn_regress_loss: 0.6081 - val_cls_logits_loss: 0.1106 - val_cls_regress_loss: 0.5575 - val_cls_mask_loss: 0.3520
# Epoch 81/100
# 31/31 [==============================] - 18s 591ms/step - loss: 1.1848 - rpn_score_accuracy: 0.9560 - cls_logits_accuracy: 0.8476 - rpn_score_loss: 0.1233 - rpn_regress_loss: 0.1775 - cls_logits_loss: 0.1081 - cls_regress_loss: 0.4845 - cls_mask_loss: 0.2915 - val_loss: 2.2148 - val_rpn_score_accuracy: 0.8512 - val_cls_logits_accuracy: 0.8214 - val_rpn_score_loss: 0.5492 - val_rpn_regress_loss: 0.6549 - val_cls_logits_loss: 0.1059 - val_cls_regress_loss: 0.5683 - val_cls_mask_loss: 0.3365
# Epoch 82/100
# 31/31 [==============================] - 18s 592ms/step - loss: 1.1871 - rpn_score_accuracy: 0.9613 - cls_logits_accuracy: 0.8420 - rpn_score_loss: 0.1023 - rpn_regress_loss: 0.1951 - cls_logits_loss: 0.1029 - cls_regress_loss: 0.4776 - cls_mask_loss: 0.3092 - val_loss: 2.1915 - val_rpn_score_accuracy: 0.8585 - val_cls_logits_accuracy: 0.8430 - val_rpn_score_loss: 0.5004 - val_rpn_regress_loss: 0.6681 - val_cls_logits_loss: 0.0997 - val_cls_regress_loss: 0.5750 - val_cls_mask_loss: 0.3483
# Epoch 83/100
# 31/31 [==============================] - 18s 593ms/step - loss: 1.1381 - rpn_score_accuracy: 0.9557 - cls_logits_accuracy: 0.8466 - rpn_score_loss: 0.1190 - rpn_regress_loss: 0.1759 - cls_logits_loss: 0.0981 - cls_regress_loss: 0.4530 - cls_mask_loss: 0.2920 - val_loss: 2.1858 - val_rpn_score_accuracy: 0.8320 - val_cls_logits_accuracy: 0.8108 - val_rpn_score_loss: 0.5674 - val_rpn_regress_loss: 0.6117 - val_cls_logits_loss: 0.1069 - val_cls_regress_loss: 0.5384 - val_cls_mask_loss: 0.3613
# Epoch 84/100
# 31/31 [==============================] - 18s 592ms/step - loss: 1.1202 - rpn_score_accuracy: 0.9717 - cls_logits_accuracy: 0.8471 - rpn_score_loss: 0.0914 - rpn_regress_loss: 0.1764 - cls_logits_loss: 0.0982 - cls_regress_loss: 0.4621 - cls_mask_loss: 0.2921 - val_loss: 2.2481 - val_rpn_score_accuracy: 0.8407 - val_cls_logits_accuracy: 0.8356 - val_rpn_score_loss: 0.6079 - val_rpn_regress_loss: 0.6423 - val_cls_logits_loss: 0.1052 - val_cls_regress_loss: 0.5596 - val_cls_mask_loss: 0.3331
# Epoch 85/100
# 31/31 [==============================] - 18s 592ms/step - loss: 1.1171 - rpn_score_accuracy: 0.9683 - cls_logits_accuracy: 0.8460 - rpn_score_loss: 0.1069 - rpn_regress_loss: 0.1830 - cls_logits_loss: 0.1120 - cls_regress_loss: 0.4382 - cls_mask_loss: 0.2771 - val_loss: 2.2189 - val_rpn_score_accuracy: 0.8549 - val_cls_logits_accuracy: 0.8089 - val_rpn_score_loss: 0.5818 - val_rpn_regress_loss: 0.6441 - val_cls_logits_loss: 0.1157 - val_cls_regress_loss: 0.5231 - val_cls_mask_loss: 0.3541
# Epoch 86/100
# 31/31 [==============================] - 18s 593ms/step - loss: 1.1420 - rpn_score_accuracy: 0.9571 - cls_logits_accuracy: 0.8439 - rpn_score_loss: 0.1307 - rpn_regress_loss: 0.1717 - cls_logits_loss: 0.1052 - cls_regress_loss: 0.4557 - cls_mask_loss: 0.2786 - val_loss: 2.2470 - val_rpn_score_accuracy: 0.8474 - val_cls_logits_accuracy: 0.8212 - val_rpn_score_loss: 0.6510 - val_rpn_regress_loss: 0.6074 - val_cls_logits_loss: 0.1088 - val_cls_regress_loss: 0.5387 - val_cls_mask_loss: 0.3411
# Epoch 87/100
# 31/31 [==============================] - 18s 593ms/step - loss: 1.1111 - rpn_score_accuracy: 0.9601 - cls_logits_accuracy: 0.8518 - rpn_score_loss: 0.1142 - rpn_regress_loss: 0.1571 - cls_logits_loss: 0.0904 - cls_regress_loss: 0.4438 - cls_mask_loss: 0.3057 - val_loss: 2.2341 - val_rpn_score_accuracy: 0.8301 - val_cls_logits_accuracy: 0.8096 - val_rpn_score_loss: 0.6101 - val_rpn_regress_loss: 0.6408 - val_cls_logits_loss: 0.1061 - val_cls_regress_loss: 0.5205 - val_cls_mask_loss: 0.3565
# Epoch 88/100
# 31/31 [==============================] - 18s 593ms/step - loss: 1.0700 - rpn_score_accuracy: 0.9655 - cls_logits_accuracy: 0.8567 - rpn_score_loss: 0.1050 - rpn_regress_loss: 0.1729 - cls_logits_loss: 0.0883 - cls_regress_loss: 0.4275 - cls_mask_loss: 0.2763 - val_loss: 2.1473 - val_rpn_score_accuracy: 0.8590 - val_cls_logits_accuracy: 0.8209 - val_rpn_score_loss: 0.5492 - val_rpn_regress_loss: 0.6473 - val_cls_logits_loss: 0.1080 - val_cls_regress_loss: 0.5179 - val_cls_mask_loss: 0.3249
# Epoch 89/100
# 31/31 [==============================] - 18s 592ms/step - loss: 1.0734 - rpn_score_accuracy: 0.9630 - cls_logits_accuracy: 0.8443 - rpn_score_loss: 0.0991 - rpn_regress_loss: 0.1607 - cls_logits_loss: 0.0973 - cls_regress_loss: 0.4348 - cls_mask_loss: 0.2816 - val_loss: 2.0938 - val_rpn_score_accuracy: 0.8539 - val_cls_logits_accuracy: 0.8144 - val_rpn_score_loss: 0.5048 - val_rpn_regress_loss: 0.6068 - val_cls_logits_loss: 0.1079 - val_cls_regress_loss: 0.5249 - val_cls_mask_loss: 0.3494
# Epoch 90/100
# 31/31 [==============================] - 18s 594ms/step - loss: 1.0783 - rpn_score_accuracy: 0.9608 - cls_logits_accuracy: 0.8507 - rpn_score_loss: 0.1210 - rpn_regress_loss: 0.1788 - cls_logits_loss: 0.0895 - cls_regress_loss: 0.4202 - cls_mask_loss: 0.2688 - val_loss: 2.1214 - val_rpn_score_accuracy: 0.8347 - val_cls_logits_accuracy: 0.8081 - val_rpn_score_loss: 0.5541 - val_rpn_regress_loss: 0.6434 - val_cls_logits_loss: 0.1046 - val_cls_regress_loss: 0.4836 - val_cls_mask_loss: 0.3357
# Epoch 91/100
# 31/31 [==============================] - 19s 595ms/step - loss: 1.0656 - rpn_score_accuracy: 0.9668 - cls_logits_accuracy: 0.8536 - rpn_score_loss: 0.1155 - rpn_regress_loss: 0.1636 - cls_logits_loss: 0.0938 - cls_regress_loss: 0.4239 - cls_mask_loss: 0.2688 - val_loss: 2.1364 - val_rpn_score_accuracy: 0.8368 - val_cls_logits_accuracy: 0.8011 - val_rpn_score_loss: 0.4801 - val_rpn_regress_loss: 0.6459 - val_cls_logits_loss: 0.1233 - val_cls_regress_loss: 0.5167 - val_cls_mask_loss: 0.3704
# Epoch 92/100
# 31/31 [==============================] - 18s 592ms/step - loss: 1.0806 - rpn_score_accuracy: 0.9432 - cls_logits_accuracy: 0.8479 - rpn_score_loss: 0.1675 - rpn_regress_loss: 0.1560 - cls_logits_loss: 0.0926 - cls_regress_loss: 0.4074 - cls_mask_loss: 0.2570 - val_loss: 1.9770 - val_rpn_score_accuracy: 0.8663 - val_cls_logits_accuracy: 0.8242 - val_rpn_score_loss: 0.4445 - val_rpn_regress_loss: 0.5981 - val_cls_logits_loss: 0.1033 - val_cls_regress_loss: 0.4755 - val_cls_mask_loss: 0.3555
# Epoch 93/100
# 31/31 [==============================] - 18s 593ms/step - loss: 1.1046 - rpn_score_accuracy: 0.9420 - cls_logits_accuracy: 0.8493 - rpn_score_loss: 0.1419 - rpn_regress_loss: 0.1648 - cls_logits_loss: 0.0981 - cls_regress_loss: 0.4297 - cls_mask_loss: 0.2700 - val_loss: 1.9599 - val_rpn_score_accuracy: 0.8554 - val_cls_logits_accuracy: 0.8431 - val_rpn_score_loss: 0.4793 - val_rpn_regress_loss: 0.5902 - val_cls_logits_loss: 0.0993 - val_cls_regress_loss: 0.4610 - val_cls_mask_loss: 0.3302
# Epoch 94/100
# 31/31 [==============================] - 18s 590ms/step - loss: 1.0907 - rpn_score_accuracy: 0.9586 - cls_logits_accuracy: 0.8545 - rpn_score_loss: 0.1196 - rpn_regress_loss: 0.1866 - cls_logits_loss: 0.1023 - cls_regress_loss: 0.4060 - cls_mask_loss: 0.2763 - val_loss: 2.1269 - val_rpn_score_accuracy: 0.8294 - val_cls_logits_accuracy: 0.8276 - val_rpn_score_loss: 0.5887 - val_rpn_regress_loss: 0.6261 - val_cls_logits_loss: 0.1031 - val_cls_regress_loss: 0.4676 - val_cls_mask_loss: 0.3413
# Epoch 95/100
# 31/31 [==============================] - 18s 591ms/step - loss: 1.0467 - rpn_score_accuracy: 0.9628 - cls_logits_accuracy: 0.8562 - rpn_score_loss: 0.1097 - rpn_regress_loss: 0.1882 - cls_logits_loss: 0.0934 - cls_regress_loss: 0.3980 - cls_mask_loss: 0.2574 - val_loss: 2.0101 - val_rpn_score_accuracy: 0.8449 - val_cls_logits_accuracy: 0.8136 - val_rpn_score_loss: 0.5055 - val_rpn_regress_loss: 0.6180 - val_cls_logits_loss: 0.1077 - val_cls_regress_loss: 0.4514 - val_cls_mask_loss: 0.3275
# Epoch 96/100
# 31/31 [==============================] - 18s 592ms/step - loss: 1.0485 - rpn_score_accuracy: 0.9548 - cls_logits_accuracy: 0.8498 - rpn_score_loss: 0.1183 - rpn_regress_loss: 0.1539 - cls_logits_loss: 0.1013 - cls_regress_loss: 0.4101 - cls_mask_loss: 0.2649 - val_loss: 2.1029 - val_rpn_score_accuracy: 0.8587 - val_cls_logits_accuracy: 0.8321 - val_rpn_score_loss: 0.5689 - val_rpn_regress_loss: 0.6249 - val_cls_logits_loss: 0.1046 - val_cls_regress_loss: 0.4866 - val_cls_mask_loss: 0.3179
# Epoch 97/100
# 31/31 [==============================] - 18s 591ms/step - loss: 1.0078 - rpn_score_accuracy: 0.9566 - cls_logits_accuracy: 0.8616 - rpn_score_loss: 0.1215 - rpn_regress_loss: 0.1411 - cls_logits_loss: 0.0871 - cls_regress_loss: 0.3889 - cls_mask_loss: 0.2692 - val_loss: 2.1334 - val_rpn_score_accuracy: 0.8397 - val_cls_logits_accuracy: 0.8418 - val_rpn_score_loss: 0.6005 - val_rpn_regress_loss: 0.6300 - val_cls_logits_loss: 0.0946 - val_cls_regress_loss: 0.4822 - val_cls_mask_loss: 0.3260
# Epoch 98/100
# 31/31 [==============================] - 18s 590ms/step - loss: 1.0265 - rpn_score_accuracy: 0.9534 - cls_logits_accuracy: 0.8630 - rpn_score_loss: 0.1094 - rpn_regress_loss: 0.1545 - cls_logits_loss: 0.0948 - cls_regress_loss: 0.3985 - cls_mask_loss: 0.2694 - val_loss: 2.2174 - val_rpn_score_accuracy: 0.8445 - val_cls_logits_accuracy: 0.8286 - val_rpn_score_loss: 0.6497 - val_rpn_regress_loss: 0.6155 - val_cls_logits_loss: 0.1034 - val_cls_regress_loss: 0.5046 - val_cls_mask_loss: 0.3442
# Epoch 99/100
# 31/31 [==============================] - 18s 588ms/step - loss: 0.9972 - rpn_score_accuracy: 0.9582 - cls_logits_accuracy: 0.8528 - rpn_score_loss: 0.1177 - rpn_regress_loss: 0.1436 - cls_logits_loss: 0.0893 - cls_regress_loss: 0.3787 - cls_mask_loss: 0.2679 - val_loss: 2.1092 - val_rpn_score_accuracy: 0.8235 - val_cls_logits_accuracy: 0.8508 - val_rpn_score_loss: 0.6122 - val_rpn_regress_loss: 0.6068 - val_cls_logits_loss: 0.0936 - val_cls_regress_loss: 0.4829 - val_cls_mask_loss: 0.3138
# Epoch 100/100
# 31/31 [==============================] - 18s 590ms/step - loss: 0.9903 - rpn_score_accuracy: 0.9681 - cls_logits_accuracy: 0.8604 - rpn_score_loss: 0.1105 - rpn_regress_loss: 0.1561 - cls_logits_loss: 0.0895 - cls_regress_loss: 0.3877 - cls_mask_loss: 0.2465 - val_loss: 2.0915 - val_rpn_score_accuracy: 0.8380 - val_cls_logits_accuracy: 0.8707 - val_rpn_score_loss: 0.5690 - val_rpn_regress_loss: 0.6280 - val_cls_logits_loss: 0.0945 - val_cls_regress_loss: 0.4768 - val_cls_mask_loss: 0.3233

# %%
model.save_weights("model.h5")

# %%
x = tf.keras.layers.Input(shape = (512, 512, 3))
feature = tfdet.model.backbone.resnet50(x)
#scale = [32, 64, 128, 256, 512]
scale = [24, 48, 96, 192, 384]
ratio = [0.5, 1, 2]
bifpn = functools.partial(tfdet.model.neck.bifpn, weighted_add = False)
neck = functools.partial(tfdet.model.neck.FeatureAlign, pre_sampling = False, neck = bifpn)
out = tfdet.model.detector.mask_rcnn(feature, n_class = 2, image_shape = tf.shape(x)[1:3], scale = scale, ratio = ratio, soft_nms = False, neck = neck, proposal_count = 1000)
prediction = tfdet.model.postprocess.rcnn.FilterDetection(proposal_count = 100, iou_threshold = 0.3, score_threshold = 0.7, soft_nms = False)(out)
model = tf.keras.Model(x, prediction)
model.load_weights("model.h5")

# %%
images = te_x[:1]
logits, proposal, mask = model.predict(images)
images = tfdet.util.draw_bbox(images, proposal, logits, mask, label = ["Background", "Balloon"])

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (10, 10))
plt.imshow(images[0])
