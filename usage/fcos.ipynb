# %%
import os
# !git clone https://github.com/burf/tfdetection
os.chdir(os.path.join(os.getcwd(), "tfdetection"))
# !python setup.py bdist_wheel
# !pip install ./dist/tfdet-1.0.0-py3-none-any.whl
os.chdir(os.path.dirname(os.getcwd()))
# Out:
# Cloning into 'tfdetection'...
# remote: Enumerating objects: 85, done.
# remote: Counting objects: 100% (85/85), done.
# remote: Compressing objects: 100% (72/72), done.
# remote: Total 85 (delta 12), reused 81 (delta 9), pack-reused 0
# Unpacking objects: 100% (85/85), done.
# running bdist_wheel
# running build
# running build_py
# creating build
# creating build/lib
# creating build/lib/tfdet
# copying tfdet/__init__.py -> build/lib/tfdet
# creating build/lib/tfdet/core
# copying tfdet/core/__init__.py -> build/lib/tfdet/core
# creating build/lib/tfdet/util
# copying tfdet/util/metric.py -> build/lib/tfdet/util
# copying tfdet/util/__init__.py -> build/lib/tfdet/util
# copying tfdet/util/visualize.py -> build/lib/tfdet/util
# creating build/lib/tfdet/model
# copying tfdet/model/__init__.py -> build/lib/tfdet/model
# creating build/lib/tfdet/core/target
# copying tfdet/core/target/rcnn_target.py -> build/lib/tfdet/core/target
# copying tfdet/core/target/__init__.py -> build/lib/tfdet/core/target
# copying tfdet/core/target/anchor_target.py -> build/lib/tfdet/core/target
# copying tfdet/core/target/yolo_target.py -> build/lib/tfdet/core/target
# copying tfdet/core/target/point_target.py -> build/lib/tfdet/core/target
# creating build/lib/tfdet/core/util
# copying tfdet/core/util/nms.py -> build/lib/tfdet/core/util
# copying tfdet/core/util/anchor.py -> build/lib/tfdet/core/util
# copying tfdet/core/util/__init__.py -> build/lib/tfdet/core/util
# copying tfdet/core/util/loss.py -> build/lib/tfdet/core/util
# copying tfdet/core/util/overlap.py -> build/lib/tfdet/core/util
# copying tfdet/core/util/tf.py -> build/lib/tfdet/core/util
# copying tfdet/core/util/bbox.py -> build/lib/tfdet/core/util
# creating build/lib/tfdet/model/backbone
# copying tfdet/model/backbone/darknet.py -> build/lib/tfdet/model/backbone
# copying tfdet/model/backbone/densenet.py -> build/lib/tfdet/model/backbone
# copying tfdet/model/backbone/vgg.py -> build/lib/tfdet/model/backbone
# copying tfdet/model/backbone/mobilenet.py -> build/lib/tfdet/model/backbone
# copying tfdet/model/backbone/__init__.py -> build/lib/tfdet/model/backbone
# copying tfdet/model/backbone/swin_transformer.py -> build/lib/tfdet/model/backbone
# copying tfdet/model/backbone/effnet.py -> build/lib/tfdet/model/backbone
# copying tfdet/model/backbone/resnest.py -> build/lib/tfdet/model/backbone
# copying tfdet/model/backbone/resnet_torch.py -> build/lib/tfdet/model/backbone
# copying tfdet/model/backbone/resnet.py -> build/lib/tfdet/model/backbone
# creating build/lib/tfdet/model/loss
# copying tfdet/model/loss/yolo.py -> build/lib/tfdet/model/loss
# copying tfdet/model/loss/common.py -> build/lib/tfdet/model/loss
# copying tfdet/model/loss/__init__.py -> build/lib/tfdet/model/loss
# copying tfdet/model/loss/retina.py -> build/lib/tfdet/model/loss
# copying tfdet/model/loss/fcos.py -> build/lib/tfdet/model/loss
# copying tfdet/model/loss/rcnn.py -> build/lib/tfdet/model/loss
# creating build/lib/tfdet/model/neck
# copying tfdet/model/neck/__init__.py -> build/lib/tfdet/model/neck
# copying tfdet/model/neck/fpn.py -> build/lib/tfdet/model/neck
# creating build/lib/tfdet/model/head
# copying tfdet/model/head/yolo.py -> build/lib/tfdet/model/head
# copying tfdet/model/head/__init__.py -> build/lib/tfdet/model/head
# copying tfdet/model/head/retina.py -> build/lib/tfdet/model/head
# copying tfdet/model/head/fcos.py -> build/lib/tfdet/model/head
# copying tfdet/model/head/rcnn.py -> build/lib/tfdet/model/head
# creating build/lib/tfdet/model/detector
# copying tfdet/model/detector/effdet.py -> build/lib/tfdet/model/detector
# copying tfdet/model/detector/yolo.py -> build/lib/tfdet/model/detector
# copying tfdet/model/detector/__init__.py -> build/lib/tfdet/model/detector
# copying tfdet/model/detector/retina.py -> build/lib/tfdet/model/detector
# copying tfdet/model/detector/fcos.py -> build/lib/tfdet/model/detector
# copying tfdet/model/detector/rcnn.py -> build/lib/tfdet/model/detector
# creating build/lib/tfdet/model/train
# copying tfdet/model/train/yolo.py -> build/lib/tfdet/model/train
# copying tfdet/model/train/__init__.py -> build/lib/tfdet/model/train
# copying tfdet/model/train/retina.py -> build/lib/tfdet/model/train
# copying tfdet/model/train/fcos.py -> build/lib/tfdet/model/train
# copying tfdet/model/train/rcnn.py -> build/lib/tfdet/model/train
# creating build/lib/tfdet/model/postprocess
# copying tfdet/model/postprocess/yolo.py -> build/lib/tfdet/model/postprocess
# copying tfdet/model/postprocess/__init__.py -> build/lib/tfdet/model/postprocess
# copying tfdet/model/postprocess/retina.py -> build/lib/tfdet/model/postprocess
# copying tfdet/model/postprocess/rcnn.py -> build/lib/tfdet/model/postprocess
# installing to build/bdist.linux-x86_64/wheel
# running install
# running install_lib
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/wheel
# creating build/bdist.linux-x86_64/wheel/tfdet
# creating build/bdist.linux-x86_64/wheel/tfdet/core
# copying build/lib/tfdet/core/__init__.py -> build/bdist.linux-x86_64/wheel/tfdet/core
# creating build/bdist.linux-x86_64/wheel/tfdet/core/target
# copying build/lib/tfdet/core/target/rcnn_target.py -> build/bdist.linux-x86_64/wheel/tfdet/core/target
# copying build/lib/tfdet/core/target/__init__.py -> build/bdist.linux-x86_64/wheel/tfdet/core/target
# copying build/lib/tfdet/core/target/anchor_target.py -> build/bdist.linux-x86_64/wheel/tfdet/core/target
# copying build/lib/tfdet/core/target/yolo_target.py -> build/bdist.linux-x86_64/wheel/tfdet/core/target
# copying build/lib/tfdet/core/target/point_target.py -> build/bdist.linux-x86_64/wheel/tfdet/core/target
# creating build/bdist.linux-x86_64/wheel/tfdet/core/util
# copying build/lib/tfdet/core/util/nms.py -> build/bdist.linux-x86_64/wheel/tfdet/core/util
# copying build/lib/tfdet/core/util/anchor.py -> build/bdist.linux-x86_64/wheel/tfdet/core/util
# copying build/lib/tfdet/core/util/__init__.py -> build/bdist.linux-x86_64/wheel/tfdet/core/util
# copying build/lib/tfdet/core/util/loss.py -> build/bdist.linux-x86_64/wheel/tfdet/core/util
# copying build/lib/tfdet/core/util/overlap.py -> build/bdist.linux-x86_64/wheel/tfdet/core/util
# copying build/lib/tfdet/core/util/tf.py -> build/bdist.linux-x86_64/wheel/tfdet/core/util
# copying build/lib/tfdet/core/util/bbox.py -> build/bdist.linux-x86_64/wheel/tfdet/core/util
# copying build/lib/tfdet/__init__.py -> build/bdist.linux-x86_64/wheel/tfdet
# creating build/bdist.linux-x86_64/wheel/tfdet/util
# copying build/lib/tfdet/util/metric.py -> build/bdist.linux-x86_64/wheel/tfdet/util
# copying build/lib/tfdet/util/__init__.py -> build/bdist.linux-x86_64/wheel/tfdet/util
# copying build/lib/tfdet/util/visualize.py -> build/bdist.linux-x86_64/wheel/tfdet/util
# creating build/bdist.linux-x86_64/wheel/tfdet/model
# creating build/bdist.linux-x86_64/wheel/tfdet/model/backbone
# copying build/lib/tfdet/model/backbone/darknet.py -> build/bdist.linux-x86_64/wheel/tfdet/model/backbone
# copying build/lib/tfdet/model/backbone/densenet.py -> build/bdist.linux-x86_64/wheel/tfdet/model/backbone
# copying build/lib/tfdet/model/backbone/vgg.py -> build/bdist.linux-x86_64/wheel/tfdet/model/backbone
# copying build/lib/tfdet/model/backbone/mobilenet.py -> build/bdist.linux-x86_64/wheel/tfdet/model/backbone
# copying build/lib/tfdet/model/backbone/__init__.py -> build/bdist.linux-x86_64/wheel/tfdet/model/backbone
# copying build/lib/tfdet/model/backbone/swin_transformer.py -> build/bdist.linux-x86_64/wheel/tfdet/model/backbone
# copying build/lib/tfdet/model/backbone/effnet.py -> build/bdist.linux-x86_64/wheel/tfdet/model/backbone
# copying build/lib/tfdet/model/backbone/resnest.py -> build/bdist.linux-x86_64/wheel/tfdet/model/backbone
# copying build/lib/tfdet/model/backbone/resnet_torch.py -> build/bdist.linux-x86_64/wheel/tfdet/model/backbone
# copying build/lib/tfdet/model/backbone/resnet.py -> build/bdist.linux-x86_64/wheel/tfdet/model/backbone
# creating build/bdist.linux-x86_64/wheel/tfdet/model/loss
# copying build/lib/tfdet/model/loss/yolo.py -> build/bdist.linux-x86_64/wheel/tfdet/model/loss
# copying build/lib/tfdet/model/loss/common.py -> build/bdist.linux-x86_64/wheel/tfdet/model/loss
# copying build/lib/tfdet/model/loss/__init__.py -> build/bdist.linux-x86_64/wheel/tfdet/model/loss
# copying build/lib/tfdet/model/loss/retina.py -> build/bdist.linux-x86_64/wheel/tfdet/model/loss
# copying build/lib/tfdet/model/loss/fcos.py -> build/bdist.linux-x86_64/wheel/tfdet/model/loss
# copying build/lib/tfdet/model/loss/rcnn.py -> build/bdist.linux-x86_64/wheel/tfdet/model/loss
# copying build/lib/tfdet/model/__init__.py -> build/bdist.linux-x86_64/wheel/tfdet/model
# creating build/bdist.linux-x86_64/wheel/tfdet/model/neck
# copying build/lib/tfdet/model/neck/__init__.py -> build/bdist.linux-x86_64/wheel/tfdet/model/neck
# copying build/lib/tfdet/model/neck/fpn.py -> build/bdist.linux-x86_64/wheel/tfdet/model/neck
# creating build/bdist.linux-x86_64/wheel/tfdet/model/head
# copying build/lib/tfdet/model/head/yolo.py -> build/bdist.linux-x86_64/wheel/tfdet/model/head
# copying build/lib/tfdet/model/head/__init__.py -> build/bdist.linux-x86_64/wheel/tfdet/model/head
# copying build/lib/tfdet/model/head/retina.py -> build/bdist.linux-x86_64/wheel/tfdet/model/head
# copying build/lib/tfdet/model/head/fcos.py -> build/bdist.linux-x86_64/wheel/tfdet/model/head
# copying build/lib/tfdet/model/head/rcnn.py -> build/bdist.linux-x86_64/wheel/tfdet/model/head
# creating build/bdist.linux-x86_64/wheel/tfdet/model/detector
# copying build/lib/tfdet/model/detector/effdet.py -> build/bdist.linux-x86_64/wheel/tfdet/model/detector
# copying build/lib/tfdet/model/detector/yolo.py -> build/bdist.linux-x86_64/wheel/tfdet/model/detector
# copying build/lib/tfdet/model/detector/__init__.py -> build/bdist.linux-x86_64/wheel/tfdet/model/detector
# copying build/lib/tfdet/model/detector/retina.py -> build/bdist.linux-x86_64/wheel/tfdet/model/detector
# copying build/lib/tfdet/model/detector/fcos.py -> build/bdist.linux-x86_64/wheel/tfdet/model/detector
# copying build/lib/tfdet/model/detector/rcnn.py -> build/bdist.linux-x86_64/wheel/tfdet/model/detector
# creating build/bdist.linux-x86_64/wheel/tfdet/model/train
# copying build/lib/tfdet/model/train/yolo.py -> build/bdist.linux-x86_64/wheel/tfdet/model/train
# copying build/lib/tfdet/model/train/__init__.py -> build/bdist.linux-x86_64/wheel/tfdet/model/train
# copying build/lib/tfdet/model/train/retina.py -> build/bdist.linux-x86_64/wheel/tfdet/model/train
# copying build/lib/tfdet/model/train/fcos.py -> build/bdist.linux-x86_64/wheel/tfdet/model/train
# copying build/lib/tfdet/model/train/rcnn.py -> build/bdist.linux-x86_64/wheel/tfdet/model/train
# creating build/bdist.linux-x86_64/wheel/tfdet/model/postprocess
# copying build/lib/tfdet/model/postprocess/yolo.py -> build/bdist.linux-x86_64/wheel/tfdet/model/postprocess
# copying build/lib/tfdet/model/postprocess/__init__.py -> build/bdist.linux-x86_64/wheel/tfdet/model/postprocess
# copying build/lib/tfdet/model/postprocess/retina.py -> build/bdist.linux-x86_64/wheel/tfdet/model/postprocess
# copying build/lib/tfdet/model/postprocess/rcnn.py -> build/bdist.linux-x86_64/wheel/tfdet/model/postprocess
# running install_egg_info
# running egg_info
# creating tfdet.egg-info
# writing tfdet.egg-info/PKG-INFO
# writing dependency_links to tfdet.egg-info/dependency_links.txt
# writing requirements to tfdet.egg-info/requires.txt
# writing top-level names to tfdet.egg-info/top_level.txt
# writing manifest file 'tfdet.egg-info/SOURCES.txt'
# adding license file 'LICENSE'
# writing manifest file 'tfdet.egg-info/SOURCES.txt'
# Copying tfdet.egg-info to build/bdist.linux-x86_64/wheel/tfdet-1.0.0-py3.7.egg-info
# running install_scripts
# adding license file "LICENSE" (matched pattern "LICEN[CS]E*")
# creating build/bdist.linux-x86_64/wheel/tfdet-1.0.0.dist-info/WHEEL
# creating 'dist/tfdet-1.0.0-py3-none-any.whl' and adding 'build/bdist.linux-x86_64/wheel' to it
# adding 'tfdet/__init__.py'
# adding 'tfdet/core/__init__.py'
# adding 'tfdet/core/target/__init__.py'
# adding 'tfdet/core/target/anchor_target.py'
# adding 'tfdet/core/target/point_target.py'
# adding 'tfdet/core/target/rcnn_target.py'
# adding 'tfdet/core/target/yolo_target.py'
# adding 'tfdet/core/util/__init__.py'
# adding 'tfdet/core/util/anchor.py'
# adding 'tfdet/core/util/bbox.py'
# adding 'tfdet/core/util/loss.py'
# adding 'tfdet/core/util/nms.py'
# adding 'tfdet/core/util/overlap.py'
# adding 'tfdet/core/util/tf.py'
# adding 'tfdet/model/__init__.py'
# adding 'tfdet/model/backbone/__init__.py'
# adding 'tfdet/model/backbone/darknet.py'
# adding 'tfdet/model/backbone/densenet.py'
# adding 'tfdet/model/backbone/effnet.py'
# adding 'tfdet/model/backbone/mobilenet.py'
# adding 'tfdet/model/backbone/resnest.py'
# adding 'tfdet/model/backbone/resnet.py'
# adding 'tfdet/model/backbone/resnet_torch.py'
# adding 'tfdet/model/backbone/swin_transformer.py'
# adding 'tfdet/model/backbone/vgg.py'
# adding 'tfdet/model/detector/__init__.py'
# adding 'tfdet/model/detector/effdet.py'
# adding 'tfdet/model/detector/fcos.py'
# adding 'tfdet/model/detector/rcnn.py'
# adding 'tfdet/model/detector/retina.py'
# adding 'tfdet/model/detector/yolo.py'
# adding 'tfdet/model/head/__init__.py'
# adding 'tfdet/model/head/fcos.py'
# adding 'tfdet/model/head/rcnn.py'
# adding 'tfdet/model/head/retina.py'
# adding 'tfdet/model/head/yolo.py'
# adding 'tfdet/model/loss/__init__.py'
# adding 'tfdet/model/loss/common.py'
# adding 'tfdet/model/loss/fcos.py'
# adding 'tfdet/model/loss/rcnn.py'
# adding 'tfdet/model/loss/retina.py'
# adding 'tfdet/model/loss/yolo.py'
# adding 'tfdet/model/neck/__init__.py'
# adding 'tfdet/model/neck/fpn.py'
# adding 'tfdet/model/postprocess/__init__.py'
# adding 'tfdet/model/postprocess/rcnn.py'
# adding 'tfdet/model/postprocess/retina.py'
# adding 'tfdet/model/postprocess/yolo.py'
# adding 'tfdet/model/train/__init__.py'
# adding 'tfdet/model/train/fcos.py'
# adding 'tfdet/model/train/rcnn.py'
# adding 'tfdet/model/train/retina.py'
# adding 'tfdet/model/train/yolo.py'
# adding 'tfdet/util/__init__.py'
# adding 'tfdet/util/metric.py'
# adding 'tfdet/util/visualize.py'
# adding 'tfdet-1.0.0.dist-info/LICENSE'
# adding 'tfdet-1.0.0.dist-info/METADATA'
# adding 'tfdet-1.0.0.dist-info/WHEEL'
# adding 'tfdet-1.0.0.dist-info/top_level.txt'
# adding 'tfdet-1.0.0.dist-info/RECORD'
# removing build/bdist.linux-x86_64/wheel
# Processing ./dist/tfdet-1.0.0-py3-none-any.whl
# Requirement already satisfied: tensorflow>=2.4 in /usr/local/lib/python3.7/dist-packages (from tfdet==1.0.0) (2.8.0)
# Requirement already satisfied: keras in /usr/local/lib/python3.7/dist-packages (from tfdet==1.0.0) (2.8.0)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.4->tfdet==1.0.0) (2.8.0)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.4->tfdet==1.0.0) (1.21.5)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.4->tfdet==1.0.0) (1.0.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.4->tfdet==1.0.0) (0.2.0)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.4->tfdet==1.0.0) (0.5.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.4->tfdet==1.0.0) (1.44.0)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.4->tfdet==1.0.0) (2.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.4->tfdet==1.0.0) (1.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.4->tfdet==1.0.0) (1.15.0)
# Collecting tf-estimator-nightly==2.8.0.dev2021122109
#   Downloading tf_estimator_nightly-2.8.0.dev2021122109-py2.py3-none-any.whl (462 kB)
#      |████████████████████████████████| 462 kB 30.8 MB/s
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.4->tfdet==1.0.0) (1.14.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.4->tfdet==1.0.0) (3.3.0)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.4->tfdet==1.0.0) (13.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.4->tfdet==1.0.0) (57.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.4->tfdet==1.0.0) (1.6.3)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.4->tfdet==1.0.0) (3.17.3)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.4->tfdet==1.0.0) (3.1.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.4->tfdet==1.0.0) (1.1.2)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.4->tfdet==1.0.0) (0.24.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.4->tfdet==1.0.0) (3.10.0.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow>=2.4->tfdet==1.0.0) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow>=2.4->tfdet==1.0.0) (1.5.2)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.4->tfdet==1.0.0) (1.0.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.4->tfdet==1.0.0) (1.35.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.4->tfdet==1.0.0) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.4->tfdet==1.0.0) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.4->tfdet==1.0.0) (0.6.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.4->tfdet==1.0.0) (2.23.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.4->tfdet==1.0.0) (3.3.6)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.4->tfdet==1.0.0) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.4->tfdet==1.0.0) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.4->tfdet==1.0.0) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow>=2.4->tfdet==1.0.0) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow>=2.4->tfdet==1.0.0) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow>=2.4->tfdet==1.0.0) (3.7.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.4->tfdet==1.0.0) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow>=2.4->tfdet==1.0.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow>=2.4->tfdet==1.0.0) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow>=2.4->tfdet==1.0.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow>=2.4->tfdet==1.0.0) (1.24.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow>=2.4->tfdet==1.0.0) (3.2.0)
# Installing collected packages: tf-estimator-nightly, tfdet
# Successfully installed tf-estimator-nightly-2.8.0.dev2021122109 tfdet-1.0.0

# %%
# !wget -qq https://github.com/matterport/Mask_RCNN/releases/download/v2.1/balloon_dataset.zip
# !unzip -qq balloon_dataset.zip

import os
import json
import cv2
import skimage.draw
import tensorflow as tf
import numpy as np

def parse(path, target_size = (512, 512), method = cv2.INTER_CUBIC):
    dir_path = os.path.dirname(path)
    with open(path, "r") as file:
        anno = json.loads(file.read())
    anno = [a for a in list(anno.values()) if a["regions"]]

    images = []
    masks = []
    for a in anno:
        if type(a['regions']) is dict:
            polygons = [r['shape_attributes'] for r in a['regions'].values()]
        else:
            polygons = [r['shape_attributes'] for r in a['regions']]
        image = cv2.cvtColor(cv2.imread(os.path.join(dir_path, a["filename"]), -1), cv2.COLOR_BGR2RGB)
        h, w = np.shape(image)[:2]
        mask = np.zeros((h, w, len(polygons)), dtype = np.uint8)
        for i, p in enumerate(polygons):
            rr, cc = skimage.draw.polygon(p['all_points_y'], p['all_points_x'])
            rr = np.clip(rr, 0, h - 1)
            cc = np.clip(cc, 0, w - 1)
            mask[rr, cc, i] = 1
        
        if target_size is not None:
            image = cv2.resize(image, target_size[::-1], interpolation = method)
            mask = cv2.resize(mask, target_size[::-1], interpolation = method)
            if np.ndim(mask) == 2:
                mask = np.expand_dims(mask, axis = -1)
            mask = np.where(mask != 0, 1, 0)

        images.append(image)
        masks.append(np.transpose(mask, [2, 0, 1]))
    return images, masks

def mask2bbox(mask_true, normalize = True, decimal = 4):
    #mask_true = #(padded_num_true, h, w, 1)
    padded_num_true, h, w = np.shape(mask_true)[:3]

    bbox_true = []
    for index in range(padded_num_true):
        mask = mask_true[index]
        if 0 < np.max(mask):
            pos = np.where(0 < mask)[:2]
            bbox = [np.min(pos[1]), np.min(pos[0]), np.max(pos[1]), np.max(pos[0])] #x1, y1, x2, y2
        else:
            bbox = [0, 0, 0, 0]
        bbox_true.append(bbox)
    
    bbox_true = np.round(np.divide(bbox_true, [w, h, w, h]).astype(np.float32), decimal) if normalize else np.array(bbox_true, dtype = np.int32)
    return bbox_true

def pipe(data, func = None, batch_size = 2, shuffle = False):
    dataset = tf.data.Dataset.from_tensor_slices(data)
    if callable(func):
        dataset = dataset.map(func, num_parallel_calls = tf.data.experimental.AUTOTUNE)
    if shuffle:
        dataset = dataset.shuffle(buffer_size = batch_size * 10)
    dataset = dataset.batch(batch_size)
    #dataset = dataset.prefetch((batch_size * 2) + 1)
    dataset = dataset.prefetch(tf.data.experimental.AUTOTUNE)
    return dataset

tr_anno = "./balloon/train/via_region_data.json"
te_anno = "./balloon/val/via_region_data.json"

tr_x, tr_mask = parse(tr_anno, target_size = (512, 512))
te_x, te_mask = parse(te_anno, target_size = (512, 512))

max_cnt = 0
for mask in tr_mask + te_mask:
    if max_cnt < len(mask):
        max_cnt = len(mask)

tr_x = np.array(tr_x, dtype = np.float32) * 1/255
tr_mask = [np.pad(mask, [[0, max_cnt - len(mask)], [0, 0], [0, 0]]) for mask in tr_mask]
tr_mask = np.expand_dims(np.array(tr_mask, dtype = np.float32), axis = -1)
tr_bbox = np.array([mask2bbox(mask) for mask in tr_mask], dtype = np.float32)
tr_y = np.expand_dims(np.where(0 < np.max(tr_bbox, axis = -1), 1., 0.), axis = -1)

te_x = np.array(te_x, dtype = np.float32) * 1/255
te_mask = [np.pad(mask, [[0, max_cnt - len(mask)], [0, 0], [0, 0]]) for mask in te_mask]
te_mask = np.expand_dims(np.array(te_mask, dtype = np.float32), axis = -1)
te_bbox = np.array([mask2bbox(mask) for mask in te_mask], dtype = np.float32)
te_y = np.expand_dims(np.where(0 < np.max(te_bbox, axis = -1), 1., 0.), axis = -1)

# %%
import tfdet
import functools

x = tf.keras.layers.Input(shape = (512, 512, 3))
feature = tfdet.model.backbone.resnet50(x)

scale = [0.03125, 0.0625, 0.125, 0.25, 0.5] #[16, 32, 64, 128, 256]
ratio = [0.5, 1, 2]
bifpn = functools.partial(tfdet.model.neck.bifpn, weighted_add = False)

out = tfdet.model.detector.fcos(feature, n_class = 2, scale = scale, ratio = ratio, fpn = bifpn)
model = tfdet.model.train.fcos.train_model(x, *out)

# %%
import albumentations
method = [albumentations.RandomBrightness(0.2, p = 0.5),
          albumentations.RandomContrast(0.2, p = 0.5),
          albumentations.ChannelShuffle(p = 0.5)]
method = albumentations.Compose(method)
    
def aug_func(image):
    return method(image = image)["image"]

key = x.name
def func(dic):
    shape = tf.shape(dic[key])
    dic[key] = tf.reshape(tf.py_function(lambda *args: aug_func(args[0].numpy()), inp = [dic[key]], Tout = tf.float32), shape)
    return dic

batch_size = 2

tr_data = pipe({x.name:tr_x, "y_true":tr_y, "bbox_true":tr_bbox}, func = func, batch_size = batch_size, shuffle = True)
te_data = pipe({x.name:te_x, "y_true":te_y, "bbox_true":te_bbox}, batch_size = batch_size, shuffle = False)

# %%
opt = tf.keras.optimizers.SGD(5e-3, momentum = 0.9, nesterov = True)
model.compile(optimizer = opt)
model.fit(tr_data, validation_data = te_data, epochs = 100)
# Out:
# Epoch 1/100
# 31/31 [==============================] - 37s 487ms/step - loss: 1.2243 - score_accuracy: 0.5857 - score_loss: 0.0831 - regress_loss: 0.4548 - centerness_loss: 0.6859 - val_loss: 1.3338 - val_score_accuracy: 0.5000 - val_score_loss: 0.0838 - val_regress_loss: 0.6635 - val_centerness_loss: 0.5860
# Epoch 2/100
# 31/31 [==============================] - 12s 391ms/step - loss: 0.8303 - score_accuracy: 0.7206 - score_loss: 0.0688 - regress_loss: 0.0866 - centerness_loss: 0.6744 - val_loss: 1.2728 - val_score_accuracy: 0.5000 - val_score_loss: 0.0817 - val_regress_loss: 0.6081 - val_centerness_loss: 0.5825
# Epoch 3/100
# 31/31 [==============================] - 12s 393ms/step - loss: 0.7839 - score_accuracy: 0.7900 - score_loss: 0.0606 - regress_loss: 0.0627 - centerness_loss: 0.6601 - val_loss: 1.2499 - val_score_accuracy: 0.5000 - val_score_loss: 0.0807 - val_regress_loss: 0.5886 - val_centerness_loss: 0.5801
# Epoch 4/100
# 31/31 [==============================] - 12s 395ms/step - loss: 0.7512 - score_accuracy: 0.8276 - score_loss: 0.0558 - regress_loss: 0.0485 - centerness_loss: 0.6464 - val_loss: 1.2324 - val_score_accuracy: 0.5000 - val_score_loss: 0.0802 - val_regress_loss: 0.5727 - val_centerness_loss: 0.5790
# Epoch 5/100
# 31/31 [==============================] - 12s 396ms/step - loss: 0.7321 - score_accuracy: 0.8484 - score_loss: 0.0532 - regress_loss: 0.0411 - centerness_loss: 0.6373 - val_loss: 1.2178 - val_score_accuracy: 0.5000 - val_score_loss: 0.0799 - val_regress_loss: 0.5590 - val_centerness_loss: 0.5783
# Epoch 6/100
# 31/31 [==============================] - 13s 397ms/step - loss: 0.7094 - score_accuracy: 0.8685 - score_loss: 0.0497 - regress_loss: 0.0320 - centerness_loss: 0.6271 - val_loss: 1.2069 - val_score_accuracy: 0.5000 - val_score_loss: 0.0798 - val_regress_loss: 0.5488 - val_centerness_loss: 0.5778
# Epoch 7/100
# 31/31 [==============================] - 12s 395ms/step - loss: 0.7035 - score_accuracy: 0.8756 - score_loss: 0.0473 - regress_loss: 0.0292 - centerness_loss: 0.6266 - val_loss: 1.2001 - val_score_accuracy: 0.5000 - val_score_loss: 0.0800 - val_regress_loss: 0.5427 - val_centerness_loss: 0.5769
# Epoch 8/100
# 31/31 [==============================] - 12s 394ms/step - loss: 0.6887 - score_accuracy: 0.8860 - score_loss: 0.0449 - regress_loss: 0.0241 - centerness_loss: 0.6192 - val_loss: 1.1912 - val_score_accuracy: 0.5000 - val_score_loss: 0.0802 - val_regress_loss: 0.5346 - val_centerness_loss: 0.5758
# Epoch 9/100
# 31/31 [==============================] - 12s 393ms/step - loss: 0.6804 - score_accuracy: 0.8817 - score_loss: 0.0437 - regress_loss: 0.0228 - centerness_loss: 0.6134 - val_loss: 1.1873 - val_score_accuracy: 0.5000 - val_score_loss: 0.0806 - val_regress_loss: 0.5304 - val_centerness_loss: 0.5759
# Epoch 10/100
# 31/31 [==============================] - 12s 394ms/step - loss: 0.6716 - score_accuracy: 0.8918 - score_loss: 0.0414 - regress_loss: 0.0215 - centerness_loss: 0.6082 - val_loss: 1.1824 - val_score_accuracy: 0.5000 - val_score_loss: 0.0810 - val_regress_loss: 0.5267 - val_centerness_loss: 0.5742
# Epoch 11/100
# 31/31 [==============================] - 12s 395ms/step - loss: 0.6615 - score_accuracy: 0.8996 - score_loss: 0.0389 - regress_loss: 0.0205 - centerness_loss: 0.6016 - val_loss: 1.1783 - val_score_accuracy: 0.5000 - val_score_loss: 0.0816 - val_regress_loss: 0.5226 - val_centerness_loss: 0.5737
# Epoch 12/100
# 31/31 [==============================] - 12s 397ms/step - loss: 0.6591 - score_accuracy: 0.9121 - score_loss: 0.0371 - regress_loss: 0.0192 - centerness_loss: 0.6023 - val_loss: 1.1785 - val_score_accuracy: 0.5000 - val_score_loss: 0.0821 - val_regress_loss: 0.5202 - val_centerness_loss: 0.5756
# Epoch 13/100
# 31/31 [==============================] - 13s 397ms/step - loss: 0.6529 - score_accuracy: 0.9141 - score_loss: 0.0360 - regress_loss: 0.0177 - centerness_loss: 0.5987 - val_loss: 1.1766 - val_score_accuracy: 0.5000 - val_score_loss: 0.0828 - val_regress_loss: 0.5185 - val_centerness_loss: 0.5748
# Epoch 14/100
# 31/31 [==============================] - 12s 394ms/step - loss: 0.6520 - score_accuracy: 0.9172 - score_loss: 0.0347 - regress_loss: 0.0171 - centerness_loss: 0.5997 - val_loss: 1.1723 - val_score_accuracy: 0.5000 - val_score_loss: 0.0834 - val_regress_loss: 0.5155 - val_centerness_loss: 0.5728
# Epoch 15/100
# 31/31 [==============================] - 12s 396ms/step - loss: 0.6499 - score_accuracy: 0.9041 - score_loss: 0.0344 - regress_loss: 0.0170 - centerness_loss: 0.5980 - val_loss: 1.1708 - val_score_accuracy: 0.5000 - val_score_loss: 0.0841 - val_regress_loss: 0.5128 - val_centerness_loss: 0.5733
# Epoch 16/100
# 31/31 [==============================] - 12s 398ms/step - loss: 0.6444 - score_accuracy: 0.9167 - score_loss: 0.0331 - regress_loss: 0.0149 - centerness_loss: 0.5959 - val_loss: 1.1715 - val_score_accuracy: 0.5000 - val_score_loss: 0.0849 - val_regress_loss: 0.5111 - val_centerness_loss: 0.5749
# Epoch 17/100
# 31/31 [==============================] - 12s 397ms/step - loss: 0.6410 - score_accuracy: 0.9249 - score_loss: 0.0316 - regress_loss: 0.0153 - centerness_loss: 0.5936 - val_loss: 1.1668 - val_score_accuracy: 0.5000 - val_score_loss: 0.0857 - val_regress_loss: 0.5077 - val_centerness_loss: 0.5729
# Epoch 18/100
# 31/31 [==============================] - 13s 397ms/step - loss: 0.6391 - score_accuracy: 0.9201 - score_loss: 0.0309 - regress_loss: 0.0144 - centerness_loss: 0.5934 - val_loss: 1.1658 - val_score_accuracy: 0.5000 - val_score_loss: 0.0865 - val_regress_loss: 0.5051 - val_centerness_loss: 0.5736
# Epoch 19/100
# 31/31 [==============================] - 12s 395ms/step - loss: 0.6368 - score_accuracy: 0.9244 - score_loss: 0.0298 - regress_loss: 0.0148 - centerness_loss: 0.5917 - val_loss: 1.1646 - val_score_accuracy: 0.5000 - val_score_loss: 0.0873 - val_regress_loss: 0.5033 - val_centerness_loss: 0.5735
# Epoch 20/100
# 31/31 [==============================] - 12s 398ms/step - loss: 0.6336 - score_accuracy: 0.9352 - score_loss: 0.0276 - regress_loss: 0.0130 - centerness_loss: 0.5924 - val_loss: 1.1631 - val_score_accuracy: 0.5000 - val_score_loss: 0.0882 - val_regress_loss: 0.5008 - val_centerness_loss: 0.5736
# Epoch 21/100
# 31/31 [==============================] - 13s 399ms/step - loss: 0.6342 - score_accuracy: 0.9191 - score_loss: 0.0298 - regress_loss: 0.0128 - centerness_loss: 0.5911 - val_loss: 1.1602 - val_score_accuracy: 0.5000 - val_score_loss: 0.0891 - val_regress_loss: 0.4977 - val_centerness_loss: 0.5729
# Epoch 22/100
# 31/31 [==============================] - 13s 397ms/step - loss: 0.6285 - score_accuracy: 0.9257 - score_loss: 0.0283 - regress_loss: 0.0122 - centerness_loss: 0.5875 - val_loss: 1.1595 - val_score_accuracy: 0.5000 - val_score_loss: 0.0900 - val_regress_loss: 0.4950 - val_centerness_loss: 0.5739
# Epoch 23/100
# 31/31 [==============================] - 13s 404ms/step - loss: 0.6291 - score_accuracy: 0.9247 - score_loss: 0.0280 - regress_loss: 0.0143 - centerness_loss: 0.5863 - val_loss: 1.1555 - val_score_accuracy: 0.5000 - val_score_loss: 0.0909 - val_regress_loss: 0.4915 - val_centerness_loss: 0.5725
# Epoch 24/100
# 31/31 [==============================] - 13s 397ms/step - loss: 0.6240 - score_accuracy: 0.9382 - score_loss: 0.0256 - regress_loss: 0.0116 - centerness_loss: 0.5863 - val_loss: 1.1523 - val_score_accuracy: 0.5000 - val_score_loss: 0.0919 - val_regress_loss: 0.4876 - val_centerness_loss: 0.5722
# Epoch 25/100
# 31/31 [==============================] - 13s 398ms/step - loss: 0.6220 - score_accuracy: 0.9362 - score_loss: 0.0254 - regress_loss: 0.0114 - centerness_loss: 0.5846 - val_loss: 1.1530 - val_score_accuracy: 0.5000 - val_score_loss: 0.0930 - val_regress_loss: 0.4868 - val_centerness_loss: 0.5727
# Epoch 26/100
# 31/31 [==============================] - 13s 397ms/step - loss: 0.6221 - score_accuracy: 0.9399 - score_loss: 0.0243 - regress_loss: 0.0119 - centerness_loss: 0.5854 - val_loss: 1.1556 - val_score_accuracy: 0.5000 - val_score_loss: 0.0942 - val_regress_loss: 0.4848 - val_centerness_loss: 0.5761
# Epoch 27/100
# 31/31 [==============================] - 13s 401ms/step - loss: 0.6180 - score_accuracy: 0.9416 - score_loss: 0.0239 - regress_loss: 0.0108 - centerness_loss: 0.5828 - val_loss: 1.1524 - val_score_accuracy: 0.5000 - val_score_loss: 0.0955 - val_regress_loss: 0.4818 - val_centerness_loss: 0.5745
# Epoch 28/100
# 31/31 [==============================] - 13s 403ms/step - loss: 0.6153 - score_accuracy: 0.9472 - score_loss: 0.0226 - regress_loss: 0.0109 - centerness_loss: 0.5812 - val_loss: 1.1481 - val_score_accuracy: 0.5000 - val_score_loss: 0.0967 - val_regress_loss: 0.4803 - val_centerness_loss: 0.5706
# Epoch 29/100
# 31/31 [==============================] - 13s 403ms/step - loss: 0.6185 - score_accuracy: 0.9483 - score_loss: 0.0220 - regress_loss: 0.0104 - centerness_loss: 0.5855 - val_loss: 1.1509 - val_score_accuracy: 0.5000 - val_score_loss: 0.0982 - val_regress_loss: 0.4778 - val_centerness_loss: 0.5745
# Epoch 30/100
# 31/31 [==============================] - 13s 397ms/step - loss: 0.6134 - score_accuracy: 0.9470 - score_loss: 0.0210 - regress_loss: 0.0097 - centerness_loss: 0.5822 - val_loss: 1.1457 - val_score_accuracy: 0.5000 - val_score_loss: 0.0997 - val_regress_loss: 0.4748 - val_centerness_loss: 0.5707
# Epoch 31/100
# 31/31 [==============================] - 13s 398ms/step - loss: 0.6151 - score_accuracy: 0.9430 - score_loss: 0.0222 - regress_loss: 0.0099 - centerness_loss: 0.5825 - val_loss: 1.1464 - val_score_accuracy: 0.5000 - val_score_loss: 0.1012 - val_regress_loss: 0.4720 - val_centerness_loss: 0.5727
# Epoch 32/100
# 31/31 [==============================] - 13s 398ms/step - loss: 0.6191 - score_accuracy: 0.9479 - score_loss: 0.0211 - regress_loss: 0.0090 - centerness_loss: 0.5884 - val_loss: 1.1466 - val_score_accuracy: 0.5000 - val_score_loss: 0.1030 - val_regress_loss: 0.4698 - val_centerness_loss: 0.5733
# Epoch 33/100
# 31/31 [==============================] - 12s 395ms/step - loss: 0.6168 - score_accuracy: 0.9464 - score_loss: 0.0210 - regress_loss: 0.0099 - centerness_loss: 0.5854 - val_loss: 1.1438 - val_score_accuracy: 0.5000 - val_score_loss: 0.1047 - val_regress_loss: 0.4656 - val_centerness_loss: 0.5730
# Epoch 34/100
# 31/31 [==============================] - 12s 396ms/step - loss: 0.6140 - score_accuracy: 0.9433 - score_loss: 0.0213 - regress_loss: 0.0105 - centerness_loss: 0.5817 - val_loss: 1.1423 - val_score_accuracy: 0.5000 - val_score_loss: 0.1066 - val_regress_loss: 0.4632 - val_centerness_loss: 0.5720
# Epoch 35/100
# 31/31 [==============================] - 12s 395ms/step - loss: 0.6102 - score_accuracy: 0.9501 - score_loss: 0.0203 - regress_loss: 0.0091 - centerness_loss: 0.5803 - val_loss: 1.1375 - val_score_accuracy: 0.5000 - val_score_loss: 0.1080 - val_regress_loss: 0.4583 - val_centerness_loss: 0.5707
# Epoch 36/100
# 31/31 [==============================] - 12s 394ms/step - loss: 0.6088 - score_accuracy: 0.9552 - score_loss: 0.0190 - regress_loss: 0.0089 - centerness_loss: 0.5804 - val_loss: 1.1387 - val_score_accuracy: 0.5000 - val_score_loss: 0.1102 - val_regress_loss: 0.4561 - val_centerness_loss: 0.5718
# Epoch 37/100
# 31/31 [==============================] - 12s 395ms/step - loss: 0.6066 - score_accuracy: 0.9535 - score_loss: 0.0183 - regress_loss: 0.0094 - centerness_loss: 0.5784 - val_loss: 1.1367 - val_score_accuracy: 0.5000 - val_score_loss: 0.1123 - val_regress_loss: 0.4522 - val_centerness_loss: 0.5716
# Epoch 38/100
# 31/31 [==============================] - 12s 397ms/step - loss: 0.6042 - score_accuracy: 0.9625 - score_loss: 0.0165 - regress_loss: 0.0085 - centerness_loss: 0.5787 - val_loss: 1.1366 - val_score_accuracy: 0.5000 - val_score_loss: 0.1149 - val_regress_loss: 0.4496 - val_centerness_loss: 0.5716
# Epoch 39/100
# 31/31 [==============================] - 12s 396ms/step - loss: 0.6079 - score_accuracy: 0.9520 - score_loss: 0.0178 - regress_loss: 0.0097 - centerness_loss: 0.5799 - val_loss: 1.1321 - val_score_accuracy: 0.5000 - val_score_loss: 0.1176 - val_regress_loss: 0.4441 - val_centerness_loss: 0.5699
# Epoch 40/100
# 31/31 [==============================] - 13s 397ms/step - loss: 0.6015 - score_accuracy: 0.9646 - score_loss: 0.0165 - regress_loss: 0.0084 - centerness_loss: 0.5761 - val_loss: 1.1333 - val_score_accuracy: 0.5000 - val_score_loss: 0.1201 - val_regress_loss: 0.4407 - val_centerness_loss: 0.5720
# Epoch 41/100
# 31/31 [==============================] - 13s 400ms/step - loss: 0.6030 - score_accuracy: 0.9598 - score_loss: 0.0174 - regress_loss: 0.0085 - centerness_loss: 0.5765 - val_loss: 1.1315 - val_score_accuracy: 0.5000 - val_score_loss: 0.1230 - val_regress_loss: 0.4353 - val_centerness_loss: 0.5726
# Epoch 42/100
# 31/31 [==============================] - 13s 397ms/step - loss: 0.6034 - score_accuracy: 0.9625 - score_loss: 0.0161 - regress_loss: 0.0085 - centerness_loss: 0.5783 - val_loss: 1.1289 - val_score_accuracy: 0.5000 - val_score_loss: 0.1259 - val_regress_loss: 0.4304 - val_centerness_loss: 0.5721
# Epoch 43/100
# 31/31 [==============================] - 13s 400ms/step - loss: 0.6021 - score_accuracy: 0.9622 - score_loss: 0.0159 - regress_loss: 0.0079 - centerness_loss: 0.5778 - val_loss: 1.1217 - val_score_accuracy: 0.5000 - val_score_loss: 0.1287 - val_regress_loss: 0.4218 - val_centerness_loss: 0.5706
# Epoch 44/100
# 31/31 [==============================] - 12s 398ms/step - loss: 0.5998 - score_accuracy: 0.9658 - score_loss: 0.0153 - regress_loss: 0.0075 - centerness_loss: 0.5765 - val_loss: 1.1191 - val_score_accuracy: 0.5000 - val_score_loss: 0.1319 - val_regress_loss: 0.4162 - val_centerness_loss: 0.5705
# Epoch 45/100
# 31/31 [==============================] - 12s 396ms/step - loss: 0.5986 - score_accuracy: 0.9680 - score_loss: 0.0152 - regress_loss: 0.0074 - centerness_loss: 0.5755 - val_loss: 1.1162 - val_score_accuracy: 0.5000 - val_score_loss: 0.1357 - val_regress_loss: 0.4097 - val_centerness_loss: 0.5703
# Epoch 46/100
# 31/31 [==============================] - 13s 400ms/step - loss: 0.5980 - score_accuracy: 0.9684 - score_loss: 0.0146 - regress_loss: 0.0070 - centerness_loss: 0.5759 - val_loss: 1.1101 - val_score_accuracy: 0.5000 - val_score_loss: 0.1389 - val_regress_loss: 0.4015 - val_centerness_loss: 0.5692
# Epoch 47/100
# 31/31 [==============================] - 12s 398ms/step - loss: 0.5995 - score_accuracy: 0.9676 - score_loss: 0.0142 - regress_loss: 0.0070 - centerness_loss: 0.5778 - val_loss: 1.1036 - val_score_accuracy: 0.5000 - val_score_loss: 0.1408 - val_regress_loss: 0.3926 - val_centerness_loss: 0.5697
# Epoch 48/100
# 31/31 [==============================] - 13s 400ms/step - loss: 0.5985 - score_accuracy: 0.9631 - score_loss: 0.0143 - regress_loss: 0.0070 - centerness_loss: 0.5767 - val_loss: 1.1001 - val_score_accuracy: 0.5000 - val_score_loss: 0.1449 - val_regress_loss: 0.3855 - val_centerness_loss: 0.5691
# Epoch 49/100
# 31/31 [==============================] - 13s 401ms/step - loss: 0.5973 - score_accuracy: 0.9671 - score_loss: 0.0132 - regress_loss: 0.0079 - centerness_loss: 0.5756 - val_loss: 1.0904 - val_score_accuracy: 0.5000 - val_score_loss: 0.1476 - val_regress_loss: 0.3740 - val_centerness_loss: 0.5683
# Epoch 50/100
# 31/31 [==============================] - 12s 396ms/step - loss: 0.5976 - score_accuracy: 0.9634 - score_loss: 0.0150 - regress_loss: 0.0075 - centerness_loss: 0.5745 - val_loss: 1.0789 - val_score_accuracy: 0.5000 - val_score_loss: 0.1499 - val_regress_loss: 0.3633 - val_centerness_loss: 0.5652
# Epoch 51/100
# 31/31 [==============================] - 12s 395ms/step - loss: 0.5989 - score_accuracy: 0.9652 - score_loss: 0.0148 - regress_loss: 0.0076 - centerness_loss: 0.5759 - val_loss: 1.0754 - val_score_accuracy: 0.5000 - val_score_loss: 0.1530 - val_regress_loss: 0.3546 - val_centerness_loss: 0.5673
# Epoch 52/100
# 31/31 [==============================] - 13s 398ms/step - loss: 0.5936 - score_accuracy: 0.9735 - score_loss: 0.0120 - regress_loss: 0.0066 - centerness_loss: 0.5745 - val_loss: 1.0638 - val_score_accuracy: 0.5000 - val_score_loss: 0.1558 - val_regress_loss: 0.3439 - val_centerness_loss: 0.5636
# Epoch 53/100
# 31/31 [==============================] - 12s 398ms/step - loss: 0.6007 - score_accuracy: 0.9725 - score_loss: 0.0128 - regress_loss: 0.0067 - centerness_loss: 0.5806 - val_loss: 1.0554 - val_score_accuracy: 0.5000 - val_score_loss: 0.1572 - val_regress_loss: 0.3329 - val_centerness_loss: 0.5648
# Epoch 54/100
# 31/31 [==============================] - 13s 402ms/step - loss: 0.5958 - score_accuracy: 0.9700 - score_loss: 0.0131 - regress_loss: 0.0071 - centerness_loss: 0.5751 - val_loss: 1.0343 - val_score_accuracy: 0.5000 - val_score_loss: 0.1584 - val_regress_loss: 0.3148 - val_centerness_loss: 0.5605
# Epoch 55/100
# 31/31 [==============================] - 13s 397ms/step - loss: 0.5936 - score_accuracy: 0.9730 - score_loss: 0.0122 - regress_loss: 0.0064 - centerness_loss: 0.5744 - val_loss: 1.0113 - val_score_accuracy: 0.5000 - val_score_loss: 0.1561 - val_regress_loss: 0.2986 - val_centerness_loss: 0.5561
# Epoch 56/100
# 31/31 [==============================] - 13s 399ms/step - loss: 0.5978 - score_accuracy: 0.9645 - score_loss: 0.0147 - regress_loss: 0.0079 - centerness_loss: 0.5747 - val_loss: 1.0161 - val_score_accuracy: 0.5000 - val_score_loss: 0.1671 - val_regress_loss: 0.2913 - val_centerness_loss: 0.5572
# Epoch 57/100
# 31/31 [==============================] - 13s 399ms/step - loss: 0.5960 - score_accuracy: 0.9628 - score_loss: 0.0142 - regress_loss: 0.0068 - centerness_loss: 0.5745 - val_loss: 0.9843 - val_score_accuracy: 0.5000 - val_score_loss: 0.1527 - val_regress_loss: 0.2754 - val_centerness_loss: 0.5557
# Epoch 58/100
# 31/31 [==============================] - 13s 396ms/step - loss: 0.5922 - score_accuracy: 0.9719 - score_loss: 0.0122 - regress_loss: 0.0062 - centerness_loss: 0.5734 - val_loss: 0.9656 - val_score_accuracy: 0.5000 - val_score_loss: 0.1528 - val_regress_loss: 0.2593 - val_centerness_loss: 0.5530
# Epoch 59/100
# 31/31 [==============================] - 12s 396ms/step - loss: 0.5917 - score_accuracy: 0.9763 - score_loss: 0.0111 - regress_loss: 0.0062 - centerness_loss: 0.5738 - val_loss: 0.9566 - val_score_accuracy: 0.5000 - val_score_loss: 0.1571 - val_regress_loss: 0.2493 - val_centerness_loss: 0.5496
# Epoch 60/100
# 31/31 [==============================] - 12s 395ms/step - loss: 0.5925 - score_accuracy: 0.9698 - score_loss: 0.0119 - regress_loss: 0.0060 - centerness_loss: 0.5741 - val_loss: 0.9311 - val_score_accuracy: 0.5000 - val_score_loss: 0.1521 - val_regress_loss: 0.2328 - val_centerness_loss: 0.5456
# Epoch 61/100
# 31/31 [==============================] - 13s 396ms/step - loss: 0.5903 - score_accuracy: 0.9768 - score_loss: 0.0114 - regress_loss: 0.0063 - centerness_loss: 0.5720 - val_loss: 0.9046 - val_score_accuracy: 0.5000 - val_score_loss: 0.1419 - val_regress_loss: 0.2183 - val_centerness_loss: 0.5438
# Epoch 62/100
# 31/31 [==============================] - 13s 400ms/step - loss: 0.5918 - score_accuracy: 0.9744 - score_loss: 0.0113 - regress_loss: 0.0062 - centerness_loss: 0.5738 - val_loss: 0.9068 - val_score_accuracy: 0.5000 - val_score_loss: 0.1545 - val_regress_loss: 0.2107 - val_centerness_loss: 0.5411
# Epoch 63/100
# 31/31 [==============================] - 13s 400ms/step - loss: 0.5916 - score_accuracy: 0.9768 - score_loss: 0.0106 - regress_loss: 0.0063 - centerness_loss: 0.5743 - val_loss: 0.8588 - val_score_accuracy: 0.5127 - val_score_loss: 0.1266 - val_regress_loss: 0.1920 - val_centerness_loss: 0.5396
# Epoch 64/100
# 31/31 [==============================] - 13s 402ms/step - loss: 0.5906 - score_accuracy: 0.9767 - score_loss: 0.0100 - regress_loss: 0.0058 - centerness_loss: 0.5743 - val_loss: 0.8419 - val_score_accuracy: 0.5281 - val_score_loss: 0.1274 - val_regress_loss: 0.1785 - val_centerness_loss: 0.5355
# Epoch 65/100
# 31/31 [==============================] - 13s 402ms/step - loss: 0.5912 - score_accuracy: 0.9753 - score_loss: 0.0113 - regress_loss: 0.0066 - centerness_loss: 0.5728 - val_loss: 0.8152 - val_score_accuracy: 0.5556 - val_score_loss: 0.1228 - val_regress_loss: 0.1622 - val_centerness_loss: 0.5297
# Epoch 66/100
# 31/31 [==============================] - 13s 399ms/step - loss: 0.5899 - score_accuracy: 0.9748 - score_loss: 0.0115 - regress_loss: 0.0059 - centerness_loss: 0.5720 - val_loss: 0.8289 - val_score_accuracy: 0.5714 - val_score_loss: 0.1333 - val_regress_loss: 0.1623 - val_centerness_loss: 0.5327
# Epoch 67/100
# 31/31 [==============================] - 13s 401ms/step - loss: 0.5904 - score_accuracy: 0.9799 - score_loss: 0.0098 - regress_loss: 0.0058 - centerness_loss: 0.5744 - val_loss: 0.7865 - val_score_accuracy: 0.6198 - val_score_loss: 0.1180 - val_regress_loss: 0.1389 - val_centerness_loss: 0.5291
# Epoch 68/100
# 31/31 [==============================] - 13s 399ms/step - loss: 0.5877 - score_accuracy: 0.9806 - score_loss: 0.0098 - regress_loss: 0.0059 - centerness_loss: 0.5715 - val_loss: 0.7625 - val_score_accuracy: 0.6451 - val_score_loss: 0.1090 - val_regress_loss: 0.1257 - val_centerness_loss: 0.5273
# Epoch 69/100
# 31/31 [==============================] - 13s 400ms/step - loss: 0.5881 - score_accuracy: 0.9811 - score_loss: 0.0094 - regress_loss: 0.0058 - centerness_loss: 0.5724 - val_loss: 0.7440 - val_score_accuracy: 0.6783 - val_score_loss: 0.1050 - val_regress_loss: 0.1146 - val_centerness_loss: 0.5239
# Epoch 70/100
# 31/31 [==============================] - 13s 398ms/step - loss: 0.5886 - score_accuracy: 0.9783 - score_loss: 0.0101 - regress_loss: 0.0058 - centerness_loss: 0.5722 - val_loss: 0.7212 - val_score_accuracy: 0.7477 - val_score_loss: 0.0894 - val_regress_loss: 0.1079 - val_centerness_loss: 0.5234
# Epoch 71/100
# 31/31 [==============================] - 12s 396ms/step - loss: 0.5869 - score_accuracy: 0.9780 - score_loss: 0.0092 - regress_loss: 0.0054 - centerness_loss: 0.5717 - val_loss: 0.7135 - val_score_accuracy: 0.7250 - val_score_loss: 0.0895 - val_regress_loss: 0.1010 - val_centerness_loss: 0.5225
# Epoch 72/100
# 31/31 [==============================] - 13s 398ms/step - loss: 0.5902 - score_accuracy: 0.9725 - score_loss: 0.0113 - regress_loss: 0.0061 - centerness_loss: 0.5724 - val_loss: 0.7394 - val_score_accuracy: 0.6840 - val_score_loss: 0.1220 - val_regress_loss: 0.0975 - val_centerness_loss: 0.5194
# Epoch 73/100
# 31/31 [==============================] - 12s 395ms/step - loss: 0.5886 - score_accuracy: 0.9760 - score_loss: 0.0101 - regress_loss: 0.0061 - centerness_loss: 0.5719 - val_loss: 0.6954 - val_score_accuracy: 0.7165 - val_score_loss: 0.0983 - val_regress_loss: 0.0785 - val_centerness_loss: 0.5181
# Epoch 74/100
# 31/31 [==============================] - 12s 397ms/step - loss: 0.5860 - score_accuracy: 0.9812 - score_loss: 0.0085 - regress_loss: 0.0056 - centerness_loss: 0.5714 - val_loss: 0.6683 - val_score_accuracy: 0.8008 - val_score_loss: 0.0745 - val_regress_loss: 0.0749 - val_centerness_loss: 0.5184
# Epoch 75/100
# 31/31 [==============================] - 13s 401ms/step - loss: 0.5878 - score_accuracy: 0.9803 - score_loss: 0.0089 - regress_loss: 0.0059 - centerness_loss: 0.5724 - val_loss: 0.6574 - val_score_accuracy: 0.8061 - val_score_loss: 0.0773 - val_regress_loss: 0.0669 - val_centerness_loss: 0.5127
# Epoch 76/100
# 31/31 [==============================] - 13s 400ms/step - loss: 0.5853 - score_accuracy: 0.9831 - score_loss: 0.0089 - regress_loss: 0.0052 - centerness_loss: 0.5707 - val_loss: 0.6376 - val_score_accuracy: 0.8250 - val_score_loss: 0.0613 - val_regress_loss: 0.0612 - val_centerness_loss: 0.5146
# Epoch 77/100
# 31/31 [==============================] - 13s 403ms/step - loss: 0.5845 - score_accuracy: 0.9843 - score_loss: 0.0088 - regress_loss: 0.0055 - centerness_loss: 0.5697 - val_loss: 0.6699 - val_score_accuracy: 0.7445 - val_score_loss: 0.0994 - val_regress_loss: 0.0564 - val_centerness_loss: 0.5136
# Epoch 78/100
# 31/31 [==============================] - 13s 399ms/step - loss: 0.5847 - score_accuracy: 0.9822 - score_loss: 0.0078 - regress_loss: 0.0051 - centerness_loss: 0.5712 - val_loss: 0.6308 - val_score_accuracy: 0.8260 - val_score_loss: 0.0714 - val_regress_loss: 0.0479 - val_centerness_loss: 0.5109
# Epoch 79/100
# 31/31 [==============================] - 13s 404ms/step - loss: 0.5839 - score_accuracy: 0.9815 - score_loss: 0.0083 - regress_loss: 0.0051 - centerness_loss: 0.5699 - val_loss: 0.6257 - val_score_accuracy: 0.8304 - val_score_loss: 0.0706 - val_regress_loss: 0.0430 - val_centerness_loss: 0.5116
# Epoch 80/100
# 31/31 [==============================] - 13s 405ms/step - loss: 0.5863 - score_accuracy: 0.9755 - score_loss: 0.0094 - regress_loss: 0.0055 - centerness_loss: 0.5709 - val_loss: 0.6099 - val_score_accuracy: 0.8535 - val_score_loss: 0.0603 - val_regress_loss: 0.0403 - val_centerness_loss: 0.5088
# Epoch 81/100
# 31/31 [==============================] - 13s 400ms/step - loss: 0.5857 - score_accuracy: 0.9790 - score_loss: 0.0099 - regress_loss: 0.0052 - centerness_loss: 0.5702 - val_loss: 0.6233 - val_score_accuracy: 0.8068 - val_score_loss: 0.0784 - val_regress_loss: 0.0364 - val_centerness_loss: 0.5080
# Epoch 82/100
# 31/31 [==============================] - 13s 399ms/step - loss: 0.5877 - score_accuracy: 0.9798 - score_loss: 0.0088 - regress_loss: 0.0058 - centerness_loss: 0.5726 - val_loss: 0.6125 - val_score_accuracy: 0.8494 - val_score_loss: 0.0714 - val_regress_loss: 0.0325 - val_centerness_loss: 0.5082
# Epoch 83/100
# 31/31 [==============================] - 13s 397ms/step - loss: 0.5868 - score_accuracy: 0.9728 - score_loss: 0.0112 - regress_loss: 0.0059 - centerness_loss: 0.5692 - val_loss: 0.6205 - val_score_accuracy: 0.8231 - val_score_loss: 0.0764 - val_regress_loss: 0.0354 - val_centerness_loss: 0.5082
# Epoch 84/100
# 31/31 [==============================] - 12s 396ms/step - loss: 0.5853 - score_accuracy: 0.9801 - score_loss: 0.0087 - regress_loss: 0.0051 - centerness_loss: 0.5709 - val_loss: 0.5901 - val_score_accuracy: 0.8717 - val_score_loss: 0.0442 - val_regress_loss: 0.0370 - val_centerness_loss: 0.5085
# Epoch 85/100
# 31/31 [==============================] - 12s 395ms/step - loss: 0.5837 - score_accuracy: 0.9802 - score_loss: 0.0085 - regress_loss: 0.0047 - centerness_loss: 0.5699 - val_loss: 0.6037 - val_score_accuracy: 0.8427 - val_score_loss: 0.0662 - val_regress_loss: 0.0294 - val_centerness_loss: 0.5076
# Epoch 86/100
# 31/31 [==============================] - 12s 396ms/step - loss: 0.5828 - score_accuracy: 0.9805 - score_loss: 0.0081 - regress_loss: 0.0051 - centerness_loss: 0.5691 - val_loss: 0.5920 - val_score_accuracy: 0.8535 - val_score_loss: 0.0638 - val_regress_loss: 0.0246 - val_centerness_loss: 0.5031
# Epoch 87/100
# 31/31 [==============================] - 12s 398ms/step - loss: 0.5834 - score_accuracy: 0.9849 - score_loss: 0.0075 - regress_loss: 0.0049 - centerness_loss: 0.5705 - val_loss: 0.5813 - val_score_accuracy: 0.8694 - val_score_loss: 0.0535 - val_regress_loss: 0.0218 - val_centerness_loss: 0.5055
# Epoch 88/100
# 31/31 [==============================] - 12s 397ms/step - loss: 0.5859 - score_accuracy: 0.9791 - score_loss: 0.0090 - regress_loss: 0.0054 - centerness_loss: 0.5709 - val_loss: 0.5954 - val_score_accuracy: 0.8566 - val_score_loss: 0.0644 - val_regress_loss: 0.0233 - val_centerness_loss: 0.5072
# Epoch 89/100
# 31/31 [==============================] - 14s 427ms/step - loss: 0.5820 - score_accuracy: 0.9851 - score_loss: 0.0072 - regress_loss: 0.0047 - centerness_loss: 0.5696 - val_loss: 0.6029 - val_score_accuracy: 0.8508 - val_score_loss: 0.0771 - val_regress_loss: 0.0229 - val_centerness_loss: 0.5023
# Epoch 90/100
# 31/31 [==============================] - 13s 416ms/step - loss: 0.5838 - score_accuracy: 0.9834 - score_loss: 0.0081 - regress_loss: 0.0046 - centerness_loss: 0.5706 - val_loss: 0.5641 - val_score_accuracy: 0.8852 - val_score_loss: 0.0382 - val_regress_loss: 0.0195 - val_centerness_loss: 0.5059
# Epoch 91/100
# 31/31 [==============================] - 12s 395ms/step - loss: 0.5815 - score_accuracy: 0.9808 - score_loss: 0.0084 - regress_loss: 0.0051 - centerness_loss: 0.5675 - val_loss: 0.6095 - val_score_accuracy: 0.8106 - val_score_loss: 0.0847 - val_regress_loss: 0.0205 - val_centerness_loss: 0.5038
# Epoch 92/100
# 31/31 [==============================] - 12s 395ms/step - loss: 0.5816 - score_accuracy: 0.9856 - score_loss: 0.0070 - regress_loss: 0.0049 - centerness_loss: 0.5693 - val_loss: 0.5894 - val_score_accuracy: 0.8656 - val_score_loss: 0.0661 - val_regress_loss: 0.0202 - val_centerness_loss: 0.5027
# Epoch 93/100
# 31/31 [==============================] - 12s 397ms/step - loss: 0.5818 - score_accuracy: 0.9851 - score_loss: 0.0074 - regress_loss: 0.0047 - centerness_loss: 0.5691 - val_loss: 0.5730 - val_score_accuracy: 0.8753 - val_score_loss: 0.0498 - val_regress_loss: 0.0188 - val_centerness_loss: 0.5038
# Epoch 94/100
# 31/31 [==============================] - 13s 402ms/step - loss: 0.5827 - score_accuracy: 0.9809 - score_loss: 0.0079 - regress_loss: 0.0044 - centerness_loss: 0.5699 - val_loss: 0.5779 - val_score_accuracy: 0.8667 - val_score_loss: 0.0542 - val_regress_loss: 0.0187 - val_centerness_loss: 0.5044
# Epoch 95/100
# 31/31 [==============================] - 13s 397ms/step - loss: 0.5850 - score_accuracy: 0.9736 - score_loss: 0.0098 - regress_loss: 0.0054 - centerness_loss: 0.5692 - val_loss: 0.5984 - val_score_accuracy: 0.8513 - val_score_loss: 0.0712 - val_regress_loss: 0.0187 - val_centerness_loss: 0.5080
# Epoch 96/100
# 31/31 [==============================] - 12s 396ms/step - loss: 0.5815 - score_accuracy: 0.9801 - score_loss: 0.0081 - regress_loss: 0.0048 - centerness_loss: 0.5682 - val_loss: 0.5726 - val_score_accuracy: 0.8704 - val_score_loss: 0.0469 - val_regress_loss: 0.0186 - val_centerness_loss: 0.5065
# Epoch 97/100
# 31/31 [==============================] - 12s 397ms/step - loss: 0.5826 - score_accuracy: 0.9842 - score_loss: 0.0072 - regress_loss: 0.0048 - centerness_loss: 0.5701 - val_loss: 0.5948 - val_score_accuracy: 0.8580 - val_score_loss: 0.0704 - val_regress_loss: 0.0175 - val_centerness_loss: 0.5064
# Epoch 98/100
# 31/31 [==============================] - 13s 400ms/step - loss: 0.5829 - score_accuracy: 0.9849 - score_loss: 0.0069 - regress_loss: 0.0044 - centerness_loss: 0.5710 - val_loss: 0.5807 - val_score_accuracy: 0.8747 - val_score_loss: 0.0602 - val_regress_loss: 0.0151 - val_centerness_loss: 0.5049
# Epoch 99/100
# 31/31 [==============================] - 12s 396ms/step - loss: 0.5820 - score_accuracy: 0.9822 - score_loss: 0.0073 - regress_loss: 0.0044 - centerness_loss: 0.5698 - val_loss: 0.5795 - val_score_accuracy: 0.8744 - val_score_loss: 0.0600 - val_regress_loss: 0.0150 - val_centerness_loss: 0.5039
# Epoch 100/100
# 31/31 [==============================] - 12s 396ms/step - loss: 0.5853 - score_accuracy: 0.9775 - score_loss: 0.0082 - regress_loss: 0.0052 - centerness_loss: 0.5714 - val_loss: 0.5769 - val_score_accuracy: 0.8780 - val_score_loss: 0.0562 - val_regress_loss: 0.0182 - val_centerness_loss: 0.5020

# %%
model.save_weights("model.h5")

# %%
x = tf.keras.layers.Input(shape = (512, 512, 3))
feature = tfdet.model.backbone.resnet50(x)
scale = [0.03125, 0.0625, 0.125, 0.25, 0.5] #[16, 32, 64, 128, 256]
ratio = [0.5, 1, 2]
out = tfdet.model.detector.fcos(feature, n_class = 2, scale = scale, ratio = ratio, fpn = bifpn)
prediction = tfdet.model.postprocess.fcos.FilterDetection(proposal_count = 100, iou_threshold = 0.3, score_threshold = 0.9, soft_nms = False)(out)
model = tf.keras.Model(x, prediction)
model.load_weights("model.h5")

# %%
images = te_x[:1]
logits, proposal = model.predict(images)
images = tfdet.util.visualize.draw_bbox(images, proposal, logits, label = ["Background", "Balloon"])

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (10, 10))
plt.imshow(images[0])
