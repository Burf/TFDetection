# %%
import os, shutil
if os.path.exists(os.path.join(os.getcwd(),"tfdetection")):
    shutil.rmtree(os.path.join(os.getcwd(),"tfdetection"))
if os.path.exists(os.path.join(os.getcwd(),"tfdet")):
    shutil.rmtree(os.path.join(os.getcwd(),"tfdet"))
# !git clone https://github.com/burf/tfdetection
shutil.copytree(os.path.join(os.getcwd(),"tfdetection", "tfdet"), os.path.join(os.getcwd(),"tfdet"))
# Out:
# Cloning into 'tfdetection'...
# remote: Enumerating objects: 811, done.
# remote: Counting objects: 100% (424/424), done.
# remote: Compressing objects: 100% (263/263), done.
# remote: Total 811 (delta 249), reused 296 (delta 161), pack-reused 387
# Receiving objects: 100% (811/811), 13.32 MiB | 15.24 MiB/s, done.
# Resolving deltas: 100% (458/458), done.
# '/content/tfdet'

# %%
# !wget -qq https://github.com/matterport/Mask_RCNN/releases/download/v2.1/balloon_dataset.zip
# !unzip -qq balloon_dataset.zip

import os
import json
import cv2
import skimage.draw
import tensorflow as tf
import numpy as np

def parse(path, target_size = (512, 512), method = cv2.INTER_CUBIC):
    dir_path = os.path.dirname(path)
    with open(path, "r") as file:
        anno = json.loads(file.read())
    anno = [a for a in list(anno.values()) if a["regions"]]

    images = []
    masks = []
    for a in anno:
        if type(a['regions']) is dict:
            polygons = [r['shape_attributes'] for r in a['regions'].values()]
        else:
            polygons = [r['shape_attributes'] for r in a['regions']]
        image = cv2.cvtColor(cv2.imread(os.path.join(dir_path, a["filename"]), -1), cv2.COLOR_BGR2RGB)
        h, w = np.shape(image)[:2]
        mask = np.zeros((h, w, len(polygons)), dtype = np.uint8)
        for i, p in enumerate(polygons):
            rr, cc = skimage.draw.polygon(p['all_points_y'], p['all_points_x'])
            rr = np.clip(rr, 0, h - 1)
            cc = np.clip(cc, 0, w - 1)
            mask[rr, cc, i] = 1
        
        if target_size is not None:
            image = cv2.resize(image, target_size[::-1], interpolation = method)
            mask = cv2.resize(mask, target_size[::-1], interpolation = method)
            if np.ndim(mask) == 2:
                mask = np.expand_dims(mask, axis = -1)
            mask = np.where(mask != 0, 1, 0)

        images.append(image)
        masks.append(np.transpose(mask, [2, 0, 1]))
    return images, masks

def mask2bbox(mask_true, normalize = True, decimal = 4):
    #mask_true = #(padded_num_true, h, w, 1)
    padded_num_true, h, w = np.shape(mask_true)[:3]

    bbox_true = []
    for index in range(padded_num_true):
        mask = mask_true[index]
        if 0 < np.max(mask):
            pos = np.where(0 < mask)[:2]
            bbox = [np.min(pos[1]), np.min(pos[0]), np.max(pos[1]), np.max(pos[0])] #x1, y1, x2, y2
        else:
            bbox = [0, 0, 0, 0]
        bbox_true.append(bbox)
    
    bbox_true = np.round(np.divide(bbox_true, [w, h, w, h]).astype(np.float32), decimal) if normalize else np.array(bbox_true, dtype = np.int32)
    return bbox_true

def pipe(data, func = None, batch_size = 2, shuffle = False):
    dataset = tf.data.Dataset.from_tensor_slices(data)
    if callable(func):
        dataset = dataset.map(func, num_parallel_calls = tf.data.experimental.AUTOTUNE)
    if shuffle:
        dataset = dataset.shuffle(buffer_size = batch_size * 10)
    dataset = dataset.batch(batch_size)
    #dataset = dataset.prefetch((batch_size * 2) + 1)
    dataset = dataset.prefetch(tf.data.experimental.AUTOTUNE)
    return dataset

tr_anno = "./balloon/train/via_region_data.json"
te_anno = "./balloon/val/via_region_data.json"

tr_x, tr_mask = parse(tr_anno, target_size = (512, 512))
te_x, te_mask = parse(te_anno, target_size = (512, 512))

max_cnt = 0
for mask in tr_mask + te_mask:
    if max_cnt < len(mask):
        max_cnt = len(mask)

tr_x = np.array(tr_x, dtype = np.float32) * 1/255
tr_mask = [np.pad(mask, [[0, max_cnt - len(mask)], [0, 0], [0, 0]]) for mask in tr_mask]
tr_mask = np.expand_dims(np.array(tr_mask, dtype = np.float32), axis = -1)
tr_bbox = np.array([mask2bbox(mask) for mask in tr_mask], dtype = np.float32)
tr_y = np.expand_dims(np.where(0 < np.max(tr_bbox, axis = -1), 1., 0.), axis = -1)

te_x = np.array(te_x, dtype = np.float32) * 1/255
te_mask = [np.pad(mask, [[0, max_cnt - len(mask)], [0, 0], [0, 0]]) for mask in te_mask]
te_mask = np.expand_dims(np.array(te_mask, dtype = np.float32), axis = -1)
te_bbox = np.array([mask2bbox(mask) for mask in te_mask], dtype = np.float32)
te_y = np.expand_dims(np.where(0 < np.max(te_bbox, axis = -1), 1., 0.), axis = -1)

tr_semantic = np.max(tr_mask, axis = 1)
te_semantic = np.max(te_mask, axis = 1)

# %%
import tfdet
import functools

x = tf.keras.layers.Input(shape = (512, 512, 3))
feature = tfdet.model.backbone.resnet50(x)

out = tfdet.model.detector.upernet(feature, n_class = 2)
out = tf.keras.layers.UpSampling2D((4, 4))(out)
model = tf.keras.Model(x, out)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 1s 0us/step
# 94781440/94765736 [==============================] - 1s 0us/step

# %%
import albumentations
method = [albumentations.RandomBrightness(0.2, p = 0.5),
          albumentations.RandomContrast(0.2, p = 0.5),
          albumentations.ChannelShuffle(p = 0.5)]
method = albumentations.Compose(method)
    
def aug_func(image):
    return method(image = image)["image"]

def func(image, mask):
    shape = tf.shape(image)
    image = tf.reshape(tf.py_function(lambda *args: aug_func(args[0].numpy()), inp = [image], Tout = tf.float32), shape)
    return image, mask

batch_size = 8

tr_data = pipe((tr_x, tr_semantic), func = func, batch_size = batch_size, shuffle = True)
te_data = pipe((te_x, te_semantic), batch_size = batch_size, shuffle = False)

# %%
loss = tf.keras.losses.sparse_categorical_crossentropy
opt = tf.keras.optimizers.SGD(5e-3, momentum = 0.9, nesterov = True)
metric = [tf.keras.metrics.sparse_categorical_accuracy]
model.compile(loss = loss, optimizer = opt, metrics = metric)
model.fit(tr_data, validation_data = te_data, epochs = 100)
# Out:
# Epoch 1/100
# 8/8 [==============================] - 37s 2s/step - loss: 0.6929 - sparse_categorical_accuracy: 0.5310 - val_loss: 0.6931 - val_sparse_categorical_accuracy: 0.3306
# Epoch 2/100
# 8/8 [==============================] - 8s 970ms/step - loss: 0.2718 - sparse_categorical_accuracy: 0.9320 - val_loss: 0.6917 - val_sparse_categorical_accuracy: 0.8189
# Epoch 3/100
# 8/8 [==============================] - 8s 972ms/step - loss: 0.1301 - sparse_categorical_accuracy: 0.9525 - val_loss: 0.6762 - val_sparse_categorical_accuracy: 0.8477
# Epoch 4/100
# 8/8 [==============================] - 8s 970ms/step - loss: 0.1148 - sparse_categorical_accuracy: 0.9532 - val_loss: 0.6730 - val_sparse_categorical_accuracy: 0.4348
# Epoch 5/100
# 8/8 [==============================] - 8s 970ms/step - loss: 0.0775 - sparse_categorical_accuracy: 0.9708 - val_loss: 0.7246 - val_sparse_categorical_accuracy: 0.2341
# Epoch 6/100
# 8/8 [==============================] - 8s 968ms/step - loss: 0.0799 - sparse_categorical_accuracy: 0.9673 - val_loss: 0.7062 - val_sparse_categorical_accuracy: 0.3137
# Epoch 7/100
# 8/8 [==============================] - 8s 968ms/step - loss: 0.0594 - sparse_categorical_accuracy: 0.9764 - val_loss: 0.6489 - val_sparse_categorical_accuracy: 0.5671
# Epoch 8/100
# 8/8 [==============================] - 8s 966ms/step - loss: 0.0556 - sparse_categorical_accuracy: 0.9780 - val_loss: 0.5876 - val_sparse_categorical_accuracy: 0.7219
# Epoch 9/100
# 8/8 [==============================] - 8s 967ms/step - loss: 0.0520 - sparse_categorical_accuracy: 0.9796 - val_loss: 0.5211 - val_sparse_categorical_accuracy: 0.8140
# Epoch 10/100
# 8/8 [==============================] - 8s 969ms/step - loss: 0.0478 - sparse_categorical_accuracy: 0.9814 - val_loss: 0.5536 - val_sparse_categorical_accuracy: 0.7384
# Epoch 11/100
# 8/8 [==============================] - 8s 967ms/step - loss: 0.0559 - sparse_categorical_accuracy: 0.9770 - val_loss: 0.4722 - val_sparse_categorical_accuracy: 0.8036
# Epoch 12/100
# 8/8 [==============================] - 8s 966ms/step - loss: 0.0418 - sparse_categorical_accuracy: 0.9835 - val_loss: 0.5014 - val_sparse_categorical_accuracy: 0.7828
# Epoch 13/100
# 8/8 [==============================] - 8s 969ms/step - loss: 0.0399 - sparse_categorical_accuracy: 0.9840 - val_loss: 0.4323 - val_sparse_categorical_accuracy: 0.8200
# Epoch 14/100
# 8/8 [==============================] - 8s 968ms/step - loss: 0.0582 - sparse_categorical_accuracy: 0.9766 - val_loss: 0.3926 - val_sparse_categorical_accuracy: 0.8369
# Epoch 15/100
# 8/8 [==============================] - 8s 965ms/step - loss: 0.0382 - sparse_categorical_accuracy: 0.9852 - val_loss: 0.3701 - val_sparse_categorical_accuracy: 0.8636
# Epoch 16/100
# 8/8 [==============================] - 8s 971ms/step - loss: 0.0414 - sparse_categorical_accuracy: 0.9837 - val_loss: 0.3840 - val_sparse_categorical_accuracy: 0.8852
# Epoch 17/100
# 8/8 [==============================] - 8s 970ms/step - loss: 0.0431 - sparse_categorical_accuracy: 0.9826 - val_loss: 0.3952 - val_sparse_categorical_accuracy: 0.8980
# Epoch 18/100
# 8/8 [==============================] - 8s 967ms/step - loss: 0.0332 - sparse_categorical_accuracy: 0.9875 - val_loss: 0.3919 - val_sparse_categorical_accuracy: 0.9115
# Epoch 19/100
# 8/8 [==============================] - 8s 967ms/step - loss: 0.0322 - sparse_categorical_accuracy: 0.9878 - val_loss: 0.3854 - val_sparse_categorical_accuracy: 0.9150
# Epoch 20/100
# 8/8 [==============================] - 8s 967ms/step - loss: 0.0347 - sparse_categorical_accuracy: 0.9866 - val_loss: 0.3976 - val_sparse_categorical_accuracy: 0.9165
# Epoch 21/100
# 8/8 [==============================] - 8s 965ms/step - loss: 0.0365 - sparse_categorical_accuracy: 0.9857 - val_loss: 0.3958 - val_sparse_categorical_accuracy: 0.9171
# Epoch 22/100
# 8/8 [==============================] - 8s 964ms/step - loss: 0.0290 - sparse_categorical_accuracy: 0.9889 - val_loss: 0.3628 - val_sparse_categorical_accuracy: 0.9169
# Epoch 23/100
# 8/8 [==============================] - 8s 967ms/step - loss: 0.0269 - sparse_categorical_accuracy: 0.9899 - val_loss: 0.3454 - val_sparse_categorical_accuracy: 0.9177
# Epoch 24/100
# 8/8 [==============================] - 8s 967ms/step - loss: 0.0274 - sparse_categorical_accuracy: 0.9895 - val_loss: 0.3348 - val_sparse_categorical_accuracy: 0.9176
# Epoch 25/100
# 8/8 [==============================] - 8s 968ms/step - loss: 0.0272 - sparse_categorical_accuracy: 0.9897 - val_loss: 0.3543 - val_sparse_categorical_accuracy: 0.9214
# Epoch 26/100
# 8/8 [==============================] - 8s 965ms/step - loss: 0.0499 - sparse_categorical_accuracy: 0.9793 - val_loss: 0.3225 - val_sparse_categorical_accuracy: 0.9215
# Epoch 27/100
# 8/8 [==============================] - 8s 966ms/step - loss: 0.0337 - sparse_categorical_accuracy: 0.9871 - val_loss: 0.3611 - val_sparse_categorical_accuracy: 0.8640
# Epoch 28/100
# 8/8 [==============================] - 8s 966ms/step - loss: 0.0579 - sparse_categorical_accuracy: 0.9797 - val_loss: 0.3509 - val_sparse_categorical_accuracy: 0.9203
# Epoch 29/100
# 8/8 [==============================] - 8s 970ms/step - loss: 0.0382 - sparse_categorical_accuracy: 0.9853 - val_loss: 0.4689 - val_sparse_categorical_accuracy: 0.9236
# Epoch 30/100
# 8/8 [==============================] - 8s 968ms/step - loss: 0.0429 - sparse_categorical_accuracy: 0.9838 - val_loss: 0.4824 - val_sparse_categorical_accuracy: 0.9234
# Epoch 31/100
# 8/8 [==============================] - 8s 966ms/step - loss: 0.0287 - sparse_categorical_accuracy: 0.9891 - val_loss: 0.4585 - val_sparse_categorical_accuracy: 0.9228
# Epoch 32/100
# 8/8 [==============================] - 8s 968ms/step - loss: 0.0309 - sparse_categorical_accuracy: 0.9879 - val_loss: 0.4318 - val_sparse_categorical_accuracy: 0.9230
# Epoch 33/100
# 8/8 [==============================] - 8s 965ms/step - loss: 0.0282 - sparse_categorical_accuracy: 0.9897 - val_loss: 0.4181 - val_sparse_categorical_accuracy: 0.9235
# Epoch 34/100
# 8/8 [==============================] - 8s 968ms/step - loss: 0.0283 - sparse_categorical_accuracy: 0.9892 - val_loss: 0.4023 - val_sparse_categorical_accuracy: 0.9236
# Epoch 35/100
# 8/8 [==============================] - 8s 968ms/step - loss: 0.0295 - sparse_categorical_accuracy: 0.9885 - val_loss: 0.3763 - val_sparse_categorical_accuracy: 0.9234
# Epoch 36/100
# 8/8 [==============================] - 8s 965ms/step - loss: 0.0258 - sparse_categorical_accuracy: 0.9902 - val_loss: 0.3366 - val_sparse_categorical_accuracy: 0.9231
# Epoch 37/100
# 8/8 [==============================] - 8s 965ms/step - loss: 0.0241 - sparse_categorical_accuracy: 0.9909 - val_loss: 0.3082 - val_sparse_categorical_accuracy: 0.9099
# Epoch 38/100
# 8/8 [==============================] - 8s 966ms/step - loss: 0.0296 - sparse_categorical_accuracy: 0.9885 - val_loss: 0.3150 - val_sparse_categorical_accuracy: 0.9053
# Epoch 39/100
# 8/8 [==============================] - 8s 969ms/step - loss: 0.0213 - sparse_categorical_accuracy: 0.9920 - val_loss: 0.3171 - val_sparse_categorical_accuracy: 0.9063
# Epoch 40/100
# 8/8 [==============================] - 8s 968ms/step - loss: 0.0254 - sparse_categorical_accuracy: 0.9906 - val_loss: 0.2905 - val_sparse_categorical_accuracy: 0.9280
# Epoch 41/100
# 8/8 [==============================] - 8s 967ms/step - loss: 0.0200 - sparse_categorical_accuracy: 0.9923 - val_loss: 0.3170 - val_sparse_categorical_accuracy: 0.9285
# Epoch 42/100
# 8/8 [==============================] - 8s 967ms/step - loss: 0.0232 - sparse_categorical_accuracy: 0.9912 - val_loss: 0.3197 - val_sparse_categorical_accuracy: 0.9285
# Epoch 43/100
# 8/8 [==============================] - 8s 965ms/step - loss: 0.0220 - sparse_categorical_accuracy: 0.9916 - val_loss: 0.3180 - val_sparse_categorical_accuracy: 0.9289
# Epoch 44/100
# 8/8 [==============================] - 8s 965ms/step - loss: 0.0210 - sparse_categorical_accuracy: 0.9920 - val_loss: 0.2921 - val_sparse_categorical_accuracy: 0.9323
# Epoch 45/100
# 8/8 [==============================] - 8s 967ms/step - loss: 0.0212 - sparse_categorical_accuracy: 0.9919 - val_loss: 0.2744 - val_sparse_categorical_accuracy: 0.9349
# Epoch 46/100
# 8/8 [==============================] - 8s 967ms/step - loss: 0.0200 - sparse_categorical_accuracy: 0.9924 - val_loss: 0.2575 - val_sparse_categorical_accuracy: 0.9374
# Epoch 47/100
# 8/8 [==============================] - 8s 964ms/step - loss: 0.0196 - sparse_categorical_accuracy: 0.9926 - val_loss: 0.2419 - val_sparse_categorical_accuracy: 0.9396
# Epoch 48/100
# 8/8 [==============================] - 8s 966ms/step - loss: 0.0202 - sparse_categorical_accuracy: 0.9924 - val_loss: 0.2292 - val_sparse_categorical_accuracy: 0.9418
# Epoch 49/100
# 8/8 [==============================] - 8s 966ms/step - loss: 0.0293 - sparse_categorical_accuracy: 0.9889 - val_loss: 0.2236 - val_sparse_categorical_accuracy: 0.9431
# Epoch 50/100
# 8/8 [==============================] - 8s 967ms/step - loss: 0.0228 - sparse_categorical_accuracy: 0.9914 - val_loss: 0.2011 - val_sparse_categorical_accuracy: 0.9462
# Epoch 51/100
# 8/8 [==============================] - 8s 965ms/step - loss: 0.0212 - sparse_categorical_accuracy: 0.9920 - val_loss: 0.1857 - val_sparse_categorical_accuracy: 0.9476
# Epoch 52/100
# 8/8 [==============================] - 8s 967ms/step - loss: 0.0189 - sparse_categorical_accuracy: 0.9928 - val_loss: 0.1798 - val_sparse_categorical_accuracy: 0.9489
# Epoch 53/100
# 8/8 [==============================] - 8s 965ms/step - loss: 0.0195 - sparse_categorical_accuracy: 0.9929 - val_loss: 0.1639 - val_sparse_categorical_accuracy: 0.9512
# Epoch 54/100
# 8/8 [==============================] - 8s 967ms/step - loss: 0.0182 - sparse_categorical_accuracy: 0.9932 - val_loss: 0.1526 - val_sparse_categorical_accuracy: 0.9533
# Epoch 55/100
# 8/8 [==============================] - 8s 967ms/step - loss: 0.0177 - sparse_categorical_accuracy: 0.9933 - val_loss: 0.1511 - val_sparse_categorical_accuracy: 0.9540
# Epoch 56/100
# 8/8 [==============================] - 8s 969ms/step - loss: 0.0177 - sparse_categorical_accuracy: 0.9933 - val_loss: 0.1454 - val_sparse_categorical_accuracy: 0.9551
# Epoch 57/100
# 8/8 [==============================] - 8s 968ms/step - loss: 0.0185 - sparse_categorical_accuracy: 0.9929 - val_loss: 0.1360 - val_sparse_categorical_accuracy: 0.9569
# Epoch 58/100
# 8/8 [==============================] - 8s 965ms/step - loss: 0.0182 - sparse_categorical_accuracy: 0.9931 - val_loss: 0.1291 - val_sparse_categorical_accuracy: 0.9589
# Epoch 59/100
# 8/8 [==============================] - 8s 968ms/step - loss: 0.0174 - sparse_categorical_accuracy: 0.9934 - val_loss: 0.1211 - val_sparse_categorical_accuracy: 0.9611
# Epoch 60/100
# 8/8 [==============================] - 8s 968ms/step - loss: 0.0188 - sparse_categorical_accuracy: 0.9928 - val_loss: 0.1183 - val_sparse_categorical_accuracy: 0.9626
# Epoch 61/100
# 8/8 [==============================] - 8s 965ms/step - loss: 0.0178 - sparse_categorical_accuracy: 0.9933 - val_loss: 0.1164 - val_sparse_categorical_accuracy: 0.9637
# Epoch 62/100
# 8/8 [==============================] - 8s 967ms/step - loss: 0.0162 - sparse_categorical_accuracy: 0.9938 - val_loss: 0.1109 - val_sparse_categorical_accuracy: 0.9655
# Epoch 63/100
# 8/8 [==============================] - 8s 965ms/step - loss: 0.0185 - sparse_categorical_accuracy: 0.9930 - val_loss: 0.1024 - val_sparse_categorical_accuracy: 0.9675
# Epoch 64/100
# 8/8 [==============================] - 8s 967ms/step - loss: 0.0173 - sparse_categorical_accuracy: 0.9935 - val_loss: 0.1015 - val_sparse_categorical_accuracy: 0.9680
# Epoch 65/100
# 8/8 [==============================] - 8s 963ms/step - loss: 0.0173 - sparse_categorical_accuracy: 0.9935 - val_loss: 0.0957 - val_sparse_categorical_accuracy: 0.9688
# Epoch 66/100
# 8/8 [==============================] - 8s 965ms/step - loss: 0.0155 - sparse_categorical_accuracy: 0.9941 - val_loss: 0.0926 - val_sparse_categorical_accuracy: 0.9692
# Epoch 67/100
# 8/8 [==============================] - 8s 968ms/step - loss: 0.0172 - sparse_categorical_accuracy: 0.9933 - val_loss: 0.0903 - val_sparse_categorical_accuracy: 0.9695
# Epoch 68/100
# 8/8 [==============================] - 8s 965ms/step - loss: 0.0172 - sparse_categorical_accuracy: 0.9935 - val_loss: 0.0925 - val_sparse_categorical_accuracy: 0.9695
# Epoch 69/100
# 8/8 [==============================] - 8s 963ms/step - loss: 0.0164 - sparse_categorical_accuracy: 0.9937 - val_loss: 0.0949 - val_sparse_categorical_accuracy: 0.9695
# Epoch 70/100
# 8/8 [==============================] - 8s 968ms/step - loss: 0.0168 - sparse_categorical_accuracy: 0.9936 - val_loss: 0.0904 - val_sparse_categorical_accuracy: 0.9703
# Epoch 71/100
# 8/8 [==============================] - 8s 965ms/step - loss: 0.0170 - sparse_categorical_accuracy: 0.9935 - val_loss: 0.0910 - val_sparse_categorical_accuracy: 0.9708
# Epoch 72/100
# 8/8 [==============================] - 8s 967ms/step - loss: 0.0192 - sparse_categorical_accuracy: 0.9927 - val_loss: 0.0961 - val_sparse_categorical_accuracy: 0.9701
# Epoch 73/100
# 8/8 [==============================] - 8s 967ms/step - loss: 0.0169 - sparse_categorical_accuracy: 0.9935 - val_loss: 0.0958 - val_sparse_categorical_accuracy: 0.9702
# Epoch 74/100
# 8/8 [==============================] - 8s 966ms/step - loss: 0.0167 - sparse_categorical_accuracy: 0.9936 - val_loss: 0.0913 - val_sparse_categorical_accuracy: 0.9712
# Epoch 75/100
# 8/8 [==============================] - 8s 969ms/step - loss: 0.0175 - sparse_categorical_accuracy: 0.9935 - val_loss: 0.0792 - val_sparse_categorical_accuracy: 0.9732
# Epoch 76/100
# 8/8 [==============================] - 8s 968ms/step - loss: 0.0169 - sparse_categorical_accuracy: 0.9936 - val_loss: 0.0791 - val_sparse_categorical_accuracy: 0.9732
# Epoch 77/100
# 8/8 [==============================] - 8s 969ms/step - loss: 0.0156 - sparse_categorical_accuracy: 0.9940 - val_loss: 0.0782 - val_sparse_categorical_accuracy: 0.9735
# Epoch 78/100
# 8/8 [==============================] - 8s 966ms/step - loss: 0.0242 - sparse_categorical_accuracy: 0.9910 - val_loss: 0.0778 - val_sparse_categorical_accuracy: 0.9734
# Epoch 79/100
# 8/8 [==============================] - 8s 968ms/step - loss: 0.0174 - sparse_categorical_accuracy: 0.9934 - val_loss: 0.0839 - val_sparse_categorical_accuracy: 0.9725
# Epoch 80/100
# 8/8 [==============================] - 8s 968ms/step - loss: 0.0167 - sparse_categorical_accuracy: 0.9937 - val_loss: 0.0864 - val_sparse_categorical_accuracy: 0.9719
# Epoch 81/100
# 8/8 [==============================] - 8s 967ms/step - loss: 0.0167 - sparse_categorical_accuracy: 0.9936 - val_loss: 0.0847 - val_sparse_categorical_accuracy: 0.9725
# Epoch 82/100
# 8/8 [==============================] - 8s 968ms/step - loss: 0.0168 - sparse_categorical_accuracy: 0.9936 - val_loss: 0.0779 - val_sparse_categorical_accuracy: 0.9740
# Epoch 83/100
# 8/8 [==============================] - 8s 965ms/step - loss: 0.0155 - sparse_categorical_accuracy: 0.9941 - val_loss: 0.0763 - val_sparse_categorical_accuracy: 0.9746
# Epoch 84/100
# 8/8 [==============================] - 8s 970ms/step - loss: 0.0153 - sparse_categorical_accuracy: 0.9942 - val_loss: 0.0741 - val_sparse_categorical_accuracy: 0.9751
# Epoch 85/100
# 8/8 [==============================] - 8s 965ms/step - loss: 0.0149 - sparse_categorical_accuracy: 0.9943 - val_loss: 0.0720 - val_sparse_categorical_accuracy: 0.9758
# Epoch 86/100
# 8/8 [==============================] - 8s 965ms/step - loss: 0.0175 - sparse_categorical_accuracy: 0.9932 - val_loss: 0.0684 - val_sparse_categorical_accuracy: 0.9763
# Epoch 87/100
# 8/8 [==============================] - 8s 964ms/step - loss: 0.0157 - sparse_categorical_accuracy: 0.9940 - val_loss: 0.0704 - val_sparse_categorical_accuracy: 0.9759
# Epoch 88/100
# 8/8 [==============================] - 8s 964ms/step - loss: 0.0162 - sparse_categorical_accuracy: 0.9939 - val_loss: 0.0748 - val_sparse_categorical_accuracy: 0.9756
# Epoch 89/100
# 8/8 [==============================] - 8s 965ms/step - loss: 0.0148 - sparse_categorical_accuracy: 0.9944 - val_loss: 0.0705 - val_sparse_categorical_accuracy: 0.9766
# Epoch 90/100
# 8/8 [==============================] - 8s 965ms/step - loss: 0.0144 - sparse_categorical_accuracy: 0.9945 - val_loss: 0.0701 - val_sparse_categorical_accuracy: 0.9769
# Epoch 91/100
# 8/8 [==============================] - 8s 967ms/step - loss: 0.0156 - sparse_categorical_accuracy: 0.9941 - val_loss: 0.0681 - val_sparse_categorical_accuracy: 0.9772
# Epoch 92/100
# 8/8 [==============================] - 8s 965ms/step - loss: 0.0142 - sparse_categorical_accuracy: 0.9945 - val_loss: 0.0655 - val_sparse_categorical_accuracy: 0.9775
# Epoch 93/100
# 8/8 [==============================] - 8s 966ms/step - loss: 0.0143 - sparse_categorical_accuracy: 0.9945 - val_loss: 0.0658 - val_sparse_categorical_accuracy: 0.9774
# Epoch 94/100
# 8/8 [==============================] - 8s 965ms/step - loss: 0.0142 - sparse_categorical_accuracy: 0.9945 - val_loss: 0.0637 - val_sparse_categorical_accuracy: 0.9777
# Epoch 95/100
# 8/8 [==============================] - 8s 969ms/step - loss: 0.0143 - sparse_categorical_accuracy: 0.9945 - val_loss: 0.0621 - val_sparse_categorical_accuracy: 0.9781
# Epoch 96/100
# 8/8 [==============================] - 8s 967ms/step - loss: 0.0142 - sparse_categorical_accuracy: 0.9946 - val_loss: 0.0596 - val_sparse_categorical_accuracy: 0.9785
# Epoch 97/100
# 8/8 [==============================] - 8s 966ms/step - loss: 0.0167 - sparse_categorical_accuracy: 0.9937 - val_loss: 0.0631 - val_sparse_categorical_accuracy: 0.9783
# Epoch 98/100
# 8/8 [==============================] - 8s 969ms/step - loss: 0.0149 - sparse_categorical_accuracy: 0.9943 - val_loss: 0.0616 - val_sparse_categorical_accuracy: 0.9787
# Epoch 99/100
# 8/8 [==============================] - 8s 965ms/step - loss: 0.0143 - sparse_categorical_accuracy: 0.9944 - val_loss: 0.0607 - val_sparse_categorical_accuracy: 0.9789
# Epoch 100/100
# 8/8 [==============================] - 8s 965ms/step - loss: 0.0139 - sparse_categorical_accuracy: 0.9946 - val_loss: 0.0614 - val_sparse_categorical_accuracy: 0.9788

# %%
import matplotlib.pyplot as plt
pred = model.predict(te_x[:1])
pred = np.argmax(pred, axis = -1)
plt.figure(figsize = (5, 5))
plt.imshow(te_x[0])
plt.figure(figsize = (5, 5))
plt.imshow(te_semantic[0][..., 0])
plt.figure(figsize = (5, 5))
plt.imshow(pred[0])
